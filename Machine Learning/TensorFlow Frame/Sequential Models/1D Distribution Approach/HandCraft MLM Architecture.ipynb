# %% [markdown]
# # Notebook Dedicated to Build a Handcraft DNN Model Architectura that learns from cos($\alpha$) and $t_{res}$ 1D Distributions.
#
# The idea is to pass each bin count on cos(α) and Time residual, energy and position as features to train the model.

# %%
#import uproot
import numpy as np

import pickle
 
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import font_manager

import seaborn as sn
import pandas as pd

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, concatenate, Dropout
from keras.losses import BinaryCrossentropy
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve, auc
from sklearn.utils import shuffle
import optuna
from keras.backend import clear_session

# %% [markdown]
# # Useful Functions

# %% [markdown]
# ## Multi-color Generator

# %%
import colorsys
# Función para generar variantes más claras y más oscuras de un color
def generate_color_variants(base_color, num_variants, factor = 0.3):
    # Convertir el color base a valores de HSV
    r, g, b = base_color
    h, l, s = colorsys.rgb_to_hls(r, g, b)
    
    # Generar variantes
    variants = []
    for i in range(1, num_variants + 1):
        # Hacer el color más claro
        lighter = colorsys.hls_to_rgb(h, min(1, l * (1 + factor * i)), s)
        # Hacer el color más oscuro
        darker = colorsys.hls_to_rgb(h, max(0, l * (1 - factor * i)), s)
        variants.append(lighter)
        variants.append(darker)
        
    return variants

# Color base (rojo)
base_red = (1, 0, 0) # RGB para rojo puro
# Color base (azuk)
base_blue = (0, 0, 1) # RGB para azul puro
num_variants = 5

red_variants = generate_color_variants(base_red, num_variants)
blue_variants = generate_color_variants(base_blue, num_variants)

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Define the Data Cuts of the original pd.DataFrame

# %%
energy_inf_cut = 2.5
energy_sup_cut = 12

posr_cut = 5500

time_res_inf_cut = -1
time_res_sup_cut = 5

nhits_cut = 20

n_bins_cos = 12
n_bins_time = 12

# %%
#Directories
train_dataset_dir = "E:/Data/solars/mc/ML Data/pd_dataframe/1D Histograms/Train/"
train_dataset_fname = f'df_cos_{n_bins_cos}_time_{n_bins_time}_bins_E_{energy_inf_cut}_{energy_sup_cut}_MeV_R_{posr_cut}_mm_Delta_{time_res_inf_cut}_{time_res_sup_cut}_ns.csv'

test_dataset_dir = "E:/Data/solars/mc/ML Data/pd_dataframe/1D Histograms/Test/"
test_dataset_fname = f'df_cos_{n_bins_cos}_time_{n_bins_time}_bins_E_{energy_inf_cut}_{energy_sup_cut}_MeV_R_{posr_cut}_mm_Delta_{time_res_inf_cut}_{time_res_sup_cut}_ns.csv'

#Load in Pandas  DataFrame
df_train = shuffle(pd.read_csv(train_dataset_dir + train_dataset_fname))
df_test = shuffle(pd.read_csv(test_dataset_dir + test_dataset_fname))

# %%
df_train.describe()
# Out:
#               cos_0         cos_1         cos_2         cos_3         cos_4  \
# count  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06
# mean   1.072412e+01  1.069690e+01  1.052237e+01  1.035581e+01  1.037639e+01
# std    1.787176e+01  1.297819e+01  1.055255e+01  9.182380e+00  8.441184e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  2.000000e+00  3.000000e+00  4.000000e+00  4.000000e+00
# 50%    4.000000e+00  5.000000e+00  7.000000e+00  8.000000e+00  8.000000e+00
# 75%    1.200000e+01  1.500000e+01  1.500000e+01  1.500000e+01  1.400000e+01
# max    2.240000e+02  1.110000e+02  9.100000e+01  8.200000e+01  7.900000e+01
#
#               cos_5         cos_6         cos_7         cos_8         cos_9  \
# count  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06
# mean   1.028084e+01  1.035724e+01  1.042671e+01  1.052552e+01  1.062043e+01
# std    8.057143e+00  8.054549e+00  8.357241e+00  9.163633e+00  1.071582e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.000000e+00  5.000000e+00  4.000000e+00  4.000000e+00  3.000000e+00
# 50%    8.000000e+00  8.000000e+00  8.000000e+00  8.000000e+00  7.000000e+00
# 75%    1.400000e+01  1.400000e+01  1.400000e+01  1.500000e+01  1.500000e+01
# max    7.400000e+01  7.500000e+01  7.800000e+01  8.100000e+01  9.300000e+01
#
#        ...  chi_sqrt_bkg       jsd_sig       jsd_bkg       emd_sig  \
# count  ...  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06
# mean   ...  8.041031e-01  1.006036e-01  1.001235e-01  3.550559e-01
# std    ...  7.150114e-01  6.176662e-02  6.423550e-02  1.834905e-01
# min    ...  1.837582e-02  1.899016e-03  2.243835e-03  1.111793e-02
# 25%    ...  3.414201e-01  5.377856e-02  5.076882e-02  1.985818e-01
# 50%    ...  5.511694e-01  8.468341e-02  8.248405e-02  3.254062e-01
# 75%    ...  1.001110e+00  1.355080e-01  1.369698e-01  4.996635e-01
# max    ...  8.296711e+00  4.355173e-01  4.399689e-01  8.672494e-01
#
#             emd_bkg  energy (MeV)   radius (mm)         nhits          IsNu  \
# count  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06
# mean   3.528048e-01  4.661723e+00  4.096745e+03  1.257121e+02  6.572734e-01
# std    1.860564e-01  1.753361e+00  1.072686e+03  5.465191e+01  4.746211e-01
# min    1.282913e-02  2.500002e+00  3.176235e+01  2.000000e+01  0.000000e+00
# 25%    1.926671e-01  3.457328e+00  3.424745e+03  8.600000e+01  0.000000e+00
# 50%    3.246557e-01  4.015488e+00  4.333659e+03  1.160000e+02  1.000000e+00
# 75%    4.996529e-01  5.501708e+00  4.976263e+03  1.530000e+02  1.000000e+00
# max    8.661090e-01  1.199876e+01  5.500000e+03  4.300000e+02  1.000000e+00
#
#                IsTl
# count  1.502813e+06
# mean   3.427266e-01
# std    4.746211e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.000000e+00
# max    1.000000e+00
#
# [8 rows x 47 columns]

# %% [markdown]
# # Data Procesing

# %% [markdown]
# ## Define and Apply Energy and Position Cuts

# %%
energy_cut = 5
radial_cut = 4500

condition_train = (df_train['energy (MeV)'] <= energy_cut) & (df_train['radius (mm)'] <= radial_cut)
condition_test = (df_test['energy (MeV)'] <= energy_cut) & (df_test['radius (mm)'] <= radial_cut)

df_train = df_train[condition_train]
df_test = df_test[condition_test]

# %% [markdown]
# ### Extract Train Data

# %%
# ======== Separate signal from background ========
df_train_sig = df_train[df_train['IsNu'] == 1]
df_train_bkg = df_train[df_train['IsTl'] == 1]

#======== Igualar cantidad de datos de neutrinos solares y de Tálio ========
N_solar_ev = df_train_sig.shape[0]
N_Tl_ev = df_train_bkg.shape[0]

if N_solar_ev > N_Tl_ev:
    df_train_sig = (df_train_sig.iloc[:N_Tl_ev, :])

else:
    df_train_bkg = (df_train_bkg.iloc[:N_solar_ev, :])


# ======== Re-join the Signal and Background Data and Separate labels ========

df_train_join = shuffle(pd.concat([df_train_sig, df_train_bkg], axis=0, ignore_index = True))
# ------ Extract Lables ------
labels_train = df_train_join[['IsNu', 'IsTl']]
# ------ Remove lables from dataset ------
df_train_join = df_train_join.drop(columns = ['IsNu', 'IsTl'])
df_train_join
# Out:
#         cos_0  cos_1  cos_2  cos_3  cos_4  cos_5  cos_6  cos_7  cos_8  cos_9  \
# 483835      1      1      4      4      6      6      6      4      4      6
# 372381      9     13     15      3      3      7      5      4      2      0
# 124732     19     11     11      8      4      5      6      4      3      1
# 250718     14     12     14     17     25     17     12     11      5      5
# 473893      9     11      7     10      7      3      4      8      3      1
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 552769      1      4      5      5      3      3      4      4     10      5
# 90149       9     14     13     11      9     13      6      4      8      0
# 492105     27     18      8     12      3      2      2      2      0      1
# 405652     24     20     19     15      3      2      6      1      0      1
# 375374      0      0      3      5      5      2      8     20     11     25
#
#         ...  time_entropy  chi_sqrt_sig  chi_sqrt_bkg   jsd_sig   jsd_bkg  \
# 483835  ...      2.162616      0.208491      0.193022  0.033444  0.031666
# 372381  ...      1.944453      0.650613      0.612308  0.085155  0.079533
# 124732  ...      2.093265      0.758606      0.767776  0.114551  0.109327
# 250718  ...      2.148600      0.344278      0.284949  0.049261  0.041774
# 473893  ...      2.093571      0.339306      0.316800  0.051325  0.047433
# ...     ...           ...           ...           ...       ...       ...
# 552769  ...      1.863424      0.228561      0.259911  0.028758  0.030880
# 90149   ...      2.173163      0.430789      0.386787  0.089629  0.082198
# 492105  ...      2.185363      1.678974      1.724166  0.199757  0.196543
# 405652  ...      2.172851      1.262182      1.256972  0.180233  0.175726
# 375374  ...      2.161383      0.822389      0.936287  0.128717  0.137625
#
#          emd_sig   emd_bkg  energy (MeV)  radius (mm)  nhits
# 483835  0.112451  0.119741      3.570986  2663.864746     48
# 372381  0.350258  0.332601      3.588921  2705.217529     66
# 124732  0.467051  0.449394      4.136052  2814.742432     72
# 250718  0.234742  0.217085      4.730788  4420.260254    137
# 473893  0.276283  0.258626      3.544065  3187.481689     68
# ...          ...       ...           ...          ...    ...
# 552769  0.155965  0.173622      3.542243  2018.285156     56
# 90149   0.315444  0.297787      3.798973  3794.243896     89
# 492105  0.636218  0.618561      3.295119  3835.873047     75
# 405652  0.579672  0.562015      4.206294  3257.183105     92
# 375374  0.478025  0.495682      4.247122  4469.703613    132
#
# [574986 rows x 45 columns]

# %% [markdown]
# ### Extract Test Data

# %%
# ======== Separate signal from background ========
df_test_sig = df_test[df_test['IsNu'] == 1]
df_test_bkg = df_test[df_test['IsTl'] == 1]

#======== Igualar cantidad de datos de neutrinos solares y de Tálio ========
N_solar_ev = df_test_sig.shape[0]
N_Tl_ev = df_test_bkg.shape[0]

if N_solar_ev > N_Tl_ev:
    df_test_sig = (df_test_sig.iloc[:N_Tl_ev, :])

else:
    df_test_bkg = (df_test_bkg.iloc[:N_solar_ev, :])


# ======== Re-join the Background and Background Data and Separate labels ========

df_test_join = shuffle(pd.concat([df_test_sig, df_test_bkg], axis=0, ignore_index = True))
# ------ Extract Lables ------
labels_test = df_test_join[['IsNu', 'IsTl']]
# ------ Remove lables from dataset ------
df_test_join = df_test_join.drop(columns = ['IsNu', 'IsTl'])
df_test_join
# Out:
#        cos_0  cos_1  cos_2  cos_3  cos_4  cos_5  cos_6  cos_7  cos_8  cos_9  \
# 21930      8     10     10      7      4     10      7      2      2      2
# 14230      3      6      9      7      7      4      5      9      2      7
# 17362     20     11      5      7      7      4      3      2      3      2
# 1298       2      4      4      8     14     15      7     13      9      7
# 23071      1      1      3      2      1      3      5      6     11     13
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6890       0      2      2      1      2      3      0      3      5     10
# 30054     32     19     13      6      7      6      0      2      1      0
# 5615       0      0      0      1      3      3      5      5     13      8
# 30076      1      6     10     14     13     11      7      5      5      6
# 20944     11     17     13      9     17      6      6      6      2      1
#
#        ...  time_entropy  chi_sqrt_sig  chi_sqrt_bkg   jsd_sig   jsd_bkg  \
# 21930  ...      2.181915      0.517057      0.445320  0.087173  0.076258
# 14230  ...      2.097337      0.200437      0.188081  0.027863  0.025716
# 17362  ...      2.013957      0.844891      0.787244  0.081910  0.075350
# 1298   ...      2.122228      0.228745      0.211766  0.031157  0.030881
# 23071  ...      2.128643      0.703888      0.820224  0.089978  0.102370
# ...    ...           ...           ...           ...       ...       ...
# 6890   ...      2.191478      0.894533      1.020039  0.119833  0.132142
# 30054  ...      2.055849      1.718269      1.631323  0.214351  0.203773
# 5615   ...      2.071992      1.305904      1.439226  0.167591  0.180187
# 30076  ...      2.048948      0.433552      0.372883  0.063300  0.056970
# 20944  ...      2.046482      0.611926      0.527026  0.090192  0.078400
#
#         emd_sig   emd_bkg  energy (MeV)  radius (mm)  nhits
# 21930  0.351409  0.322099      4.558779  1978.119751     63
# 14230  0.112097  0.085423      2.657202  3643.191406     65
# 17362  0.443054  0.413744      4.078661  2363.851807     67
# 1298   0.109754  0.130460      3.647602  4277.494629    101
# 23071  0.442983  0.472292      3.859444  2960.023438     75
# ...         ...       ...           ...          ...    ...
# 6890   0.446872  0.476181      3.253487  2472.674561     48
# 30054  0.650997  0.621687      3.447864  3789.994873     86
# 5615   0.573880  0.603189      4.618978  2941.553223     83
# 30076  0.216360  0.192510      2.965268  4197.802734     81
# 20944  0.387388  0.358078      3.562122  3618.239014     90
#
# [32750 rows x 45 columns]

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Standards Scaler()

# %%
# Train Transform History
scaler_cos_train = StandardScaler()
scaler_time_train = StandardScaler()
scaler_energy_train = StandardScaler()
scaler_position_train = StandardScaler()

# Test Transform History
scaler_cos_test = StandardScaler()
scaler_time_test = StandardScaler()
scaler_energy_test = StandardScaler()
scaler_position_test = StandardScaler()

# %% [markdown]
# ### MinMaxScaler()

# %%
#Intervals for MinMax Scaler ------------------------------------
epsilon = 1e-2
min_val = 0 + epsilon
max_val = 1 + epsilon # equals to one + epsilon
# ---------------------------------------------------------------

scaler_energy_train = MinMaxScaler(feature_range=(min_val, max_val))
scaler_position_train = MinMaxScaler(feature_range=(min_val, max_val))

scaler_energy_test = MinMaxScaler(feature_range=(min_val, max_val))
scaler_position_test = MinMaxScaler(feature_range=(min_val, max_val))

# %% [markdown]
# ### Pipeline MinMaxScaler(StandardScaler()) Avoid Reruning Again!

# %%
#Intervals for MinMax Scaler ------------------------------------
epsilon = 1e-2
min_val = 0 + epsilon
max_val = 1 + epsilon # equals to one + epsilon

# ======== Train Transformation ========

# Transform from radial position to norm. vol:
df_train_join['norm_vol'] =  (df_train_join['radius (mm)']/posr_cut) ** 3
df_train_join = df_train_join.drop(columns = ['radius (mm)'])

scaling_pipeline_train = Pipeline([('std', StandardScaler()),
    ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])

df_train_scaled = pd.DataFrame(scaling_pipeline_train.fit_transform(df_train_join),columns = df_train_join.columns)

# ======== Test Transformation ========

# Transform from radial position to norm. vol:
df_test_join['norm_vol'] =  (df_test_join['radius (mm)']/posr_cut) ** 3
df_test_join = df_test_join.drop(columns = ['radius (mm)'])

scaling_pipeline_test = Pipeline([('std', StandardScaler()),
    ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])

df_test_scaled = pd.DataFrame(scaling_pipeline_test.fit_transform(df_test_join),columns = df_test_join.columns)

# %%
# Out:
# array([[0.22111111, 0.22153846, 0.23      , ..., 0.66442161, 0.33911392,
#         0.25472528],
#        [0.16555556, 0.24076923, 0.29      , ..., 0.9023169 , 0.75050633,
#         0.95778025],
#        [0.08777778, 0.10615385, 0.07      , ..., 0.33070354, 0.18088608,
#         0.14218863],
#        ...,
#        [0.07666667, 0.20230769, 0.05      , ..., 0.6963757 , 0.45303797,
#         0.61665323],
#        [0.06555556, 0.10615385, 0.15      , ..., 0.73068957, 0.45303797,
#         0.55461567],
#        [0.11      , 0.27923077, 0.27      , ..., 0.52958991, 0.44670886,
#         0.60943156]])

# %% [markdown]
# # Plots of Transf. Data Verification

# %%
features_list = df_train_scaled.columns

feature_dict_sig = {feat_i : np.array(df_train_scaled[feat_i])[np.array(labels_train['IsNu'] == 1)] for feat_i in features_list}
feature_dict_bkg = {feat_i : np.array(df_train_scaled[feat_i])[np.array(labels_train['IsTl'] == 1)] for feat_i in features_list}

bins = 35
N_features = len(features_list)

for feature_i in features_list:
    
    sn.histplot(feature_dict_sig[feature_i], bins = bins, element = 'step', alpha = 0, color = 'r')
    sn.histplot(feature_dict_bkg[feature_i], bins = bins, element = 'step', alpha = 0, color = 'b')

    plt.xlabel(feature_i)
    plt.show()

# %% [markdown]
# # Data Split

# %%
df_test1_scaled, df_val_scaled, \
labels_test1, labels_val = train_test_split(df_test_scaled, labels_test, 
                                            test_size = 0.5,
                                            stratify = labels_test,
                                            random_state=42)

# %% [markdown]
# # Deep Learning Model Building

# %% [markdown]
# - Convert Pandas DataFrame to Numpy (Keras works better with numpy)

# %%
# -------- Data --------
X_train = df_train_scaled.to_numpy()
X_test = df_test1_scaled.to_numpy()
X_val = df_val_scaled.to_numpy()

# -------- Labels --------
labels_train = labels_train.to_numpy()
labels_test = labels_test1.to_numpy()
labels_val = labels_val.to_numpy()

# -------- Separate Sig from Bkg for test Dataset --------
mask_sig = np.array([1,0])
mask_bkg = np.array([0,1])

X_test_sig = X_test[(labels_test == mask_sig)[:,0]]
X_test_bkg = X_test[(labels_test == mask_bkg)[:,0]]

labels_test_sig = labels_test[(labels_test == mask_sig)[:,0]]
labels_test_bkg = labels_test[(labels_test == mask_bkg)[:,0]]

# %%
X_train.shape[1]
# Out:
# 45

# %% [markdown]
# ## Energy-Position One Layer Model without BatchNorm

# %%
n_features = X_train.shape[1]

#Model Layers and Neuron Architecture ------------------------------------------------

input_ly = Input(shape = (n_features,), name = 'input_ly')

x = Dense(40, activation = 'gelu')(input_ly)
x = Dense(38, activation = 'gelu')(x)
x = Dense(35, activation = 'gelu')(x)
x = Dense(33, activation = 'gelu')(x)
x = Dense(30, activation = 'gelu')(x)
x = Dense(28, activation = 'gelu')(x)
x = Dense(25, activation = 'gelu')(x)

x = Dropout(rate = 0.2)(x)

x = Dense(20, activation = 'gelu')(x)
x = Dense(15, activation = 'gelu')(x)
x = Dense(10, activation = 'gelu')(x)
x = Dense(7, activation = 'gelu')(x)
x = Dense(5, activation = 'gelu')(x)

output_layer = Dense(2, activation = 'sigmoid', name = 'nu_predict')(x)
#-------------------------------------------------------------------------------------

model = Model(inputs = input_ly, outputs = output_layer)

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-5),
              loss = tf.keras.losses.BinaryCrossentropy(), 
              metrics = [tf.keras.metrics.AUC(curve='ROC', name='roc_auc'),
                         tf.keras.metrics.AUC(curve='PR', name='pr_auc'),
                         'accuracy'])


history = model.fit(x = X_train, 
                    y = labels_train, 
                    epochs = 200, 
                    batch_size = 1000,
                    validation_data=(X_val, labels_val),
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience = 30, min_delta = 1e-3, monitor="val_loss")],
                    shuffle = True,
                    verbose = 1)
# Out:
# Epoch 1/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5044 - loss: 0.6931 - pr_auc: 0.5000 - roc_auc: 0.5000 - val_accuracy: 0.5681 - val_loss: 0.6931 - val_pr_auc: 0.5000 - val_roc_auc: 0.5000
# Epoch 2/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5507 - loss: 0.6931 - pr_auc: 0.5000 - roc_auc: 0.5000 - val_accuracy: 0.5964 - val_loss: 0.6930 - val_pr_auc: 0.5000 - val_roc_auc: 0.5000
# Epoch 3/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5826 - loss: 0.6929 - pr_auc: 0.5090 - roc_auc: 0.5069 - val_accuracy: 0.5911 - val_loss: 0.6914 - val_pr_auc: 0.5851 - val_roc_auc: 0.6032
# Epoch 4/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5859 - loss: 0.6893 - pr_auc: 0.5847 - roc_auc: 0.6035 - val_accuracy: 0.6354 - val_loss: 0.6723 - val_pr_auc: 0.6483 - val_roc_auc: 0.6770
# Epoch 5/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6354 - loss: 0.6652 - pr_auc: 0.6444 - roc_auc: 0.6746 - val_accuracy: 0.6428 - val_loss: 0.6377 - val_pr_auc: 0.6625 - val_roc_auc: 0.6918
# Epoch 6/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6469 - loss: 0.6381 - pr_auc: 0.6621 - roc_auc: 0.6933 - val_accuracy: 0.6503 - val_loss: 0.6313 - val_pr_auc: 0.6797 - val_roc_auc: 0.7028
# Epoch 7/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6514 - loss: 0.6305 - pr_auc: 0.6749 - roc_auc: 0.7019 - val_accuracy: 0.6540 - val_loss: 0.6278 - val_pr_auc: 0.6980 - val_roc_auc: 0.7094
# Epoch 8/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6537 - loss: 0.6263 - pr_auc: 0.6865 - roc_auc: 0.7076 - val_accuracy: 0.6567 - val_loss: 0.6242 - val_pr_auc: 0.7069 - val_roc_auc: 0.7143
# Epoch 9/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6571 - loss: 0.6216 - pr_auc: 0.6971 - roc_auc: 0.7135 - val_accuracy: 0.6587 - val_loss: 0.6212 - val_pr_auc: 0.7121 - val_roc_auc: 0.7181
# Epoch 10/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6582 - loss: 0.6202 - pr_auc: 0.7010 - roc_auc: 0.7152 - val_accuracy: 0.6602 - val_loss: 0.6193 - val_pr_auc: 0.7163 - val_roc_auc: 0.7211
# Epoch 11/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6611 - loss: 0.6166 - pr_auc: 0.7075 - roc_auc: 0.7196 - val_accuracy: 0.6617 - val_loss: 0.6159 - val_pr_auc: 0.7202 - val_roc_auc: 0.7247
# Epoch 12/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6626 - loss: 0.6139 - pr_auc: 0.7123 - roc_auc: 0.7227 - val_accuracy: 0.6649 - val_loss: 0.6132 - val_pr_auc: 0.7236 - val_roc_auc: 0.7277
# Epoch 13/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6650 - loss: 0.6113 - pr_auc: 0.7162 - roc_auc: 0.7258 - val_accuracy: 0.6662 - val_loss: 0.6101 - val_pr_auc: 0.7269 - val_roc_auc: 0.7309
# Epoch 14/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6674 - loss: 0.6081 - pr_auc: 0.7208 - roc_auc: 0.7295 - val_accuracy: 0.6667 - val_loss: 0.6068 - val_pr_auc: 0.7299 - val_roc_auc: 0.7341
# Epoch 15/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6707 - loss: 0.6053 - pr_auc: 0.7248 - roc_auc: 0.7331 - val_accuracy: 0.6682 - val_loss: 0.6054 - val_pr_auc: 0.7328 - val_roc_auc: 0.7362
# Epoch 16/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6723 - loss: 0.6021 - pr_auc: 0.7296 - roc_auc: 0.7367 - val_accuracy: 0.6702 - val_loss: 0.6023 - val_pr_auc: 0.7358 - val_roc_auc: 0.7393
# Epoch 17/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6733 - loss: 0.6013 - pr_auc: 0.7307 - roc_auc: 0.7376 - val_accuracy: 0.6719 - val_loss: 0.6000 - val_pr_auc: 0.7388 - val_roc_auc: 0.7421
# Epoch 18/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6752 - loss: 0.5983 - pr_auc: 0.7346 - roc_auc: 0.7410 - val_accuracy: 0.6731 - val_loss: 0.5975 - val_pr_auc: 0.7416 - val_roc_auc: 0.7448
# Epoch 19/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6773 - loss: 0.5954 - pr_auc: 0.7386 - roc_auc: 0.7443 - val_accuracy: 0.6759 - val_loss: 0.5946 - val_pr_auc: 0.7447 - val_roc_auc: 0.7478
# Epoch 20/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6800 - loss: 0.5931 - pr_auc: 0.7415 - roc_auc: 0.7469 - val_accuracy: 0.6786 - val_loss: 0.5929 - val_pr_auc: 0.7475 - val_roc_auc: 0.7502
# Epoch 21/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6809 - loss: 0.5905 - pr_auc: 0.7446 - roc_auc: 0.7495 - val_accuracy: 0.6813 - val_loss: 0.5896 - val_pr_auc: 0.7511 - val_roc_auc: 0.7537
# Epoch 22/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6854 - loss: 0.5863 - pr_auc: 0.7496 - roc_auc: 0.7544 - val_accuracy: 0.6844 - val_loss: 0.5865 - val_pr_auc: 0.7545 - val_roc_auc: 0.7571
# Epoch 23/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6883 - loss: 0.5822 - pr_auc: 0.7547 - roc_auc: 0.7588 - val_accuracy: 0.6874 - val_loss: 0.5823 - val_pr_auc: 0.7589 - val_roc_auc: 0.7614
# Epoch 24/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6903 - loss: 0.5795 - pr_auc: 0.7577 - roc_auc: 0.7616 - val_accuracy: 0.6922 - val_loss: 0.5779 - val_pr_auc: 0.7636 - val_roc_auc: 0.7660
# Epoch 25/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6936 - loss: 0.5761 - pr_auc: 0.7617 - roc_auc: 0.7653 - val_accuracy: 0.6936 - val_loss: 0.5749 - val_pr_auc: 0.7675 - val_roc_auc: 0.7697
# Epoch 26/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6976 - loss: 0.5711 - pr_auc: 0.7672 - roc_auc: 0.7705 - val_accuracy: 0.6982 - val_loss: 0.5695 - val_pr_auc: 0.7728 - val_roc_auc: 0.7749
# Epoch 27/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7016 - loss: 0.5660 - pr_auc: 0.7728 - roc_auc: 0.7757 - val_accuracy: 0.7022 - val_loss: 0.5622 - val_pr_auc: 0.7795 - val_roc_auc: 0.7814
# Epoch 28/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7059 - loss: 0.5603 - pr_auc: 0.7788 - roc_auc: 0.7812 - val_accuracy: 0.7075 - val_loss: 0.5568 - val_pr_auc: 0.7851 - val_roc_auc: 0.7867
# Epoch 29/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7099 - loss: 0.5545 - pr_auc: 0.7848 - roc_auc: 0.7868 - val_accuracy: 0.7127 - val_loss: 0.5511 - val_pr_auc: 0.7909 - val_roc_auc: 0.7922
# Epoch 30/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7154 - loss: 0.5485 - pr_auc: 0.7907 - roc_auc: 0.7926 - val_accuracy: 0.7165 - val_loss: 0.5442 - val_pr_auc: 0.7975 - val_roc_auc: 0.7984
# Epoch 31/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7201 - loss: 0.5405 - pr_auc: 0.7987 - roc_auc: 0.7996 - val_accuracy: 0.7220 - val_loss: 0.5371 - val_pr_auc: 0.8040 - val_roc_auc: 0.8045
# Epoch 32/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7243 - loss: 0.5353 - pr_auc: 0.8035 - roc_auc: 0.8043 - val_accuracy: 0.7287 - val_loss: 0.5307 - val_pr_auc: 0.8099 - val_roc_auc: 0.8101
# Epoch 33/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7286 - loss: 0.5283 - pr_auc: 0.8099 - roc_auc: 0.8102 - val_accuracy: 0.7315 - val_loss: 0.5244 - val_pr_auc: 0.8155 - val_roc_auc: 0.8153
# Epoch 34/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7332 - loss: 0.5211 - pr_auc: 0.8163 - roc_auc: 0.8160 - val_accuracy: 0.7355 - val_loss: 0.5162 - val_pr_auc: 0.8220 - val_roc_auc: 0.8213
# Epoch 35/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7373 - loss: 0.5162 - pr_auc: 0.8204 - roc_auc: 0.8202 - val_accuracy: 0.7381 - val_loss: 0.5123 - val_pr_auc: 0.8255 - val_roc_auc: 0.8244
# Epoch 36/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7406 - loss: 0.5116 - pr_auc: 0.8244 - roc_auc: 0.8236 - val_accuracy: 0.7413 - val_loss: 0.5095 - val_pr_auc: 0.8282 - val_roc_auc: 0.8268
# Epoch 37/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7427 - loss: 0.5072 - pr_auc: 0.8280 - roc_auc: 0.8270 - val_accuracy: 0.7442 - val_loss: 0.5048 - val_pr_auc: 0.8320 - val_roc_auc: 0.8302
# Epoch 38/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7451 - loss: 0.5032 - pr_auc: 0.8312 - roc_auc: 0.8300 - val_accuracy: 0.7435 - val_loss: 0.5013 - val_pr_auc: 0.8344 - val_roc_auc: 0.8323
# Epoch 39/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7460 - loss: 0.5015 - pr_auc: 0.8326 - roc_auc: 0.8312 - val_accuracy: 0.7456 - val_loss: 0.4978 - val_pr_auc: 0.8370 - val_roc_auc: 0.8348
# Epoch 40/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7474 - loss: 0.4989 - pr_auc: 0.8346 - roc_auc: 0.8331 - val_accuracy: 0.7480 - val_loss: 0.4975 - val_pr_auc: 0.8377 - val_roc_auc: 0.8352
# Epoch 41/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7490 - loss: 0.4965 - pr_auc: 0.8366 - roc_auc: 0.8350 - val_accuracy: 0.7483 - val_loss: 0.4959 - val_pr_auc: 0.8389 - val_roc_auc: 0.8362
# Epoch 42/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7491 - loss: 0.4962 - pr_auc: 0.8367 - roc_auc: 0.8352 - val_accuracy: 0.7503 - val_loss: 0.4932 - val_pr_auc: 0.8407 - val_roc_auc: 0.8380
# Epoch 43/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7499 - loss: 0.4942 - pr_auc: 0.8383 - roc_auc: 0.8364 - val_accuracy: 0.7503 - val_loss: 0.4939 - val_pr_auc: 0.8405 - val_roc_auc: 0.8377
# Epoch 44/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7506 - loss: 0.4929 - pr_auc: 0.8393 - roc_auc: 0.8371 - val_accuracy: 0.7510 - val_loss: 0.4925 - val_pr_auc: 0.8415 - val_roc_auc: 0.8386
# Epoch 45/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7513 - loss: 0.4922 - pr_auc: 0.8398 - roc_auc: 0.8378 - val_accuracy: 0.7521 - val_loss: 0.4906 - val_pr_auc: 0.8429 - val_roc_auc: 0.8399
# Epoch 46/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7523 - loss: 0.4904 - pr_auc: 0.8412 - roc_auc: 0.8390 - val_accuracy: 0.7523 - val_loss: 0.4900 - val_pr_auc: 0.8432 - val_roc_auc: 0.8402
# Epoch 47/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7519 - loss: 0.4898 - pr_auc: 0.8417 - roc_auc: 0.8394 - val_accuracy: 0.7532 - val_loss: 0.4883 - val_pr_auc: 0.8443 - val_roc_auc: 0.8413
# Epoch 48/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7533 - loss: 0.4892 - pr_auc: 0.8422 - roc_auc: 0.8400 - val_accuracy: 0.7528 - val_loss: 0.4894 - val_pr_auc: 0.8439 - val_roc_auc: 0.8408
# Epoch 49/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7522 - loss: 0.4892 - pr_auc: 0.8421 - roc_auc: 0.8397 - val_accuracy: 0.7548 - val_loss: 0.4867 - val_pr_auc: 0.8456 - val_roc_auc: 0.8424
# Epoch 50/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7540 - loss: 0.4866 - pr_auc: 0.8441 - roc_auc: 0.8418 - val_accuracy: 0.7549 - val_loss: 0.4856 - val_pr_auc: 0.8463 - val_roc_auc: 0.8431
# Epoch 51/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7531 - loss: 0.4868 - pr_auc: 0.8439 - roc_auc: 0.8412 - val_accuracy: 0.7568 - val_loss: 0.4850 - val_pr_auc: 0.8468 - val_roc_auc: 0.8436
# Epoch 52/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7541 - loss: 0.4870 - pr_auc: 0.8438 - roc_auc: 0.8412 - val_accuracy: 0.7555 - val_loss: 0.4848 - val_pr_auc: 0.8471 - val_roc_auc: 0.8438
# Epoch 53/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7550 - loss: 0.4851 - pr_auc: 0.8452 - roc_auc: 0.8427 - val_accuracy: 0.7569 - val_loss: 0.4838 - val_pr_auc: 0.8477 - val_roc_auc: 0.8445
# Epoch 54/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7545 - loss: 0.4857 - pr_auc: 0.8447 - roc_auc: 0.8421 - val_accuracy: 0.7575 - val_loss: 0.4836 - val_pr_auc: 0.8481 - val_roc_auc: 0.8448
# Epoch 55/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7535 - loss: 0.4856 - pr_auc: 0.8448 - roc_auc: 0.8419 - val_accuracy: 0.7571 - val_loss: 0.4815 - val_pr_auc: 0.8494 - val_roc_auc: 0.8461
# Epoch 56/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7554 - loss: 0.4841 - pr_auc: 0.8459 - roc_auc: 0.8430 - val_accuracy: 0.7577 - val_loss: 0.4809 - val_pr_auc: 0.8497 - val_roc_auc: 0.8463
# Epoch 57/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7558 - loss: 0.4838 - pr_auc: 0.8461 - roc_auc: 0.8434 - val_accuracy: 0.7569 - val_loss: 0.4826 - val_pr_auc: 0.8488 - val_roc_auc: 0.8455
# Epoch 58/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7568 - loss: 0.4812 - pr_auc: 0.8480 - roc_auc: 0.8450 - val_accuracy: 0.7595 - val_loss: 0.4786 - val_pr_auc: 0.8511 - val_roc_auc: 0.8477
# Epoch 59/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7573 - loss: 0.4811 - pr_auc: 0.8482 - roc_auc: 0.8453 - val_accuracy: 0.7594 - val_loss: 0.4775 - val_pr_auc: 0.8518 - val_roc_auc: 0.8484
# Epoch 60/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7569 - loss: 0.4814 - pr_auc: 0.8479 - roc_auc: 0.8450 - val_accuracy: 0.7587 - val_loss: 0.4790 - val_pr_auc: 0.8510 - val_roc_auc: 0.8476
# Epoch 61/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7577 - loss: 0.4811 - pr_auc: 0.8481 - roc_auc: 0.8454 - val_accuracy: 0.7594 - val_loss: 0.4776 - val_pr_auc: 0.8518 - val_roc_auc: 0.8484
# Epoch 62/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7572 - loss: 0.4809 - pr_auc: 0.8483 - roc_auc: 0.8454 - val_accuracy: 0.7594 - val_loss: 0.4777 - val_pr_auc: 0.8518 - val_roc_auc: 0.8485
# Epoch 63/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7575 - loss: 0.4802 - pr_auc: 0.8487 - roc_auc: 0.8456 - val_accuracy: 0.7578 - val_loss: 0.4804 - val_pr_auc: 0.8505 - val_roc_auc: 0.8472
# Epoch 64/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7580 - loss: 0.4787 - pr_auc: 0.8499 - roc_auc: 0.8468 - val_accuracy: 0.7618 - val_loss: 0.4749 - val_pr_auc: 0.8535 - val_roc_auc: 0.8501
# Epoch 65/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7578 - loss: 0.4798 - pr_auc: 0.8490 - roc_auc: 0.8461 - val_accuracy: 0.7589 - val_loss: 0.4776 - val_pr_auc: 0.8521 - val_roc_auc: 0.8488
# Epoch 66/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7589 - loss: 0.4781 - pr_auc: 0.8503 - roc_auc: 0.8473 - val_accuracy: 0.7606 - val_loss: 0.4761 - val_pr_auc: 0.8531 - val_roc_auc: 0.8497
# Epoch 67/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7568 - loss: 0.4797 - pr_auc: 0.8490 - roc_auc: 0.8456 - val_accuracy: 0.7601 - val_loss: 0.4775 - val_pr_auc: 0.8524 - val_roc_auc: 0.8490
# Epoch 68/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7591 - loss: 0.4778 - pr_auc: 0.8505 - roc_auc: 0.8476 - val_accuracy: 0.7607 - val_loss: 0.4765 - val_pr_auc: 0.8530 - val_roc_auc: 0.8497
# Epoch 69/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7588 - loss: 0.4774 - pr_auc: 0.8508 - roc_auc: 0.8477 - val_accuracy: 0.7610 - val_loss: 0.4749 - val_pr_auc: 0.8540 - val_roc_auc: 0.8506
# Epoch 70/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7595 - loss: 0.4772 - pr_auc: 0.8509 - roc_auc: 0.8478 - val_accuracy: 0.7636 - val_loss: 0.4729 - val_pr_auc: 0.8551 - val_roc_auc: 0.8516
# Epoch 71/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7596 - loss: 0.4762 - pr_auc: 0.8516 - roc_auc: 0.8484 - val_accuracy: 0.7620 - val_loss: 0.4738 - val_pr_auc: 0.8546 - val_roc_auc: 0.8513
# Epoch 72/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7591 - loss: 0.4760 - pr_auc: 0.8517 - roc_auc: 0.8483 - val_accuracy: 0.7619 - val_loss: 0.4744 - val_pr_auc: 0.8544 - val_roc_auc: 0.8511
# Epoch 73/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7586 - loss: 0.4769 - pr_auc: 0.8511 - roc_auc: 0.8479 - val_accuracy: 0.7615 - val_loss: 0.4756 - val_pr_auc: 0.8538 - val_roc_auc: 0.8505
# Epoch 74/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7596 - loss: 0.4759 - pr_auc: 0.8519 - roc_auc: 0.8487 - val_accuracy: 0.7626 - val_loss: 0.4739 - val_pr_auc: 0.8549 - val_roc_auc: 0.8515
# Epoch 75/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7604 - loss: 0.4751 - pr_auc: 0.8524 - roc_auc: 0.8490 - val_accuracy: 0.7635 - val_loss: 0.4719 - val_pr_auc: 0.8559 - val_roc_auc: 0.8526
# Epoch 76/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7606 - loss: 0.4744 - pr_auc: 0.8529 - roc_auc: 0.8496 - val_accuracy: 0.7629 - val_loss: 0.4732 - val_pr_auc: 0.8553 - val_roc_auc: 0.8519
# Epoch 77/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7612 - loss: 0.4733 - pr_auc: 0.8537 - roc_auc: 0.8504 - val_accuracy: 0.7640 - val_loss: 0.4716 - val_pr_auc: 0.8562 - val_roc_auc: 0.8528
# Epoch 78/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7606 - loss: 0.4752 - pr_auc: 0.8524 - roc_auc: 0.8491 - val_accuracy: 0.7646 - val_loss: 0.4713 - val_pr_auc: 0.8564 - val_roc_auc: 0.8530
# Epoch 79/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7607 - loss: 0.4741 - pr_auc: 0.8531 - roc_auc: 0.8497 - val_accuracy: 0.7638 - val_loss: 0.4726 - val_pr_auc: 0.8557 - val_roc_auc: 0.8524
# Epoch 80/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7613 - loss: 0.4735 - pr_auc: 0.8535 - roc_auc: 0.8503 - val_accuracy: 0.7645 - val_loss: 0.4698 - val_pr_auc: 0.8574 - val_roc_auc: 0.8540
# Epoch 81/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7612 - loss: 0.4740 - pr_auc: 0.8532 - roc_auc: 0.8500 - val_accuracy: 0.7645 - val_loss: 0.4704 - val_pr_auc: 0.8571 - val_roc_auc: 0.8537
# Epoch 82/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7607 - loss: 0.4747 - pr_auc: 0.8527 - roc_auc: 0.8494 - val_accuracy: 0.7642 - val_loss: 0.4706 - val_pr_auc: 0.8571 - val_roc_auc: 0.8537
# Epoch 83/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7614 - loss: 0.4729 - pr_auc: 0.8540 - roc_auc: 0.8505 - val_accuracy: 0.7643 - val_loss: 0.4717 - val_pr_auc: 0.8565 - val_roc_auc: 0.8532
# Epoch 84/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7619 - loss: 0.4723 - pr_auc: 0.8544 - roc_auc: 0.8511 - val_accuracy: 0.7636 - val_loss: 0.4726 - val_pr_auc: 0.8559 - val_roc_auc: 0.8527
# Epoch 85/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7618 - loss: 0.4728 - pr_auc: 0.8540 - roc_auc: 0.8507 - val_accuracy: 0.7634 - val_loss: 0.4730 - val_pr_auc: 0.8558 - val_roc_auc: 0.8526
# Epoch 86/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7631 - loss: 0.4712 - pr_auc: 0.8552 - roc_auc: 0.8519 - val_accuracy: 0.7649 - val_loss: 0.4703 - val_pr_auc: 0.8572 - val_roc_auc: 0.8540
# Epoch 87/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7622 - loss: 0.4712 - pr_auc: 0.8552 - roc_auc: 0.8516 - val_accuracy: 0.7649 - val_loss: 0.4701 - val_pr_auc: 0.8574 - val_roc_auc: 0.8542
# Epoch 88/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7624 - loss: 0.4715 - pr_auc: 0.8550 - roc_auc: 0.8517 - val_accuracy: 0.7651 - val_loss: 0.4690 - val_pr_auc: 0.8581 - val_roc_auc: 0.8548
# Epoch 89/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7620 - loss: 0.4718 - pr_auc: 0.8547 - roc_auc: 0.8513 - val_accuracy: 0.7654 - val_loss: 0.4692 - val_pr_auc: 0.8581 - val_roc_auc: 0.8548
# Epoch 90/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7633 - loss: 0.4704 - pr_auc: 0.8558 - roc_auc: 0.8524 - val_accuracy: 0.7649 - val_loss: 0.4697 - val_pr_auc: 0.8577 - val_roc_auc: 0.8545
# Epoch 91/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7628 - loss: 0.4709 - pr_auc: 0.8553 - roc_auc: 0.8519 - val_accuracy: 0.7656 - val_loss: 0.4690 - val_pr_auc: 0.8582 - val_roc_auc: 0.8549
# Epoch 92/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7634 - loss: 0.4701 - pr_auc: 0.8559 - roc_auc: 0.8525 - val_accuracy: 0.7664 - val_loss: 0.4670 - val_pr_auc: 0.8593 - val_roc_auc: 0.8560
# Epoch 93/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7630 - loss: 0.4700 - pr_auc: 0.8560 - roc_auc: 0.8525 - val_accuracy: 0.7642 - val_loss: 0.4711 - val_pr_auc: 0.8569 - val_roc_auc: 0.8538
# Epoch 94/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7640 - loss: 0.4685 - pr_auc: 0.8571 - roc_auc: 0.8536 - val_accuracy: 0.7654 - val_loss: 0.4690 - val_pr_auc: 0.8583 - val_roc_auc: 0.8550
# Epoch 95/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7638 - loss: 0.4695 - pr_auc: 0.8564 - roc_auc: 0.8531 - val_accuracy: 0.7664 - val_loss: 0.4692 - val_pr_auc: 0.8581 - val_roc_auc: 0.8549
# Epoch 96/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7639 - loss: 0.4694 - pr_auc: 0.8565 - roc_auc: 0.8531 - val_accuracy: 0.7668 - val_loss: 0.4677 - val_pr_auc: 0.8592 - val_roc_auc: 0.8560
# Epoch 97/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7650 - loss: 0.4684 - pr_auc: 0.8572 - roc_auc: 0.8539 - val_accuracy: 0.7670 - val_loss: 0.4664 - val_pr_auc: 0.8598 - val_roc_auc: 0.8565
# Epoch 98/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7642 - loss: 0.4682 - pr_auc: 0.8572 - roc_auc: 0.8537 - val_accuracy: 0.7651 - val_loss: 0.4707 - val_pr_auc: 0.8576 - val_roc_auc: 0.8545
# Epoch 99/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7640 - loss: 0.4689 - pr_auc: 0.8568 - roc_auc: 0.8534 - val_accuracy: 0.7655 - val_loss: 0.4715 - val_pr_auc: 0.8571 - val_roc_auc: 0.8539
# Epoch 100/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7657 - loss: 0.4677 - pr_auc: 0.8576 - roc_auc: 0.8542 - val_accuracy: 0.7666 - val_loss: 0.4684 - val_pr_auc: 0.8587 - val_roc_auc: 0.8555
# Epoch 101/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7644 - loss: 0.4690 - pr_auc: 0.8567 - roc_auc: 0.8533 - val_accuracy: 0.7655 - val_loss: 0.4696 - val_pr_auc: 0.8584 - val_roc_auc: 0.8552
# Epoch 102/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7647 - loss: 0.4676 - pr_auc: 0.8577 - roc_auc: 0.8543 - val_accuracy: 0.7666 - val_loss: 0.4688 - val_pr_auc: 0.8586 - val_roc_auc: 0.8554
# Epoch 103/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7643 - loss: 0.4680 - pr_auc: 0.8574 - roc_auc: 0.8538 - val_accuracy: 0.7657 - val_loss: 0.4700 - val_pr_auc: 0.8582 - val_roc_auc: 0.8551
# Epoch 104/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7647 - loss: 0.4683 - pr_auc: 0.8572 - roc_auc: 0.8538 - val_accuracy: 0.7669 - val_loss: 0.4686 - val_pr_auc: 0.8590 - val_roc_auc: 0.8558
# Epoch 105/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7646 - loss: 0.4675 - pr_auc: 0.8577 - roc_auc: 0.8541 - val_accuracy: 0.7657 - val_loss: 0.4697 - val_pr_auc: 0.8584 - val_roc_auc: 0.8553
# Epoch 106/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7663 - loss: 0.4662 - pr_auc: 0.8587 - roc_auc: 0.8552 - val_accuracy: 0.7661 - val_loss: 0.4691 - val_pr_auc: 0.8587 - val_roc_auc: 0.8555
# Epoch 107/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7645 - loss: 0.4681 - pr_auc: 0.8573 - roc_auc: 0.8539 - val_accuracy: 0.7656 - val_loss: 0.4735 - val_pr_auc: 0.8562 - val_roc_auc: 0.8532
# Epoch 108/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7650 - loss: 0.4665 - pr_auc: 0.8585 - roc_auc: 0.8550 - val_accuracy: 0.7678 - val_loss: 0.4676 - val_pr_auc: 0.8596 - val_roc_auc: 0.8564
# Epoch 109/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7657 - loss: 0.4658 - pr_auc: 0.8590 - roc_auc: 0.8554 - val_accuracy: 0.7663 - val_loss: 0.4702 - val_pr_auc: 0.8581 - val_roc_auc: 0.8550
# Epoch 110/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7663 - loss: 0.4649 - pr_auc: 0.8596 - roc_auc: 0.8562 - val_accuracy: 0.7666 - val_loss: 0.4689 - val_pr_auc: 0.8587 - val_roc_auc: 0.8557
# Epoch 111/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7654 - loss: 0.4669 - pr_auc: 0.8582 - roc_auc: 0.8548 - val_accuracy: 0.7674 - val_loss: 0.4687 - val_pr_auc: 0.8589 - val_roc_auc: 0.8559
# Epoch 112/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7649 - loss: 0.4667 - pr_auc: 0.8583 - roc_auc: 0.8548 - val_accuracy: 0.7659 - val_loss: 0.4725 - val_pr_auc: 0.8571 - val_roc_auc: 0.8541
# Epoch 113/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7659 - loss: 0.4656 - pr_auc: 0.8591 - roc_auc: 0.8555 - val_accuracy: 0.7668 - val_loss: 0.4690 - val_pr_auc: 0.8588 - val_roc_auc: 0.8557
# Epoch 114/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7661 - loss: 0.4649 - pr_auc: 0.8596 - roc_auc: 0.8560 - val_accuracy: 0.7655 - val_loss: 0.4726 - val_pr_auc: 0.8570 - val_roc_auc: 0.8541
# Epoch 115/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7662 - loss: 0.4656 - pr_auc: 0.8591 - roc_auc: 0.8556 - val_accuracy: 0.7666 - val_loss: 0.4699 - val_pr_auc: 0.8585 - val_roc_auc: 0.8554
# Epoch 116/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7657 - loss: 0.4659 - pr_auc: 0.8589 - roc_auc: 0.8554 - val_accuracy: 0.7654 - val_loss: 0.4734 - val_pr_auc: 0.8567 - val_roc_auc: 0.8537
# Epoch 117/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7653 - loss: 0.4660 - pr_auc: 0.8587 - roc_auc: 0.8551 - val_accuracy: 0.7650 - val_loss: 0.4739 - val_pr_auc: 0.8564 - val_roc_auc: 0.8535
# Epoch 118/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7660 - loss: 0.4659 - pr_auc: 0.8589 - roc_auc: 0.8555 - val_accuracy: 0.7672 - val_loss: 0.4689 - val_pr_auc: 0.8592 - val_roc_auc: 0.8561
# Epoch 119/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7672 - loss: 0.4650 - pr_auc: 0.8595 - roc_auc: 0.8561 - val_accuracy: 0.7662 - val_loss: 0.4722 - val_pr_auc: 0.8574 - val_roc_auc: 0.8544
# Epoch 120/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7670 - loss: 0.4640 - pr_auc: 0.8602 - roc_auc: 0.8567 - val_accuracy: 0.7656 - val_loss: 0.4725 - val_pr_auc: 0.8573 - val_roc_auc: 0.8543
# Epoch 121/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7673 - loss: 0.4640 - pr_auc: 0.8602 - roc_auc: 0.8568 - val_accuracy: 0.7651 - val_loss: 0.4747 - val_pr_auc: 0.8563 - val_roc_auc: 0.8533
# Epoch 122/200
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7666 - loss: 0.4645 - pr_auc: 0.8599 - roc_auc: 0.8564 - val_accuracy: 0.7651 - val_loss: 0.4736 - val_pr_auc: 0.8569 - val_roc_auc: 0.8538

# %% [markdown]
# # Learning Curves

# %%
import matplotlib as mpl
# -------Save settings -------
save_dir = 'figs/Optimized Models/10x10/pipeline_std_minmax/'
fname = 'training_curves_'
pattern_train_save_name = f'E_{energy_inf_cut}_{energy_cut}_MeV_R_{posr_cut}_mm_Delta_({time_res_inf_cut}_{time_res_sup_cut})_ns'

# ------- Superior Title -------
main_title = 'Training Progress '
train_cut_title = rf'Dim ($\mathcal{{L}}(\Delta, \alpha) = (10,10)$), E$_\text{{train}}$: [{energy_inf_cut}, {energy_cut}] (MeV), R $\leq$ {radial_cut} (mm), $\Delta$: [{time_res_inf_cut}, {time_res_sup_cut}] (ns)'
full_title = main_title + '\n' + train_cut_title

plt.style.use('seaborn-v0_8-whitegrid')  # O prueba 'ggplot', 'seaborn-dark', etc.
font_style_title = {'family':'serif', 'weight': 'normal','color':'black','size':13}
font_style_axis= {'family':'serif', 'weight': 'normal','color':'black','size':12}

# Figura y subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# --- Plot 1: Loss & Accuracy ---
axes[0].plot(history.history['loss'], 'o:', color='#0528f2', label='Train Loss', linewidth=1.5, markersize=4)
axes[0].plot(history.history['accuracy'], 'x:', color='#27ad05', label='Train Accuracy', linewidth=1.5, markersize=4)
axes[0].plot(history.history['val_loss'], 's:', color='#f50505', label='Val. Loss', linewidth=1.5, markersize=4)
axes[0].plot(history.history['val_accuracy'], '*:', color='#fa9005', label='Val. Accuracy', linewidth=1.5, markersize=4)

axes[0].set_title('Training and Validation Loss / Accuracy', fontdict = font_style_title)
axes[0].set_xlabel('Epoch', fontdict = font_style_axis)
axes[0].set_ylabel('Value', fontdict = font_style_axis)
axes[0].legend(loc='center right', frameon=True, edgecolor='black', fancybox=False)
axes[0].grid(True, linestyle='--', alpha=0.5)

# axes[0].set_yscale('log')  # solo si realmente lo necesitas

# --- Plot 2: AUC ---
axes[1].plot(history.history['roc_auc'], 'o:', color='#f21d05', label='Train ROC AUC', linewidth=1.5, markersize=4)
axes[1].plot(history.history['val_roc_auc'], 'x:', color='#0d05f2', label='Val. ROC AUC', linewidth=1.5, markersize=4)
axes[1].plot(history.history['pr_auc'], 's:', color='#fa9005', label='Train PR AUC', linewidth=1.5, markersize=4)
axes[1].plot(history.history['val_pr_auc'], '*:', color='#27ad05', label='Val. PR AUC', linewidth=1.5, markersize=4)

axes[1].set_title('ROC AUC and PR AUC', fontdict = font_style_title)
axes[1].set_xlabel('Epoch', fontdict = font_style_axis)
axes[1].set_ylabel('AUC', fontdict = font_style_axis)
axes[1].set_ylim(0.7, 1)
axes[1].legend(loc='lower right', frameon=True, edgecolor='black', fancybox=False)
axes[1].grid(True, linestyle='--', alpha=0.5)

# axes[1].set_yscale('log')  # igual que arriba, solo si necesario

# Super título
fig.suptitle(full_title, backgroundcolor='#095f91', family = 'serif', color='white', fontsize=13, weight='normal', y=1.01)

fig.tight_layout()

# Save Plot
#if save_fig:
#    fig.savefig(save_dir + fname + pattern_train_save_name + '.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Observation and Analysis of Predictions

# %% [markdown]
# ## DNN Prediction

# %%
X_sig_pred = model.predict(X_test_sig)
X_bkg_pred = model.predict(X_test_bkg)
# Out:
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step

# %%
X_sig_pred
# Out:
# array([[0.99742216, 0.00203012],
#        [0.42230618, 0.5795325 ],
#        [0.9746123 , 0.02491236],
#        ...,
#        [0.59616846, 0.40209457],
#        [0.88287896, 0.11884747],
#        [0.24492747, 0.7575278 ]], dtype=float32)

# %% [markdown]
# ## Representation of Predictions

# %%
# ------- Save settings : -------
save_dir = 'figs/Optimized Models/10x10/pipeline_std_minmax/'
fname = 'Classifier_Model_Output_'
pattern_train_save_name = f'E_{energy_inf_cut}_{energy_cut}_MeV_R_{posr_cut}_mm_Delta_({time_res_inf_cut}_{time_res_sup_cut})_ns'

# ------- Superior Title -------
main_title = 'Classifier Model Output Distributions '
train_cut_title = rf'Dim ($\mathcal{{L}}(\Delta, \alpha) = (10,10)$), E$_\text{{train}}$: [{energy_inf_cut}, {energy_cut}] (MeV), R $\leq$ {radial_cut} (mm), $\Delta$: [{time_res_inf_cut}, {time_res_sup_cut}] (ns)'
full_title = main_title + '\n' + train_cut_title

sn.set_theme(style="ticks")  # o "ticks", "darkgrid", etc.
font_style_title = {'family':'serif', 'weight': 'normal','color':'black','size':16}
font_style_axis= {'family':'serif', 'weight': 'normal','color':'black','size':15}

bins = 65
fig, axes = plt.subplots(1, 2, figsize=(22, 8), sharey=True)

# Solar ν predictions
sn.histplot(X_sig_pred[:, 0], bins=bins, label='SAS', color='#bf1c0b',
             edgecolor='black', linewidth=0.3, alpha=0.8, ax=axes[0])
sn.histplot(X_sig_pred[:, 1], bins=bins, label='SAB', color='#0b14bf',
             edgecolor='black', linewidth=0.3, alpha=0.6, ax=axes[0])

# Background predictions
sn.histplot(X_bkg_pred[:, 1], bins=bins, label='BAB', color='#bf1c0b',
             edgecolor='black', linewidth=0.3, alpha=0.8, ax=axes[1])
sn.histplot(X_bkg_pred[:, 0], bins=bins, label='BAS', color='#0b14bf',
             edgecolor='black', linewidth=0.3, alpha=0.6, ax=axes[1])

# Titles and labels
axes[0].set_title('MC Solar $^8$B-$\\nu_e$ events Classification', fontdict = font_style_title)
axes[0].set_xlabel('Model Probability Predictions', fontdict = font_style_axis)
axes[0].set_ylabel('Counts (log scale)', fontdict = font_style_axis)
axes[0].legend(loc = 'best', frameon=True, edgecolor='black', fancybox=False, fontsize=14)
axes[0].set_yscale('log')

axes[1].set_title('MC $^{208}$Tl events Classification', fontdict = font_style_title)
axes[1].set_xlabel('Model Probability Predictions', fontdict = font_style_axis)
axes[1].set_ylabel('Counts (log scale)', fontdict = font_style_axis)
axes[1].legend(loc = 'upper center', frameon=True, edgecolor='black', fancybox=False, fontsize=14)
axes[1].set_yscale('log')

# General formatting
plt.suptitle(full_title, backgroundcolor='#095f91', family = 'serif', color='white', fontsize=17, weight='normal', y=1.02)

plt.tight_layout()
#if save_fig:
#    fig.savefig(save_dir + fname + pattern_train_save_name + '.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### ROC and PR Curves

# %%
X_pred = np.concatenate((X_sig_pred, X_bkg_pred))              #Predicted
X_exp = np.concatenate((labels_test_sig, labels_test_bkg))     #Expected

# ====================== ROC Calculation ======================
fpr_sig, tpr_sig, _ = roc_curve(X_exp[:,0], X_pred[:,0])
auc_sig = auc(fpr_sig, tpr_sig)

fpr_bkg, tpr_bkg, _ = roc_curve(X_exp[:,1], X_pred[:,1])
auc_bkg = auc(fpr_bkg, tpr_bkg)

fpr_all, tpr_all, _ = roc_curve(
    np.concatenate((X_exp[:,0], X_exp[:,1])),
    np.concatenate((X_pred[:,0], X_pred[:,1]))
)
auc_all = auc(fpr_all, tpr_all)

# ====================== PR Calculation ======================
prec_sig, rec_sig, _ = precision_recall_curve(X_exp[:,0], X_pred[:,0])
pr_auc_sig = auc(rec_sig, prec_sig)
N_positive = X_sig_pred.shape[0]
N_samples = X_sig_pred.shape[0] + X_bkg_pred.shape[0]
random_guess_line = N_positive/N_samples  #The random guess line is given by an horizontal line in the precision coordinate = (Nº of positive smaples)/(Nº of samples)

prec_bkg, rec_bkg, _ = precision_recall_curve(X_exp[:,1], X_pred[:,1])
pr_auc_bkg = auc(rec_bkg, prec_bkg)

prec_all, rec_all, _ = precision_recall_curve(
    np.concatenate((X_exp[:,0], X_exp[:,1])),
    np.concatenate((X_pred[:,0], X_pred[:,1]))
)
pr_auc_all = auc(rec_all, prec_all)

# %%
# ------- Save settings : -------
save_dir = 'figs/Optimized Models/10x10/pipeline_std_minmax/'
fname = 'ROC_PR_'
pattern_train_save_name = f'E_{energy_inf_cut}_{energy_cut}_MeV_R_{posr_cut}_mm_Delta_({time_res_inf_cut}_{time_res_sup_cut})_ns'

# ------- Superior Title -------
main_title = 'Classifier Model Performance '
train_cut_title = rf'Dim ($\mathcal{{L}}(\Delta, \alpha) = (10,10)$), E$_\text{{train}}$: [{energy_inf_cut}, {energy_cut}] (MeV), R $\leq$ {radial_cut} (mm), $\Delta$: [{time_res_inf_cut}, {time_res_sup_cut}] (ns)'
full_title = main_title + '\n' + train_cut_title

sn.set_theme(style="whitegrid")
font_style_title = {'family':'serif', 'weight': 'normal','color':'black','size':14}
font_style_axis  = {'family':'serif', 'weight': 'normal','color':'black','size':13}

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# ---------- Subplot 1: ROC para sig, bkg y overall ----------
axes[0].plot([0, 1], [0, 1], 'k--', label='Random Guessing', linewidth=1)
axes[0].plot(fpr_sig, tpr_sig, color='#e74c3c', linewidth=2,
             label=f'Signal (AUC = {auc_sig:.4f})')
axes[0].plot(fpr_bkg, tpr_bkg, color='#3498db', linewidth=2,
             label=f'Background (AUC = {auc_bkg:.4f})')
axes[0].plot(fpr_all, tpr_all, color='#18a308', linewidth=2,
             label=f'Overall (AUC = {auc_all:.4f})')

axes[0].set_title('ROC Curves', fontdict=font_style_title)
axes[0].set_xlabel('False Positive Rate', fontdict=font_style_axis)
axes[0].set_ylabel('True Positive Rate', fontdict=font_style_axis)
axes[0].legend(loc='lower right', frameon=True, edgecolor='black', fancybox=False, fontsize=10)
axes[0].grid(True, linestyle='--', alpha=0.5)

# ---------- Subplot 2: Precision-Recall para sig, bkg y overall ----------
axes[1].hlines(random_guess_line, 0, 1, colors="gray", linestyles="--", label="Random Baseline")
axes[1].plot(rec_sig, prec_sig, color='#e74c3c', linewidth=2,
             label=f'Signal (PR AUC = {pr_auc_sig:.4f})')
axes[1].plot(rec_bkg, prec_bkg, color='#3498db', linewidth=2,
             label=f'Background (PR AUC = {pr_auc_bkg:.4f})')
axes[1].plot(rec_all, prec_all, color='#18a308', linewidth=2,
             label=f'Overall (PR AUC = {pr_auc_all:.4f})')

axes[1].set_title('Precision-Recall Curves', fontdict=font_style_title)
axes[1].set_xlabel('Recall', fontdict=font_style_axis)
axes[1].set_ylabel('Precision', fontdict=font_style_axis)
axes[1].legend(loc='center left', frameon=True, edgecolor='black', fancybox=False, fontsize=10)
axes[1].grid(True, linestyle='--', alpha=0.5)

# --------- Título general ---------
fig.suptitle(full_title, backgroundcolor='#095f91', family = 'serif', color='white', fontsize=15, weight='normal', y=1.02)

plt.tight_layout()
#if save_fig:
#    fig.savefig(save_dir + fname + pattern_train_save_name + '.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ###  Reconstrucción de espector de solar $ν_e$ y de Tálio
#
# Seran seleccionados unicamente energias de eventos de neutrinos solar con un predicción X_pred[:,0] > threshold para ver que tan bueno se reconstruye el espectro de neutrinos solares. Los mismo para eventos de Tálio. Asi, podra ser observado en que energias el modelo tiene mas dificultades en acertar predicciones

# %%
# ==== Reconstruct the original test1 dataset ====

original_data_test = scaling_pipeline_test.inverse_transform(df_test1_scaled)

original_data_test_sig = original_data_test[(labels_test == mask_sig)[:,0]]
original_data_test_bkg = original_data_test[(labels_test == mask_bkg)[:,0]]

# Separate sig. and bkg components:
original_data_test_sig = pd.DataFrame(original_data_test_sig, columns = df_test1_scaled.columns)
original_data_test_bkg = pd.DataFrame(original_data_test_bkg, columns = df_test1_scaled.columns)

# Extract physical observables of interest to analyze the model performance:

energy_sig_rc = original_data_test_sig['energy (MeV)'].to_numpy()
energy_bkg_rc = original_data_test_bkg['energy (MeV)'].to_numpy()

norm_vol_sig_rc = original_data_test_sig['norm_vol'].to_numpy()
norm_vol_bkg_rc = original_data_test_bkg['norm_vol'].to_numpy()

vol = posr_cut**3

radi_sig_rc = np.cbrt(norm_vol_sig_rc*vol)
radi_bkg_rc = np.cbrt(norm_vol_bkg_rc*vol)

# %% [markdown]
# ### Normalized Efficiency by N_Counts(true)
#
# Construir un plot de eficicencia normalizada por el numero total de eventos en un bin del plot "Separated Spectrums for Threshold (trh)".
# Procedimientos de construcción:
#
# 1) extraer valores de energia contenidos en cada bin de "Separated Spectrums for Threshold (trh)"
# 2) Contabilizar el nº de eventos que superan el treshold dentro del bin de energia, y dividir por el número de eventos contenido en el bin, esta será la eficiencia normalizado por N_events_true
# 3) Hacer plot de la eficiciencia normalizada en funcion del valor medio de las energias contenida en el bin (cuanto mas bins, mas puntos de eficiencia habra)

# %% [markdown]
# #### Graficos de Energia Reconstruida y de Eficiencia Normalizada para varios Threshold de Predicción del Modelo

# %% [markdown]
# ##### Extraer Información para los Gráficos

# %%
#Idea: A cada loop de thr, agregar a las listas arrays de energia reconstruida y de eficiciencia normalizada, asi cada indice de lista corresponde a un thr

bins_nu = 15             #-> Define how many intervals in energy. Equals to the number of point of norm_eff. PREDEFINED BINS = 20
bins_tl = 8              #-> BINS = 8

thr = [0.90, 0.80, 0.70, 0.60]  #-> Define the thresholds

prob_sas = X_sig_pred[:,0]      #probiblity of the event of neutrino being detected as neutrino
#prob_bab = X_bkg_pred[:,1]      #probiblity of the event of thallium being detected as thallium
prob_bas = X_bkg_pred[:,0]      #probiblity of the event of thallium being detected as neutrino

en_sig_test_count, en_sig_test_edge = np.histogram(energy_sig_rc, bins = bins_nu)   #Extract interval of binned data
en_bkg_test_count, en_bkg_test_edge = np.histogram(energy_bkg_rc, bins = bins_tl)   #Extract interval of binned data

# Extract the binwidth - Expresion only valid for constant binning!
binwidth_en_sig = en_sig_test_edge[2] - en_sig_test_edge[1]  
binwidth_en_bkg = en_bkg_test_edge[2] - en_bkg_test_edge[1]


N_edges_sig = len(en_sig_test_edge)
N_edges_bkg = len(en_bkg_test_edge)

#Information to extract--------------------------------------
nu_energy_in_sas = []
#nu_energy_out_sas = []

tl_energy_in_bas = []
#tl_energy_out_bab = []

#mean normalized eficiency values for signal as signal and bkg as sig
norm_eff_sig_in_sas = []
norm_eff_bkg_in_bas = []

norm_eff_bkg = []

#mean energy within each bin for signal and bkg data
mean_energy_sig = []  
mean_energy_bkg = []   

for thr_i in thr: 

    #Information to save in each loop of threshold --------------
    nu_energy_in_sas_thr = []
    #nu_energy_out_sas_thr = []
    
    tl_energy_in_bas_thr = []
    #tl_energy_out_bas_thr = []

    #normalized eficiency values for signal and bkg for each thr
    #Used to contruct the norm eff plot
    norm_eff_sig_in_sas_thr = np.array([])
    norm_eff_bkg_in_bas_thr = np.array([])

    #mean energy within each bin for signal and bkg data for each thr (aunque acaba siendo el mismo valor medio para cado thr y para los histogramas que preservan el número de bins).
    #Used to contruct the norm eff plot
    mean_energy_sig_thr = np.array([]) 
    mean_energy_bkg_thr = np.array([]) 

    #mean radial values within each bin for signal and bkg data for each thr
    #Used to contruct the norm eff plot
    mean_rad_sig_thr = np.array([]) 
    mean_rad_bkg_thr = np.array([]) 
    
    #----------------------------------------------

    #Extract info for Plot of energy > thr and energy < thr

    #Extract
    for i in np.where(prob_sas >= thr_i)[0]:
        nu_energy_in_sas_thr.append(energy_sig_rc[i])
        
    #for j in np.where(prob_sas < thr_i)[0]:
        #nu_energy_out_sas_thr.append(energy_sig_rc[j])
    
    for m in np.where(prob_bas >= thr_i)[0]:
        tl_energy_in_bas_thr.append(energy_bkg_rc[m])
    
    #for k in np.where(prob_bab < thr_i)[0]:
        #tl_energy_out_spectrum_thr.append(energy_bkg_rc[k])
        
    nu_energy_in_sas.append(np.array(nu_energy_in_sas_thr))
    #nu_energy_out_sas.append(np.array(nu_energy_out_sas_thr))
    tl_energy_in_bas.append(np.array(tl_energy_in_bas_thr))
    #tl_energy_out_bab.append(np.array(tl_energy_out_spectrum_thr))

    #Extract norm_eff and mean nu enery within each bin:
    #1) Extract for solar nu event predictions
    for i in range(N_edges_sig-1):
        #extract edges value of energy at each bin
        energy_edge_i = en_sig_test_edge[i]
        energy_edge_f = en_sig_test_edge[i+1]
    
        #find energy in energy_test_sig between edges values and the model prediction for SAS 
        energy_interval = np.extract((energy_sig_rc >= energy_edge_i) & (energy_sig_rc <= energy_edge_f), energy_sig_rc)
        prob_sas_interval = np.extract((energy_sig_rc >= energy_edge_i) & (energy_sig_rc <= energy_edge_f), prob_sas)
    
        #extract mean energy of binned interval
        mean_energy_interval = np.mean(energy_interval)
        
        mean_energy_sig_thr = np.append(mean_energy_sig_thr, mean_energy_interval)
        
        #Total Number of events we know are true
        N_true = len(prob_sas_interval)
    
        #find where prob. is higher than threshold and count
        condition_thr = prob_sas_interval >= thr_i
        energy_up_thr = np.extract(condition_thr, energy_interval)
        N_up_thr = len(energy_up_thr)
    
        #compute and extract normalized efficiency
        norm_eff_interval = N_up_thr / N_true
        norm_eff_sig_in_sas_thr = np.append(norm_eff_sig_in_sas_thr, norm_eff_interval)

    norm_eff_sig_in_sas.append(norm_eff_sig_in_sas_thr)
    mean_energy_sig.append(mean_energy_sig_thr)
        
    #2) Extract for Tl event predictions
    for i in range(N_edges_bkg-1):
        #extract edges value of energy at each bin
        energy_edge_i = en_bkg_test_edge[i]
        energy_edge_f = en_bkg_test_edge[i+1]
    
        #find energy in energy_test_bkg between edges values and the model prediction for BAS
        energy_interval = np.extract((energy_bkg_rc >= energy_edge_i) & (energy_bkg_rc <= energy_edge_f), energy_bkg_rc)
        prob_bas_interval = np.extract((energy_bkg_rc >= energy_edge_i) & (energy_bkg_rc <= energy_edge_f), prob_bas)
    
        #extract mean energy of binned interval
        mean_energy_interval = np.mean(energy_interval)
        
        mean_energy_bkg_thr = np.append(mean_energy_bkg_thr, mean_energy_interval)
        
        #Total Number of events we know are true
        N_true = len(prob_bas_interval)
    
        #find where prob. is higher than threshold and count
        condition_thr = prob_bas_interval >= thr_i
        energy_up_thr = np.extract(condition_thr, energy_interval)
        N_up_thr = len(energy_up_thr)
    
        #compute and extract normalized efficiency
        norm_eff_interval = N_up_thr / N_true
        norm_eff_bkg_in_bas_thr = np.append(norm_eff_bkg_in_bas_thr, norm_eff_interval)
    
    norm_eff_bkg_in_bas.append(norm_eff_bkg_in_bas_thr)
    mean_energy_bkg.append(mean_energy_bkg_thr)

#Transform lists to array where each arrow correspond to the values of (energy, norm_eff) for a certain thr
mean_energy_sig = np.array(mean_energy_sig)
norm_eff_sig_in_sas = np.array(norm_eff_sig_in_sas)

mean_energy_bkg = np.array(mean_energy_bkg)
norm_eff_bkg_in_bas = np.array(norm_eff_bkg_in_bas)

# %% [markdown]
# #### Construir los Gráficos

# %% [markdown]
# - Energia

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
sn.reset_orig

# ------- Save settings : -------
save_dir = 'figs/Optimized Models/10x10/pipeline_std_minmax/'
fname = 'classified_ev_energy_per_and_eff_per_thr'
pattern_train_save_name = f'E_{energy_inf_cut}_{energy_cut}_MeV_R_{posr_cut}_mm_Delta_({time_res_inf_cut}_{time_res_sup_cut})_ns'

# ------- Superior Title -------
main_title = 'Event Selection through Thresholds on Model Predictions '
train_cut_title = rf'Dim ($\mathcal{{L}}(\Delta, \alpha) = (10,10)$), E$_\text{{train}}$: [{energy_inf_cut}, {energy_cut}] (MeV), R $\leq$ {radial_cut} (mm), $\Delta$: [{time_res_inf_cut}, {time_res_sup_cut}] (ns)'
full_title = main_title + '\n' + train_cut_title

# ------- Font Styles -------
font_style_title = {'family':'serif', 'weight': 'normal','color':'black','size':13}
font_style_axis  = {'family':'serif', 'weight': 'normal','color':'black','size':12}

bas_on = False
alpha = 0

#main plot: Test Solar Energy
fig, axes = plt.subplots(1,2, figsize =(18, 6)) 

sn.histplot(energy_sig_rc, ax = axes[0], bins = bins_nu, color = 'g' , label = r'$^8$B-$ν_e$ Spectrum', alpha = alpha, element = 'step')

for i_dx, thr_i in enumerate(thr):  
    #Sig Spectral distribution
    sn.histplot(nu_energy_in_sas[i_dx], ax = axes[0], bins = bins_nu, color = red_variants[i_dx] , label = r'SAS (thr $\geq$'+str(thr_i)+')', 
                alpha = alpha, element = 'step')

    #Sig Efficiency normalized by N_true counts
    sn.histplot(x = mean_energy_sig[i_dx], ax = axes[1], bins=len(mean_energy_sig[i_dx]), color = red_variants[i_dx], 
                weights=norm_eff_sig_in_sas[i_dx], element = 'step', alpha = 0.0, label = r'$\epsilon_{SAS}$ (thr $\geq$ '+str(thr_i)+')')

    if bas_on:
        #bkg spectra
        sn.histplot(tl_energy_in_bas[i_dx], ax = axes[0], bins = bins_tl, color = blue_variants[i_dx] , label = r'BAS (thr $\geq$'+str(thr_i)+')', 
                    alpha = alpha, element = 'step')

        #bkg efficiency
        ax1_1 = axes[1].twinx()  #Right axis for the norm_eff plot due to differences between eff scales
        sn.histplot(x = mean_energy_bkg[i_dx], ax = ax1_1, bins=len(mean_energy_bkg[i_dx]), color = blue_variants[i_dx], 
                    weights=norm_eff_bkg_in_bas[i_dx], element = 'step', alpha = 0.0, label = r'$\epsilon_{BAS}$ (thr $\geq$ '+str(thr_i)+')')

        ax1_1.legend(loc = 'upper right')
        ax1_1.set_ylabel(r'$\epsilon_{BAS}$', fontdict=font_style_axis)
        ax1_1.tick_params(axis='y', labelcolor='b')
        

axes[0].set_title(r'Spectral Distribution for each threshold (thr) of Model Predictions', fontdict=font_style_title)
axes[0].set_xlabel('Energy (MeV)', fontdict=font_style_axis)
axes[0].set_ylabel(f'Count per {binwidth_en_sig:.2f} MeV', fontdict=font_style_axis)
axes[0].legend(loc = 'upper right', frameon=True, edgecolor='black', fancybox=False, fontsize=9.5)
#axes[0].set_yscale('log')

axes[1].set_title(r'$\epsilon = \frac{N(>thr)}{N_{true}}$', fontdict=font_style_title)
axes[1].set_xlabel('Energy (MeV)', fontdict=font_style_axis)
axes[1].set_ylabel(rf'$\epsilon_{{SAS}}$ per {binwidth_en_sig:.2f} MeV', fontdict=font_style_axis)
axes[1].legend(loc = 'lower center', frameon=True, edgecolor='black', fancybox=False, fontsize=9.5)
axes[1].tick_params(axis='y', labelcolor='r')
axes[1].set_yscale('log')

plt.suptitle(full_title, backgroundcolor='#095f91', family = 'serif', color='white', fontsize=13, weight='normal', y=1.05)

#if save_fig:
#    fig.savefig(save_dir + fname + pattern_train_save_name + '.png', dpi=300, bbox_inches='tight')
    
plt.show()

# %%
# Mean eficiency calculation in [2.5,10] for each thr in SAS

mean_eff = []  # List with the values of the mean efficicency for each threshold in energy within a range [2.5,10] MeV
eff_error = [] # list with the error value associated to hte mean_eff by the maximum desviation.
results = []   # List with explicit result of the thr and mean value of efficiency

for i_dx, thr_i in enumerate(thr):

    eff_sas_thr = norm_eff_sig_in_sas[i_dx]
    energy_sas_thr = mean_energy_sig[i_dx]
    
    #Extract the values of efficiency which verifies the energy cut
    condition = (energy_sas_thr <= 10)
    eff_sas_filter = np.extract(condition, eff_sas_thr)

    #Obtain mean value as the mean percentage of events in thr which are truly solar nu
    mean_eff_sas_thr = np.mean(eff_sas_filter, dtype = np.float16)
    mean_eff.append(mean_eff_sas_thr)

    #Compute the eff error by the maximum deviation of the samples from the mean value
    deviations = abs(eff_sas_thr -  mean_eff_sas_thr)
    max_deviation = np.max(deviations)
    eff_error.append(max_deviation)

    result_thr = 'For thr='+str(thr_i) + r', the eff for SAS is = ' + str(mean_eff_sas_thr) + ' with an error of ' + str(max_deviation)
    results.append(result_thr)

# %%
results
# Out:
# ['For thr=0.9, the eff for SAS is = 0.3093 with an error of 0.6698714507104383',
#  'For thr=0.8, the eff for SAS is = 0.4053 with an error of 0.5858112578937593',
#  'For thr=0.7, the eff for SAS is = 0.4895 with an error of 0.5075262786729198',
#  'For thr=0.6, the eff for SAS is = 0.5806 with an error of 0.44204648215132825']

# %% [markdown]
# - Radius

# %%
#Idea: A cada loop de thr, agregar a las listas arrays de energia reconstruida y de eficiciencia normalizada, asi cada indice de lista corresponde a un thr

bins_rad = 20            #-> BINS = 20
thr = [0.95, 0.8, 0.70]  #-> Define the thresholds

prob_sas = X_sig_pred[:,0]
prob_bas = X_bkg_pred[:,0]

rad_sig_test_count, rad_sig_test_edge = np.histogram(radi_sig_rc, bins = bins_rad)
rad_bkg_test_count, rad_bkg_test_edge = np.histogram(radi_bkg_rc, bins = bins_rad)

N_edges= len(rad_sig_test_edge)

#mean normalized eficiency values for signal and bkg
norm_eff_sig_in_sas = []
norm_eff_bkg_in_bas = []  

#mean radial values within each bin for signal and bkg data
mean_rad_sig = []
mean_rad_bkg = []

for thr_i in thr: 

    #mean normalized eficiency values for signal and bkg for each thr
    norm_eff_sig_in_sas_thr = np.array([])
    norm_eff_bkg_in_bas_thr = np.array([])
    
    #mean radial values within each bin for signal and bkg data for each thr
    mean_rad_sig_thr = np.array([]) 
    mean_rad_bkg_thr = np.array([]) 
    
    #----------------------------------------------

    #Extract norm_eff and mean radius within each bin:
    #1) Extract for solar nu event predictions
    for i in range(N_edges-1):
        #extract edges value of energy at each bin
        radi_edge_i = rad_sig_test_edge[i]
        radi_edge_f = rad_sig_test_edge[i+1]
    
        #find energy in energy_test_sig and energy_test_bkg between edges values is and the model prediction
        radi_interval = np.extract((radi_sig_rc >= radi_edge_i) & (radi_sig_rc <= radi_edge_f), radi_sig_rc)
        prob_sas_interval = np.extract((radi_sig_rc >= radi_edge_i) & (radi_sig_rc <= radi_edge_f), prob_sas)
    
        #extract and save the mean radi of binned interval
        mean_rad_interval = np.mean(radi_interval)
        mean_rad_sig_thr = np.append(mean_rad_sig_thr, mean_rad_interval)
        
        #Total Number of events we know are true
        N_true = len(prob_sas_interval)
    
        #find where prob. is higher than threshold and count
        condition_thr = prob_sas_interval >= thr_i
        radi_up_thr = np.extract(condition_thr, radi_interval)
        N_up_thr = len(radi_up_thr)
    
        #compute and extract normalized efficiency
        norm_eff_interval = N_up_thr / N_true
        norm_eff_sig_in_sas_thr = np.append(norm_eff_sig_in_sas_thr, norm_eff_interval)

    norm_eff_sig_in_sas.append(norm_eff_sig_in_sas_thr)
    mean_rad_sig.append(mean_rad_sig_thr)
        
    #2) Extract for Tl event predictions
    for i in range(N_edges-1):
        #extract edges value of radius at each bin
        radi_edge_i = rad_bkg_test_edge[i]
        radi_edge_f = rad_bkg_test_edge[i+1]
    
        #find energy in energy_test_sig and energy_test_bkg between edges values is and the model prediction
        radi_interval = np.extract((radi_bkg_rc >= radi_edge_i) & (radi_bkg_rc <= radi_edge_f), radi_bkg_rc)
        prob_bas_interval = np.extract((radi_bkg_rc >= radi_edge_i) & (radi_bkg_rc <= radi_edge_f), prob_bas)
    
        #extract and save the mean radi of binned interval
        mean_rad_interval = np.mean(radi_interval)
        mean_rad_bkg_thr = np.append(mean_rad_bkg_thr, mean_rad_interval)
        
        #Total Number of events we know are true
        N_true = len(prob_bas_interval)
    
        #find where prob. is higher than threshold and count
        condition_thr = prob_bas_interval >= thr_i
        radi_up_thr = np.extract(condition_thr, radi_interval)
        N_up_thr = len(radi_up_thr)
    
        #compute and extract value of normalized efficiency for each bin
        norm_eff_interval = N_up_thr / N_true
        norm_eff_bkg_in_bas_thr = np.append(norm_eff_bkg_in_bas_thr, norm_eff_interval)
    
    norm_eff_bkg_in_bas.append(norm_eff_bkg_in_bas_thr)
    mean_rad_bkg.append(mean_rad_bkg_thr)
    

#Transform lists to array where each arrow correspond to the values of (energy, norm_eff) for a certain thr
mean_rad_sig = np.array(mean_rad_sig)
norm_eff_sig_in_sas = np.array(norm_eff_sig_in_sas)

mean_rad_bkg = np.array(mean_rad_bkg)
norm_eff_bkg_in_bas = np.array(norm_eff_bkg_in_bas)

# %%
bas_on = False

#main plot: Test Solar radius vs. Normalized efficiency
fig, axes_1 = plt.subplots(figsize =(8, 6))
axes_2 = axes_1.twinx()

for i_dx, thr_i in enumerate(thr):  
    #Sig Efficiency normalized by N_true counts
    sn.histplot(x = mean_rad_sig[i_dx], ax = axes_1,bins = len(mean_rad_sig[i_dx]), color = red_variants[i_dx], 
                weights = norm_eff_sig_in_sas[i_dx], element = 'step', alpha = 0.0, label = r'$\epsilon_{SAS}$(thr $\geq$ '+str(thr_i)+')')

    if bas_on:
        #bkg efficiency
        sn.histplot(x = mean_rad_bkg[i_dx], ax = axes_2, bins=len(mean_rad_bkg[i_dx]), color = blue_variants[i_dx], kde=False,
                    weights = norm_eff_bkg_in_bas[i_dx], element = 'step', alpha = 0.0, label = r'$\epsilon_{BAS}$(thr $\geq$ '+str(thr_i)+')')
        

plt.suptitle('Energy: [2.5,12] MeV - R < 5500 (mm)', fontsize = 10)
axes_1.set_title(r'$\epsilon = \frac{N(>thr)}{N_{true}}$', fontsize = 12)
axes_1.legend(loc = 'lower center')
axes_2.legend(loc = 'center right')

axes_1.tick_params(axis='y', labelcolor='r')
axes_2.tick_params(axis='y', labelcolor='b')


axes_1.set_xlabel('Radius (mm)')
axes_1.set_ylabel(r'$\epsilon_{SAS}$', fontsize = 14)
axes_2.set_ylabel(r'$\epsilon_{BAS}$', fontsize = 14)

#axes_1.set_xlim(0, 5500.0)
#axes_2.set_ylim(0, np.max(norm_eff_bkg_in_bas) + 0.15)
#axes_1.set_yscale('log')

#if bas_on:
#    plt.savefig('figs/Optimized Models/10x10/Radial_sig_bkg_thr_and_Norm_eff.png', format = 'png', bbox_inches = 'tight')
#else:
#    plt.savefig('figs/Optimized Models/10x10/Radial_thr_and_Norm_eff.png', format = 'png', bbox_inches = 'tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
