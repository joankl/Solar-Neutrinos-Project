# %% [markdown]
# # Notebook Dedicated to Contrust Hand-craft Deep Learning Models - Define by hand the architecture and hyperparms.

# %%
#import uproot
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm

import seaborn as sn
import pandas as pd

from sklearn.preprocessing import FunctionTransformer, StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, concatenate, Dropout, BatchNormalization, Activation
from keras.losses import BinaryCrossentropy
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.utils import shuffle
import optuna
from keras.backend import clear_session

# %% [markdown]
# # Useful Functions

# %% [markdown]
# ## Multi-color Generator

# %%
import colorsys
# Función para generar variantes más claras y más oscuras de un color
def generate_color_variants(base_color, num_variants, factor = 0.3):
    # Convertir el color base a valores de HSV
    r, g, b = base_color
    h, l, s = colorsys.rgb_to_hls(r, g, b)
    
    # Generar variantes
    variants = []
    for i in range(1, num_variants + 1):
        # Hacer el color más claro
        lighter = colorsys.hls_to_rgb(h, min(1, l * (1 + factor * i)), s)
        # Hacer el color más oscuro
        darker = colorsys.hls_to_rgb(h, max(0, l * (1 - factor * i)), s)
        variants.append(lighter)
        variants.append(darker)
        
    return variants

# Color base (rojo)
base_red = (1, 0, 0) # RGB para rojo puro
# Color base (azuk)
base_blue = (0, 0, 1) # RGB para azul puro
num_variants = 5

red_variants = generate_color_variants(base_red, num_variants)
blue_variants = generate_color_variants(base_blue, num_variants)

# %% [markdown]
# # Load Data

# %%
image_dim = (10, 10)

#Directories
train_dataset_dir = "E:/Data/solars/mc/ML Data/Train/pd_dataframe/df_10_5500_(2.5_14)_(-5_7).csv"
test_dataset_dir = "E:/Data/solars/mc/ML Data/Test/pd_dataframe/df_10_5500_(2.5_14)_(-5_7).csv"

#Load in Pandas  DataFrame
df_train = shuffle(pd.read_csv(train_dataset_dir))
df_test = shuffle(pd.read_csv(test_dataset_dir))

# %%
df_train.describe()
# Out:
#             pixel_0       pixel_1       pixel_2       pixel_3       pixel_4  \
# count  1.349021e+06  1.349021e+06  1.349021e+06  1.349021e+06  1.349021e+06
# mean   9.993543e-02  9.980577e-02  1.005760e-01  1.043642e-01  1.059846e-01
# std    6.464745e-02  8.595156e-02  1.630611e-01  2.294494e-01  2.108756e-01
# min    2.500000e-11  1.428571e-11  9.090909e-12  5.555556e-12  2.564103e-12
# 25%    1.000000e-01  1.000000e-01  1.000000e-10  3.333333e-11  1.111111e-11
# 50%    1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-10  2.500000e-11
# 75%    1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-01
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#             pixel_5       pixel_6       pixel_7       pixel_8       pixel_9  \
# count  1.349021e+06  1.349021e+06  1.349021e+06  1.349021e+06  1.349021e+06
# mean   1.048672e-01  1.035444e-01  1.025265e-01  1.017616e-01  1.009763e-01
# std    1.741944e-01  1.494614e-01  1.303658e-01  1.140813e-01  1.008402e-01
# min    1.190476e-12  7.751938e-13  5.847953e-13  5.617978e-13  5.714286e-13
# 25%    5.555556e-12  3.846154e-12  4.545455e-12  2.040816e-02  2.702703e-02
# 50%    1.666667e-11  3.703704e-02  5.000000e-02  6.060606e-02  6.818182e-02
# 75%    1.428571e-01  1.470588e-01  1.481481e-01  1.463415e-01  1.428571e-01
# max    1.000000e+00  1.000000e+00  9.062500e-01  8.800000e-01  8.709677e-01
#
#        ...      pixel_94      pixel_95      pixel_96      pixel_97  \
# count  ...  1.349021e+06  1.349021e+06  1.349021e+06  1.349021e+06
# mean   ...  1.008739e-01  1.000148e-01  9.908965e-02  9.825741e-02
# std    ...  2.009989e-01  1.661818e-01  1.431982e-01  1.257707e-01
# min    ...  2.564103e-12  1.234568e-12  7.812500e-13  6.250000e-13
# 25%    ...  1.111111e-11  5.555556e-12  3.846154e-12  4.166667e-12
# 50%    ...  2.500000e-11  1.666667e-11  3.703704e-02  4.705882e-02
# 75%    ...  1.000000e-01  1.428571e-01  1.428571e-01  1.410256e-01
# max    ...  1.000000e+00  1.000000e+00  1.000000e+00  8.888889e-01
#
#            pixel_98      pixel_99  energy (MeV)   radius (mm)          IsNu  \
# count  1.349021e+06  1.349021e+06  1.349021e+06  1.349021e+06  1.349021e+06
# mean   9.783097e-02  9.800693e-02  4.772251e+00  4.096566e+03  7.322051e-01
# std    1.109717e-01  9.900637e-02  1.813391e+00  1.072851e+03  4.428103e-01
# min    5.434783e-13  5.434783e-13  2.500002e+00  3.176235e+01  0.000000e+00
# 25%    1.923077e-02  2.564103e-02  3.468300e+00  3.424202e+03  0.000000e+00
# 50%    5.714286e-02  6.521739e-02  4.118018e+00  4.333190e+03  1.000000e+00
# 75%    1.403509e-01  1.388889e-01  5.759998e+00  4.976413e+03  1.000000e+00
# max    8.536585e-01  7.826087e-01  1.199876e+01  5.500000e+03  1.000000e+00
#
#                IsTl
# count  1.349021e+06
# mean   2.677949e-01
# std    4.428103e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.000000e+00
# max    1.000000e+00
#
# [8 rows x 104 columns]

# %%
df_test.describe()
# Out:
#             pixel_0       pixel_1       pixel_2       pixel_3       pixel_4  \
# count  1.058530e+05  1.058530e+05  1.058530e+05  1.058530e+05  1.058530e+05
# mean   1.002283e-01  9.979783e-02  9.958949e-02  1.028242e-01  1.041983e-01
# std    6.668651e-02  9.169222e-02  1.683634e-01  2.276104e-01  2.074007e-01
# min    2.500000e-11  1.666667e-11  1.111111e-11  5.882353e-12  2.857143e-12
# 25%    1.000000e-01  1.000000e-01  1.000000e-10  3.333333e-11  1.111111e-11
# 50%    1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-10  2.500000e-11
# 75%    1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-01
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#             pixel_5       pixel_6       pixel_7       pixel_8       pixel_9  \
# count  1.058530e+05  1.058530e+05  1.058530e+05  1.058530e+05  1.058530e+05
# mean   1.029729e-01  1.022066e-01  1.012160e-01  1.009131e-01  1.005162e-01
# std    1.711965e-01  1.480433e-01  1.297756e-01  1.145044e-01  1.017684e-01
# min    1.333333e-12  8.403361e-13  6.666667e-13  5.952381e-13  5.714286e-13
# 25%    5.555556e-12  3.846154e-12  4.000000e-12  2.000000e-02  2.564103e-02
# 50%    1.428571e-11  3.703704e-02  4.761905e-02  5.882353e-02  6.666667e-02
# 75%    1.428571e-01  1.428571e-01  1.445783e-01  1.428571e-01  1.428571e-01
# max    1.000000e+00  9.259259e-01  8.000000e-01  7.843137e-01  7.297297e-01
#
#        ...      pixel_94      pixel_95      pixel_96      pixel_97  \
# count  ...  1.058530e+05  1.058530e+05  1.058530e+05  1.058530e+05
# mean   ...  1.006398e-01  1.006360e-01  9.977991e-02  9.943178e-02
# std    ...  1.990196e-01  1.656662e-01  1.434477e-01  1.266235e-01
# min    ...  2.857143e-12  1.351351e-12  9.009009e-13  6.493506e-13
# 25%    ...  1.111111e-11  5.882353e-12  4.000000e-12  4.166667e-12
# 50%    ...  2.500000e-11  1.666667e-11  3.846154e-02  4.761905e-02
# 75%    ...  1.000000e-01  1.428571e-01  1.428571e-01  1.428571e-01
# max    ...  1.000000e+00  1.000000e+00  9.310345e-01  9.111111e-01
#
#            pixel_98      pixel_99   energy (MeV)    radius (mm)          IsNu  \
# count  1.058530e+05  1.058530e+05  105853.000000  105853.000000  105853.00000
# mean   9.917479e-02  9.910808e-02       4.442687    4100.569736       0.51768
# std    1.123855e-01  1.006284e-01       1.620965    1074.302059       0.49969
# min    5.586592e-13  5.917160e-13       2.500107      44.561459       0.00000
# 25%    2.000000e-02  2.500000e-02       3.429666    3429.710693       0.00000
# 50%    5.882353e-02  6.578947e-02       3.873336    4338.892578       1.00000
# 75%    1.428571e-01  1.395349e-01       4.873020    4980.766602       1.00000
# max    7.837838e-01  7.428571e-01      11.995671    5499.963379       1.00000
#
#                IsTl
# count  105853.00000
# mean        0.48232
# std         0.49969
# min         0.00000
# 25%         0.00000
# 50%         0.00000
# 75%         1.00000
# max         1.00000
#
# [8 rows x 104 columns]

# %% [markdown]
# # Information Check on Norm($\Delta\alpha$) Images of 8B-$\nu_e$ and 208-Tl

# %%
#Separate the solar_nue data from 208-Tl for train and test dataset
dataset_nue_train = (df_train[df_train['IsNu'] == 1]).reset_index()
dataset_208tl_train = (df_train[df_train['IsTl'] == 1]).reset_index()

dataset_nue_test = (df_train[df_train['IsNu'] == 1]).reset_index()
dataset_208tl_test = (df_train[df_train['IsTl'] == 1]).reset_index()

#Extract the pixels values of the normalized delta-alpha imaged and transform to np.array
pixels_nue_train = np.array(dataset_nue_train.filter(regex=pixel_pattern))
pixels_208tl_train = np.array(dataset_208tl_train.filter(regex=pixel_pattern))

pixels_nue_test = np.array(dataset_nue_test.filter(regex=pixel_pattern))
pixels_208tl_test = np.array(dataset_208tl_test.filter(regex=pixel_pattern))

#Recover the high-stat Delta-alpha distributions for solarnue and 208-Tl for train and test
DeltaAlpha_nue_train = np.sum(pixels_nue_train, axis = 0).reshape(10,10)
DeltaAlpha_208tl_train = np.sum(pixels_208tl_train, axis = 0).reshape(10,10)

DeltaAlpha_nue_test = np.sum(pixels_nue_test, axis = 0).reshape(10,10)
DeltaAlpha_208tl_test = np.sum(pixels_208tl_test, axis = 0).reshape(10,10)

#Plot: Just choose which image you want to observe
plt.imshow(DeltaAlpha_nue_train)

# Añadir los índices sobre cada celda
num_rows, num_cols = DeltaAlpha_nue_test.shape
for i in range(num_rows):
    for j in range(num_cols):
        text = f"({i},{j})"
        plt.text(j, i, text, ha='center', va='center', color='white', fontsize=8)

plt.colorbar()
plt.show()

# %% [markdown]
# # Data Procesing

# %% [markdown]
# ## Extract information and Define Energy Cuts

# %%
pixel_pattern = r'^pixel_\d+$'

energy_cut_train = 7
energy_cut_test = 7

# %% [markdown]
# ### Extract Trainning Data

# %%
#Separate signal from background 
dataset_sig_train = (df_train[df_train['IsNu'] == 1]).reset_index()
dataset_bkg_train = (df_train[df_train['IsTl'] == 1]).reset_index()

#cut in solar energy
dataset_sig_train = (dataset_sig_train[dataset_sig_train['energy (MeV)'] <= energy_cut_train])

#Igualar cantidad de datos de neutrinos solares y de Tálio
N_solar_ev = dataset_sig_train.shape[0]
N_Tl_ev = dataset_bkg_train.shape[0]

if N_solar_ev > N_Tl_ev:
    dataset_sig_train = (dataset_sig_train.iloc[:N_Tl_ev, :]).reset_index()

else:
    dataset_bkg_train = (dataset_bkg_train.iloc[:N_solar_ev, :]).reset_index()
    
# Separate Features for signal and background: Useful for plots
df_pixel_sig_train = dataset_sig_train.filter(regex=pixel_pattern)
df_energy_sig_train = (dataset_sig_train[['energy (MeV)']])
df_radi_sig_train = (dataset_sig_train[['radius (mm)']])
df_label_sig_train = pd.DataFrame(dataset_sig_train, columns = ['IsNu', 'IsTl'])

df_pixel_bkg_train = dataset_bkg_train.filter(regex=pixel_pattern)
df_energy_bkg_train = (dataset_bkg_train[['energy (MeV)']])
df_radi_bkg_train = (dataset_bkg_train[['radius (mm)']])
df_label_bkg_train = pd.DataFrame(dataset_bkg_train, columns = ['IsNu', 'IsTl'])

# Also save the join bkg+sig datasets and its labels to perform the standard scaler overall data
df_pixel_train = pd.concat([df_pixel_sig_train, df_pixel_bkg_train])
df_energy_train = pd.concat([df_energy_sig_train, df_energy_bkg_train])
df_radi_train = pd.concat([df_radi_sig_train, df_radi_bkg_train])
df_labels_train = pd.concat([df_label_sig_train, df_label_bkg_train])
labels_train = np.array(df_labels_train)

# %% [markdown]
# ### Extract Test Data

# %%
equal_evs = True #Cambiar a True para Igualar eventos de 208-Tl y Solar Nu en test dataset!

#Separate signal from background 
dataset_sig_test = (df_test[df_test['IsNu'] == 1])
dataset_bkg_test = (df_test[df_test['IsTl'] == 1])

#cut in solar energy
dataset_sig_test = (dataset_sig_test[dataset_sig_test['energy (MeV)'] <= energy_cut_test])

if equal_evs:
    #Igualar cantidad de datos de neutrinos solares y de Tálio
    N_solar_ev = dataset_sig_test.shape[0]
    N_Tl_ev = dataset_bkg_test.shape[0]
    
    if N_solar_ev > N_Tl_ev:
        dataset_sig_test = (dataset_sig_test.iloc[:N_Tl_ev, :]).reset_index()
    
    else:
        dataset_bkg_test = (dataset_bkg_test.iloc[:N_solar_ev, :]).reset_index()

df_test_cut = shuffle(pd.concat([dataset_sig_test, dataset_bkg_test]))
        

#Separate Features
df_pixel_test = df_test_cut.filter(regex=pixel_pattern)
df_energy_test = df_test_cut[['energy (MeV)']]
df_radi_test = df_test_cut[['radius (mm)']]
df_labels_test = pd.DataFrame(df_test_cut, columns = ['IsNu', 'IsTl'])
labels_test = np.array(df_labels_test)

# %%
np.max(df_pixel_train)
# Out:
# 0.9999999999590916

# %% [markdown]
# ## Data Transformation
#
# Choose a Data Transformation Option by running the corresponding cell

# %% [markdown]
# ### Identity Transform - NOT WORKNING FOR NOW!

# %%
scaler_pixels_train = FunctionTransformer()
scaler_energy_train = FunctionTransformer()
scaler_position_train = FunctionTransformer()

# Test Transformation History
scaler_pixels_test = FunctionTransformer() 
scaler_energy_test = FunctionTransformer()
scaler_position_test = FunctionTransformer()

# %% [markdown]
# ### Standard Scaler

# %%
# Train Transformation History
scaler_pixels_train = StandardScaler() 
scaler_energy_train = StandardScaler()
scaler_position_train = StandardScaler()

# Test Transformation History
scaler_pixels_test = StandardScaler() 
scaler_energy_test = StandardScaler() 
scaler_position_test = StandardScaler()

# %% [markdown]
# ### MinMax Scaler

# %%
# Train Transformation History
epsilon = 1e-2
min_val = np.min(df_pixel_train) + epsilon # equals to zero + epsilon
max_val = np.max(df_pixel_train) + epsilon # equals to one

#scaler_pixels_train = MinMaxScaler(feature_range=(min_val, max_val)) 
scaler_energy_train = MinMaxScaler(feature_range=(min_val, max_val))
scaler_position_train = MinMaxScaler(feature_range=(min_val, max_val))

# Test Transformation History
scaler_pixels_test = MinMaxScaler(feature_range=(min_val, max_val)) 
scaler_energy_test = MinMaxScaler(feature_range=(min_val, max_val)) 
scaler_position_test = MinMaxScaler(feature_range=(min_val, max_val))

# %% [markdown]
# ### Pipeline MinMaxScaler(StandardScaler())

# %%
# Train Transformation History

#Intervals for MinMax Scaler ------------------------------------
epsilon = 1e-2
min_val = np.min(df_pixel_train) + epsilon # equals to zero + epsilon
max_val = np.max(df_pixel_train) + epsilon # equals to one + epsilon
# ---------------------------------------------------------------

scaler_pixels_train = Pipeline([('standardization', StandardScaler()),
                                ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])
scaler_energy_train = Pipeline([('standardization', StandardScaler()),
                                ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])
scaler_position_train = Pipeline([('standardization', StandardScaler()),
                                ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])
# Test Transformation History
scaler_pixels_test = Pipeline([('standardization', StandardScaler()),
                                ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])
scaler_energy_test = Pipeline([('standardization', StandardScaler()),
                               ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])
scaler_position_test = Pipeline([('standardization', StandardScaler()),
                                 ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])

# %% [markdown]
# ### Train Dataset Transformation

# %%
#pixel_train_transf = scaler_pixels_train.fit_transform(df_pixel_train)
pixel_train_transf = np.array(df_pixel_train) + epsilon
energy_train_transf = scaler_energy_train.fit_transform(df_energy_train).T[0]

#radial position to volume normalization Transformation
vol = 5500**3 
position_train_transf_volnorm = (np.array(df_radi_train).T[0]**3)/vol

position_train_transf = scaler_position_train.fit_transform(position_train_transf_volnorm.reshape(-1, 1)).T[0]

# %%
energy_train_transf.shape
# Out:
# (722522,)

# %% [markdown]
# ### Test Dataset Transformation

# %%
#pixel_test_transf = scaler_pixels_test.fit_transform(df_pixel_test)
pixel_test_transf = np.array(df_pixel_test) + epsilon
energy_test_transf = scaler_energy_test.fit_transform(df_energy_test).T[0]

#radial position to volume normalization Transformationm
vol = 5500**3 
position_test_transf_volnorm = (np.array(df_radi_test).T[0]**3)/vol

position_test_transf = scaler_position_test.fit_transform(position_test_transf_volnorm.reshape(-1, 1)).T[0]

# %% [markdown]
# ### Separation of sig from bkg in the Train and Test Datasets

# %%
#Separar sig from bkg and train from test
IsNu = np.array([1,0])
IsTl = np.array([0,1])

#Train: Separation sig from bkg
pixel_train_transf_sig = pixel_train_transf[np.array(df_labels_train == IsNu)[:,0]]
pixel_train_transf_bkg = pixel_train_transf[np.array(df_labels_train == IsTl)[:,0]]

energy_train_transf_sig = energy_train_transf[np.array(df_labels_train == IsNu)[:,0]]
energy_train_transf_bkg = energy_train_transf[np.array(df_labels_train == IsTl)[:,0]]

position_train_transf_sig = position_train_transf[np.array(df_labels_train == IsNu)[:,0]]
position_train_transf_bkg = position_train_transf[np.array(df_labels_train == IsTl)[:,0]]

#Test: Separation sig from bkg
pixel_test_transf_sig = pixel_test_transf[np.array(df_labels_test == IsNu)[:,0]]
pixel_test_transf_bkg = pixel_test_transf[np.array(df_labels_test == IsTl)[:,0]]

pixel_test_transf_sig = pixel_test_transf[np.array(df_labels_test == IsNu)[:,0]]
pixel_test_transf_bkg = pixel_test_transf[np.array(df_labels_test == IsTl)[:,0]]

energy_test_transf_sig = energy_test_transf[np.array(df_labels_test == IsNu)[:,0]]
energy_test_transf_bkg = energy_test_transf[np.array(df_labels_test == IsTl)[:,0]]

position_test_transf_sig = position_test_transf[np.array(df_labels_test == IsNu)[:,0]]
position_test_transf_bkg = position_test_transf[np.array(df_labels_test == IsTl)[:,0]]

labels_test_sig = labels_test[np.array(labels_test == IsNu)[:,0]]
labels_test_bkg = labels_test[np.array(labels_test == IsTl)[:,0]]

# %% [markdown]
# ### Plots of the Transformed Features and Datasets

# %% [markdown]
# #### Pixels 2D Images

# %%
DeltaAlpha_sig_train_transf = np.sum(pixel_train_transf_sig, axis = 0).reshape(10,10)
DeltaAlpha_bkg_train_transf = np.sum(pixel_train_transf_bkg, axis = 0).reshape(10,10)

#Plot: Just choose which image you want to observe
plt.imshow(DeltaAlpha_sig_train_transf)

# Añadir los índices sobre cada celda
num_rows, num_cols = DeltaAlpha_nue_test.shape
for i in range(num_rows):
    for j in range(num_cols):
        text = f"({i},{j})"
        plt.text(j, i, text, ha='center', va='center', color='white', fontsize=8)

plt.colorbar()
plt.show()

# %% [markdown]
# #### Pixel_i Distributions

# %%
bins_pxl = 40

N_pixels = pixel_train_transf_bkg.shape[1]
for pixel_i in range(N_pixels):
    pixel_i_train_sig = pixel_train_transf_sig[:,pixel_i]
    pixel_i_train_bkg = pixel_train_transf_bkg[:,pixel_i]

    fig, axes = plt.subplots(1, 2,  figsize=(18, 6))
    sn.histplot(pixel_i_train_sig, ax = axes[0], bins = bins_pxl, color = red_variants[0], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ train')
    sn.histplot(pixel_i_train_bkg, ax = axes[1], bins = bins_pxl, color = blue_variants[0], element = 'step', alpha = 0, label = '208-Tl train')

    axes[0].set_yscale('log')
    axes[0].set_xlabel(f'pixel_{pixel_i} Transformed Values')
    axes[0].set_xlim(0, 1 + epsilon)
    
    axes[1].set_yscale('log')
    axes[1].set_xlabel(f'pixel_{pixel_i} Transformed Values')
    axes[1].set_xlim(0, 1 + epsilon)

    

    plt.show()

# %% [markdown]
# #### Energy and Position

# %%
binwidth_en = 0.02
binwidth_rad = 0.05

fig, axes = plt.subplots(1, 2,  figsize=(18, 6))

#Energy Plots
sn.histplot(energy_train_transf_sig, ax = axes[0], binwidth = binwidth_en, color = red_variants[0], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ train')
sn.histplot(energy_test_transf_sig, ax = axes[0], binwidth = binwidth_en, color = red_variants[1], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ test')
sn.histplot(energy_train_transf_bkg, ax = axes[0], binwidth = binwidth_en, color = blue_variants[0], element = 'step', alpha = 0, label = '208-Tl train')
sn.histplot(energy_test_transf_bkg, ax = axes[0], binwidth = binwidth_en, color = blue_variants[1], element = 'step', alpha = 0, label = '208-Tl test')

#Radial Plots
sn.histplot(position_train_transf_sig, ax = axes[1], binwidth = binwidth_rad, color = red_variants[0], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ train')
sn.histplot(position_test_transf_sig, ax = axes[1], binwidth = binwidth_rad, color = red_variants[1], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ test')
sn.histplot(position_train_transf_bkg, ax = axes[1], binwidth = binwidth_rad, color = blue_variants[0], element = 'step', alpha = 0, label = '208-Tl train')
sn.histplot(position_test_transf_bkg, ax = axes[1], binwidth = binwidth_rad, color = blue_variants[1], element = 'step', alpha = 0, label = '208-Tl test')

axes[0].set_xlabel('Energy (MeV)')
axes[0].legend(loc='upper right')
axes[0].set_title('Energy Distribution', fontsize = 11)
axes[0].set_yscale('log')

axes[1].set_xlabel(r'$(R_\text{ev}/R_\text{cut})^{3}$')
axes[1].legend(loc='upper right')
axes[1].set_title(r'Normalized Volume Distribution - $R_\text{cut} = $5500 (mm)', fontsize = 11)
#axes[1].set_ylim(500, 10000)

#plt.savefig('figs/Optimized Models/10x10/Std_Rad_Norm_Vol and Std_Scaler_default Solar Energy/MLM4_5500_(2.5_12)_(-5_7)_aucOP_test_split/split_test_energy.png', format = 'png', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## For Last, Extract a Validation Dataset to be implemented in the Model

# %%
pixel_train1_transf, pixel_val_transf, \
energy_train1_transf, energy_val_transf, \
position_train1_transf, position_val_transf, \
labels_train1, labels_val = train_test_split(pixel_train_transf, energy_train_transf, position_train_transf,
                                            labels_train, test_size = 0.3,
                                            stratify = labels_train,
                                            random_state=42)

# %% [markdown]
# ### Plots with Validation Dataset split

# %%
#Separar sig from bkg in new train1 and validation
IsNu = np.array([1,0])
IsTl = np.array([0,1])

sig_mask_train = np.all(labels_train1 == IsNu, axis=1)
bkg_mask_train = np.all(labels_train1 == IsTl, axis=1)

sig_mask_val = np.all(labels_val == IsNu, axis=1)
bkg_mask_val = np.all(labels_val == IsTl, axis=1)

#Train: Separation sig from bkg
pixel_train1_transf_sig = pixel_train1_transf[sig_mask_train]
pixel_train1_transf_bkg = pixel_train1_transf[bkg_mask_train]

energy_train1_transf_sig = energy_train1_transf[sig_mask_train]
energy_train1_transf_bkg = energy_train1_transf[bkg_mask_train]

position_train1_transf_sig = position_train1_transf[sig_mask_train]
position_train1_transf_bkg = position_train1_transf[bkg_mask_train]

#Validation: Separation sig from bkg
pixel_val_transf_sig = pixel_val_transf[sig_mask_val]
pixel_val_transf_bkg = pixel_val_transf[bkg_mask_val]

energy_val_transf_sig = energy_val_transf[sig_mask_val]
energy_val_transf_bkg = energy_val_transf[bkg_mask_val]

position_val_transf_sig = position_val_transf[sig_mask_val]
position_val_transf_bkg = position_val_transf[bkg_mask_val]

# %%
binwidth_en = 0.02
binwidth_rad = 0.05

fig, axes = plt.subplots(1, 2,  figsize=(18, 6))

#Energy Plots
sn.histplot(energy_train1_transf_sig, ax = axes[0], binwidth = binwidth_en, color = red_variants[0], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ train')
sn.histplot(energy_val_transf_sig, ax = axes[0], binwidth = binwidth_en, color = red_variants[1], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ validation')
sn.histplot(energy_test_transf_sig, ax = axes[0], binwidth = binwidth_en, color = red_variants[2], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ test')
sn.histplot(energy_train1_transf_bkg, ax = axes[0], binwidth = binwidth_en, color = blue_variants[0], element = 'step', alpha = 0, label = '208-Tl train')
sn.histplot(energy_val_transf_bkg, ax = axes[0], binwidth = binwidth_en, color = blue_variants[1], element = 'step', alpha = 0, label = '208-Tl validation')
sn.histplot(energy_test_transf_bkg, ax = axes[0], binwidth = binwidth_en, color = blue_variants[2], element = 'step', alpha = 0, label = '208-Tl test')

#Radial Plots
sn.histplot(position_train1_transf_sig, ax = axes[1], binwidth = binwidth_rad, color = red_variants[0], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ train')
sn.histplot(position_val_transf_sig, ax = axes[1], binwidth = binwidth_rad, color = red_variants[1], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ validation')
sn.histplot(position_test_transf_sig, ax = axes[1], binwidth = binwidth_rad, color = red_variants[2], element = 'step', alpha = 0, label = r'Solar $^8$B-$\nu_e$ test')
sn.histplot(position_train1_transf_bkg, ax = axes[1], binwidth = binwidth_rad, color = blue_variants[0], element = 'step', alpha = 0, label = '208-Tl train')
sn.histplot(position_val_transf_bkg, ax = axes[1], binwidth = binwidth_rad, color = blue_variants[1], element = 'step', alpha = 0, label = '208-Tl validation')
sn.histplot(position_test_transf_bkg, ax = axes[1], binwidth = binwidth_rad, color = blue_variants[2], element = 'step', alpha = 0, label = '208-Tl test')

axes[0].set_xlabel('Energy (MeV)')
axes[0].legend(loc='upper right')
axes[0].set_title('Energy Distribution', fontsize = 11)
axes[0].set_yscale('log')

axes[1].set_xlabel(r'$(R_\text{ev}/R_\text{cut})^{3}$')
axes[1].legend(loc='upper right')
axes[1].set_title(r'Normalized Volume Distribution - $R_\text{cut} = $5500 (mm)', fontsize = 11)
#axes[1].set_yscale('log')
#axes[1].set_ylim(500, 5000)

#plt.savefig('figs/Optimized Models/10x10/Std_Rad_Norm_Vol and Std_Scaler_default Solar Energy/MLM4_5500_(2.5_12)_(-5_7)_aucOP_test_split/split_test_energy.png', format = 'png', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# # Deep Learning Model Building

# %% [markdown]
# ## Energy and Position Hidden Layered Model with BatchNorm

# %%
#Model Layers and Neuron Architecture ------------------------------------------------
input_image = Input(shape = (100,), name = 'image_input')
input_energy = Input(shape = (1,), name = 'energy_input')
input_position = Input(shape = (1,), name = 'position_input')

#Images hidden layers
image_ly = Dense(90, name = 'im_ly_1', use_bias = False)(input_image)
image_ly = BatchNormalization()(image_ly)
image_ly = Activation('gelu')(image_ly)

image_ly = Dense(80, name = 'im_ly_2', use_bias = False)(image_ly)
image_ly = BatchNormalization()(image_ly)
image_ly = Activation('gelu')(image_ly)

image_ly = Dense(60, name = 'im_ly_3', use_bias = False)(image_ly)
image_ly = BatchNormalization()(image_ly)
image_ly = Activation('gelu')(image_ly)

image_ly = Dense(50, name = 'im_ly_4', use_bias = False)(image_ly)
image_ly = BatchNormalization()(image_ly)
image_ly = Activation('gelu')(image_ly)

image_ly = Dense(30, name = 'im_ly_5', use_bias = False)(image_ly)
image_ly = BatchNormalization()(image_ly)
image_ly = Activation('gelu')(image_ly)

#energy hidden layers
energy_ly = Dense(10, name = 'en_ly_1', use_bias = False)(input_energy)
energy_ly = BatchNormalization()(energy_ly)
energy_ly = Activation('gelu')(energy_ly)

energy_ly = Dense(5, name = 'en_ly_2', use_bias = False)(energy_ly)
energy_ly = BatchNormalization()(energy_ly)
energy_ly = Activation('gelu')(energy_ly)

energy_ly = Dense(2, name = 'en_ly_3', use_bias = False)(energy_ly)
energy_ly = BatchNormalization()(energy_ly)
energy_ly = Activation('gelu')(energy_ly)

#position hidden layers
position_ly = Dense(10, activation = 'gelu', name = 'pos_ly_1', use_bias = False)(input_position)
position_ly = BatchNormalization()(position_ly)
position_ly = Activation('gelu')(position_ly)

position_ly = Dense(5, name = 'pos_ly_2', use_bias = False)(position_ly)
position_ly = BatchNormalization()(position_ly)
position_ly = Activation('gelu')(position_ly)

position_ly = Dense(2, name = 'pos_ly_3', use_bias = False)(position_ly)
position_ly = BatchNormalization()(position_ly)
position_ly = Activation('gelu')(position_ly)

x = concatenate([image_ly, energy_ly, position_ly])

x = Dense(32, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dense(28, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dense(22, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dropout(rate = 0.5)(x)

x = Dense(20, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dense(15, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dense(10, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dense(5, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

output_layer = Dense(2, activation = 'sigmoid', name = 'nu_predict')(x)
#-------------------------------------------------------------------------------------

model = Model(inputs = [input_image, input_energy, input_position], outputs = output_layer)

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 9e-5),
              loss = tf.keras.losses.BinaryCrossentropy(), 
              metrics = ['AUC', 'accuracy'])


history = model.fit(x = {'image_input': pixel_train_transf, 'energy_input': energy_train_transf, 'position_input': position_train_transf}, 
                    y = {'nu_predict':labels_train}, 
                    epochs = 100, 
                    batch_size = 2000,
                    validation_split = 0.3,
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience = 15, min_delta = 1e-2, monitor="val_AUC")],
                    shuffle = True)
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - AUC: 0.5363 - accuracy: 0.4956 - loss: 0.7110 - val_AUC: 0.9999 - val_accuracy: 1.0000 - val_loss: 0.6806
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.5784 - accuracy: 0.5399 - loss: 0.6876 - val_AUC: 0.9894 - val_accuracy: 0.9931 - val_loss: 0.6760
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.6221 - accuracy: 0.5791 - loss: 0.6671 - val_AUC: 0.9245 - val_accuracy: 0.9397 - val_loss: 0.6760
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.6577 - accuracy: 0.6054 - loss: 0.6488 - val_AUC: 0.8154 - val_accuracy: 0.8334 - val_loss: 0.6784
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.6824 - accuracy: 0.6196 - loss: 0.6343 - val_AUC: 0.7305 - val_accuracy: 0.7588 - val_loss: 0.6841
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.7003 - accuracy: 0.6273 - loss: 0.6225 - val_AUC: 0.6953 - val_accuracy: 0.7330 - val_loss: 0.6864
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7155 - accuracy: 0.6339 - loss: 0.6115 - val_AUC: 0.6857 - val_accuracy: 0.7299 - val_loss: 0.6876
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7302 - accuracy: 0.6396 - loss: 0.6002 - val_AUC: 0.6786 - val_accuracy: 0.7325 - val_loss: 0.6906
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7386 - accuracy: 0.6438 - loss: 0.5923 - val_AUC: 0.6840 - val_accuracy: 0.7476 - val_loss: 0.6927
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7466 - accuracy: 0.6463 - loss: 0.5831 - val_AUC: 0.6951 - val_accuracy: 0.7640 - val_loss: 0.6941
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7520 - accuracy: 0.6466 - loss: 0.5761 - val_AUC: 0.7087 - val_accuracy: 0.7803 - val_loss: 0.6947
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7535 - accuracy: 0.6439 - loss: 0.5695 - val_AUC: 0.7205 - val_accuracy: 0.7944 - val_loss: 0.6953
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7589 - accuracy: 0.6490 - loss: 0.5635 - val_AUC: 0.7321 - val_accuracy: 0.8078 - val_loss: 0.6965
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7598 - accuracy: 0.6456 - loss: 0.5582 - val_AUC: 0.7501 - val_accuracy: 0.8238 - val_loss: 0.6957
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7604 - accuracy: 0.6428 - loss: 0.5540 - val_AUC: 0.7666 - val_accuracy: 0.8373 - val_loss: 0.6939
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7615 - accuracy: 0.6460 - loss: 0.5505 - val_AUC: 0.7765 - val_accuracy: 0.8448 - val_loss: 0.6935

# %% [markdown]
# ## Energy-Position One Layer Model with BatchNorm

# %% [markdown]
# ## Energy-Position One Layer Model with BatchNorm before the Output Layer

# %%
#Model Layers and Neuron Architecture ------------------------------------------------
input_image = Input(shape = (100,), name = 'image_input')
input_energy = Input(shape = (1,), name = 'energy_input')
input_position = Input(shape = (1,), name = 'position_input')

#Images hidden layers
image_ly = Dense(90, activation = 'gelu', name = 'im_ly_1')(input_image)
image_ly = Dense(80, activation = 'gelu', name = 'im_ly_2')(image_ly)
image_ly = Dense(60, activation = 'gelu', name = 'im_ly_3')(image_ly)
image_ly = Dense(50, activation = 'gelu', name = 'im_ly_4')(image_ly)
image_ly = Dense(30, activation = 'gelu', name = 'im_ly_5')(image_ly)

x = concatenate([image_ly, input_energy, input_position])

x = Dense(32, activation = 'gelu')(x)
x = Dense(28, activation = 'gelu')(x)
x = Dense(22, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dropout(rate = 0.5)(x)

x = Dense(20, activation = 'gelu')(x)
x = Dense(15, activation = 'gelu')(x)
x = Dense(10, activation = 'gelu')(x)
x = Dense(5, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

output_layer = Dense(2, activation = 'sigmoid', name = 'nu_predict')(x)

#-------------------------------------------------------------------------------------

model = Model(inputs = [input_image, input_energy, input_position], outputs = output_layer)

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3),
              loss = tf.keras.losses.BinaryCrossentropy(), 
              metrics = ['AUC', 'accuracy'])


history = model.fit(x = {'image_input': pixel_train1_transf, 'energy_input': energy_train1_transf, 'position_input': position_train1_transf}, 
                    y = {'nu_predict':labels_train1}, 
                    epochs = 200, 
                    batch_size = 1000,
                    validation_data=([pixel_val_transf, energy_val_transf, position_val_transf], labels_val),
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience = 25, min_delta = 1e-3, monitor="val_loss")],
                    shuffle = True)
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - AUC: 0.6642 - accuracy: 0.6690 - loss: 0.6666 - val_AUC: 0.6626 - val_accuracy: 0.7212 - val_loss: 0.6919
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8314 - accuracy: 0.7647 - loss: 0.5595 - val_AUC: 0.6336 - val_accuracy: 0.6386 - val_loss: 0.6792
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8481 - accuracy: 0.7733 - loss: 0.5110 - val_AUC: 0.6374 - val_accuracy: 0.6316 - val_loss: 0.6556
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8558 - accuracy: 0.7783 - loss: 0.4827 - val_AUC: 0.7068 - val_accuracy: 0.6780 - val_loss: 0.6134
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8570 - accuracy: 0.7774 - loss: 0.4709 - val_AUC: 0.7738 - val_accuracy: 0.7138 - val_loss: 0.5598
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8659 - accuracy: 0.7853 - loss: 0.4547 - val_AUC: 0.8014 - val_accuracy: 0.7041 - val_loss: 0.5565
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8664 - accuracy: 0.7854 - loss: 0.4509 - val_AUC: 0.8193 - val_accuracy: 0.7166 - val_loss: 0.5400
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8680 - accuracy: 0.7850 - loss: 0.4467 - val_AUC: 0.8330 - val_accuracy: 0.7326 - val_loss: 0.5001
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8680 - accuracy: 0.7856 - loss: 0.4457 - val_AUC: 0.8347 - val_accuracy: 0.7353 - val_loss: 0.4951
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8704 - accuracy: 0.7878 - loss: 0.4414 - val_AUC: 0.8416 - val_accuracy: 0.7457 - val_loss: 0.5014
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8695 - accuracy: 0.7863 - loss: 0.4422 - val_AUC: 0.8435 - val_accuracy: 0.7439 - val_loss: 0.4844
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8732 - accuracy: 0.7898 - loss: 0.4367 - val_AUC: 0.8410 - val_accuracy: 0.7502 - val_loss: 0.4793
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8751 - accuracy: 0.7896 - loss: 0.4335 - val_AUC: 0.8435 - val_accuracy: 0.7487 - val_loss: 0.4803
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8735 - accuracy: 0.7889 - loss: 0.4354 - val_AUC: 0.8409 - val_accuracy: 0.7428 - val_loss: 0.4960
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8732 - accuracy: 0.7883 - loss: 0.4359 - val_AUC: 0.8503 - val_accuracy: 0.7588 - val_loss: 0.4691
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8754 - accuracy: 0.7918 - loss: 0.4322 - val_AUC: 0.8413 - val_accuracy: 0.7375 - val_loss: 0.4975
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8749 - accuracy: 0.7902 - loss: 0.4328 - val_AUC: 0.8347 - val_accuracy: 0.7383 - val_loss: 0.4935
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8733 - accuracy: 0.7891 - loss: 0.4353 - val_AUC: 0.8440 - val_accuracy: 0.7502 - val_loss: 0.4806
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8763 - accuracy: 0.7917 - loss: 0.4306 - val_AUC: 0.8556 - val_accuracy: 0.7674 - val_loss: 0.4677
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8773 - accuracy: 0.7930 - loss: 0.4290 - val_AUC: 0.8375 - val_accuracy: 0.7286 - val_loss: 0.5156
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8773 - accuracy: 0.7919 - loss: 0.4289 - val_AUC: 0.8320 - val_accuracy: 0.7251 - val_loss: 0.5300
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8776 - accuracy: 0.7945 - loss: 0.4288 - val_AUC: 0.8421 - val_accuracy: 0.7432 - val_loss: 0.4812
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8788 - accuracy: 0.7933 - loss: 0.4269 - val_AUC: 0.8456 - val_accuracy: 0.7457 - val_loss: 0.4873
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8781 - accuracy: 0.7945 - loss: 0.4273 - val_AUC: 0.8404 - val_accuracy: 0.7334 - val_loss: 0.5101
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8780 - accuracy: 0.7939 - loss: 0.4282 - val_AUC: 0.8474 - val_accuracy: 0.7501 - val_loss: 0.4721
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8752 - accuracy: 0.7898 - loss: 0.4320 - val_AUC: 0.8407 - val_accuracy: 0.7421 - val_loss: 0.4847
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8794 - accuracy: 0.7944 - loss: 0.4257 - val_AUC: 0.8374 - val_accuracy: 0.7376 - val_loss: 0.5111
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8792 - accuracy: 0.7935 - loss: 0.4259 - val_AUC: 0.8461 - val_accuracy: 0.7494 - val_loss: 0.4882
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8806 - accuracy: 0.7944 - loss: 0.4241 - val_AUC: 0.8444 - val_accuracy: 0.7492 - val_loss: 0.4741
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8811 - accuracy: 0.7950 - loss: 0.4230 - val_AUC: 0.8422 - val_accuracy: 0.7492 - val_loss: 0.4947
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8775 - accuracy: 0.7925 - loss: 0.4282 - val_AUC: 0.8455 - val_accuracy: 0.7468 - val_loss: 0.4825
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8806 - accuracy: 0.7969 - loss: 0.4238 - val_AUC: 0.8459 - val_accuracy: 0.7529 - val_loss: 0.4785
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8793 - accuracy: 0.7940 - loss: 0.4254 - val_AUC: 0.8456 - val_accuracy: 0.7475 - val_loss: 0.4776
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8799 - accuracy: 0.7951 - loss: 0.4251 - val_AUC: 0.8527 - val_accuracy: 0.7618 - val_loss: 0.4691
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8820 - accuracy: 0.7961 - loss: 0.4216 - val_AUC: 0.8398 - val_accuracy: 0.7381 - val_loss: 0.5129
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8820 - accuracy: 0.7965 - loss: 0.4216 - val_AUC: 0.8431 - val_accuracy: 0.7457 - val_loss: 0.4862
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8828 - accuracy: 0.7967 - loss: 0.4205 - val_AUC: 0.8506 - val_accuracy: 0.7571 - val_loss: 0.4680
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8815 - accuracy: 0.7954 - loss: 0.4222 - val_AUC: 0.8451 - val_accuracy: 0.7495 - val_loss: 0.4919
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8811 - accuracy: 0.7941 - loss: 0.4232 - val_AUC: 0.8465 - val_accuracy: 0.7492 - val_loss: 0.4866
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8840 - accuracy: 0.7965 - loss: 0.4183 - val_AUC: 0.8475 - val_accuracy: 0.7492 - val_loss: 0.4882
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8839 - accuracy: 0.7977 - loss: 0.4185 - val_AUC: 0.8465 - val_accuracy: 0.7513 - val_loss: 0.4793
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8833 - accuracy: 0.7970 - loss: 0.4190 - val_AUC: 0.8497 - val_accuracy: 0.7561 - val_loss: 0.4732
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8839 - accuracy: 0.7972 - loss: 0.4184 - val_AUC: 0.8560 - val_accuracy: 0.7663 - val_loss: 0.4602
# Epoch 44/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8839 - accuracy: 0.7962 - loss: 0.4183 - val_AUC: 0.8568 - val_accuracy: 0.7675 - val_loss: 0.4611
# Epoch 45/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8850 - accuracy: 0.7976 - loss: 0.4164 - val_AUC: 0.8543 - val_accuracy: 0.7657 - val_loss: 0.4629
# Epoch 46/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8838 - accuracy: 0.7978 - loss: 0.4188 - val_AUC: 0.8461 - val_accuracy: 0.7482 - val_loss: 0.4806
# Epoch 47/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8856 - accuracy: 0.7980 - loss: 0.4156 - val_AUC: 0.8483 - val_accuracy: 0.7568 - val_loss: 0.4695
# Epoch 48/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8863 - accuracy: 0.7985 - loss: 0.4144 - val_AUC: 0.8418 - val_accuracy: 0.7459 - val_loss: 0.4812
# Epoch 49/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8867 - accuracy: 0.8008 - loss: 0.4142 - val_AUC: 0.8487 - val_accuracy: 0.7591 - val_loss: 0.4819
# Epoch 50/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8865 - accuracy: 0.7984 - loss: 0.4145 - val_AUC: 0.8536 - val_accuracy: 0.7626 - val_loss: 0.4650
# Epoch 51/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8876 - accuracy: 0.7998 - loss: 0.4130 - val_AUC: 0.8555 - val_accuracy: 0.7664 - val_loss: 0.4655
# Epoch 52/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8883 - accuracy: 0.8006 - loss: 0.4111 - val_AUC: 0.8497 - val_accuracy: 0.7537 - val_loss: 0.4789
# Epoch 53/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8857 - accuracy: 0.7982 - loss: 0.4156 - val_AUC: 0.8551 - val_accuracy: 0.7652 - val_loss: 0.4660
# Epoch 54/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8890 - accuracy: 0.8014 - loss: 0.4102 - val_AUC: 0.8568 - val_accuracy: 0.7689 - val_loss: 0.4632
# Epoch 55/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8884 - accuracy: 0.8008 - loss: 0.4113 - val_AUC: 0.8484 - val_accuracy: 0.7529 - val_loss: 0.4868
# Epoch 56/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8901 - accuracy: 0.8024 - loss: 0.4083 - val_AUC: 0.8497 - val_accuracy: 0.7585 - val_loss: 0.4785
# Epoch 57/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8898 - accuracy: 0.8030 - loss: 0.4091 - val_AUC: 0.8532 - val_accuracy: 0.7657 - val_loss: 0.4785
# Epoch 58/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8898 - accuracy: 0.8016 - loss: 0.4088 - val_AUC: 0.8517 - val_accuracy: 0.7600 - val_loss: 0.4704
# Epoch 59/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8889 - accuracy: 0.8015 - loss: 0.4105 - val_AUC: 0.8491 - val_accuracy: 0.7594 - val_loss: 0.4771
# Epoch 60/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8903 - accuracy: 0.8021 - loss: 0.4082 - val_AUC: 0.8518 - val_accuracy: 0.7639 - val_loss: 0.4699
# Epoch 61/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8904 - accuracy: 0.8010 - loss: 0.4074 - val_AUC: 0.8547 - val_accuracy: 0.7660 - val_loss: 0.4655
# Epoch 62/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8905 - accuracy: 0.8026 - loss: 0.4077 - val_AUC: 0.8545 - val_accuracy: 0.7700 - val_loss: 0.4749
# Epoch 63/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8908 - accuracy: 0.8028 - loss: 0.4073 - val_AUC: 0.8529 - val_accuracy: 0.7657 - val_loss: 0.4757
# Epoch 64/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8916 - accuracy: 0.8032 - loss: 0.4061 - val_AUC: 0.8595 - val_accuracy: 0.7766 - val_loss: 0.4573
# Epoch 65/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8920 - accuracy: 0.8022 - loss: 0.4049 - val_AUC: 0.8595 - val_accuracy: 0.7757 - val_loss: 0.4581
# Epoch 66/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8926 - accuracy: 0.8047 - loss: 0.4042 - val_AUC: 0.8338 - val_accuracy: 0.7459 - val_loss: 0.4973
# Epoch 67/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8913 - accuracy: 0.8020 - loss: 0.4065 - val_AUC: 0.8522 - val_accuracy: 0.7661 - val_loss: 0.4742
# Epoch 68/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8936 - accuracy: 0.8049 - loss: 0.4031 - val_AUC: 0.8519 - val_accuracy: 0.7673 - val_loss: 0.4765
# Epoch 69/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8922 - accuracy: 0.8029 - loss: 0.4050 - val_AUC: 0.8508 - val_accuracy: 0.7633 - val_loss: 0.4991
# Epoch 70/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8939 - accuracy: 0.8046 - loss: 0.4021 - val_AUC: 0.8608 - val_accuracy: 0.7768 - val_loss: 0.4563
# Epoch 71/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8929 - accuracy: 0.8038 - loss: 0.4043 - val_AUC: 0.8576 - val_accuracy: 0.7730 - val_loss: 0.4648
# Epoch 72/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8939 - accuracy: 0.8055 - loss: 0.4018 - val_AUC: 0.8523 - val_accuracy: 0.7679 - val_loss: 0.4778
# Epoch 73/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8936 - accuracy: 0.8032 - loss: 0.4024 - val_AUC: 0.8466 - val_accuracy: 0.7590 - val_loss: 0.4897
# Epoch 74/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8945 - accuracy: 0.8044 - loss: 0.4010 - val_AUC: 0.8525 - val_accuracy: 0.7656 - val_loss: 0.4704
# Epoch 75/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8951 - accuracy: 0.8049 - loss: 0.3999 - val_AUC: 0.8511 - val_accuracy: 0.7623 - val_loss: 0.4718
# Epoch 76/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8958 - accuracy: 0.8069 - loss: 0.3988 - val_AUC: 0.8582 - val_accuracy: 0.7739 - val_loss: 0.4647
# Epoch 77/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8945 - accuracy: 0.8057 - loss: 0.4013 - val_AUC: 0.8495 - val_accuracy: 0.7609 - val_loss: 0.4746
# Epoch 78/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8959 - accuracy: 0.8061 - loss: 0.3985 - val_AUC: 0.8593 - val_accuracy: 0.7775 - val_loss: 0.4652
# Epoch 79/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8973 - accuracy: 0.8076 - loss: 0.3963 - val_AUC: 0.8599 - val_accuracy: 0.7755 - val_loss: 0.4635
# Epoch 80/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8983 - accuracy: 0.8084 - loss: 0.3949 - val_AUC: 0.8568 - val_accuracy: 0.7731 - val_loss: 0.4672
# Epoch 81/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8984 - accuracy: 0.8089 - loss: 0.3945 - val_AUC: 0.8577 - val_accuracy: 0.7728 - val_loss: 0.4658
# Epoch 82/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8979 - accuracy: 0.8074 - loss: 0.3955 - val_AUC: 0.8486 - val_accuracy: 0.7581 - val_loss: 0.4749
# Epoch 83/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8955 - accuracy: 0.8054 - loss: 0.3998 - val_AUC: 0.8544 - val_accuracy: 0.7660 - val_loss: 0.4658
# Epoch 84/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8969 - accuracy: 0.8062 - loss: 0.3972 - val_AUC: 0.8583 - val_accuracy: 0.7728 - val_loss: 0.4644
# Epoch 85/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8962 - accuracy: 0.8048 - loss: 0.3978 - val_AUC: 0.8545 - val_accuracy: 0.7731 - val_loss: 0.4815
# Epoch 86/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8981 - accuracy: 0.8084 - loss: 0.3950 - val_AUC: 0.8487 - val_accuracy: 0.7626 - val_loss: 0.4875
# Epoch 87/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8983 - accuracy: 0.8078 - loss: 0.3946 - val_AUC: 0.8603 - val_accuracy: 0.7772 - val_loss: 0.4591
# Epoch 88/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8980 - accuracy: 0.8078 - loss: 0.3948 - val_AUC: 0.8535 - val_accuracy: 0.7661 - val_loss: 0.4729
# Epoch 89/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8979 - accuracy: 0.8050 - loss: 0.3947 - val_AUC: 0.8576 - val_accuracy: 0.7740 - val_loss: 0.4689
# Epoch 90/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8980 - accuracy: 0.8069 - loss: 0.3949 - val_AUC: 0.8606 - val_accuracy: 0.7780 - val_loss: 0.4622
# Epoch 91/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8987 - accuracy: 0.8074 - loss: 0.3940 - val_AUC: 0.8603 - val_accuracy: 0.7775 - val_loss: 0.4643
# Epoch 92/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8998 - accuracy: 0.8089 - loss: 0.3920 - val_AUC: 0.8570 - val_accuracy: 0.7739 - val_loss: 0.4668
# Epoch 93/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8987 - accuracy: 0.8086 - loss: 0.3939 - val_AUC: 0.8556 - val_accuracy: 0.7718 - val_loss: 0.4705
# Epoch 94/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.9025 - accuracy: 0.8113 - loss: 0.3866 - val_AUC: 0.8635 - val_accuracy: 0.7823 - val_loss: 0.4573
# Epoch 95/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.9003 - accuracy: 0.8083 - loss: 0.3908 - val_AUC: 0.8560 - val_accuracy: 0.7721 - val_loss: 0.4797

# %%
#Model Layers and Neuron Architecture ------------------------------------------------
input_image = Input(shape = (100,), name = 'image_input')
input_energy = Input(shape = (1,), name = 'energy_input')
input_position = Input(shape = (1,), name = 'position_input')

#Images hidden layers
image_ly = Dense(90, name = 'im_ly_1', use_bias = False)(input_image)
image_ly = BatchNormalization()(image_ly)
image_ly = Activation('gelu')(image_ly)

image_ly = Dense(80, name = 'im_ly_2', use_bias = False)(image_ly)
image_ly = BatchNormalization()(image_ly)
image_ly = Activation('gelu')(image_ly)

image_ly = Dense(60, name = 'im_ly_3', use_bias = False)(image_ly)
image_ly = BatchNormalization()(image_ly)
image_ly = Activation('gelu')(image_ly)

image_ly = Dense(50, name = 'im_ly_4', use_bias = False)(image_ly)
image_ly = BatchNormalization()(image_ly)
image_ly = Activation('gelu')(image_ly)

image_ly = Dense(30, name = 'im_ly_5', use_bias = False)(image_ly)
image_ly = BatchNormalization()(image_ly)
image_ly = Activation('gelu')(image_ly)

x = concatenate([image_ly, input_energy, input_position])

x = Dense(32, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dense(28, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dense(22, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dropout(rate = 0.5)(x)

x = Dense(20, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dense(15, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dense(10, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

x = Dense(5, use_bias = False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)

output_layer = Dense(2, activation = 'sigmoid', name = 'nu_predict')(x)
#-------------------------------------------------------------------------------------

model = Model(inputs = [input_image, input_energy, input_position], outputs = output_layer)

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-4),
              loss = tf.keras.losses.BinaryCrossentropy(), 
              metrics = ['AUC', 'accuracy'])


history = model.fit(x = {'image_input': pixel_train1_transf, 'energy_input': energy_train1_transf, 'position_input': position_train1_transf}, 
                    y = {'nu_predict':labels_train1}, 
                    epochs = 200, 
                    batch_size = 5000,
                    validation_data=([pixel_val_transf, energy_val_transf, position_val_transf], labels_val),
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience = 15, min_delta = 1e-3, monitor="val_AUC")],
                    shuffle = True)
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - AUC: 0.5256 - accuracy: 0.5242 - loss: 0.8081 - val_AUC: 0.5676 - val_accuracy: 0.5000 - val_loss: 0.6926
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - AUC: 0.5396 - accuracy: 0.5343 - loss: 0.7851 - val_AUC: 0.5423 - val_accuracy: 0.5000 - val_loss: 0.6929
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.5505 - accuracy: 0.5458 - loss: 0.7723 - val_AUC: 0.5641 - val_accuracy: 0.5000 - val_loss: 0.6929
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.5611 - accuracy: 0.5534 - loss: 0.7554 - val_AUC: 0.5509 - val_accuracy: 0.5000 - val_loss: 0.6925
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - AUC: 0.5739 - accuracy: 0.5653 - loss: 0.7421 - val_AUC: 0.5719 - val_accuracy: 0.5000 - val_loss: 0.6916
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.5800 - accuracy: 0.5696 - loss: 0.7374 - val_AUC: 0.5740 - val_accuracy: 0.5002 - val_loss: 0.6903
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.5853 - accuracy: 0.5759 - loss: 0.7304 - val_AUC: 0.5759 - val_accuracy: 0.5008 - val_loss: 0.6885
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.5948 - accuracy: 0.5841 - loss: 0.7256 - val_AUC: 0.5787 - val_accuracy: 0.5032 - val_loss: 0.6863
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - AUC: 0.6010 - accuracy: 0.5885 - loss: 0.7177 - val_AUC: 0.5863 - val_accuracy: 0.5180 - val_loss: 0.6839
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.6070 - accuracy: 0.5916 - loss: 0.7135 - val_AUC: 0.6065 - val_accuracy: 0.5519 - val_loss: 0.6817
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.6123 - accuracy: 0.5959 - loss: 0.7097 - val_AUC: 0.6293 - val_accuracy: 0.5799 - val_loss: 0.6800
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - AUC: 0.6233 - accuracy: 0.6078 - loss: 0.7027 - val_AUC: 0.6466 - val_accuracy: 0.6013 - val_loss: 0.6783
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.6274 - accuracy: 0.6090 - loss: 0.7007 - val_AUC: 0.6573 - val_accuracy: 0.6136 - val_loss: 0.6773
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.6346 - accuracy: 0.6148 - loss: 0.6953 - val_AUC: 0.6654 - val_accuracy: 0.6225 - val_loss: 0.6754
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.6391 - accuracy: 0.6184 - loss: 0.6911 - val_AUC: 0.6707 - val_accuracy: 0.6283 - val_loss: 0.6737
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.6466 - accuracy: 0.6242 - loss: 0.6864 - val_AUC: 0.6748 - val_accuracy: 0.6331 - val_loss: 0.6731
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.6507 - accuracy: 0.6289 - loss: 0.6848 - val_AUC: 0.6782 - val_accuracy: 0.6360 - val_loss: 0.6718
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.6554 - accuracy: 0.6323 - loss: 0.6802 - val_AUC: 0.6813 - val_accuracy: 0.6405 - val_loss: 0.6706
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.6583 - accuracy: 0.6338 - loss: 0.6803 - val_AUC: 0.6844 - val_accuracy: 0.6431 - val_loss: 0.6683
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.6637 - accuracy: 0.6397 - loss: 0.6771 - val_AUC: 0.6874 - val_accuracy: 0.6462 - val_loss: 0.6687
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.6669 - accuracy: 0.6387 - loss: 0.6734 - val_AUC: 0.6904 - val_accuracy: 0.6486 - val_loss: 0.6680
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.6736 - accuracy: 0.6445 - loss: 0.6698 - val_AUC: 0.6935 - val_accuracy: 0.6511 - val_loss: 0.6650
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.6723 - accuracy: 0.6439 - loss: 0.6680 - val_AUC: 0.6965 - val_accuracy: 0.6539 - val_loss: 0.6632
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.6782 - accuracy: 0.6495 - loss: 0.6654 - val_AUC: 0.6994 - val_accuracy: 0.6560 - val_loss: 0.6622
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.6831 - accuracy: 0.6530 - loss: 0.6640 - val_AUC: 0.7023 - val_accuracy: 0.6583 - val_loss: 0.6603
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.6847 - accuracy: 0.6540 - loss: 0.6601 - val_AUC: 0.7053 - val_accuracy: 0.6589 - val_loss: 0.6597
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.6907 - accuracy: 0.6595 - loss: 0.6571 - val_AUC: 0.7084 - val_accuracy: 0.6625 - val_loss: 0.6576
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.6978 - accuracy: 0.6650 - loss: 0.6515 - val_AUC: 0.7116 - val_accuracy: 0.6656 - val_loss: 0.6549
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.6973 - accuracy: 0.6656 - loss: 0.6531 - val_AUC: 0.7148 - val_accuracy: 0.6688 - val_loss: 0.6529
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7038 - accuracy: 0.6697 - loss: 0.6489 - val_AUC: 0.7178 - val_accuracy: 0.6720 - val_loss: 0.6505
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7043 - accuracy: 0.6708 - loss: 0.6479 - val_AUC: 0.7209 - val_accuracy: 0.6760 - val_loss: 0.6491
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7096 - accuracy: 0.6751 - loss: 0.6443 - val_AUC: 0.7239 - val_accuracy: 0.6785 - val_loss: 0.6471
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7112 - accuracy: 0.6770 - loss: 0.6424 - val_AUC: 0.7275 - val_accuracy: 0.6815 - val_loss: 0.6450
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.7139 - accuracy: 0.6795 - loss: 0.6414 - val_AUC: 0.7305 - val_accuracy: 0.6851 - val_loss: 0.6427
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.7186 - accuracy: 0.6820 - loss: 0.6385 - val_AUC: 0.7332 - val_accuracy: 0.6882 - val_loss: 0.6405
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - AUC: 0.7211 - accuracy: 0.6858 - loss: 0.6369 - val_AUC: 0.7363 - val_accuracy: 0.6909 - val_loss: 0.6388
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.7222 - accuracy: 0.6851 - loss: 0.6363 - val_AUC: 0.7394 - val_accuracy: 0.6936 - val_loss: 0.6372
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.7303 - accuracy: 0.6916 - loss: 0.6314 - val_AUC: 0.7424 - val_accuracy: 0.6979 - val_loss: 0.6357
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7322 - accuracy: 0.6961 - loss: 0.6293 - val_AUC: 0.7454 - val_accuracy: 0.7009 - val_loss: 0.6337
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7371 - accuracy: 0.7007 - loss: 0.6259 - val_AUC: 0.7480 - val_accuracy: 0.7037 - val_loss: 0.6321
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7381 - accuracy: 0.7017 - loss: 0.6254 - val_AUC: 0.7507 - val_accuracy: 0.7068 - val_loss: 0.6303
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7423 - accuracy: 0.7065 - loss: 0.6218 - val_AUC: 0.7532 - val_accuracy: 0.7091 - val_loss: 0.6284
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7407 - accuracy: 0.7068 - loss: 0.6227 - val_AUC: 0.7555 - val_accuracy: 0.7100 - val_loss: 0.6260
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7464 - accuracy: 0.7108 - loss: 0.6183 - val_AUC: 0.7582 - val_accuracy: 0.7128 - val_loss: 0.6250
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7506 - accuracy: 0.7135 - loss: 0.6163 - val_AUC: 0.7600 - val_accuracy: 0.7145 - val_loss: 0.6222
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7527 - accuracy: 0.7164 - loss: 0.6142 - val_AUC: 0.7622 - val_accuracy: 0.7167 - val_loss: 0.6201
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7574 - accuracy: 0.7214 - loss: 0.6094 - val_AUC: 0.7637 - val_accuracy: 0.7192 - val_loss: 0.6186
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7602 - accuracy: 0.7240 - loss: 0.6077 - val_AUC: 0.7653 - val_accuracy: 0.7202 - val_loss: 0.6170
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7591 - accuracy: 0.7250 - loss: 0.6070 - val_AUC: 0.7670 - val_accuracy: 0.7231 - val_loss: 0.6157
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7640 - accuracy: 0.7292 - loss: 0.6044 - val_AUC: 0.7689 - val_accuracy: 0.7252 - val_loss: 0.6136
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.7664 - accuracy: 0.7307 - loss: 0.6016 - val_AUC: 0.7707 - val_accuracy: 0.7278 - val_loss: 0.6114
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7683 - accuracy: 0.7340 - loss: 0.5997 - val_AUC: 0.7718 - val_accuracy: 0.7283 - val_loss: 0.6100
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7724 - accuracy: 0.7359 - loss: 0.5974 - val_AUC: 0.7732 - val_accuracy: 0.7300 - val_loss: 0.6085
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7706 - accuracy: 0.7348 - loss: 0.5972 - val_AUC: 0.7746 - val_accuracy: 0.7310 - val_loss: 0.6076
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.7756 - accuracy: 0.7393 - loss: 0.5935 - val_AUC: 0.7756 - val_accuracy: 0.7333 - val_loss: 0.6062
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7767 - accuracy: 0.7397 - loss: 0.5917 - val_AUC: 0.7766 - val_accuracy: 0.7345 - val_loss: 0.6048
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7798 - accuracy: 0.7452 - loss: 0.5893 - val_AUC: 0.7774 - val_accuracy: 0.7354 - val_loss: 0.6034
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7800 - accuracy: 0.7453 - loss: 0.5895 - val_AUC: 0.7785 - val_accuracy: 0.7372 - val_loss: 0.6013
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7817 - accuracy: 0.7472 - loss: 0.5868 - val_AUC: 0.7797 - val_accuracy: 0.7393 - val_loss: 0.5998
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7838 - accuracy: 0.7487 - loss: 0.5847 - val_AUC: 0.7808 - val_accuracy: 0.7411 - val_loss: 0.5987
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7808 - accuracy: 0.7468 - loss: 0.5863 - val_AUC: 0.7819 - val_accuracy: 0.7430 - val_loss: 0.5971
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7868 - accuracy: 0.7509 - loss: 0.5821 - val_AUC: 0.7825 - val_accuracy: 0.7440 - val_loss: 0.5962
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7873 - accuracy: 0.7522 - loss: 0.5815 - val_AUC: 0.7827 - val_accuracy: 0.7435 - val_loss: 0.5953
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7885 - accuracy: 0.7539 - loss: 0.5786 - val_AUC: 0.7828 - val_accuracy: 0.7432 - val_loss: 0.5948
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7902 - accuracy: 0.7555 - loss: 0.5773 - val_AUC: 0.7835 - val_accuracy: 0.7450 - val_loss: 0.5936
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7912 - accuracy: 0.7562 - loss: 0.5767 - val_AUC: 0.7841 - val_accuracy: 0.7464 - val_loss: 0.5921
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7928 - accuracy: 0.7583 - loss: 0.5741 - val_AUC: 0.7851 - val_accuracy: 0.7479 - val_loss: 0.5914
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7948 - accuracy: 0.7600 - loss: 0.5721 - val_AUC: 0.7858 - val_accuracy: 0.7477 - val_loss: 0.5908
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7934 - accuracy: 0.7590 - loss: 0.5730 - val_AUC: 0.7865 - val_accuracy: 0.7483 - val_loss: 0.5893
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.7994 - accuracy: 0.7642 - loss: 0.5679 - val_AUC: 0.7866 - val_accuracy: 0.7488 - val_loss: 0.5881
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7965 - accuracy: 0.7623 - loss: 0.5689 - val_AUC: 0.7872 - val_accuracy: 0.7503 - val_loss: 0.5872
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7981 - accuracy: 0.7644 - loss: 0.5674 - val_AUC: 0.7873 - val_accuracy: 0.7516 - val_loss: 0.5861
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8001 - accuracy: 0.7645 - loss: 0.5661 - val_AUC: 0.7878 - val_accuracy: 0.7518 - val_loss: 0.5854
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.7990 - accuracy: 0.7653 - loss: 0.5662 - val_AUC: 0.7884 - val_accuracy: 0.7508 - val_loss: 0.5851
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8032 - accuracy: 0.7678 - loss: 0.5623 - val_AUC: 0.7888 - val_accuracy: 0.7512 - val_loss: 0.5843
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8009 - accuracy: 0.7658 - loss: 0.5641 - val_AUC: 0.7884 - val_accuracy: 0.7502 - val_loss: 0.5841
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.8032 - accuracy: 0.7699 - loss: 0.5607 - val_AUC: 0.7890 - val_accuracy: 0.7522 - val_loss: 0.5826
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8065 - accuracy: 0.7717 - loss: 0.5583 - val_AUC: 0.7893 - val_accuracy: 0.7535 - val_loss: 0.5815
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8052 - accuracy: 0.7715 - loss: 0.5576 - val_AUC: 0.7898 - val_accuracy: 0.7537 - val_loss: 0.5813
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8048 - accuracy: 0.7705 - loss: 0.5585 - val_AUC: 0.7902 - val_accuracy: 0.7536 - val_loss: 0.5809
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.8089 - accuracy: 0.7743 - loss: 0.5548 - val_AUC: 0.7902 - val_accuracy: 0.7536 - val_loss: 0.5799
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8087 - accuracy: 0.7751 - loss: 0.5545 - val_AUC: 0.7903 - val_accuracy: 0.7542 - val_loss: 0.5791
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8089 - accuracy: 0.7768 - loss: 0.5540 - val_AUC: 0.7903 - val_accuracy: 0.7558 - val_loss: 0.5783
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8088 - accuracy: 0.7753 - loss: 0.5531 - val_AUC: 0.7903 - val_accuracy: 0.7547 - val_loss: 0.5786
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.8122 - accuracy: 0.7789 - loss: 0.5495 - val_AUC: 0.7907 - val_accuracy: 0.7554 - val_loss: 0.5779
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8105 - accuracy: 0.7767 - loss: 0.5509 - val_AUC: 0.7911 - val_accuracy: 0.7546 - val_loss: 0.5769
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8101 - accuracy: 0.7772 - loss: 0.5502 - val_AUC: 0.7914 - val_accuracy: 0.7559 - val_loss: 0.5758
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.8109 - accuracy: 0.7796 - loss: 0.5492 - val_AUC: 0.7909 - val_accuracy: 0.7560 - val_loss: 0.5755
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8114 - accuracy: 0.7791 - loss: 0.5481 - val_AUC: 0.7909 - val_accuracy: 0.7562 - val_loss: 0.5752
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.8164 - accuracy: 0.7831 - loss: 0.5441 - val_AUC: 0.7913 - val_accuracy: 0.7558 - val_loss: 0.5745
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.8157 - accuracy: 0.7789 - loss: 0.5446 - val_AUC: 0.7922 - val_accuracy: 0.7560 - val_loss: 0.5744
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8168 - accuracy: 0.7814 - loss: 0.5425 - val_AUC: 0.7928 - val_accuracy: 0.7560 - val_loss: 0.5733
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.8162 - accuracy: 0.7832 - loss: 0.5417 - val_AUC: 0.7925 - val_accuracy: 0.7559 - val_loss: 0.5727
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.8192 - accuracy: 0.7841 - loss: 0.5395 - val_AUC: 0.7923 - val_accuracy: 0.7561 - val_loss: 0.5721
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.8175 - accuracy: 0.7839 - loss: 0.5409 - val_AUC: 0.7923 - val_accuracy: 0.7564 - val_loss: 0.5718
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8180 - accuracy: 0.7846 - loss: 0.5403 - val_AUC: 0.7928 - val_accuracy: 0.7567 - val_loss: 0.5716
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8204 - accuracy: 0.7871 - loss: 0.5375 - val_AUC: 0.7926 - val_accuracy: 0.7569 - val_loss: 0.5721
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8189 - accuracy: 0.7857 - loss: 0.5380 - val_AUC: 0.7926 - val_accuracy: 0.7572 - val_loss: 0.5719
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8208 - accuracy: 0.7867 - loss: 0.5364 - val_AUC: 0.7924 - val_accuracy: 0.7572 - val_loss: 0.5707
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8207 - accuracy: 0.7883 - loss: 0.5351 - val_AUC: 0.7923 - val_accuracy: 0.7569 - val_loss: 0.5706
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8227 - accuracy: 0.7890 - loss: 0.5334 - val_AUC: 0.7922 - val_accuracy: 0.7576 - val_loss: 0.5696
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.8253 - accuracy: 0.7916 - loss: 0.5311 - val_AUC: 0.7924 - val_accuracy: 0.7573 - val_loss: 0.5694
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.8223 - accuracy: 0.7906 - loss: 0.5328 - val_AUC: 0.7925 - val_accuracy: 0.7574 - val_loss: 0.5697
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - AUC: 0.8255 - accuracy: 0.7922 - loss: 0.5301 - val_AUC: 0.7924 - val_accuracy: 0.7566 - val_loss: 0.5694
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8245 - accuracy: 0.7898 - loss: 0.5299 - val_AUC: 0.7926 - val_accuracy: 0.7563 - val_loss: 0.5688
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.8230 - accuracy: 0.7902 - loss: 0.5306 - val_AUC: 0.7921 - val_accuracy: 0.7573 - val_loss: 0.5692

# %% [markdown]
# ## Energy-Position One Layer Model without BatchNorm

# %%
#Model Layers and Neuron Architecture ------------------------------------------------
input_image = Input(shape = (100,), name = 'image_input')
input_energy = Input(shape = (1,), name = 'energy_input')
input_position = Input(shape = (1,), name = 'position_input')

#Images hidden layers
image_ly = Dense(90, activation = 'gelu', name = 'im_ly_1')(input_image)
image_ly = Dense(80, activation = 'gelu', name = 'im_ly_2')(image_ly)
image_ly = Dense(60, activation = 'gelu', name = 'im_ly_3')(image_ly)
image_ly = Dense(50, activation = 'gelu', name = 'im_ly_4')(image_ly)
image_ly = Dense(30, activation = 'gelu', name = 'im_ly_5')(image_ly)

x = concatenate([image_ly, input_energy, input_position])

x = Dense(32, activation = 'gelu')(x)
x = Dense(28, activation = 'gelu')(x)
x = Dense(22, activation = 'gelu')(x)

x = Dropout(rate = 0.5)(x)

x = Dense(20, activation = 'gelu')(x)
x = Dense(15, activation = 'gelu')(x)
x = Dense(10, activation = 'gelu')(x)
x = Dense(5, activation = 'gelu')(x)

output_layer = Dense(2, activation = 'sigmoid', name = 'nu_predict')(x)
#-------------------------------------------------------------------------------------

model = Model(inputs = [input_image, input_energy, input_position], outputs = output_layer)

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 5e-3),
              loss = tf.keras.losses.BinaryCrossentropy(), 
              metrics = ['AUC', 'accuracy'])


history = model.fit(x = {'image_input': pixel_train1_transf, 'energy_input': energy_train1_transf, 'position_input': position_train1_transf}, 
                    y = {'nu_predict':labels_train1}, 
                    epochs = 200, 
                    batch_size = 100000,
                    validation_data=([pixel_val_transf, energy_val_transf, position_val_transf], labels_val),
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience = 15, min_delta = 1e-3, monitor="val_loss")],
                    shuffle = True)
# Out:
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - AUC: 0.5169 - accuracy: 0.5123 - loss: 0.6929 - val_AUC: 0.6199 - val_accuracy: 0.6026 - val_loss: 0.6913
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 362ms/step - AUC: 0.6007 - accuracy: 0.5797 - loss: 0.6905 - val_AUC: 0.6250 - val_accuracy: 0.6343 - val_loss: 0.6835
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - AUC: 0.6202 - accuracy: 0.6174 - loss: 0.6815 - val_AUC: 0.6513 - val_accuracy: 0.7060 - val_loss: 0.6691
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 361ms/step - AUC: 0.6441 - accuracy: 0.6777 - loss: 0.6694 - val_AUC: 0.6430 - val_accuracy: 0.6814 - val_loss: 0.6578
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - AUC: 0.6581 - accuracy: 0.6860 - loss: 0.6566 - val_AUC: 0.6829 - val_accuracy: 0.6966 - val_loss: 0.6406
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 362ms/step - AUC: 0.6924 - accuracy: 0.7015 - loss: 0.6374 - val_AUC: 0.7328 - val_accuracy: 0.7213 - val_loss: 0.6112
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 366ms/step - AUC: 0.7356 - accuracy: 0.7263 - loss: 0.6134 - val_AUC: 0.7770 - val_accuracy: 0.7558 - val_loss: 0.5891
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 359ms/step - AUC: 0.7749 - accuracy: 0.7562 - loss: 0.5890 - val_AUC: 0.8049 - val_accuracy: 0.7770 - val_loss: 0.5697
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - AUC: 0.7919 - accuracy: 0.7687 - loss: 0.5710 - val_AUC: 0.8139 - val_accuracy: 0.7767 - val_loss: 0.5570
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - AUC: 0.8026 - accuracy: 0.7716 - loss: 0.5583 - val_AUC: 0.8130 - val_accuracy: 0.7860 - val_loss: 0.5403
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - AUC: 0.8066 - accuracy: 0.7762 - loss: 0.5458 - val_AUC: 0.8086 - val_accuracy: 0.7871 - val_loss: 0.5348
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - AUC: 0.8126 - accuracy: 0.7779 - loss: 0.5372 - val_AUC: 0.8255 - val_accuracy: 0.7866 - val_loss: 0.5221
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 361ms/step - AUC: 0.8231 - accuracy: 0.7798 - loss: 0.5265 - val_AUC: 0.8239 - val_accuracy: 0.7884 - val_loss: 0.5164
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 366ms/step - AUC: 0.8269 - accuracy: 0.7808 - loss: 0.5199 - val_AUC: 0.8331 - val_accuracy: 0.7899 - val_loss: 0.5068
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - AUC: 0.8338 - accuracy: 0.7839 - loss: 0.5104 - val_AUC: 0.8446 - val_accuracy: 0.7868 - val_loss: 0.4992
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 383ms/step - AUC: 0.8379 - accuracy: 0.7830 - loss: 0.5054 - val_AUC: 0.8487 - val_accuracy: 0.7859 - val_loss: 0.4940
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - AUC: 0.8426 - accuracy: 0.7838 - loss: 0.4988 - val_AUC: 0.8495 - val_accuracy: 0.7897 - val_loss: 0.4864
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - AUC: 0.8471 - accuracy: 0.7867 - loss: 0.4912 - val_AUC: 0.8498 - val_accuracy: 0.7919 - val_loss: 0.4816
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - AUC: 0.8499 - accuracy: 0.7883 - loss: 0.4857 - val_AUC: 0.8487 - val_accuracy: 0.7913 - val_loss: 0.4797
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - AUC: 0.8517 - accuracy: 0.7887 - loss: 0.4811 - val_AUC: 0.8544 - val_accuracy: 0.7924 - val_loss: 0.4716
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 381ms/step - AUC: 0.8557 - accuracy: 0.7904 - loss: 0.4749 - val_AUC: 0.8599 - val_accuracy: 0.7922 - val_loss: 0.4656
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 383ms/step - AUC: 0.8584 - accuracy: 0.7901 - loss: 0.4712 - val_AUC: 0.8622 - val_accuracy: 0.7929 - val_loss: 0.4611
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 394ms/step - AUC: 0.8617 - accuracy: 0.7910 - loss: 0.4663 - val_AUC: 0.8701 - val_accuracy: 0.7897 - val_loss: 0.4570
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - AUC: 0.8644 - accuracy: 0.7898 - loss: 0.4639 - val_AUC: 0.8743 - val_accuracy: 0.7914 - val_loss: 0.4510
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 381ms/step - AUC: 0.8690 - accuracy: 0.7901 - loss: 0.4581 - val_AUC: 0.8740 - val_accuracy: 0.7937 - val_loss: 0.4470
# Epoch 26/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - AUC: 0.8719 - accuracy: 0.7925 - loss: 0.4516 - val_AUC: 0.8774 - val_accuracy: 0.7938 - val_loss: 0.4419
# Epoch 27/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - AUC: 0.8741 - accuracy: 0.7931 - loss: 0.4467 - val_AUC: 0.8789 - val_accuracy: 0.7935 - val_loss: 0.4373
# Epoch 28/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - AUC: 0.8750 - accuracy: 0.7925 - loss: 0.4430 - val_AUC: 0.8770 - val_accuracy: 0.7914 - val_loss: 0.4378
# Epoch 29/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - AUC: 0.8744 - accuracy: 0.7919 - loss: 0.4414 - val_AUC: 0.8801 - val_accuracy: 0.7938 - val_loss: 0.4309
# Epoch 30/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 419ms/step - AUC: 0.8760 - accuracy: 0.7935 - loss: 0.4373 - val_AUC: 0.8799 - val_accuracy: 0.7921 - val_loss: 0.4295
# Epoch 31/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - AUC: 0.8764 - accuracy: 0.7931 - loss: 0.4355 - val_AUC: 0.8806 - val_accuracy: 0.7930 - val_loss: 0.4283
# Epoch 32/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - AUC: 0.8773 - accuracy: 0.7943 - loss: 0.4333 - val_AUC: 0.8810 - val_accuracy: 0.7924 - val_loss: 0.4276
# Epoch 33/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - AUC: 0.8777 - accuracy: 0.7941 - loss: 0.4326 - val_AUC: 0.8794 - val_accuracy: 0.7924 - val_loss: 0.4300
# Epoch 34/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - AUC: 0.8763 - accuracy: 0.7939 - loss: 0.4340 - val_AUC: 0.8830 - val_accuracy: 0.7948 - val_loss: 0.4231
# Epoch 35/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - AUC: 0.8787 - accuracy: 0.7954 - loss: 0.4304 - val_AUC: 0.8817 - val_accuracy: 0.7937 - val_loss: 0.4243
# Epoch 36/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 362ms/step - AUC: 0.8785 - accuracy: 0.7947 - loss: 0.4303 - val_AUC: 0.8824 - val_accuracy: 0.7932 - val_loss: 0.4246
# Epoch 37/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 359ms/step - AUC: 0.8790 - accuracy: 0.7951 - loss: 0.4292 - val_AUC: 0.8838 - val_accuracy: 0.7956 - val_loss: 0.4207
# Epoch 38/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - AUC: 0.8797 - accuracy: 0.7955 - loss: 0.4282 - val_AUC: 0.8834 - val_accuracy: 0.7944 - val_loss: 0.4226
# Epoch 39/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - AUC: 0.8803 - accuracy: 0.7962 - loss: 0.4269 - val_AUC: 0.8837 - val_accuracy: 0.7947 - val_loss: 0.4213
# Epoch 40/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - AUC: 0.8799 - accuracy: 0.7955 - loss: 0.4277 - val_AUC: 0.8846 - val_accuracy: 0.7961 - val_loss: 0.4195
# Epoch 41/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - AUC: 0.8807 - accuracy: 0.7960 - loss: 0.4265 - val_AUC: 0.8850 - val_accuracy: 0.7967 - val_loss: 0.4184
# Epoch 42/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 384ms/step - AUC: 0.8808 - accuracy: 0.7957 - loss: 0.4260 - val_AUC: 0.8847 - val_accuracy: 0.7960 - val_loss: 0.4191
# Epoch 43/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - AUC: 0.8816 - accuracy: 0.7963 - loss: 0.4247 - val_AUC: 0.8844 - val_accuracy: 0.7955 - val_loss: 0.4188
# Epoch 44/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 366ms/step - AUC: 0.8809 - accuracy: 0.7952 - loss: 0.4256 - val_AUC: 0.8847 - val_accuracy: 0.7963 - val_loss: 0.4186
# Epoch 45/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - AUC: 0.8791 - accuracy: 0.7933 - loss: 0.4287 - val_AUC: 0.8851 - val_accuracy: 0.7961 - val_loss: 0.4176
# Epoch 46/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - AUC: 0.8815 - accuracy: 0.7970 - loss: 0.4249 - val_AUC: 0.8850 - val_accuracy: 0.7966 - val_loss: 0.4182
# Epoch 47/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - AUC: 0.8823 - accuracy: 0.7965 - loss: 0.4235 - val_AUC: 0.8844 - val_accuracy: 0.7947 - val_loss: 0.4200
# Epoch 48/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - AUC: 0.8821 - accuracy: 0.7965 - loss: 0.4234 - val_AUC: 0.8869 - val_accuracy: 0.7975 - val_loss: 0.4151
# Epoch 49/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - AUC: 0.8836 - accuracy: 0.7978 - loss: 0.4211 - val_AUC: 0.8872 - val_accuracy: 0.7978 - val_loss: 0.4144
# Epoch 50/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 392ms/step - AUC: 0.8840 - accuracy: 0.7983 - loss: 0.4204 - val_AUC: 0.8813 - val_accuracy: 0.7909 - val_loss: 0.4346
# Epoch 51/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - AUC: 0.8774 - accuracy: 0.7920 - loss: 0.4311 - val_AUC: 0.8850 - val_accuracy: 0.7939 - val_loss: 0.4205
# Epoch 52/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 362ms/step - AUC: 0.8824 - accuracy: 0.7974 - loss: 0.4228 - val_AUC: 0.8854 - val_accuracy: 0.7965 - val_loss: 0.4169
# Epoch 53/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 366ms/step - AUC: 0.8832 - accuracy: 0.7975 - loss: 0.4215 - val_AUC: 0.8852 - val_accuracy: 0.7957 - val_loss: 0.4193
# Epoch 54/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - AUC: 0.8840 - accuracy: 0.7978 - loss: 0.4201 - val_AUC: 0.8874 - val_accuracy: 0.7979 - val_loss: 0.4137
# Epoch 55/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - AUC: 0.8844 - accuracy: 0.7984 - loss: 0.4195 - val_AUC: 0.8870 - val_accuracy: 0.7979 - val_loss: 0.4139
# Epoch 56/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - AUC: 0.8849 - accuracy: 0.7987 - loss: 0.4188 - val_AUC: 0.8861 - val_accuracy: 0.7975 - val_loss: 0.4161
# Epoch 57/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - AUC: 0.8827 - accuracy: 0.7966 - loss: 0.4224 - val_AUC: 0.8879 - val_accuracy: 0.7992 - val_loss: 0.4125
# Epoch 58/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - AUC: 0.8843 - accuracy: 0.7981 - loss: 0.4195 - val_AUC: 0.8863 - val_accuracy: 0.7959 - val_loss: 0.4167
# Epoch 59/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 360ms/step - AUC: 0.8847 - accuracy: 0.7975 - loss: 0.4187 - val_AUC: 0.8865 - val_accuracy: 0.7960 - val_loss: 0.4166
# Epoch 60/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 359ms/step - AUC: 0.8856 - accuracy: 0.7989 - loss: 0.4174 - val_AUC: 0.8887 - val_accuracy: 0.7985 - val_loss: 0.4119
# Epoch 61/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - AUC: 0.8870 - accuracy: 0.8003 - loss: 0.4150 - val_AUC: 0.8887 - val_accuracy: 0.7997 - val_loss: 0.4111
# Epoch 62/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - AUC: 0.8863 - accuracy: 0.7993 - loss: 0.4161 - val_AUC: 0.8894 - val_accuracy: 0.7996 - val_loss: 0.4101
# Epoch 63/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - AUC: 0.8874 - accuracy: 0.7997 - loss: 0.4144 - val_AUC: 0.8885 - val_accuracy: 0.7981 - val_loss: 0.4133
# Epoch 64/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 366ms/step - AUC: 0.8874 - accuracy: 0.8000 - loss: 0.4141 - val_AUC: 0.8888 - val_accuracy: 0.7996 - val_loss: 0.4108
# Epoch 65/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - AUC: 0.8861 - accuracy: 0.7990 - loss: 0.4165 - val_AUC: 0.8896 - val_accuracy: 0.8000 - val_loss: 0.4094
# Epoch 66/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - AUC: 0.8874 - accuracy: 0.8002 - loss: 0.4144 - val_AUC: 0.8890 - val_accuracy: 0.7998 - val_loss: 0.4103
# Epoch 67/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - AUC: 0.8862 - accuracy: 0.7995 - loss: 0.4162 - val_AUC: 0.8887 - val_accuracy: 0.7993 - val_loss: 0.4115
# Epoch 68/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 380ms/step - AUC: 0.8878 - accuracy: 0.8002 - loss: 0.4135 - val_AUC: 0.8882 - val_accuracy: 0.7975 - val_loss: 0.4134
# Epoch 69/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - AUC: 0.8868 - accuracy: 0.7993 - loss: 0.4153 - val_AUC: 0.8894 - val_accuracy: 0.7991 - val_loss: 0.4107
# Epoch 70/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - AUC: 0.8871 - accuracy: 0.7999 - loss: 0.4147 - val_AUC: 0.8892 - val_accuracy: 0.7996 - val_loss: 0.4098
# Epoch 71/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 389ms/step - AUC: 0.8867 - accuracy: 0.7987 - loss: 0.4151 - val_AUC: 0.8903 - val_accuracy: 0.8004 - val_loss: 0.4080
# Epoch 72/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - AUC: 0.8888 - accuracy: 0.8010 - loss: 0.4118 - val_AUC: 0.8879 - val_accuracy: 0.7974 - val_loss: 0.4139
# Epoch 73/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - AUC: 0.8884 - accuracy: 0.8006 - loss: 0.4122 - val_AUC: 0.8898 - val_accuracy: 0.8003 - val_loss: 0.4088
# Epoch 74/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - AUC: 0.8881 - accuracy: 0.8005 - loss: 0.4130 - val_AUC: 0.8903 - val_accuracy: 0.8011 - val_loss: 0.4078
# Epoch 75/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 378ms/step - AUC: 0.8871 - accuracy: 0.7995 - loss: 0.4146 - val_AUC: 0.8890 - val_accuracy: 0.7987 - val_loss: 0.4109
# Epoch 76/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - AUC: 0.8884 - accuracy: 0.8005 - loss: 0.4125 - val_AUC: 0.8907 - val_accuracy: 0.8003 - val_loss: 0.4074
# Epoch 77/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 380ms/step - AUC: 0.8880 - accuracy: 0.8003 - loss: 0.4131 - val_AUC: 0.8882 - val_accuracy: 0.7969 - val_loss: 0.4140
# Epoch 78/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - AUC: 0.8885 - accuracy: 0.8006 - loss: 0.4122 - val_AUC: 0.8905 - val_accuracy: 0.7996 - val_loss: 0.4080
# Epoch 79/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - AUC: 0.8890 - accuracy: 0.8011 - loss: 0.4111 - val_AUC: 0.8910 - val_accuracy: 0.8016 - val_loss: 0.4066
# Epoch 80/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - AUC: 0.8891 - accuracy: 0.8005 - loss: 0.4111 - val_AUC: 0.8895 - val_accuracy: 0.7988 - val_loss: 0.4098
# Epoch 81/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - AUC: 0.8898 - accuracy: 0.8013 - loss: 0.4098 - val_AUC: 0.8877 - val_accuracy: 0.7967 - val_loss: 0.4150
# Epoch 82/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 386ms/step - AUC: 0.8893 - accuracy: 0.8012 - loss: 0.4110 - val_AUC: 0.8877 - val_accuracy: 0.7965 - val_loss: 0.4166
# Epoch 83/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - AUC: 0.8884 - accuracy: 0.8004 - loss: 0.4125 - val_AUC: 0.8877 - val_accuracy: 0.7971 - val_loss: 0.4147
# Epoch 84/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 359ms/step - AUC: 0.8893 - accuracy: 0.8014 - loss: 0.4109 - val_AUC: 0.8903 - val_accuracy: 0.7999 - val_loss: 0.4084
# Epoch 85/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - AUC: 0.8898 - accuracy: 0.8018 - loss: 0.4097 - val_AUC: 0.8884 - val_accuracy: 0.7974 - val_loss: 0.4140
# Epoch 86/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - AUC: 0.8897 - accuracy: 0.8013 - loss: 0.4102 - val_AUC: 0.8869 - val_accuracy: 0.7947 - val_loss: 0.4170
# Epoch 87/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 381ms/step - AUC: 0.8889 - accuracy: 0.8004 - loss: 0.4114 - val_AUC: 0.8861 - val_accuracy: 0.7944 - val_loss: 0.4204
# Epoch 88/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - AUC: 0.8884 - accuracy: 0.8003 - loss: 0.4124 - val_AUC: 0.8904 - val_accuracy: 0.7995 - val_loss: 0.4087
# Epoch 89/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - AUC: 0.8906 - accuracy: 0.8020 - loss: 0.4083 - val_AUC: 0.8896 - val_accuracy: 0.7997 - val_loss: 0.4095
# Epoch 90/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - AUC: 0.8906 - accuracy: 0.8021 - loss: 0.4085 - val_AUC: 0.8889 - val_accuracy: 0.7981 - val_loss: 0.4113
# Epoch 91/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - AUC: 0.8907 - accuracy: 0.8022 - loss: 0.4082 - val_AUC: 0.8893 - val_accuracy: 0.7994 - val_loss: 0.4103
# Epoch 92/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 362ms/step - AUC: 0.8907 - accuracy: 0.8021 - loss: 0.4083 - val_AUC: 0.8911 - val_accuracy: 0.8007 - val_loss: 0.4067
# Epoch 93/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - AUC: 0.8915 - accuracy: 0.8029 - loss: 0.4070 - val_AUC: 0.8875 - val_accuracy: 0.7966 - val_loss: 0.4143
# Epoch 94/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 366ms/step - AUC: 0.8906 - accuracy: 0.8016 - loss: 0.4085 - val_AUC: 0.8881 - val_accuracy: 0.7971 - val_loss: 0.4131

# %% [markdown]
# ## Energy-Position Hidden Layer Model without BatchNorm

# %%
#Model Layers and Neuron Architecture ------------------------------------------------
input_image = Input(shape = (100,), name = 'image_input')
input_energy = Input(shape = (1,), name = 'energy_input')
input_position = Input(shape = (1,), name = 'position_input')

#Images hidden layers
image_ly = Dense(90, activation = 'gelu', name = 'im_ly_1')(input_image)
image_ly = Dense(80, activation = 'gelu', name = 'im_ly_2')(image_ly)
image_ly = Dense(60, activation = 'gelu', name = 'im_ly_3')(image_ly)
image_ly = Dense(50, activation = 'gelu', name = 'im_ly_4')(image_ly)
image_ly = Dense(30, activation = 'gelu', name = 'im_ly_5')(image_ly)

#Energy hidden layers
#energy_ly = Dense(10, activation = 'gelu', name = 'en_ly_1')(input_energy)
#energy_ly = Dense(5, activation = 'gelu', name = 'en_ly_2')(energy_ly)
energy_ly = Dense(2, activation = 'gelu', name = 'en_ly_3')(input_energy)
energy_ly = Dense(1, activation = 'gelu', name = 'en_ly_4')(energy_ly)

#Radius hidden layers
#position_ly = Dense(10, activation = 'gelu', name = 'pos_ly_1')(input_position)
#position_ly = Dense(5, activation = 'gelu', name = 'pos_ly_2')(position_ly)
position_ly = Dense(2, activation = 'gelu', name = 'pos_ly_3')(input_position)
position_ly = Dense(1, activation = 'gelu', name = 'pos_ly_4')(position_ly)


x = concatenate([image_ly, energy_ly, position_ly])

x = Dense(32, activation = 'gelu')(x)
x = Dense(28, activation = 'gelu')(x)
x = Dense(22, activation = 'gelu')(x)

x = Dropout(rate = 0.5)(x)

x = Dense(20, activation = 'gelu')(x)
x = Dense(15, activation = 'gelu')(x)
x = Dense(10, activation = 'gelu')(x)
x = Dense(5, activation = 'gelu')(x)

output_layer = Dense(2, activation = 'sigmoid', name = 'nu_predict')(x)
#-------------------------------------------------------------------------------------

model = Model(inputs = [input_image, input_energy, input_position], outputs = output_layer)

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-4),
              loss = tf.keras.losses.BinaryCrossentropy(), 
              metrics = ['AUC', 'accuracy'])


history = model.fit(x = {'image_input': pixel_train1_transf, 'energy_input': energy_train1_transf, 'position_input': position_train1_transf}, 
                    y = {'nu_predict':labels_train1}, 
                    epochs = 200, 
                    batch_size = 1000,
                    validation_data=([pixel_val_transf, energy_val_transf, position_val_transf], labels_val),
                    callbacks=[tf.keras.callbacks.EarlyStopping(patience = 25, min_delta = 1e-3, monitor="val_loss")],
                    shuffle = True)
# Out:
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - AUC: 0.5000 - accuracy: 0.5021 - loss: 0.6932 - val_AUC: 0.5000 - val_accuracy: 0.5004 - val_loss: 0.6931
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.5000 - accuracy: 0.5038 - loss: 0.6931 - val_AUC: 0.5000 - val_accuracy: 0.5178 - val_loss: 0.6930
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.5063 - accuracy: 0.5801 - loss: 0.6929 - val_AUC: 0.5592 - val_accuracy: 0.5463 - val_loss: 0.6914
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.5648 - accuracy: 0.5497 - loss: 0.6895 - val_AUC: 0.5755 - val_accuracy: 0.5554 - val_loss: 0.6852
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.5823 - accuracy: 0.5606 - loss: 0.6843 - val_AUC: 0.6017 - val_accuracy: 0.5726 - val_loss: 0.6805
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.6118 - accuracy: 0.5821 - loss: 0.6790 - val_AUC: 0.6425 - val_accuracy: 0.6092 - val_loss: 0.6727
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.6538 - accuracy: 0.6238 - loss: 0.6705 - val_AUC: 0.6693 - val_accuracy: 0.6619 - val_loss: 0.6619
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.6856 - accuracy: 0.6753 - loss: 0.6603 - val_AUC: 0.6977 - val_accuracy: 0.6843 - val_loss: 0.6546
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.6935 - accuracy: 0.6903 - loss: 0.6546 - val_AUC: 0.6926 - val_accuracy: 0.6938 - val_loss: 0.6494
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.6940 - accuracy: 0.6970 - loss: 0.6501 - val_AUC: 0.6901 - val_accuracy: 0.6977 - val_loss: 0.6457
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.6918 - accuracy: 0.6961 - loss: 0.6473 - val_AUC: 0.6859 - val_accuracy: 0.6971 - val_loss: 0.6428
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.6940 - accuracy: 0.6999 - loss: 0.6438 - val_AUC: 0.6931 - val_accuracy: 0.7031 - val_loss: 0.6400
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.6957 - accuracy: 0.7037 - loss: 0.6401 - val_AUC: 0.6851 - val_accuracy: 0.6968 - val_loss: 0.6375
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.6940 - accuracy: 0.7019 - loss: 0.6377 - val_AUC: 0.6941 - val_accuracy: 0.7055 - val_loss: 0.6340
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.6979 - accuracy: 0.7062 - loss: 0.6338 - val_AUC: 0.6940 - val_accuracy: 0.7079 - val_loss: 0.6291
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.7014 - accuracy: 0.7076 - loss: 0.6284 - val_AUC: 0.7088 - val_accuracy: 0.7157 - val_loss: 0.6195
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.7266 - accuracy: 0.7133 - loss: 0.6187 - val_AUC: 0.7561 - val_accuracy: 0.7204 - val_loss: 0.6002
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.7572 - accuracy: 0.7236 - loss: 0.6011 - val_AUC: 0.7947 - val_accuracy: 0.7258 - val_loss: 0.5754
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.7788 - accuracy: 0.7409 - loss: 0.5843 - val_AUC: 0.8071 - val_accuracy: 0.7719 - val_loss: 0.5620
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.7881 - accuracy: 0.7515 - loss: 0.5737 - val_AUC: 0.8129 - val_accuracy: 0.7854 - val_loss: 0.5542
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.7946 - accuracy: 0.7586 - loss: 0.5656 - val_AUC: 0.8056 - val_accuracy: 0.7728 - val_loss: 0.5536
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.7971 - accuracy: 0.7604 - loss: 0.5621 - val_AUC: 0.8150 - val_accuracy: 0.7835 - val_loss: 0.5447
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8024 - accuracy: 0.7656 - loss: 0.5560 - val_AUC: 0.8172 - val_accuracy: 0.7862 - val_loss: 0.5403
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8079 - accuracy: 0.7726 - loss: 0.5498 - val_AUC: 0.8177 - val_accuracy: 0.7869 - val_loss: 0.5374
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8088 - accuracy: 0.7680 - loss: 0.5477 - val_AUC: 0.8219 - val_accuracy: 0.7843 - val_loss: 0.5363
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8107 - accuracy: 0.7688 - loss: 0.5464 - val_AUC: 0.8190 - val_accuracy: 0.7853 - val_loss: 0.5332
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8138 - accuracy: 0.7732 - loss: 0.5426 - val_AUC: 0.8155 - val_accuracy: 0.7843 - val_loss: 0.5329
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8112 - accuracy: 0.7705 - loss: 0.5444 - val_AUC: 0.8201 - val_accuracy: 0.7868 - val_loss: 0.5291
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8183 - accuracy: 0.7756 - loss: 0.5368 - val_AUC: 0.8248 - val_accuracy: 0.7863 - val_loss: 0.5267
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8180 - accuracy: 0.7738 - loss: 0.5367 - val_AUC: 0.8251 - val_accuracy: 0.7857 - val_loss: 0.5251
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8215 - accuracy: 0.7774 - loss: 0.5327 - val_AUC: 0.8293 - val_accuracy: 0.7852 - val_loss: 0.5244
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8239 - accuracy: 0.7767 - loss: 0.5331 - val_AUC: 0.8309 - val_accuracy: 0.7847 - val_loss: 0.5234
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8229 - accuracy: 0.7741 - loss: 0.5326 - val_AUC: 0.8310 - val_accuracy: 0.7854 - val_loss: 0.5204
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8246 - accuracy: 0.7753 - loss: 0.5300 - val_AUC: 0.8285 - val_accuracy: 0.7875 - val_loss: 0.5190
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8253 - accuracy: 0.7781 - loss: 0.5275 - val_AUC: 0.8314 - val_accuracy: 0.7857 - val_loss: 0.5174
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8273 - accuracy: 0.7779 - loss: 0.5257 - val_AUC: 0.8274 - val_accuracy: 0.7857 - val_loss: 0.5176
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8260 - accuracy: 0.7781 - loss: 0.5268 - val_AUC: 0.8324 - val_accuracy: 0.7864 - val_loss: 0.5147
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8274 - accuracy: 0.7783 - loss: 0.5245 - val_AUC: 0.8332 - val_accuracy: 0.7870 - val_loss: 0.5135
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8300 - accuracy: 0.7809 - loss: 0.5216 - val_AUC: 0.8313 - val_accuracy: 0.7865 - val_loss: 0.5131
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8292 - accuracy: 0.7781 - loss: 0.5229 - val_AUC: 0.8312 - val_accuracy: 0.7863 - val_loss: 0.5115
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8305 - accuracy: 0.7804 - loss: 0.5203 - val_AUC: 0.8329 - val_accuracy: 0.7882 - val_loss: 0.5098
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8351 - accuracy: 0.7833 - loss: 0.5157 - val_AUC: 0.8381 - val_accuracy: 0.7864 - val_loss: 0.5090
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8347 - accuracy: 0.7825 - loss: 0.5158 - val_AUC: 0.8360 - val_accuracy: 0.7862 - val_loss: 0.5074
# Epoch 44/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8348 - accuracy: 0.7817 - loss: 0.5152 - val_AUC: 0.8418 - val_accuracy: 0.7839 - val_loss: 0.5067
# Epoch 45/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8344 - accuracy: 0.7807 - loss: 0.5158 - val_AUC: 0.8380 - val_accuracy: 0.7870 - val_loss: 0.5049
# Epoch 46/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8366 - accuracy: 0.7815 - loss: 0.5131 - val_AUC: 0.8422 - val_accuracy: 0.7862 - val_loss: 0.5041
# Epoch 47/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8392 - accuracy: 0.7836 - loss: 0.5101 - val_AUC: 0.8413 - val_accuracy: 0.7866 - val_loss: 0.5028
# Epoch 48/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8388 - accuracy: 0.7822 - loss: 0.5099 - val_AUC: 0.8414 - val_accuracy: 0.7866 - val_loss: 0.5025
# Epoch 49/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8400 - accuracy: 0.7850 - loss: 0.5071 - val_AUC: 0.8387 - val_accuracy: 0.7884 - val_loss: 0.5010
# Epoch 50/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8393 - accuracy: 0.7828 - loss: 0.5090 - val_AUC: 0.8417 - val_accuracy: 0.7868 - val_loss: 0.4997
# Epoch 51/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8423 - accuracy: 0.7834 - loss: 0.5056 - val_AUC: 0.8439 - val_accuracy: 0.7867 - val_loss: 0.4985
# Epoch 52/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8403 - accuracy: 0.7836 - loss: 0.5065 - val_AUC: 0.8459 - val_accuracy: 0.7872 - val_loss: 0.4978
# Epoch 53/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8428 - accuracy: 0.7838 - loss: 0.5046 - val_AUC: 0.8459 - val_accuracy: 0.7862 - val_loss: 0.4982
# Epoch 54/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8448 - accuracy: 0.7863 - loss: 0.5017 - val_AUC: 0.8466 - val_accuracy: 0.7874 - val_loss: 0.4965
# Epoch 55/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8456 - accuracy: 0.7858 - loss: 0.5003 - val_AUC: 0.8473 - val_accuracy: 0.7867 - val_loss: 0.4947
# Epoch 56/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8453 - accuracy: 0.7847 - loss: 0.5013 - val_AUC: 0.8470 - val_accuracy: 0.7873 - val_loss: 0.4937
# Epoch 57/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8439 - accuracy: 0.7824 - loss: 0.5020 - val_AUC: 0.8490 - val_accuracy: 0.7865 - val_loss: 0.4928
# Epoch 58/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8472 - accuracy: 0.7859 - loss: 0.4975 - val_AUC: 0.8506 - val_accuracy: 0.7882 - val_loss: 0.4921
# Epoch 59/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8498 - accuracy: 0.7865 - loss: 0.4965 - val_AUC: 0.8531 - val_accuracy: 0.7872 - val_loss: 0.4917
# Epoch 60/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8472 - accuracy: 0.7864 - loss: 0.4972 - val_AUC: 0.8490 - val_accuracy: 0.7891 - val_loss: 0.4904
# Epoch 61/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8508 - accuracy: 0.7890 - loss: 0.4931 - val_AUC: 0.8557 - val_accuracy: 0.7855 - val_loss: 0.4909
# Epoch 62/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8494 - accuracy: 0.7863 - loss: 0.4954 - val_AUC: 0.8518 - val_accuracy: 0.7884 - val_loss: 0.4882
# Epoch 63/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8497 - accuracy: 0.7873 - loss: 0.4934 - val_AUC: 0.8524 - val_accuracy: 0.7886 - val_loss: 0.4876
# Epoch 64/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8511 - accuracy: 0.7870 - loss: 0.4924 - val_AUC: 0.8573 - val_accuracy: 0.7865 - val_loss: 0.4871
# Epoch 65/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8508 - accuracy: 0.7863 - loss: 0.4931 - val_AUC: 0.8548 - val_accuracy: 0.7881 - val_loss: 0.4860
# Epoch 66/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8523 - accuracy: 0.7854 - loss: 0.4910 - val_AUC: 0.8558 - val_accuracy: 0.7855 - val_loss: 0.4861
# Epoch 67/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8516 - accuracy: 0.7854 - loss: 0.4923 - val_AUC: 0.8548 - val_accuracy: 0.7881 - val_loss: 0.4844
# Epoch 68/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8522 - accuracy: 0.7904 - loss: 0.4892 - val_AUC: 0.8560 - val_accuracy: 0.7885 - val_loss: 0.4835
# Epoch 69/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8518 - accuracy: 0.7847 - loss: 0.4918 - val_AUC: 0.8579 - val_accuracy: 0.7885 - val_loss: 0.4830
# Epoch 70/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8549 - accuracy: 0.7893 - loss: 0.4866 - val_AUC: 0.8602 - val_accuracy: 0.7855 - val_loss: 0.4829
# Epoch 71/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8558 - accuracy: 0.7881 - loss: 0.4862 - val_AUC: 0.8601 - val_accuracy: 0.7889 - val_loss: 0.4816
# Epoch 72/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8565 - accuracy: 0.7888 - loss: 0.4851 - val_AUC: 0.8591 - val_accuracy: 0.7891 - val_loss: 0.4807
# Epoch 73/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8571 - accuracy: 0.7876 - loss: 0.4853 - val_AUC: 0.8599 - val_accuracy: 0.7894 - val_loss: 0.4802
# Epoch 74/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8564 - accuracy: 0.7884 - loss: 0.4852 - val_AUC: 0.8552 - val_accuracy: 0.7885 - val_loss: 0.4825
# Epoch 75/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8558 - accuracy: 0.7870 - loss: 0.4856 - val_AUC: 0.8629 - val_accuracy: 0.7885 - val_loss: 0.4786
# Epoch 76/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8591 - accuracy: 0.7874 - loss: 0.4826 - val_AUC: 0.8613 - val_accuracy: 0.7890 - val_loss: 0.4788
# Epoch 77/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8610 - accuracy: 0.7909 - loss: 0.4794 - val_AUC: 0.8627 - val_accuracy: 0.7880 - val_loss: 0.4798
# Epoch 78/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8611 - accuracy: 0.7888 - loss: 0.4798 - val_AUC: 0.8655 - val_accuracy: 0.7889 - val_loss: 0.4766
# Epoch 79/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8599 - accuracy: 0.7901 - loss: 0.4814 - val_AUC: 0.8655 - val_accuracy: 0.7877 - val_loss: 0.4763
# Epoch 80/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8599 - accuracy: 0.7880 - loss: 0.4806 - val_AUC: 0.8660 - val_accuracy: 0.7892 - val_loss: 0.4755
# Epoch 81/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8614 - accuracy: 0.7903 - loss: 0.4782 - val_AUC: 0.8665 - val_accuracy: 0.7892 - val_loss: 0.4752
# Epoch 82/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8625 - accuracy: 0.7900 - loss: 0.4778 - val_AUC: 0.8657 - val_accuracy: 0.7892 - val_loss: 0.4751
# Epoch 83/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8603 - accuracy: 0.7876 - loss: 0.4800 - val_AUC: 0.8669 - val_accuracy: 0.7892 - val_loss: 0.4738
# Epoch 84/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8618 - accuracy: 0.7901 - loss: 0.4775 - val_AUC: 0.8674 - val_accuracy: 0.7893 - val_loss: 0.4733
# Epoch 85/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8627 - accuracy: 0.7903 - loss: 0.4762 - val_AUC: 0.8681 - val_accuracy: 0.7888 - val_loss: 0.4726
# Epoch 86/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8644 - accuracy: 0.7908 - loss: 0.4742 - val_AUC: 0.8659 - val_accuracy: 0.7891 - val_loss: 0.4742
# Epoch 87/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8613 - accuracy: 0.7894 - loss: 0.4771 - val_AUC: 0.8685 - val_accuracy: 0.7887 - val_loss: 0.4716
# Epoch 88/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8631 - accuracy: 0.7890 - loss: 0.4752 - val_AUC: 0.8681 - val_accuracy: 0.7896 - val_loss: 0.4725
# Epoch 89/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8652 - accuracy: 0.7909 - loss: 0.4735 - val_AUC: 0.8698 - val_accuracy: 0.7895 - val_loss: 0.4703
# Epoch 90/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8652 - accuracy: 0.7901 - loss: 0.4733 - val_AUC: 0.8687 - val_accuracy: 0.7897 - val_loss: 0.4706
# Epoch 91/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8647 - accuracy: 0.7922 - loss: 0.4723 - val_AUC: 0.8704 - val_accuracy: 0.7888 - val_loss: 0.4693
# Epoch 92/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8632 - accuracy: 0.7887 - loss: 0.4749 - val_AUC: 0.8685 - val_accuracy: 0.7889 - val_loss: 0.4700
# Epoch 93/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8647 - accuracy: 0.7913 - loss: 0.4722 - val_AUC: 0.8693 - val_accuracy: 0.7862 - val_loss: 0.4704
# Epoch 94/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8665 - accuracy: 0.7899 - loss: 0.4701 - val_AUC: 0.8706 - val_accuracy: 0.7883 - val_loss: 0.4680
# Epoch 95/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8669 - accuracy: 0.7906 - loss: 0.4698 - val_AUC: 0.8706 - val_accuracy: 0.7892 - val_loss: 0.4676
# Epoch 96/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8659 - accuracy: 0.7908 - loss: 0.4705 - val_AUC: 0.8706 - val_accuracy: 0.7872 - val_loss: 0.4677
# Epoch 97/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8652 - accuracy: 0.7895 - loss: 0.4712 - val_AUC: 0.8705 - val_accuracy: 0.7897 - val_loss: 0.4670
# Epoch 98/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8653 - accuracy: 0.7917 - loss: 0.4704 - val_AUC: 0.8714 - val_accuracy: 0.7890 - val_loss: 0.4660
# Epoch 99/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8676 - accuracy: 0.7926 - loss: 0.4678 - val_AUC: 0.8706 - val_accuracy: 0.7901 - val_loss: 0.4661
# Epoch 100/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8691 - accuracy: 0.7929 - loss: 0.4656 - val_AUC: 0.8712 - val_accuracy: 0.7892 - val_loss: 0.4652
# Epoch 101/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8655 - accuracy: 0.7889 - loss: 0.4702 - val_AUC: 0.8698 - val_accuracy: 0.7897 - val_loss: 0.4663
# Epoch 102/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8686 - accuracy: 0.7922 - loss: 0.4658 - val_AUC: 0.8715 - val_accuracy: 0.7893 - val_loss: 0.4643
# Epoch 103/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8669 - accuracy: 0.7918 - loss: 0.4675 - val_AUC: 0.8705 - val_accuracy: 0.7862 - val_loss: 0.4658
# Epoch 104/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8675 - accuracy: 0.7909 - loss: 0.4660 - val_AUC: 0.8713 - val_accuracy: 0.7896 - val_loss: 0.4641
# Epoch 105/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8685 - accuracy: 0.7897 - loss: 0.4656 - val_AUC: 0.8706 - val_accuracy: 0.7903 - val_loss: 0.4642
# Epoch 106/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8690 - accuracy: 0.7931 - loss: 0.4637 - val_AUC: 0.8713 - val_accuracy: 0.7873 - val_loss: 0.4640
# Epoch 107/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8685 - accuracy: 0.7920 - loss: 0.4645 - val_AUC: 0.8705 - val_accuracy: 0.7893 - val_loss: 0.4638
# Epoch 108/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8686 - accuracy: 0.7929 - loss: 0.4642 - val_AUC: 0.8715 - val_accuracy: 0.7900 - val_loss: 0.4624
# Epoch 109/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8674 - accuracy: 0.7892 - loss: 0.4657 - val_AUC: 0.8710 - val_accuracy: 0.7871 - val_loss: 0.4632
# Epoch 110/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8677 - accuracy: 0.7908 - loss: 0.4646 - val_AUC: 0.8719 - val_accuracy: 0.7885 - val_loss: 0.4615
# Epoch 111/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8680 - accuracy: 0.7912 - loss: 0.4640 - val_AUC: 0.8718 - val_accuracy: 0.7901 - val_loss: 0.4612
# Epoch 112/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8688 - accuracy: 0.7930 - loss: 0.4626 - val_AUC: 0.8724 - val_accuracy: 0.7887 - val_loss: 0.4604
# Epoch 113/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8675 - accuracy: 0.7900 - loss: 0.4644 - val_AUC: 0.8724 - val_accuracy: 0.7887 - val_loss: 0.4599
# Epoch 114/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8685 - accuracy: 0.7917 - loss: 0.4627 - val_AUC: 0.8710 - val_accuracy: 0.7895 - val_loss: 0.4610
# Epoch 115/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8687 - accuracy: 0.7914 - loss: 0.4623 - val_AUC: 0.8724 - val_accuracy: 0.7889 - val_loss: 0.4595
# Epoch 116/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8699 - accuracy: 0.7927 - loss: 0.4603 - val_AUC: 0.8725 - val_accuracy: 0.7896 - val_loss: 0.4589
# Epoch 117/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8698 - accuracy: 0.7913 - loss: 0.4607 - val_AUC: 0.8713 - val_accuracy: 0.7893 - val_loss: 0.4598
# Epoch 118/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8701 - accuracy: 0.7931 - loss: 0.4595 - val_AUC: 0.8724 - val_accuracy: 0.7896 - val_loss: 0.4583
# Epoch 119/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8693 - accuracy: 0.7924 - loss: 0.4605 - val_AUC: 0.8722 - val_accuracy: 0.7882 - val_loss: 0.4588
# Epoch 120/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8700 - accuracy: 0.7908 - loss: 0.4598 - val_AUC: 0.8720 - val_accuracy: 0.7884 - val_loss: 0.4581
# Epoch 121/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8702 - accuracy: 0.7928 - loss: 0.4589 - val_AUC: 0.8726 - val_accuracy: 0.7889 - val_loss: 0.4575
# Epoch 122/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8717 - accuracy: 0.7949 - loss: 0.4563 - val_AUC: 0.8721 - val_accuracy: 0.7883 - val_loss: 0.4577
# Epoch 123/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8709 - accuracy: 0.7919 - loss: 0.4577 - val_AUC: 0.8725 - val_accuracy: 0.7901 - val_loss: 0.4570
# Epoch 124/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8714 - accuracy: 0.7938 - loss: 0.4566 - val_AUC: 0.8718 - val_accuracy: 0.7897 - val_loss: 0.4572
# Epoch 125/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8689 - accuracy: 0.7910 - loss: 0.4596 - val_AUC: 0.8697 - val_accuracy: 0.7885 - val_loss: 0.4596
# Epoch 126/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - AUC: 0.8684 - accuracy: 0.7902 - loss: 0.4601 - val_AUC: 0.8708 - val_accuracy: 0.7892 - val_loss: 0.4578
# Epoch 127/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8678 - accuracy: 0.7890 - loss: 0.4607 - val_AUC: 0.8724 - val_accuracy: 0.7899 - val_loss: 0.4558
# Epoch 128/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8702 - accuracy: 0.7930 - loss: 0.4571 - val_AUC: 0.8727 - val_accuracy: 0.7901 - val_loss: 0.4556
# Epoch 129/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8713 - accuracy: 0.7938 - loss: 0.4556 - val_AUC: 0.8720 - val_accuracy: 0.7889 - val_loss: 0.4556
# Epoch 130/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8670 - accuracy: 0.7898 - loss: 0.4607 - val_AUC: 0.8727 - val_accuracy: 0.7906 - val_loss: 0.4551
# Epoch 131/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8704 - accuracy: 0.7915 - loss: 0.4563 - val_AUC: 0.8726 - val_accuracy: 0.7898 - val_loss: 0.4548
# Epoch 132/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8705 - accuracy: 0.7921 - loss: 0.4560 - val_AUC: 0.8728 - val_accuracy: 0.7897 - val_loss: 0.4546
# Epoch 133/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8720 - accuracy: 0.7935 - loss: 0.4538 - val_AUC: 0.8712 - val_accuracy: 0.7876 - val_loss: 0.4556
# Epoch 134/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8703 - accuracy: 0.7930 - loss: 0.4557 - val_AUC: 0.8725 - val_accuracy: 0.7895 - val_loss: 0.4551
# Epoch 135/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8704 - accuracy: 0.7931 - loss: 0.4552 - val_AUC: 0.8723 - val_accuracy: 0.7893 - val_loss: 0.4538
# Epoch 136/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8713 - accuracy: 0.7944 - loss: 0.4540 - val_AUC: 0.8714 - val_accuracy: 0.7893 - val_loss: 0.4549
# Epoch 137/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8705 - accuracy: 0.7903 - loss: 0.4550 - val_AUC: 0.8726 - val_accuracy: 0.7903 - val_loss: 0.4534
# Epoch 138/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8709 - accuracy: 0.7919 - loss: 0.4544 - val_AUC: 0.8717 - val_accuracy: 0.7896 - val_loss: 0.4542
# Epoch 139/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8700 - accuracy: 0.7917 - loss: 0.4553 - val_AUC: 0.8724 - val_accuracy: 0.7903 - val_loss: 0.4538
# Epoch 140/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8715 - accuracy: 0.7931 - loss: 0.4531 - val_AUC: 0.8723 - val_accuracy: 0.7896 - val_loss: 0.4530
# Epoch 141/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8694 - accuracy: 0.7915 - loss: 0.4556 - val_AUC: 0.8729 - val_accuracy: 0.7896 - val_loss: 0.4520
# Epoch 142/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8721 - accuracy: 0.7942 - loss: 0.4516 - val_AUC: 0.8728 - val_accuracy: 0.7896 - val_loss: 0.4518
# Epoch 143/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8732 - accuracy: 0.7952 - loss: 0.4501 - val_AUC: 0.8726 - val_accuracy: 0.7887 - val_loss: 0.4522
# Epoch 144/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8722 - accuracy: 0.7943 - loss: 0.4510 - val_AUC: 0.8728 - val_accuracy: 0.7899 - val_loss: 0.4515
# Epoch 145/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8711 - accuracy: 0.7934 - loss: 0.4524 - val_AUC: 0.8725 - val_accuracy: 0.7898 - val_loss: 0.4517
# Epoch 146/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8707 - accuracy: 0.7927 - loss: 0.4532 - val_AUC: 0.8731 - val_accuracy: 0.7901 - val_loss: 0.4511
# Epoch 147/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8725 - accuracy: 0.7943 - loss: 0.4502 - val_AUC: 0.8724 - val_accuracy: 0.7897 - val_loss: 0.4526
# Epoch 148/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8692 - accuracy: 0.7922 - loss: 0.4544 - val_AUC: 0.8730 - val_accuracy: 0.7910 - val_loss: 0.4511
# Epoch 149/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8717 - accuracy: 0.7933 - loss: 0.4515 - val_AUC: 0.8729 - val_accuracy: 0.7897 - val_loss: 0.4506
# Epoch 150/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8714 - accuracy: 0.7948 - loss: 0.4509 - val_AUC: 0.8726 - val_accuracy: 0.7885 - val_loss: 0.4508
# Epoch 151/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8717 - accuracy: 0.7925 - loss: 0.4510 - val_AUC: 0.8726 - val_accuracy: 0.7894 - val_loss: 0.4513
# Epoch 152/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8728 - accuracy: 0.7935 - loss: 0.4492 - val_AUC: 0.8727 - val_accuracy: 0.7899 - val_loss: 0.4503
# Epoch 153/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8734 - accuracy: 0.7953 - loss: 0.4481 - val_AUC: 0.8731 - val_accuracy: 0.7903 - val_loss: 0.4497
# Epoch 154/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8725 - accuracy: 0.7934 - loss: 0.4494 - val_AUC: 0.8725 - val_accuracy: 0.7893 - val_loss: 0.4502
# Epoch 155/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8725 - accuracy: 0.7944 - loss: 0.4489 - val_AUC: 0.8731 - val_accuracy: 0.7900 - val_loss: 0.4491
# Epoch 156/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8734 - accuracy: 0.7949 - loss: 0.4477 - val_AUC: 0.8730 - val_accuracy: 0.7898 - val_loss: 0.4497
# Epoch 157/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8711 - accuracy: 0.7915 - loss: 0.4507 - val_AUC: 0.8728 - val_accuracy: 0.7899 - val_loss: 0.4489
# Epoch 158/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8723 - accuracy: 0.7950 - loss: 0.4487 - val_AUC: 0.8724 - val_accuracy: 0.7898 - val_loss: 0.4494
# Epoch 159/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8710 - accuracy: 0.7928 - loss: 0.4501 - val_AUC: 0.8729 - val_accuracy: 0.7899 - val_loss: 0.4489
# Epoch 160/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8722 - accuracy: 0.7942 - loss: 0.4486 - val_AUC: 0.8727 - val_accuracy: 0.7892 - val_loss: 0.4504
# Epoch 161/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8739 - accuracy: 0.7959 - loss: 0.4461 - val_AUC: 0.8734 - val_accuracy: 0.7901 - val_loss: 0.4480
# Epoch 162/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8712 - accuracy: 0.7932 - loss: 0.4497 - val_AUC: 0.8730 - val_accuracy: 0.7902 - val_loss: 0.4488
# Epoch 163/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8714 - accuracy: 0.7939 - loss: 0.4493 - val_AUC: 0.8724 - val_accuracy: 0.7897 - val_loss: 0.4489
# Epoch 164/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8711 - accuracy: 0.7910 - loss: 0.4495 - val_AUC: 0.8731 - val_accuracy: 0.7901 - val_loss: 0.4480
# Epoch 165/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8739 - accuracy: 0.7952 - loss: 0.4456 - val_AUC: 0.8731 - val_accuracy: 0.7902 - val_loss: 0.4473
# Epoch 166/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8737 - accuracy: 0.7950 - loss: 0.4456 - val_AUC: 0.8733 - val_accuracy: 0.7902 - val_loss: 0.4472
# Epoch 167/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8702 - accuracy: 0.7902 - loss: 0.4504 - val_AUC: 0.8726 - val_accuracy: 0.7896 - val_loss: 0.4480
# Epoch 168/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8717 - accuracy: 0.7933 - loss: 0.4482 - val_AUC: 0.8733 - val_accuracy: 0.7901 - val_loss: 0.4470
# Epoch 169/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8706 - accuracy: 0.7919 - loss: 0.4499 - val_AUC: 0.8717 - val_accuracy: 0.7888 - val_loss: 0.4483
# Epoch 170/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8744 - accuracy: 0.7956 - loss: 0.4439 - val_AUC: 0.8732 - val_accuracy: 0.7899 - val_loss: 0.4466
# Epoch 171/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8722 - accuracy: 0.7942 - loss: 0.4473 - val_AUC: 0.8729 - val_accuracy: 0.7897 - val_loss: 0.4481
# Epoch 172/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8722 - accuracy: 0.7934 - loss: 0.4473 - val_AUC: 0.8725 - val_accuracy: 0.7898 - val_loss: 0.4478
# Epoch 173/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8736 - accuracy: 0.7947 - loss: 0.4450 - val_AUC: 0.8734 - val_accuracy: 0.7901 - val_loss: 0.4467
# Epoch 174/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8726 - accuracy: 0.7938 - loss: 0.4464 - val_AUC: 0.8711 - val_accuracy: 0.7886 - val_loss: 0.4490
# Epoch 175/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8736 - accuracy: 0.7940 - loss: 0.4446 - val_AUC: 0.8716 - val_accuracy: 0.7891 - val_loss: 0.4486
# Epoch 176/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8739 - accuracy: 0.7957 - loss: 0.4445 - val_AUC: 0.8729 - val_accuracy: 0.7901 - val_loss: 0.4465
# Epoch 177/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8728 - accuracy: 0.7933 - loss: 0.4458 - val_AUC: 0.8726 - val_accuracy: 0.7892 - val_loss: 0.4462
# Epoch 178/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8716 - accuracy: 0.7937 - loss: 0.4472 - val_AUC: 0.8721 - val_accuracy: 0.7898 - val_loss: 0.4473
# Epoch 179/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8726 - accuracy: 0.7944 - loss: 0.4459 - val_AUC: 0.8734 - val_accuracy: 0.7908 - val_loss: 0.4457
# Epoch 180/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8724 - accuracy: 0.7939 - loss: 0.4458 - val_AUC: 0.8726 - val_accuracy: 0.7899 - val_loss: 0.4468
# Epoch 181/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8718 - accuracy: 0.7928 - loss: 0.4469 - val_AUC: 0.8733 - val_accuracy: 0.7898 - val_loss: 0.4452
# Epoch 182/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8745 - accuracy: 0.7962 - loss: 0.4427 - val_AUC: 0.8722 - val_accuracy: 0.7890 - val_loss: 0.4461
# Epoch 183/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8711 - accuracy: 0.7925 - loss: 0.4472 - val_AUC: 0.8729 - val_accuracy: 0.7898 - val_loss: 0.4470
# Epoch 184/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8729 - accuracy: 0.7935 - loss: 0.4452 - val_AUC: 0.8734 - val_accuracy: 0.7898 - val_loss: 0.4450
# Epoch 185/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8715 - accuracy: 0.7941 - loss: 0.4467 - val_AUC: 0.8735 - val_accuracy: 0.7901 - val_loss: 0.4451
# Epoch 186/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8738 - accuracy: 0.7963 - loss: 0.4432 - val_AUC: 0.8730 - val_accuracy: 0.7892 - val_loss: 0.4449
# Epoch 187/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8744 - accuracy: 0.7962 - loss: 0.4426 - val_AUC: 0.8731 - val_accuracy: 0.7899 - val_loss: 0.4451
# Epoch 188/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8737 - accuracy: 0.7946 - loss: 0.4435 - val_AUC: 0.8734 - val_accuracy: 0.7904 - val_loss: 0.4444
# Epoch 189/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8738 - accuracy: 0.7951 - loss: 0.4429 - val_AUC: 0.8736 - val_accuracy: 0.7906 - val_loss: 0.4442
# Epoch 190/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8737 - accuracy: 0.7962 - loss: 0.4429 - val_AUC: 0.8735 - val_accuracy: 0.7902 - val_loss: 0.4446
# Epoch 191/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8728 - accuracy: 0.7945 - loss: 0.4441 - val_AUC: 0.8729 - val_accuracy: 0.7900 - val_loss: 0.4446
# Epoch 192/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8732 - accuracy: 0.7949 - loss: 0.4434 - val_AUC: 0.8736 - val_accuracy: 0.7904 - val_loss: 0.4439
# Epoch 193/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8730 - accuracy: 0.7926 - loss: 0.4438 - val_AUC: 0.8733 - val_accuracy: 0.7902 - val_loss: 0.4439
# Epoch 194/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8742 - accuracy: 0.7964 - loss: 0.4421 - val_AUC: 0.8733 - val_accuracy: 0.7900 - val_loss: 0.4438
# Epoch 195/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8725 - accuracy: 0.7935 - loss: 0.4444 - val_AUC: 0.8734 - val_accuracy: 0.7898 - val_loss: 0.4437
# Epoch 196/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8749 - accuracy: 0.7954 - loss: 0.4414 - val_AUC: 0.8731 - val_accuracy: 0.7897 - val_loss: 0.4438
# Epoch 197/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8742 - accuracy: 0.7950 - loss: 0.4420 - val_AUC: 0.8735 - val_accuracy: 0.7903 - val_loss: 0.4438
# Epoch 198/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8747 - accuracy: 0.7957 - loss: 0.4410 - val_AUC: 0.8728 - val_accuracy: 0.7902 - val_loss: 0.4446
# Epoch 199/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - AUC: 0.8737 - accuracy: 0.7947 - loss: 0.4426 - val_AUC: 0.8726 - val_accuracy: 0.7894 - val_loss: 0.4457
# Epoch 200/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8721 - accuracy: 0.7949 - loss: 0.4441 - val_AUC: 0.8716 - val_accuracy: 0.7888 - val_loss: 0.4473

# %% [markdown]
# ## Learning Curves

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
fig, axes = plt.subplots(1,2, figsize=(15, 5))

axes[0].plot(history.history['loss'], 'b:.', label = ' Train Loss')
axes[0].plot(history.history['val_loss'], 'r:.', label = ' Validation Loss')
axes[0].plot(history.history['accuracy'], 'g:.',  label = ' Train Accuracy')
axes[0].plot(history.history['val_accuracy'], 'c:.', label = ' Validation Accuracy')
axes[1].plot(history.history['AUC'], 'b:.',  label = ' Train AUC')
axes[1].plot(history.history['val_AUC'], 'r:.', label = ' Validation AUC')

axes[0].set_title('Loss and Validation Curves', fontsize = 10)
axes[0].set_xlabel('epoch')
axes[0].legend(loc = 'best')
axes[1].set_title('AUC Value Curve', fontsize = 10)
axes[1].set_xlabel('epoch')
axes[1].legend(loc = 'lower right')

#axes[0].set_ylim(0, 1.2)
#axes[1].set_ylim(0, 1.05)

#axes[0].set_xlim(-2, len(history.history['loss']))
#axes[1].set_xlim(-2, len(history.history['loss']))

fig.suptitle(f'Train and Validation Progress - Energy : [2.5, {energy_cut_train}] MeV - R < 5500 (mm)', backgroundcolor='blue', color='white', fontsize = 10)
plt.show()

# %% [markdown]
# # Model Predictions

# %%
X_sig_pred = model.predict([pixel_test_transf_sig, energy_test_transf_sig, position_test_transf_sig])
X_bkg_pred = model.predict([pixel_test_transf_bkg, energy_test_transf_bkg, position_test_transf_bkg])
# Out:
# 1397/1397 ━━━━━━━━━━━━━━━━━━━━ 1s 918us/step
# 1397/1397 ━━━━━━━━━━━━━━━━━━━━ 1s 795us/step

# %%
X_sig_pred
# Out:
# array([[9.0400410e-01, 8.5194468e-02],
#        [2.5142029e-01, 7.4956107e-01],
#        [2.3342474e-01, 7.6516730e-01],
#        ...,
#        [9.9996328e-01, 4.2152988e-07],
#        [9.7660291e-01, 9.9876476e-03],
#        [4.2255577e-01, 6.0438263e-01]], dtype=float32)

# %%
sn.reset_orig
bins = 65
fig, axes = plt.subplots(1, 2,  figsize=(22, 7))

sn.histplot(X_sig_pred[:,0], bins = bins, label = 'SAS', color = 'r', alpha = 0.6, ax = axes[0], log = True)
sn.histplot(X_sig_pred[:,1], bins = bins, label = 'SAB', color = 'b', alpha = 0.6, ax = axes[0])
sn.histplot(X_bkg_pred[:,0], bins = bins, label = 'BAS',color = 'b', alpha = 0.6, ax = axes[1], log = True)
sn.histplot(X_bkg_pred[:,1], bins = bins, label = 'BAB', color = 'r', alpha = 0.6, ax = axes[1])
axes[0].set_title('Probability Components for Solar $ν$ Predictions', fontsize = 10)
axes[1].set_title('Probability Components for Background Predictions', fontsize = 10)
axes[0].legend(loc = 'best')
axes[1].legend(loc = 'best')
plt.suptitle(f'Model Predictions for Solar $^8$B-$ν_e$ events and Background events - Energy : [2.5, {energy_cut_train}] MeV - R < 5500 (mm)', backgroundcolor='blue', color='white')
plt.show()

# %% [markdown]
# ## ROC Curve

# %%
X_pred = np.concatenate((X_sig_pred, X_bkg_pred))              #Predicted
X_exp = np.concatenate((labels_test_sig, labels_test_bkg))     #Expected

# Classification for solar_nu events
fpr_sig, tpr_sig, thresholds_sig = roc_curve(X_exp[:,0], X_pred[:,0])
auc_sig = auc(fpr_sig, tpr_sig)

# Classification for bkg events
fpr_bkg, tpr_bkg, thresholds_bkg = roc_curve(X_exp[:,1], X_pred[:,1])
auc_bkg = auc(fpr_bkg, tpr_bkg)

# Classification overall Model

fpr, tpr, thresholds = roc_curve(np.concatenate((X_exp[:,0], X_exp[:,1])), np.concatenate((X_pred[:,0], X_pred[:,1])))
auc_val = auc(fpr, tpr)

# %%
fig, axes = plt.subplots(1, 2,  figsize=(14, 5))


axes[0].plot([0, 1], [0, 1], 'k--') #x=y
axes[0].plot(fpr_sig, tpr_sig, 'r:,', label = 'sig ROC (area = {:.4f})'.format(auc_sig))
axes[0].plot(fpr_bkg, tpr_bkg, 'b:,', label = 'bkg ROC (area = {:.4f})'.format(auc_bkg))

axes[1].plot([0, 1], [0, 1], 'k--') #x=y
axes[1].plot(fpr, tpr, 'b:,', label = 'ROC over all Model (area = {:.4f})'.format(auc_val))

axes[0].set_ylabel('True Positive Rate')
axes[0].set_xlabel('False Positive Rate')
axes[1].set_ylabel('True Positive Rate')
axes[1].set_xlabel('False Positive Rate')

axes[0].legend(loc = 'lower right')
axes[1].legend(loc = 'lower right')

fig.suptitle(f'ROC curve for Model Predictions - Energy : [2.5, {energy_cut_train}] MeV - R < 5500 (mm)', fontsize = 10)

#plt.savefig('figs/Optimized Models/10x10/ROC.png', format = 'png', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Recovery Spectrum with thr Values

# %% [markdown]
# ### Inverse of Data Transformation

# %%
energy_sig_rc = scaler_energy_test.inverse_transform([energy_test_transf_sig])[0]
energy_bkg_rc = scaler_energy_test.inverse_transform([energy_test_transf_bkg])[0]

# Volume Normalization + Std Scaler: la formula es (R_ev^3)/(5000^3) y queremos recuperar R_ev
#Recover from Transformation Rule
position_sig_rc = scaler_position_test.inverse_transform([position_test_transf_sig])[0]
position_bkg_rc = scaler_position_test.inverse_transform([position_test_transf_bkg])[0]

#Recover the radius values from the Volume
radi_sig_rc = np.cbrt(position_sig_rc*vol)
radi_bkg_rc = np.cbrt(position_bkg_rc*vol)

# %% [markdown]
# ### Extract Data Plots

# %%
#Idea: A cada loop de thr, agregar a las listas arrays de energia reconstruida y de eficiciencia normalizada, asi cada indice de lista corresponde a un thr

bins_nu = 15             #-> Define how many intervals in energy. Equals to the number of point of norm_eff. PREDEFINED BINS = 20
bins_tl = 8              #-> BINS = 8

thr = [0.95, 0.8, 0.70]  #-> Define the thresholds

prob_sas = X_sig_pred[:,0]      #probiblity of the event of neutrino being detected as neutrino
#prob_bab = X_bkg_pred[:,1]      #probiblity of the event of thallium being detected as thallium
prob_bas = X_bkg_pred[:,0]      #probiblity of the event of thallium being detected as neutrino

en_sig_test_count, en_sig_test_edge = np.histogram(energy_sig_rc, bins = bins_nu)   #Extract interval of binned data
en_bkg_test_count, en_bkg_test_edge = np.histogram(energy_bkg_rc, bins = bins_tl)   #Extract interval of binned data


N_edges_sig = len(en_sig_test_edge)
N_edges_bkg = len(en_bkg_test_edge)

#Information to extract--------------------------------------
nu_energy_in_sas = []
#nu_energy_out_sas = []

tl_energy_in_bas = []
#tl_energy_out_bab = []

#mean normalized eficiency values for signal as signal and bkg as sig
norm_eff_sig_in_sas = []
norm_eff_bkg_in_bas = []

norm_eff_bkg = []

#mean energy within each bin for signal and bkg data
mean_energy_sig = []  
mean_energy_bkg = []   

for thr_i in thr: 

    #Information to save in each loop of threshold --------------
    nu_energy_in_sas_thr = []
    #nu_energy_out_sas_thr = []
    
    tl_energy_in_bas_thr = []
    #tl_energy_out_bas_thr = []

    #normalized eficiency values for signal and bkg for each thr
    #Used to contruct the norm eff plot
    norm_eff_sig_in_sas_thr = np.array([])
    norm_eff_bkg_in_bas_thr = np.array([])

    #mean energy within each bin for signal and bkg data for each thr (aunque acaba siendo el mismo valor medio para cado thr y para los histogramas que preservan el número de bins).
    #Used to contruct the norm eff plot
    mean_energy_sig_thr = np.array([]) 
    mean_energy_bkg_thr = np.array([]) 

    #mean radial values within each bin for signal and bkg data for each thr
    #Used to contruct the norm eff plot
    mean_rad_sig_thr = np.array([]) 
    mean_rad_bkg_thr = np.array([]) 
    
    #----------------------------------------------

    #Extract info for Plot of energy > thr and energy < thr

    #Extract
    for i in np.where(prob_sas >= thr_i)[0]:
        nu_energy_in_sas_thr.append(energy_sig_rc[i])
        
    #for j in np.where(prob_sas < thr_i)[0]:
        #nu_energy_out_sas_thr.append(energy_sig_rc[j])
    
    for m in np.where(prob_bas >= thr_i)[0]:
        tl_energy_in_bas_thr.append(energy_bkg_rc[m])
    
    #for k in np.where(prob_bab < thr_i)[0]:
        #tl_energy_out_spectrum_thr.append(energy_bkg_rc[k])
        
    nu_energy_in_sas.append(np.array(nu_energy_in_sas_thr))
    #nu_energy_out_sas.append(np.array(nu_energy_out_sas_thr))
    tl_energy_in_bas.append(np.array(tl_energy_in_bas_thr))
    #tl_energy_out_bab.append(np.array(tl_energy_out_spectrum_thr))

    #Extract norm_eff and mean nu enery within each bin:
    #1) Extract for solar nu event predictions
    for i in range(N_edges_sig-1):
        #extract edges value of energy at each bin
        energy_edge_i = en_sig_test_edge[i]
        energy_edge_f = en_sig_test_edge[i+1]
    
        #find energy in energy_test_sig between edges values and the model prediction for SAS 
        energy_interval = np.extract((energy_sig_rc >= energy_edge_i) & (energy_sig_rc <= energy_edge_f), energy_sig_rc)
        prob_sas_interval = np.extract((energy_sig_rc >= energy_edge_i) & (energy_sig_rc <= energy_edge_f), prob_sas)
    
        #extract mean energy of binned interval
        mean_energy_interval = np.mean(energy_interval)
        
        mean_energy_sig_thr = np.append(mean_energy_sig_thr, mean_energy_interval)
        
        #Total Number of events we know are true
        N_true = len(prob_sas_interval)
    
        #find where prob. is higher than threshold and count
        condition_thr = prob_sas_interval >= thr_i
        energy_up_thr = np.extract(condition_thr, energy_interval)
        N_up_thr = len(energy_up_thr)
    
        #compute and extract normalized efficiency
        norm_eff_interval = N_up_thr / N_true
        norm_eff_sig_in_sas_thr = np.append(norm_eff_sig_in_sas_thr, norm_eff_interval)

    norm_eff_sig_in_sas.append(norm_eff_sig_in_sas_thr)
    mean_energy_sig.append(mean_energy_sig_thr)
        
    #2) Extract for Tl event predictions
    for i in range(N_edges_bkg-1):
        #extract edges value of energy at each bin
        energy_edge_i = en_bkg_test_edge[i]
        energy_edge_f = en_bkg_test_edge[i+1]
    
        #find energy in energy_test_bkg between edges values and the model prediction for BAS
        energy_interval = np.extract((energy_bkg_rc >= energy_edge_i) & (energy_bkg_rc <= energy_edge_f), energy_bkg_rc)
        prob_bas_interval = np.extract((energy_bkg_rc >= energy_edge_i) & (energy_bkg_rc <= energy_edge_f), prob_bas)
    
        #extract mean energy of binned interval
        mean_energy_interval = np.mean(energy_interval)
        
        mean_energy_bkg_thr = np.append(mean_energy_bkg_thr, mean_energy_interval)
        
        #Total Number of events we know are true
        N_true = len(prob_bas_interval)
    
        #find where prob. is higher than threshold and count
        condition_thr = prob_bas_interval >= thr_i
        energy_up_thr = np.extract(condition_thr, energy_interval)
        N_up_thr = len(energy_up_thr)
    
        #compute and extract normalized efficiency
        norm_eff_interval = N_up_thr / N_true
        norm_eff_bkg_in_bas_thr = np.append(norm_eff_bkg_in_bas_thr, norm_eff_interval)
    
    norm_eff_bkg_in_bas.append(norm_eff_bkg_in_bas_thr)
    mean_energy_bkg.append(mean_energy_bkg_thr)

#Transform lists to array where each arrow correspond to the values of (energy, norm_eff) for a certain thr
mean_energy_sig = np.array(mean_energy_sig)
norm_eff_sig_in_sas = np.array(norm_eff_sig_in_sas)

mean_energy_bkg = np.array(mean_energy_bkg)
norm_eff_bkg_in_bas = np.array(norm_eff_bkg_in_bas)

# %%
bas_on = False
alpha = 0

#main plot: Test Solar Energy
fig, axes = plt.subplots(1,2, figsize =(18, 6)) 
ax1_1 = axes[1].twinx()  #Right axis for the norm_eff plot due to differences between eff scales

sn.histplot(energy_sig_rc, ax = axes[0], bins = bins_nu, color = 'g' , label = r'$^8$B-$ν_e$ Spectrum', alpha = alpha, element = 'step')

#if bkg_on:
#Bkg test energy plot
#    sn.histplot(energy_bkg_rc, ax = axes[0], bins = bins_tl, color = 'black' , label = r'208-Tl Spectrum', alpha = alpha, element = 'step')

for i_dx, thr_i in enumerate(thr):  
    #Sig Spectral distribution
    sn.histplot(nu_energy_in_sas[i_dx], ax = axes[0], bins = bins_nu, color = red_variants[i_dx] , label = r'SAS (thr $\geq$'+str(thr_i)+')', 
                alpha = alpha, element = 'step')

    #Sig Efficiency normalized by N_true counts
    sn.histplot(x = mean_energy_sig[i_dx], ax = axes[1], bins=len(mean_energy_sig[i_dx]), color = red_variants[i_dx], 
                weights=norm_eff_sig_in_sas[i_dx], element = 'step', alpha = 0.0, label = r'$\epsilon_{SAS}$ (thr $\geq$ '+str(thr_i)+')')

    if bas_on:
        #bkg spectra
        sn.histplot(tl_energy_in_bas[i_dx], ax = axes[0], bins = bins_tl, color = blue_variants[i_dx] , label = r'BAS (thr $\geq$'+str(thr_i)+')', 
                    alpha = alpha, element = 'step')

        #bkg efficiency
        sn.histplot(x = mean_energy_bkg[i_dx], ax = ax1_1, bins=len(mean_energy_bkg[i_dx]), color = blue_variants[i_dx], 
                    weights=norm_eff_bkg_in_bas[i_dx], element = 'step', alpha = 0.0, label = r'$\epsilon_{BAS}$ (thr $\geq$ '+str(thr_i)+')')
        

axes[0].set_title(r'Spectral Distribution for each Threshold (thr) of Model Predictions', fontsize = 12)
axes[1].set_title(r'$\epsilon = \frac{N(>thr)}{N_{true}}$', fontsize = 12)
axes[0].legend(loc = 'upper right')
axes[1].legend(loc = 'upper left')
ax1_1.legend(loc = 'upper right')

axes[0].set_xlabel('Energy (MeV)')
axes[1].set_xlabel('Energy (MeV)')
axes[1].set_ylabel(r'$\epsilon_{SAS}$', fontsize = 14)
ax1_1.set_ylabel(r'$\epsilon_{BAS}$', fontsize = 14)

axes[1].tick_params(axis='y', labelcolor='r')
ax1_1.tick_params(axis='y', labelcolor='b')


#Agregar marcadores al eje x
#x_en_ticks = np.arange(2.5, 12, 1)   #(x_min, x_max, step)
#axes[0].x_en_ticks(x_ticks)
#axes[1].x_en_ticks(x_ticks)


#axes[0].set_xlim(2.5,12.8)
#axes[1].set_xlim(2.5,12)
#axes[1].set_ylim(np.min(norm_eff_sig_in_sas) - 0.05, 1.05)
#ax1_1.set_ylim(0.0, np.max(norm_eff_bkg_in_bas) + 0.01)

axes[0].set_yscale('log')
axes[1].set_yscale('log')
plt.suptitle(f'Energy: [2.5,{energy_cut_train}] MeV - R < 5500 (mm)')

#if bas_on:
    #plt.savefig('figs/Optimized Models/10x10/Spectral_thr_and_Norm_eff_sig_bkg.png', format = 'png', bbox_inches = 'tight')
#else:
    #plt.savefig('figs/Optimized Models/10x10/Spectral_thr_and_Norm_eff.png', format = 'png', bbox_inches = 'tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
