# %% [markdown]
# # Notebook Dedicado a correguir la Transformación de MC Dataset para entrenar el MML y Obtener un Modelo Clasificador Optimizado
#
# Fue observado al hacer predicciones en el datos reales que los clasificacion de evento como BAB caen en energias donde no son esperados observar eventos de bkg. Originalmente la transformacion standard scaler era aplicado a talio y 8B Nue por separado, lo cual no es posible realizar en datos reales. Por lo tanto debemos sumar las distribuciones de eventos de bkg y eventos de sig y transformar todo el conjunto para ser consistente con el tratamiento de datos reales.

# %%
#import uproot
import numpy as np

import pickle

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import font_manager

import seaborn as sn
import pandas as pd

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, concatenate, Dropout
from keras.losses import BinaryCrossentropy
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve, auc
from sklearn.utils import shuffle
import optuna
from keras.backend import clear_session

# %%
import colorsys
# Función para generar variantes más claras y más oscuras de un color
def generate_color_variants(base_color, num_variants, factor = 0.3):
    # Convertir el color base a valores de HSV
    r, g, b = base_color
    h, l, s = colorsys.rgb_to_hls(r, g, b)
    
    # Generar variantes
    variants = []
    for i in range(1, num_variants + 1):
        # Hacer el color más claro
        lighter = colorsys.hls_to_rgb(h, min(1, l * (1 + factor * i)), s)
        # Hacer el color más oscuro
        darker = colorsys.hls_to_rgb(h, max(0, l * (1 - factor * i)), s)
        variants.append(lighter)
        variants.append(darker)
        
    return variants

# Color base (rojo)
base_red = (1, 0, 0) # RGB para rojo puro
# Color base (azuk)
base_blue = (0, 0, 1) # RGB para azul puro
num_variants = 5

red_variants = generate_color_variants(base_red, num_variants)
blue_variants = generate_color_variants(base_blue, num_variants)

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Define the Data Cuts of the original pd.DataFrame

# %%
energy_inf_cut = 2.5
energy_sup_cut = 12

posr_cut = 5500

time_res_inf_cut = -5
time_res_sup_cut = 7

nhits_cut = 20

# %%
image_dim = (10, 10)

#Directories
train_dataset_dir = "E:/Data/solars/mc/ML Data/Train/pd_dataframe/"
test_dataset_dir = "E:/Data/solars/mc/ML Data/Test/pd_dataframe/"
fname = f'df_Dim_{image_dim[0]}_E_{energy_inf_cut}_{energy_sup_cut}_MeV_R_{posr_cut}_mm_Delta_{time_res_inf_cut}_{time_res_sup_cut}_ns.csv'

#Load in Pandas  DataFrame
df_train = shuffle(pd.read_csv(train_dataset_dir + fname))
df_test = shuffle(pd.read_csv(test_dataset_dir + fname))

# %%
df_train.describe()
# Out:
#             pixel_0       pixel_1       pixel_2       pixel_3       pixel_4  \
# count  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06
# mean   4.751179e-03  8.916556e-03  3.346255e-02  8.171818e-02  1.029404e-01
# std    6.830940e-02  9.276742e-02  1.720649e-01  2.329533e-01  2.103047e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e-01
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#             pixel_5       pixel_6       pixel_7       pixel_8       pixel_9  \
# count  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06
# mean   1.043776e-01  1.032111e-01  1.022776e-01  1.015866e-01  1.008871e-01
# std    1.733036e-01  1.489336e-01  1.302089e-01  1.142410e-01  1.012036e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  2.040816e-02  2.702703e-02
# 50%    0.000000e+00  3.773585e-02  4.918033e-02  6.000000e-02  6.779661e-02
# 75%    1.428571e-01  1.463415e-01  1.475410e-01  1.463415e-01  1.428571e-01
# max    1.000000e+00  1.000000e+00  9.062500e-01  8.800000e-01  8.709677e-01
#
#        ...      pixel_94      pixel_95      pixel_96      pixel_97  \
# count  ...  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06
# mean   ...  9.824976e-02  1.000255e-01  9.920891e-02  9.846786e-02
# std    ...  2.013336e-01  1.661350e-01  1.433708e-01  1.261326e-01
# min    ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    ...  0.000000e+00  0.000000e+00  3.703704e-02  4.761905e-02
# 75%    ...  1.000000e-01  1.428571e-01  1.428571e-01  1.428571e-01
# max    ...  1.000000e+00  1.000000e+00  1.000000e+00  8.888889e-01
#
#            pixel_98      pixel_99  energy (MeV)   radius (mm)          IsNu  \
# count  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06  1.502813e+06
# mean   9.808736e-02  9.822454e-02  4.661723e+00  4.096745e+03  6.572734e-01
# std    1.114815e-01  9.960804e-02  1.753361e+00  1.072686e+03  4.746211e-01
# min    0.000000e+00  0.000000e+00  2.500002e+00  3.176235e+01  0.000000e+00
# 25%    1.960784e-02  2.500000e-02  3.457328e+00  3.424745e+03  0.000000e+00
# 50%    5.714286e-02  6.521739e-02  4.015488e+00  4.333659e+03  1.000000e+00
# 75%    1.403509e-01  1.392405e-01  5.501708e+00  4.976263e+03  1.000000e+00
# max    8.536585e-01  7.843137e-01  1.199876e+01  5.500000e+03  1.000000e+00
#
#                IsTl
# count  1.502813e+06
# mean   3.427266e-01
# std    4.746211e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    1.000000e+00
# max    1.000000e+00
#
# [8 rows x 104 columns]

# %%
df_test.describe()
# Out:
#              pixel_0        pixel_1        pixel_2        pixel_3  \
# count  106135.000000  106135.000000  106135.000000  106135.000000
# mean        0.005148       0.009495       0.034872       0.082514
# std         0.071118       0.095286       0.174460       0.231872
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#              pixel_4        pixel_5        pixel_6        pixel_7  \
# count  106135.000000  106135.000000  106135.000000  106135.000000
# mean        0.101413       0.103084       0.102483       0.101362
# std         0.207495       0.171604       0.148245       0.129989
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.037037       0.047619
# 75%         0.100000       0.142857       0.142857       0.145455
# max         1.000000       1.000000       0.925926       0.833333
#
#              pixel_8        pixel_9  ...       pixel_94       pixel_95  \
# count  106135.000000  106135.000000  ...  106135.000000  106135.000000
# mean        0.101043       0.100600  ...       0.098402       0.100782
# std         0.114736       0.102026  ...       0.199750       0.165745
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.020202       0.025641  ...       0.000000       0.000000
# 50%         0.058824       0.066667  ...       0.000000       0.000000
# 75%         0.145161       0.142857  ...       0.100000       0.142857
# max         0.784314       0.720930  ...       1.000000       1.000000
#
#             pixel_96       pixel_97       pixel_98       pixel_99  \
# count  106135.000000  106135.000000  106135.000000  106135.000000
# mean        0.099969       0.099588       0.099413       0.099458
# std         0.143593       0.126685       0.112832       0.100883
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.020000       0.025000
# 50%         0.038462       0.047619       0.058824       0.066667
# 75%         0.142857       0.142857       0.142857       0.140351
# max         0.931034       0.911111       0.783784       0.742857
#
#         energy (MeV)    radius (mm)           IsNu           IsTl
# count  106135.000000  106135.000000  106135.000000  106135.000000
# mean        4.441370    4100.741511       0.516305       0.483695
# std         1.619007    1072.746857       0.499736       0.499736
# min         2.500107      95.603500       0.000000       0.000000
# 25%         3.430564    3433.121094       0.000000       0.000000
# 50%         3.871514    4336.885742       1.000000       0.000000
# 75%         4.865570    4979.068604       1.000000       1.000000
# max        11.995671    5499.963379       1.000000       1.000000
#
# [8 rows x 104 columns]

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Extract information and Define Energy Cuts

# %%
pixel_pattern = r'^pixel_\d+$'

energy_cut_train = 7
energy_cut_test = 7

# %% [markdown]
# ### Extract Trainning Data

# %%
#Separate signal from background 
dataset_sig_train = (df_train[df_train['IsNu'] == 1]).reset_index()
dataset_bkg_train = (df_train[df_train['IsTl'] == 1]).reset_index()

#cut in solar energy
dataset_sig_train = (dataset_sig_train[dataset_sig_train['energy (MeV)'] <= energy_cut_train])

#Igualar cantidad de datos de neutrinos solares y de Tálio
N_solar_ev = dataset_sig_train.shape[0]
N_Tl_ev = dataset_bkg_train.shape[0]

if N_solar_ev > N_Tl_ev:
    dataset_sig_train = (dataset_sig_train.iloc[:N_Tl_ev, :]).reset_index()

else:
    dataset_bkg_train = (dataset_bkg_train.iloc[:N_solar_ev, :]).reset_index()
    
# Separate Features for signal and background: Useful for plots
df_pixel_sig_train = dataset_sig_train.filter(regex=pixel_pattern)
df_energy_sig_train = (dataset_sig_train[['energy (MeV)']])
df_radi_sig_train = (dataset_sig_train[['radius (mm)']])
df_label_sig_train = pd.DataFrame(dataset_sig_train, columns = ['IsNu', 'IsTl'])

df_pixel_bkg_train = dataset_bkg_train.filter(regex=pixel_pattern)
df_energy_bkg_train = (dataset_bkg_train[['energy (MeV)']])
df_radi_bkg_train = (dataset_bkg_train[['radius (mm)']])
df_label_bkg_train = pd.DataFrame(dataset_bkg_train, columns = ['IsNu', 'IsTl'])

# Also save the join bkg+sig datasets and its labels to perform the standard scaler overall data
df_pixel_train = pd.concat([df_pixel_sig_train, df_pixel_bkg_train])
df_energy_train = pd.concat([df_energy_sig_train, df_energy_bkg_train])
df_radi_train = pd.concat([df_radi_sig_train, df_radi_bkg_train])
df_labels_train = pd.concat([df_label_sig_train, df_label_bkg_train])
labels_train = np.array(df_labels_train)

# %% [markdown]
# ### Extract Test Data

# %%
equal_evs = True #Cambiar a True para Igualar eventos de 208-Tl y Solar Nu en test dataset!

#Separate signal from background 
dataset_sig_test = (df_test[df_test['IsNu'] == 1])
dataset_bkg_test = (df_test[df_test['IsTl'] == 1])

#cut in solar energy
dataset_sig_test = (dataset_sig_test[dataset_sig_test['energy (MeV)'] <= energy_cut_test])

if equal_evs:
    #Igualar cantidad de datos de neutrinos solares y de Tálio
    N_solar_ev = dataset_sig_test.shape[0]
    N_Tl_ev = dataset_bkg_test.shape[0]
    
    if N_solar_ev > N_Tl_ev:
        dataset_sig_test = (dataset_sig_test.iloc[:N_Tl_ev, :]).reset_index()
    
    else:
        dataset_bkg_test = (dataset_bkg_test.iloc[:N_solar_ev, :]).reset_index()

df_test_cut = shuffle(pd.concat([dataset_sig_test, dataset_bkg_test]))

# Separate Features for signal and background: Useful for plots
df_pixel_sig_test = dataset_sig_test.filter(regex=pixel_pattern)
df_energy_sig_test = (dataset_sig_test[['energy (MeV)']])
df_radi_sig_test = (dataset_sig_test[['radius (mm)']])
df_label_sig_test = pd.DataFrame(dataset_sig_test, columns = ['IsNu', 'IsTl'])

df_pixel_bkg_test = dataset_bkg_test.filter(regex=pixel_pattern)
df_energy_bkg_test = (dataset_bkg_test[['energy (MeV)']])
df_radi_bkg_test = (dataset_bkg_test[['radius (mm)']])
df_label_bkg_test = pd.DataFrame(dataset_bkg_test, columns = ['IsNu', 'IsTl'])
        
#Separate Features
df_pixel_test = df_test_cut.filter(regex=pixel_pattern)
df_energy_test = df_test_cut[['energy (MeV)']]
df_radi_test = df_test_cut[['radius (mm)']]
df_labels_test = pd.DataFrame(df_test_cut, columns = ['IsNu', 'IsTl'])
labels_test = np.array(df_labels_test)

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Standard Scaler

# %%
# Train Transformation History
scaler_pixels_train = StandardScaler() 
scaler_energy_train = StandardScaler()
scaler_position_train = StandardScaler()

# Test Transformation History
scaler_pixels_test = StandardScaler() 
scaler_energy_test = StandardScaler() 
scaler_position_test = StandardScaler()

# %% [markdown]
# ### MinMax Scaler

# %%
# Train Transformation History
epsilon = 1e-2
min_val = np.min(df_pixel_train) + epsilon # equals to zero + epsilon
max_val = np.max(df_pixel_train) + epsilon # equals to one

#scaler_pixels_train = MinMaxScaler(feature_range=(min_val, max_val)) 
scaler_energy_train = MinMaxScaler(feature_range=(min_val, max_val))
scaler_position_train = MinMaxScaler(feature_range=(min_val, max_val))

# Test Transformation History
scaler_pixels_test = MinMaxScaler(feature_range=(min_val, max_val)) 
scaler_energy_test = MinMaxScaler(feature_range=(min_val, max_val)) 
scaler_position_test = MinMaxScaler(feature_range=(min_val, max_val))

# %% [markdown]
# ### Pipeline MinMaxScaler(StandardScaler())

# %%
# Train Transformation History

#Intervals for MinMax Scaler ------------------------------------
epsilon = 1e-2
min_val = np.min(df_pixel_train) + epsilon # equals to zero + epsilon
max_val = np.max(df_pixel_train) + epsilon # equals to one
# ---------------------------------------------------------------

scaler_pixels_train = Pipeline([('standardization', StandardScaler()),
                                ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])
scaler_energy_train = Pipeline([('standardization', StandardScaler()),
                                ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])
scaler_position_train = Pipeline([('standardization', StandardScaler()),
                                ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])
# Test Transformation History
scaler_pixels_test = Pipeline([('standardization', StandardScaler()),
                                ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])
scaler_energy_test = Pipeline([('standardization', StandardScaler()),
                               ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])
scaler_position_test = Pipeline([('standardization', StandardScaler()),
                                 ('minmax', MinMaxScaler(feature_range=(min_val, max_val)))])

# %% [markdown]
# ### Train Dataset Transformation

# %%
#pixel_train_transf = scaler_pixels_train.fit_transform(df_pixel_train)
pixel_train_transf = np.array(df_pixel_train) + epsilon
energy_train_transf = scaler_energy_train.fit_transform(df_energy_train).T[0]

#radial position to volume normalization Transformationm
vol = 5500**3 
position_train_transf_volnorm = (np.array(df_radi_train).T[0]**3)/vol

position_train_transf = scaler_position_train.fit_transform(position_train_transf_volnorm.reshape(-1, 1)).T[0]

# %% [markdown]
# ### Test Dataset Transformation

# %%
#pixel_test_transf = scaler_pixels_test.fit_transform(df_pixel_test)
pixel_test_transf = np.array(df_pixel_test) + epsilon
energy_test_transf = scaler_energy_test.fit_transform(df_energy_test).T[0]

#radial position to volume normalization Transformationm
vol = 5500**3 
position_test_transf_volnorm = (np.array(df_radi_test).T[0]**3)/vol

position_test_transf = scaler_position_test.fit_transform(position_test_transf_volnorm.reshape(-1, 1)).T[0]

# %% [markdown]
# ### Separation of sig from bkg in the Train and Test Datasets

# %%
#Separar sig from bkg and train from test
IsNu = np.array([1,0])
IsTl = np.array([0,1])

#Train: Separation sig from bkg
pixel_train_transf_sig = pixel_train_transf[np.array(df_labels_train == IsNu)[:,0]]
pixel_train_transf_bkg = pixel_train_transf[np.array(df_labels_train == IsTl)[:,0]]

energy_train_transf_sig = energy_train_transf[np.array(df_labels_train == IsNu)[:,0]]
energy_train_transf_bkg = energy_train_transf[np.array(df_labels_train == IsTl)[:,0]]

position_train_transf_sig = position_train_transf[np.array(df_labels_train == IsNu)[:,0]]
position_train_transf_bkg = position_train_transf[np.array(df_labels_train == IsTl)[:,0]]

#Test: Separation sig from bkg
pixel_test_transf_sig = pixel_test_transf[np.array(df_labels_test == IsNu)[:,0]]
pixel_test_transf_bkg = pixel_test_transf[np.array(df_labels_test == IsTl)[:,0]]

pixel_test_transf_sig = pixel_test_transf[np.array(df_labels_test == IsNu)[:,0]]
pixel_test_transf_bkg = pixel_test_transf[np.array(df_labels_test == IsTl)[:,0]]

energy_test_transf_sig = energy_test_transf[np.array(df_labels_test == IsNu)[:,0]]
energy_test_transf_bkg = energy_test_transf[np.array(df_labels_test == IsTl)[:,0]]

position_test_transf_sig = position_test_transf[np.array(df_labels_test == IsNu)[:,0]]
position_test_transf_bkg = position_test_transf[np.array(df_labels_test == IsTl)[:,0]]

# %% [markdown]
# ## Datasets Splits: test->(test,validation)

# %%
pixel_test1_transf, pixel_val_transf, \
energy_test1_transf, energy_val_transf, \
position_test1_transf, position_val_transf, \
labels_test1, labels_val = train_test_split(pixel_test_transf, energy_test_transf, position_test_transf,
                                              labels_test, test_size = 0.5,
                                              stratify = labels_test,
                                              random_state=42)

# %% [markdown]
# ## Plots with Transformed Datasplit

# %%
#Separar sig from bkg in new train1 and validation
IsNu = np.array([1,0])
IsTl = np.array([0,1])

#Train and validation extract sig and bkg conditions:
sig_mask_train = np.all(labels_train == IsNu, axis=1)
bkg_mask_train = np.all(labels_train == IsTl, axis=1)

sig_mask_val = np.all(labels_val == IsNu, axis=1)
bkg_mask_val = np.all(labels_val == IsTl, axis=1)

#test1 extract sig and bkg conditions:
sig_mask_test1 = np.all(labels_test1 == IsNu, axis=1)
bkg_mask_test1 = np.all(labels_test1 == IsTl, axis=1)

#Train: Separation sig from bkg
pixel_train_transf_sig = pixel_train_transf[sig_mask_train]
pixel_train_transf_bkg = pixel_train_transf[bkg_mask_train]

energy_train_transf_sig = energy_train_transf[sig_mask_train]
energy_train_transf_bkg = energy_train_transf[bkg_mask_train]

position_train_transf_sig = position_train_transf[sig_mask_train]
position_train_transf_bkg = position_train_transf[bkg_mask_train]

#Validation: Separation sig from bkg
pixel_val_transf_sig = pixel_val_transf[sig_mask_val]
pixel_val_transf_bkg = pixel_val_transf[bkg_mask_val]

energy_val_transf_sig = energy_val_transf[sig_mask_val]
energy_val_transf_bkg = energy_val_transf[bkg_mask_val]

position_val_transf_sig = position_val_transf[sig_mask_val]
position_val_transf_bkg = position_val_transf[bkg_mask_val]

labels_val_sig = labels_val[sig_mask_val]
labels_val_bkg = labels_val[bkg_mask_val]

#test1: Separation sig from bkg
pixel_test1_transf_sig = pixel_test1_transf[sig_mask_test1]
pixel_test1_transf_bkg = pixel_test1_transf[bkg_mask_test1]

energy_test1_transf_sig = energy_test1_transf[sig_mask_test1]
energy_test1_transf_bkg = energy_test1_transf[bkg_mask_test1]

position_test1_transf_sig = position_test1_transf[sig_mask_test1]
position_test1_transf_bkg = position_test1_transf[bkg_mask_test1]

labels_test1_sig = labels_test1[sig_mask_test1]
labels_test1_bkg = labels_test1[bkg_mask_test1]

# %%
# Save Settings:
save_fig = False
save_dir = 'figs/Optimized Models/10x10/pipeline_std_minmax/'
fname = f'Energy_Radius_Features_'
pattern_train_save_name = f'E_{energy_inf_cut}_{energy_cut_train}_MeV_R_{posr_cut}_mm_Delta_({time_res_inf_cut}_{time_res_sup_cut})_ns'

# ========= Plots Settings ===================
mpl.rcParams.update(mpl.rcParamsDefault)
sn.reset_orig


# Font settings:
font_style_title = {'family':'serif', 'weight': 'normal','color':'black','size':16}
font_style_axis= {'family':'serif', 'weight': 'normal','color':'black','size':14}
font_prop = font_manager.FontProperties(family=font_style_axis['family'], weight=font_style_axis['weight'], size=12)

# Plot Representation settings:
linewidth = 1.2
alpha = 0

binwidth_en = 0.02
binwidth_rad = 0.1

bins = 50

# ========= Variables to plot lists =========
# non-transformed features:
energy_sig_tot = np.concatenate((df_energy_sig_train, df_energy_sig_test)).T[0]
energy_bkg_tot = np.concatenate((df_energy_bkg_train, df_energy_bkg_test)).T[0]

radius_sig_tot = np.concatenate((df_radi_sig_train, df_radi_sig_test)).T[0]
radius_bkg_tot = np.concatenate((df_radi_bkg_train, df_radi_bkg_test)).T[0]

energy_var_list = [energy_sig_tot, energy_bkg_tot]
radius_var_list = [radius_sig_tot, radius_bkg_tot]
labels_list = [r'Solar $^8$B-$\nu_e$', r'$^{208}$Tl']
colors_list = [red_variants[0], blue_variants[0]]

# Transformed features:
energy_transf_list = [energy_train_transf_sig, energy_val_transf_sig, energy_test1_transf_sig, 
                      energy_train_transf_bkg, energy_val_transf_bkg, energy_test1_transf_bkg]
radius_transf_list = [position_train_transf_sig, position_val_transf_sig, position_test1_transf_sig,
                      position_train_transf_bkg, position_val_transf_bkg, position_test1_transf_bkg]
lables_dataset_split_list = [r'Solar $^8$B-$\nu_e$ train', r'Solar $^8$B-$\nu_e$ validation', r'Solar $^8$B-$\nu_e$ test',
                             r'$^{208}$Tl train', r'$^{208}$Tl validation', r'$^{208}$Tl test']
colors_dataset_split_list = [red_variants[0], red_variants[1], red_variants[2],
                             blue_variants[0], blue_variants[1], blue_variants[2]]


# ========= Plots =========

fig, axes = plt.subplots(2, 2,
                         figsize=(19, 12),
                         gridspec_kw={'hspace': 0.2, 'wspace': 0.25}  # (vertica space, horizontal space)
                        )

# ---------- Fila 1: Features no transformadas ----------
# Columna 1: Energía no transformada
ax = axes[0, 0]
for data, label, color in zip(energy_var_list, labels_list, colors_list):
    # To limit the shown plot using to the bin edges
    sn.histplot(data, bins = bins, label=label, ax = ax, color = color,
                alpha = alpha, element = 'step', linewidth = linewidth)
ax.set_xlabel("Energy (Mev)", fontdict = font_style_axis)
ax.set_ylabel(r'Counts', fontdict = font_style_axis)
ax.set_yscale('log')
#ax.legend()

# Columna 2: Posición (radio) no transformada
ax = axes[0, 1]
for data, label, color in zip(radius_var_list, labels_list, colors_list):
    sn.histplot(data, bins = bins, label=label, ax = ax, color = color, 
                alpha = alpha, element = 'step', linewidth = linewidth)
ax.set_xlabel("Radial Position (mm)", fontdict = font_style_axis)
ax.set_ylabel(r'Counts', fontdict = font_style_axis)
#ax.set_yscale('log')
#ax.legend()

# ---------- Fila 2: Features transformadas ----------
# Columna 1: Energía transformada
ax = axes[1, 0]
for data, label, color in zip(energy_transf_list, lables_dataset_split_list, colors_dataset_split_list):
    sn.histplot(data, bins = bins, label=label, ax = ax, color = color, 
                alpha = alpha, element = 'step', linewidth = linewidth)
ax.set_xlabel("Transformed Energy", fontdict = font_style_axis)
ax.set_ylabel(r'Counts', fontdict = font_style_axis)
ax.set_yscale('log')
#ax.legend()

# Columna 2: Posición transformada
ax = axes[1, 1]
for data, label, color in zip(radius_transf_list, lables_dataset_split_list, colors_dataset_split_list):
    sn.histplot(data, bins = bins, label=label, ax = ax, color = color, 
                alpha = alpha, element = 'step', linewidth = linewidth)
ax.set_xlabel(r'Transformed Normalized Volume $(R_\text{ev}/R_\text{cut})^{3}$', fontdict = font_style_axis)
ax.set_ylabel(r'Counts', fontdict = font_style_axis)
ax.set_yscale('log')
#ax.legend()

# ========= Crear leyendas únicas =========
# Leyenda para la primera fila (fuera de los plots)
handles_row1, labels_row1 = axes[0, 0].get_legend_handles_labels()
fig.legend(handles_row1, labels_row1,
           loc='upper right', bbox_to_anchor=(0.89, 0.885),
           prop=font_prop, frameon=True, edgecolor='black', labelcolor = font_style_axis['color'])
# Adjunts the plot size to left space to the legend box 
fig.subplots_adjust(right = 1.2)  # right space

# Leyenda para la segunda fila (fuera de los plots)
handles_row2, labels_row2 = axes[1, 0].get_legend_handles_labels()
fig.legend(handles_row2, labels_row2,
           loc='upper right', bbox_to_anchor=(0.94, 0.466),
           prop=font_prop, frameon=True, edgecolor='black', labelcolor = font_style_axis['color'])

# Adjunts the plot size to left space to the legend box 
fig.subplots_adjust(right = 0.80) # Plots contraction to right space

plt.suptitle(rf'Energy and Position Features Before and After Data Transformation', y = 0.93,
             family = 'serif', weight = 'normal', color = 'black', size = 16)

if save_fig:
    plt.savefig(save_dir + fname + pattern_train_save_name + '.png', format = 'png' , dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Initial Weights Suggestions
#
# Use the flatten High Stat. Norm$[\mathcal{L}(\Delta,\alpha)]$ distribution as initial weights

# %%
initial_pixel_weights = np.sum(pixel_train_transf_sig, axis = 0)

#Normalize the weights values by the maximum value and then multiply by a factor < 1
reducer_factor = 0.2
initial_pixel_weights = (initial_pixel_weights/np.max(initial_pixel_weights)) * reducer_factor

# %%
plt.imshow(initial_pixel_weights.reshape(10,10))

# %% [markdown]
# ### Weight Intializar: Keras Initializer

# %%
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom", name="PixelHintInitializer")
class PixelHintInitializer(tf.keras.initializers.Initializer):
    def __init__(self, weights_hint):
        self.weights_hint = np.array(weights_hint)

    def __call__(self, shape, dtype=None):
        W = np.tile(self.weights_hint.reshape(-1, 1), (1, shape[1]))
        return tf.convert_to_tensor(W, dtype=dtype)

    def get_config(self):
        return {"weights_hint": self.weights_hint.tolist()}

# %% [markdown]
# # Model Optimization

# %% [markdown]
# ## Vary of Nº of Layers, Nº of Neurons, LR and Drop-out Rate.

# %%
def create_OP_Model(trial, weights_hint = None):
    # clear the Keras Session
    tf.keras.backend.clear_session()

    # Adam Optimizer Hyperparams
    lr_rate = trial.suggest_float('learning_rate', 1e-4, 5e-3)
    
    # Dropout rate
    do_rate = trial.suggest_float('Drop_out_rate', 0.1, 0.7)

    # Image Dimensions
    image_dim = (10, 10)
    input_im_shape = image_dim[0] * image_dim[1]

    # Input Layers
    input_image = Input(shape=(input_im_shape,), name='image_input')
    input_energy = Input(shape=(1,), name='energy_input')
    input_position = Input(shape=(1,), name='position_input')

    # =======================
    # Image Model Branch
    # =======================
    n_layers_image = trial.suggest_int('n_layers_image', 1, 5)
    x_img = input_image
    image_layer_ranges = [(85, 95), (70, 80), (65, 75), (50, 60), (30, 45)]  #List with len = max(value_n_layers_suggest) where each entry is a tuple (min_suggest_neurons, max_suggest_neurons)

    for i in range(n_layers_image):
        n_units = trial.suggest_int(f'n_neurons_image_hidden_ly{i}', image_layer_ranges[i][0], image_layer_ranges[i][1])
        
        if i == 0 and weights_hint is not None:
            # Custom weights initialization function in the first hidden layer
            x_img = Dense(n_units, activation='gelu', kernel_initializer = PixelHintInitializer(weights_hint), name=f'imag_ly_{i}')(x_img)
        else:
            x_img = Dense(n_units, activation='gelu', name=f'imag_ly_{i}')(x_img)
            
    '''
    for i in range(n_layers_image):
        n_units = trial.suggest_int(f'n_neurons_image_hidden_ly{i}', image_layer_ranges[i][0], image_layer_ranges[i][1])
        x_img = Dense(n_units, activation='gelu', name=f'imag_ly_{i}')(x_img)
    '''
    
    # Concatenate Layer
    x = concatenate([x_img, input_energy, input_position])

    # =======================
    # Before DropOut (BDO) Model Branch
    # =======================
    n_layers_bdo = trial.suggest_int('n_layers_bdo', 1, 3)
    bdo_layer_ranges = [(26, 47), (22, 24), (18, 20)]
    x_bdo = x
    for i in range(n_layers_bdo):
        n_units = trial.suggest_int(f'n_neurons_bdo_hidden_ly{i}', bdo_layer_ranges[i][0], bdo_layer_ranges[i][1])
        x_bdo = Dense(n_units, activation='gelu', name=f'bdo_ly_{i}')(x_bdo)

    # Dropout
    x_bdo = Dropout(rate=do_rate)(x_bdo)

    # =======================
    # After DropOut (ADO) Model Branch
    # =======================
    n_layers_ado = trial.suggest_int('n_layers_ado', 1, 3)
    ado_layer_ranges = [(12, 16), (8, 10), (5, 7)] 
    x_ado = x_bdo
    for i in range(n_layers_ado):
        n_units = trial.suggest_int(f'n_neurons_ado_hidden_ly{i}', ado_layer_ranges[i][0], ado_layer_ranges[i][1])
        x_ado = Dense(n_units, activation='gelu', name=f'ado_ly_{i}')(x_ado)

    # Output Layer
    output_layer = Dense(2, activation='sigmoid', name='nu_predict')(x_ado)

    # Model Compilation ----------------------------------------------------------------------
    model = Model(inputs=[input_image, input_energy, input_position], outputs=output_layer)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_rate),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=[tf.keras.metrics.AUC(curve='ROC', name='roc_auc'),
                           tf.keras.metrics.AUC(curve='PR', name='pr_auc'),
                           'accuracy'])

    return model

# %%
# ========= OPTUNA Model Optimization ===============
def objective(trial):
    
    global best_model_overall, best_score_overall
    
    model = create_OP_Model(trial, weights_hint = initial_pixel_weights)

    # Trainning
    history = model.fit(
        x = {'image_input': pixel_train_transf, 'energy_input': energy_train_transf, 'position_input': position_train_transf}, 
        y = {'nu_predict': labels_train}, 
        epochs = 200, 
        batch_size = 1000,
        validation_data = ([pixel_val_transf, energy_val_transf, position_val_transf], labels_val),
        callbacks = [tf.keras.callbacks.EarlyStopping(patience=20, min_delta=1e-3, monitor="val_loss")],
        shuffle = True,
        verbose = 1
    )

    # Validation Predictions for signal events (better to evaluate the Precision-Recall AUC)
    model_predictions = model.predict([pixel_val_transf, energy_val_transf, position_val_transf], verbose=0)
    expected_labels = labels_val

    # Compute Precision-Recall AUC for signal
    precision, recall, _ = precision_recall_curve(expected_labels.flatten(), model_predictions.flatten())
    pr_auc_val = auc(recall, precision)

    return pr_auc_val

# %%
study = optuna.create_study(directions = ["maximize"])
study.optimize(objective, n_trials = 100)
best_trial = study.best_trial

# Print the best Model Results
print("Best Hyperparms.:", study.best_trial.params)
print("Best PR-AUC Value: ", best_trial.value)
# Out:
# [I 2025-08-14 01:03:37,494] A new study created in memory with name: no-name-c6bb83a9-6ca0-4cd7-a0d3-fafe32ac7110
# WARNING:tensorflow:From C:\Users\joanc\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6747 - loss: 0.5611 - pr_auc: 0.7517 - roc_auc: 0.7465 - val_accuracy: 0.7969 - val_loss: 0.4240 - val_pr_auc: 0.8857 - val_roc_auc: 0.8817
# Epoch 2/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7910 - loss: 0.4388 - pr_auc: 0.8743 - roc_auc: 0.8710 - val_accuracy: 0.7939 - val_loss: 0.4244 - val_pr_auc: 0.8869 - val_roc_auc: 0.8824
# Epoch 3/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7960 - loss: 0.4276 - pr_auc: 0.8822 - roc_auc: 0.8788 - val_accuracy: 0.7929 - val_loss: 0.4234 - val_pr_auc: 0.8876 - val_roc_auc: 0.8832
# Epoch 4/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7990 - loss: 0.4219 - pr_auc: 0.8859 - roc_auc: 0.8825 - val_accuracy: 0.8041 - val_loss: 0.4105 - val_pr_auc: 0.8946 - val_roc_auc: 0.8907
# Epoch 5/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8025 - loss: 0.4160 - pr_auc: 0.8896 - roc_auc: 0.8863 - val_accuracy: 0.8003 - val_loss: 0.4161 - val_pr_auc: 0.8911 - val_roc_auc: 0.8874
# Epoch 6/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8034 - loss: 0.4121 - pr_auc: 0.8920 - roc_auc: 0.8886 - val_accuracy: 0.7984 - val_loss: 0.4197 - val_pr_auc: 0.8901 - val_roc_auc: 0.8862
# Epoch 7/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8045 - loss: 0.4088 - pr_auc: 0.8940 - roc_auc: 0.8906 - val_accuracy: 0.7872 - val_loss: 0.4334 - val_pr_auc: 0.8813 - val_roc_auc: 0.8773
# Epoch 8/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8058 - loss: 0.4054 - pr_auc: 0.8961 - roc_auc: 0.8926 - val_accuracy: 0.7943 - val_loss: 0.4262 - val_pr_auc: 0.8851 - val_roc_auc: 0.8816
# Epoch 9/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8075 - loss: 0.4015 - pr_auc: 0.8983 - roc_auc: 0.8948 - val_accuracy: 0.7765 - val_loss: 0.4537 - val_pr_auc: 0.8682 - val_roc_auc: 0.8646
# Epoch 10/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8086 - loss: 0.3999 - pr_auc: 0.8992 - roc_auc: 0.8957 - val_accuracy: 0.7843 - val_loss: 0.4449 - val_pr_auc: 0.8739 - val_roc_auc: 0.8708
# Epoch 11/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8098 - loss: 0.3976 - pr_auc: 0.9004 - roc_auc: 0.8969 - val_accuracy: 0.7790 - val_loss: 0.4542 - val_pr_auc: 0.8674 - val_roc_auc: 0.8645
# Epoch 12/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8099 - loss: 0.3964 - pr_auc: 0.9011 - roc_auc: 0.8976 - val_accuracy: 0.7869 - val_loss: 0.4421 - val_pr_auc: 0.8757 - val_roc_auc: 0.8730
# Epoch 13/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8098 - loss: 0.3962 - pr_auc: 0.9013 - roc_auc: 0.8977 - val_accuracy: 0.7842 - val_loss: 0.4453 - val_pr_auc: 0.8739 - val_roc_auc: 0.8715
# Epoch 14/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8112 - loss: 0.3942 - pr_auc: 0.9023 - roc_auc: 0.8989 - val_accuracy: 0.7927 - val_loss: 0.4448 - val_pr_auc: 0.8749 - val_roc_auc: 0.8735
# Epoch 15/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8107 - loss: 0.3944 - pr_auc: 0.9022 - roc_auc: 0.8986 - val_accuracy: 0.7925 - val_loss: 0.4395 - val_pr_auc: 0.8769 - val_roc_auc: 0.8744
# Epoch 16/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8116 - loss: 0.3934 - pr_auc: 0.9028 - roc_auc: 0.8993 - val_accuracy: 0.7852 - val_loss: 0.4464 - val_pr_auc: 0.8725 - val_roc_auc: 0.8696
# Epoch 17/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8116 - loss: 0.3925 - pr_auc: 0.9033 - roc_auc: 0.8997 - val_accuracy: 0.7890 - val_loss: 0.4446 - val_pr_auc: 0.8735 - val_roc_auc: 0.8712
# Epoch 18/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8125 - loss: 0.3918 - pr_auc: 0.9037 - roc_auc: 0.9002 - val_accuracy: 0.7968 - val_loss: 0.4338 - val_pr_auc: 0.8802 - val_roc_auc: 0.8780
# Epoch 19/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8119 - loss: 0.3925 - pr_auc: 0.9035 - roc_auc: 0.9000 - val_accuracy: 0.7847 - val_loss: 0.4480 - val_pr_auc: 0.8725 - val_roc_auc: 0.8695
# Epoch 20/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8136 - loss: 0.3902 - pr_auc: 0.9045 - roc_auc: 0.9010 - val_accuracy: 0.7991 - val_loss: 0.4289 - val_pr_auc: 0.8830 - val_roc_auc: 0.8807
# Epoch 21/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8132 - loss: 0.3896 - pr_auc: 0.9049 - roc_auc: 0.9013 - val_accuracy: 0.7914 - val_loss: 0.4385 - val_pr_auc: 0.8773 - val_roc_auc: 0.8750
# Epoch 22/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8138 - loss: 0.3890 - pr_auc: 0.9052 - roc_auc: 0.9017 - val_accuracy: 0.8028 - val_loss: 0.4232 - val_pr_auc: 0.8869 - val_roc_auc: 0.8848
# Epoch 23/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8144 - loss: 0.3883 - pr_auc: 0.9057 - roc_auc: 0.9022 - val_accuracy: 0.7950 - val_loss: 0.4338 - val_pr_auc: 0.8805 - val_roc_auc: 0.8784
# Epoch 24/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8140 - loss: 0.3885 - pr_auc: 0.9054 - roc_auc: 0.9020 - val_accuracy: 0.8033 - val_loss: 0.4229 - val_pr_auc: 0.8880 - val_roc_auc: 0.8855
# [I 2025-08-14 01:05:07,801] Trial 0 finished with value: 0.8880517931612052 and parameters: {'learning_rate': 0.0030604753118754747, 'Drop_out_rate': 0.5064109461253863, 'n_layers_image': 2, 'n_neurons_image_hidden_ly0': 91, 'n_neurons_image_hidden_ly1': 75, 'n_layers_bdo': 2, 'n_neurons_bdo_hidden_ly0': 36, 'n_neurons_bdo_hidden_ly1': 22, 'n_layers_ado': 2, 'n_neurons_ado_hidden_ly0': 14, 'n_neurons_ado_hidden_ly1': 9}. Best is trial 0 with value: 0.8880517931612052.
# Epoch 1/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6136 - loss: 0.6328 - pr_auc: 0.6638 - roc_auc: 0.6617 - val_accuracy: 0.7738 - val_loss: 0.4591 - val_pr_auc: 0.8598 - val_roc_auc: 0.8565
# Epoch 2/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7687 - loss: 0.4686 - pr_auc: 0.8532 - roc_auc: 0.8501 - val_accuracy: 0.7829 - val_loss: 0.4440 - val_pr_auc: 0.8734 - val_roc_auc: 0.8688
# Epoch 3/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7796 - loss: 0.4565 - pr_auc: 0.8620 - roc_auc: 0.8590 - val_accuracy: 0.7745 - val_loss: 0.4555 - val_pr_auc: 0.8675 - val_roc_auc: 0.8619
# Epoch 4/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7824 - loss: 0.4526 - pr_auc: 0.8647 - roc_auc: 0.8616 - val_accuracy: 0.7926 - val_loss: 0.4326 - val_pr_auc: 0.8801 - val_roc_auc: 0.8763
# Epoch 5/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7861 - loss: 0.4475 - pr_auc: 0.8680 - roc_auc: 0.8648 - val_accuracy: 0.7870 - val_loss: 0.4373 - val_pr_auc: 0.8786 - val_roc_auc: 0.8741
# Epoch 6/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7868 - loss: 0.4468 - pr_auc: 0.8683 - roc_auc: 0.8650 - val_accuracy: 0.7854 - val_loss: 0.4387 - val_pr_auc: 0.8784 - val_roc_auc: 0.8736
# Epoch 7/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7866 - loss: 0.4457 - pr_auc: 0.8691 - roc_auc: 0.8657 - val_accuracy: 0.7885 - val_loss: 0.4359 - val_pr_auc: 0.8777 - val_roc_auc: 0.8737
# Epoch 8/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7870 - loss: 0.4454 - pr_auc: 0.8695 - roc_auc: 0.8662 - val_accuracy: 0.7929 - val_loss: 0.4274 - val_pr_auc: 0.8839 - val_roc_auc: 0.8795
# Epoch 9/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7883 - loss: 0.4420 - pr_auc: 0.8718 - roc_auc: 0.8683 - val_accuracy: 0.7942 - val_loss: 0.4252 - val_pr_auc: 0.8856 - val_roc_auc: 0.8813
# Epoch 10/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7893 - loss: 0.4403 - pr_auc: 0.8732 - roc_auc: 0.8698 - val_accuracy: 0.7836 - val_loss: 0.4385 - val_pr_auc: 0.8783 - val_roc_auc: 0.8735
# Epoch 11/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7903 - loss: 0.4388 - pr_auc: 0.8742 - roc_auc: 0.8708 - val_accuracy: 0.7938 - val_loss: 0.4253 - val_pr_auc: 0.8854 - val_roc_auc: 0.8811
# Epoch 12/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7900 - loss: 0.4379 - pr_auc: 0.8750 - roc_auc: 0.8715 - val_accuracy: 0.7949 - val_loss: 0.4242 - val_pr_auc: 0.8863 - val_roc_auc: 0.8819
# Epoch 13/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7903 - loss: 0.4379 - pr_auc: 0.8751 - roc_auc: 0.8717 - val_accuracy: 0.7887 - val_loss: 0.4332 - val_pr_auc: 0.8818 - val_roc_auc: 0.8772
# Epoch 14/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7906 - loss: 0.4367 - pr_auc: 0.8760 - roc_auc: 0.8725 - val_accuracy: 0.7903 - val_loss: 0.4306 - val_pr_auc: 0.8827 - val_roc_auc: 0.8783
# Epoch 15/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7910 - loss: 0.4354 - pr_auc: 0.8768 - roc_auc: 0.8733 - val_accuracy: 0.7844 - val_loss: 0.4378 - val_pr_auc: 0.8798 - val_roc_auc: 0.8750
# Epoch 16/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7906 - loss: 0.4350 - pr_auc: 0.8772 - roc_auc: 0.8736 - val_accuracy: 0.7891 - val_loss: 0.4333 - val_pr_auc: 0.8812 - val_roc_auc: 0.8767
# Epoch 17/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7923 - loss: 0.4322 - pr_auc: 0.8790 - roc_auc: 0.8754 - val_accuracy: 0.7761 - val_loss: 0.4519 - val_pr_auc: 0.8713 - val_roc_auc: 0.8664
# Epoch 18/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7924 - loss: 0.4319 - pr_auc: 0.8792 - roc_auc: 0.8757 - val_accuracy: 0.7782 - val_loss: 0.4485 - val_pr_auc: 0.8732 - val_roc_auc: 0.8684
# Epoch 19/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7932 - loss: 0.4301 - pr_auc: 0.8804 - roc_auc: 0.8768 - val_accuracy: 0.7657 - val_loss: 0.4671 - val_pr_auc: 0.8634 - val_roc_auc: 0.8578
# Epoch 20/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7933 - loss: 0.4298 - pr_auc: 0.8806 - roc_auc: 0.8770 - val_accuracy: 0.7784 - val_loss: 0.4458 - val_pr_auc: 0.8720 - val_roc_auc: 0.8671
# Epoch 21/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7944 - loss: 0.4285 - pr_auc: 0.8815 - roc_auc: 0.8779 - val_accuracy: 0.7816 - val_loss: 0.4419 - val_pr_auc: 0.8762 - val_roc_auc: 0.8715
# Epoch 22/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7947 - loss: 0.4270 - pr_auc: 0.8825 - roc_auc: 0.8790 - val_accuracy: 0.7715 - val_loss: 0.4562 - val_pr_auc: 0.8678 - val_roc_auc: 0.8626
# Epoch 23/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7944 - loss: 0.4274 - pr_auc: 0.8824 - roc_auc: 0.8788 - val_accuracy: 0.7755 - val_loss: 0.4509 - val_pr_auc: 0.8707 - val_roc_auc: 0.8658
# Epoch 24/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7944 - loss: 0.4266 - pr_auc: 0.8828 - roc_auc: 0.8792 - val_accuracy: 0.7691 - val_loss: 0.4606 - val_pr_auc: 0.8684 - val_roc_auc: 0.8633
# Epoch 25/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7963 - loss: 0.4243 - pr_auc: 0.8843 - roc_auc: 0.8808 - val_accuracy: 0.7728 - val_loss: 0.4544 - val_pr_auc: 0.8677 - val_roc_auc: 0.8626
# Epoch 26/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7969 - loss: 0.4235 - pr_auc: 0.8849 - roc_auc: 0.8814 - val_accuracy: 0.7684 - val_loss: 0.4613 - val_pr_auc: 0.8647 - val_roc_auc: 0.8595
# Epoch 27/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7980 - loss: 0.4214 - pr_auc: 0.8861 - roc_auc: 0.8826 - val_accuracy: 0.7625 - val_loss: 0.4686 - val_pr_auc: 0.8627 - val_roc_auc: 0.8572
# Epoch 28/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7967 - loss: 0.4226 - pr_auc: 0.8855 - roc_auc: 0.8820 - val_accuracy: 0.7534 - val_loss: 0.4833 - val_pr_auc: 0.8571 - val_roc_auc: 0.8514
# Epoch 29/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7979 - loss: 0.4207 - pr_auc: 0.8867 - roc_auc: 0.8832 - val_accuracy: 0.7729 - val_loss: 0.4533 - val_pr_auc: 0.8693 - val_roc_auc: 0.8643
# Epoch 30/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7979 - loss: 0.4199 - pr_auc: 0.8871 - roc_auc: 0.8835 - val_accuracy: 0.7530 - val_loss: 0.4877 - val_pr_auc: 0.8581 - val_roc_auc: 0.8522
# Epoch 31/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7982 - loss: 0.4203 - pr_auc: 0.8869 - roc_auc: 0.8834 - val_accuracy: 0.7530 - val_loss: 0.4850 - val_pr_auc: 0.8531 - val_roc_auc: 0.8472
# Epoch 32/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7985 - loss: 0.4195 - pr_auc: 0.8874 - roc_auc: 0.8839 - val_accuracy: 0.7660 - val_loss: 0.4599 - val_pr_auc: 0.8641 - val_roc_auc: 0.8587
# [I 2025-08-14 01:06:46,749] Trial 1 finished with value: 0.8640803620602524 and parameters: {'learning_rate': 0.00035731289993167127, 'Drop_out_rate': 0.5209870639255518, 'n_layers_image': 1, 'n_neurons_image_hidden_ly0': 91, 'n_layers_bdo': 3, 'n_neurons_bdo_hidden_ly0': 30, 'n_neurons_bdo_hidden_ly1': 22, 'n_neurons_bdo_hidden_ly2': 18, 'n_layers_ado': 2, 'n_neurons_ado_hidden_ly0': 15, 'n_neurons_ado_hidden_ly1': 9}. Best is trial 0 with value: 0.8880517931612052.
# Epoch 1/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6579 - loss: 0.5924 - pr_auc: 0.7270 - roc_auc: 0.7225 - val_accuracy: 0.7991 - val_loss: 0.4223 - val_pr_auc: 0.8873 - val_roc_auc: 0.8837
# Epoch 2/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7917 - loss: 0.4310 - pr_auc: 0.8806 - roc_auc: 0.8769 - val_accuracy: 0.7989 - val_loss: 0.4166 - val_pr_auc: 0.8896 - val_roc_auc: 0.8855
# Epoch 3/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7956 - loss: 0.4240 - pr_auc: 0.8847 - roc_auc: 0.8810 - val_accuracy: 0.7987 - val_loss: 0.4173 - val_pr_auc: 0.8893 - val_roc_auc: 0.8853
# Epoch 4/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7978 - loss: 0.4206 - pr_auc: 0.8866 - roc_auc: 0.8829 - val_accuracy: 0.8035 - val_loss: 0.4104 - val_pr_auc: 0.8936 - val_roc_auc: 0.8896
# Epoch 5/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7983 - loss: 0.4184 - pr_auc: 0.8881 - roc_auc: 0.8844 - val_accuracy: 0.8057 - val_loss: 0.4052 - val_pr_auc: 0.8958 - val_roc_auc: 0.8920
# Epoch 6/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8009 - loss: 0.4148 - pr_auc: 0.8902 - roc_auc: 0.8865 - val_accuracy: 0.8045 - val_loss: 0.4057 - val_pr_auc: 0.8958 - val_roc_auc: 0.8919
# Epoch 7/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8006 - loss: 0.4136 - pr_auc: 0.8910 - roc_auc: 0.8872 - val_accuracy: 0.8070 - val_loss: 0.4024 - val_pr_auc: 0.8974 - val_roc_auc: 0.8937
# Epoch 8/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8031 - loss: 0.4100 - pr_auc: 0.8931 - roc_auc: 0.8895 - val_accuracy: 0.8083 - val_loss: 0.3983 - val_pr_auc: 0.9000 - val_roc_auc: 0.8962
# Epoch 9/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8030 - loss: 0.4092 - pr_auc: 0.8936 - roc_auc: 0.8899 - val_accuracy: 0.8069 - val_loss: 0.4015 - val_pr_auc: 0.8983 - val_roc_auc: 0.8945
# Epoch 10/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8049 - loss: 0.4063 - pr_auc: 0.8954 - roc_auc: 0.8918 - val_accuracy: 0.8090 - val_loss: 0.3978 - val_pr_auc: 0.9003 - val_roc_auc: 0.8965
# Epoch 11/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8052 - loss: 0.4047 - pr_auc: 0.8963 - roc_auc: 0.8927 - val_accuracy: 0.8104 - val_loss: 0.3953 - val_pr_auc: 0.9018 - val_roc_auc: 0.8981
# Epoch 12/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8067 - loss: 0.4026 - pr_auc: 0.8975 - roc_auc: 0.8939 - val_accuracy: 0.8110 - val_loss: 0.3942 - val_pr_auc: 0.9023 - val_roc_auc: 0.8986
# Epoch 13/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8064 - loss: 0.4023 - pr_auc: 0.8977 - roc_auc: 0.8940 - val_accuracy: 0.8120 - val_loss: 0.3921 - val_pr_auc: 0.9036 - val_roc_auc: 0.8999
# Epoch 14/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8077 - loss: 0.4003 - pr_auc: 0.8989 - roc_auc: 0.8953 - val_accuracy: 0.8122 - val_loss: 0.3918 - val_pr_auc: 0.9036 - val_roc_auc: 0.8998
# Epoch 15/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8083 - loss: 0.3990 - pr_auc: 0.8996 - roc_auc: 0.8960 - val_accuracy: 0.8121 - val_loss: 0.3925 - val_pr_auc: 0.9032 - val_roc_auc: 0.8996
# Epoch 16/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8082 - loss: 0.3984 - pr_auc: 0.8999 - roc_auc: 0.8963 - val_accuracy: 0.8127 - val_loss: 0.3912 - val_pr_auc: 0.9040 - val_roc_auc: 0.9002
# Epoch 17/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8091 - loss: 0.3982 - pr_auc: 0.9000 - roc_auc: 0.8964 - val_accuracy: 0.8132 - val_loss: 0.3899 - val_pr_auc: 0.9046 - val_roc_auc: 0.9010
# Epoch 18/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8094 - loss: 0.3965 - pr_auc: 0.9010 - roc_auc: 0.8974 - val_accuracy: 0.8099 - val_loss: 0.3946 - val_pr_auc: 0.9022 - val_roc_auc: 0.8983
# Epoch 19/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8104 - loss: 0.3958 - pr_auc: 0.9014 - roc_auc: 0.8979 - val_accuracy: 0.8139 - val_loss: 0.3887 - val_pr_auc: 0.9052 - val_roc_auc: 0.9016
# Epoch 20/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8106 - loss: 0.3947 - pr_auc: 0.9021 - roc_auc: 0.8985 - val_accuracy: 0.8132 - val_loss: 0.3902 - val_pr_auc: 0.9047 - val_roc_auc: 0.9010
# Epoch 21/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8105 - loss: 0.3950 - pr_auc: 0.9019 - roc_auc: 0.8982 - val_accuracy: 0.8129 - val_loss: 0.3914 - val_pr_auc: 0.9039 - val_roc_auc: 0.9002
# Epoch 22/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8111 - loss: 0.3938 - pr_auc: 0.9026 - roc_auc: 0.8990 - val_accuracy: 0.8129 - val_loss: 0.3909 - val_pr_auc: 0.9040 - val_roc_auc: 0.9004
# Epoch 23/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8114 - loss: 0.3931 - pr_auc: 0.9029 - roc_auc: 0.8993 - val_accuracy: 0.8123 - val_loss: 0.3914 - val_pr_auc: 0.9038 - val_roc_auc: 0.9002
# Epoch 24/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8114 - loss: 0.3926 - pr_auc: 0.9032 - roc_auc: 0.8996 - val_accuracy: 0.8151 - val_loss: 0.3878 - val_pr_auc: 0.9057 - val_roc_auc: 0.9021
# Epoch 25/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8114 - loss: 0.3923 - pr_auc: 0.9033 - roc_auc: 0.8997 - val_accuracy: 0.8133 - val_loss: 0.3891 - val_pr_auc: 0.9051 - val_roc_auc: 0.9015
# Epoch 26/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8118 - loss: 0.3915 - pr_auc: 0.9038 - roc_auc: 0.9002 - val_accuracy: 0.8145 - val_loss: 0.3881 - val_pr_auc: 0.9055 - val_roc_auc: 0.9020
# Epoch 27/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8126 - loss: 0.3909 - pr_auc: 0.9042 - roc_auc: 0.9006 - val_accuracy: 0.8131 - val_loss: 0.3894 - val_pr_auc: 0.9050 - val_roc_auc: 0.9014
# Epoch 28/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8127 - loss: 0.3903 - pr_auc: 0.9045 - roc_auc: 0.9009 - val_accuracy: 0.8109 - val_loss: 0.3934 - val_pr_auc: 0.9035 - val_roc_auc: 0.8998
# Epoch 29/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8119 - loss: 0.3910 - pr_auc: 0.9041 - roc_auc: 0.9004 - val_accuracy: 0.8147 - val_loss: 0.3882 - val_pr_auc: 0.9056 - val_roc_auc: 0.9021
# Epoch 30/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8127 - loss: 0.3898 - pr_auc: 0.9047 - roc_auc: 0.9011 - val_accuracy: 0.8144 - val_loss: 0.3884 - val_pr_auc: 0.9054 - val_roc_auc: 0.9019
# Epoch 31/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8130 - loss: 0.3894 - pr_auc: 0.9050 - roc_auc: 0.9014 - val_accuracy: 0.8156 - val_loss: 0.3887 - val_pr_auc: 0.9056 - val_roc_auc: 0.9022
# Epoch 32/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8136 - loss: 0.3887 - pr_auc: 0.9053 - roc_auc: 0.9017 - val_accuracy: 0.8120 - val_loss: 0.3913 - val_pr_auc: 0.9041 - val_roc_auc: 0.9006
# Epoch 33/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8131 - loss: 0.3892 - pr_auc: 0.9051 - roc_auc: 0.9015 - val_accuracy: 0.8133 - val_loss: 0.3911 - val_pr_auc: 0.9041 - val_roc_auc: 0.9005
# Epoch 34/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8145 - loss: 0.3877 - pr_auc: 0.9059 - roc_auc: 0.9023 - val_accuracy: 0.8148 - val_loss: 0.3877 - val_pr_auc: 0.9058 - val_roc_auc: 0.9023
# Epoch 35/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8133 - loss: 0.3887 - pr_auc: 0.9053 - roc_auc: 0.9017 - val_accuracy: 0.8136 - val_loss: 0.3883 - val_pr_auc: 0.9056 - val_roc_auc: 0.9021
# Epoch 36/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8145 - loss: 0.3870 - pr_auc: 0.9063 - roc_auc: 0.9027 - val_accuracy: 0.8134 - val_loss: 0.3906 - val_pr_auc: 0.9042 - val_roc_auc: 0.9008
# Epoch 37/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8145 - loss: 0.3863 - pr_auc: 0.9066 - roc_auc: 0.9031 - val_accuracy: 0.8140 - val_loss: 0.3889 - val_pr_auc: 0.9052 - val_roc_auc: 0.9017
# Epoch 38/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8147 - loss: 0.3867 - pr_auc: 0.9064 - roc_auc: 0.9029 - val_accuracy: 0.8145 - val_loss: 0.3884 - val_pr_auc: 0.9056 - val_roc_auc: 0.9020
# Epoch 39/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8149 - loss: 0.3860 - pr_auc: 0.9068 - roc_auc: 0.9032 - val_accuracy: 0.8133 - val_loss: 0.3894 - val_pr_auc: 0.9049 - val_roc_auc: 0.9014
# [I 2025-08-14 01:08:57,215] Trial 2 finished with value: 0.9049863561836399 and parameters: {'learning_rate': 0.0015959018280590443, 'Drop_out_rate': 0.25022347731962613, 'n_layers_image': 2, 'n_neurons_image_hidden_ly0': 89, 'n_neurons_image_hidden_ly1': 76, 'n_layers_bdo': 1, 'n_neurons_bdo_hidden_ly0': 33, 'n_layers_ado': 2, 'n_neurons_ado_hidden_ly0': 14, 'n_neurons_ado_hidden_ly1': 9}. Best is trial 2 with value: 0.9049863561836399.
# Epoch 1/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.6857 - loss: 0.5533 - pr_auc: 0.7645 - roc_auc: 0.7593 - val_accuracy: 0.7893 - val_loss: 0.4344 - val_pr_auc: 0.8802 - val_roc_auc: 0.8760
# Epoch 2/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7921 - loss: 0.4328 - pr_auc: 0.8787 - roc_auc: 0.8751 - val_accuracy: 0.7988 - val_loss: 0.4184 - val_pr_auc: 0.8900 - val_roc_auc: 0.8858
# Epoch 3/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7947 - loss: 0.4264 - pr_auc: 0.8829 - roc_auc: 0.8793 - val_accuracy: 0.8022 - val_loss: 0.4107 - val_pr_auc: 0.8930 - val_roc_auc: 0.8892
# Epoch 4/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7991 - loss: 0.4185 - pr_auc: 0.8879 - roc_auc: 0.8843 - val_accuracy: 0.8013 - val_loss: 0.4104 - val_pr_auc: 0.8938 - val_roc_auc: 0.8897
# Epoch 5/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8014 - loss: 0.4138 - pr_auc: 0.8908 - roc_auc: 0.8873 - val_accuracy: 0.7944 - val_loss: 0.4188 - val_pr_auc: 0.8901 - val_roc_auc: 0.8856
# Epoch 6/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8026 - loss: 0.4107 - pr_auc: 0.8927 - roc_auc: 0.8891 - val_accuracy: 0.7993 - val_loss: 0.4135 - val_pr_auc: 0.8936 - val_roc_auc: 0.8892
# Epoch 7/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8039 - loss: 0.4086 - pr_auc: 0.8939 - roc_auc: 0.8903 - val_accuracy: 0.7955 - val_loss: 0.4178 - val_pr_auc: 0.8906 - val_roc_auc: 0.8862
# Epoch 8/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8048 - loss: 0.4065 - pr_auc: 0.8952 - roc_auc: 0.8917 - val_accuracy: 0.8016 - val_loss: 0.4080 - val_pr_auc: 0.8950 - val_roc_auc: 0.8909
# Epoch 9/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8060 - loss: 0.4035 - pr_auc: 0.8969 - roc_auc: 0.8933 - val_accuracy: 0.7956 - val_loss: 0.4159 - val_pr_auc: 0.8911 - val_roc_auc: 0.8867
# Epoch 10/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8061 - loss: 0.4023 - pr_auc: 0.8977 - roc_auc: 0.8940 - val_accuracy: 0.8069 - val_loss: 0.4035 - val_pr_auc: 0.8976 - val_roc_auc: 0.8935
# Epoch 11/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8074 - loss: 0.4006 - pr_auc: 0.8986 - roc_auc: 0.8951 - val_accuracy: 0.8095 - val_loss: 0.4005 - val_pr_auc: 0.8999 - val_roc_auc: 0.8962
# Epoch 12/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8074 - loss: 0.4005 - pr_auc: 0.8988 - roc_auc: 0.8952 - val_accuracy: 0.8098 - val_loss: 0.3967 - val_pr_auc: 0.9010 - val_roc_auc: 0.8973
# Epoch 13/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8074 - loss: 0.3989 - pr_auc: 0.8996 - roc_auc: 0.8960 - val_accuracy: 0.8095 - val_loss: 0.3965 - val_pr_auc: 0.9014 - val_roc_auc: 0.8975
# Epoch 14/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8084 - loss: 0.3974 - pr_auc: 0.9005 - roc_auc: 0.8968 - val_accuracy: 0.8110 - val_loss: 0.3974 - val_pr_auc: 0.9021 - val_roc_auc: 0.8983
# Epoch 15/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8089 - loss: 0.3964 - pr_auc: 0.9011 - roc_auc: 0.8974 - val_accuracy: 0.8089 - val_loss: 0.3966 - val_pr_auc: 0.9011 - val_roc_auc: 0.8973
# Epoch 16/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8105 - loss: 0.3944 - pr_auc: 0.9022 - roc_auc: 0.8986 - val_accuracy: 0.8057 - val_loss: 0.3997 - val_pr_auc: 0.8996 - val_roc_auc: 0.8956
# Epoch 17/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8100 - loss: 0.3948 - pr_auc: 0.9019 - roc_auc: 0.8983 - val_accuracy: 0.8109 - val_loss: 0.3933 - val_pr_auc: 0.9034 - val_roc_auc: 0.8996
# Epoch 18/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8105 - loss: 0.3936 - pr_auc: 0.9027 - roc_auc: 0.8990 - val_accuracy: 0.8123 - val_loss: 0.3936 - val_pr_auc: 0.9038 - val_roc_auc: 0.9001
# Epoch 19/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8108 - loss: 0.3935 - pr_auc: 0.9027 - roc_auc: 0.8991 - val_accuracy: 0.8069 - val_loss: 0.3992 - val_pr_auc: 0.8999 - val_roc_auc: 0.8960
# Epoch 20/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8119 - loss: 0.3906 - pr_auc: 0.9043 - roc_auc: 0.9006 - val_accuracy: 0.8134 - val_loss: 0.3911 - val_pr_auc: 0.9048 - val_roc_auc: 0.9012
# Epoch 21/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8122 - loss: 0.3905 - pr_auc: 0.9043 - roc_auc: 0.9007 - val_accuracy: 0.8081 - val_loss: 0.3976 - val_pr_auc: 0.9014 - val_roc_auc: 0.8977
# Epoch 22/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8120 - loss: 0.3908 - pr_auc: 0.9041 - roc_auc: 0.9005 - val_accuracy: 0.8087 - val_loss: 0.4005 - val_pr_auc: 0.9001 - val_roc_auc: 0.8963
# Epoch 23/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8122 - loss: 0.3902 - pr_auc: 0.9045 - roc_auc: 0.9008 - val_accuracy: 0.8074 - val_loss: 0.3998 - val_pr_auc: 0.9001 - val_roc_auc: 0.8963
# Epoch 24/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8132 - loss: 0.3889 - pr_auc: 0.9052 - roc_auc: 0.9016 - val_accuracy: 0.8100 - val_loss: 0.3972 - val_pr_auc: 0.9019 - val_roc_auc: 0.8982
# Epoch 25/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8127 - loss: 0.3893 - pr_auc: 0.9049 - roc_auc: 0.9013 - val_accuracy: 0.8065 - val_loss: 0.4028 - val_pr_auc: 0.8981 - val_roc_auc: 0.8944
# Epoch 26/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8133 - loss: 0.3880 - pr_auc: 0.9057 - roc_auc: 0.9021 - val_accuracy: 0.8045 - val_loss: 0.4016 - val_pr_auc: 0.8986 - val_roc_auc: 0.8946
# Epoch 27/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8139 - loss: 0.3872 - pr_auc: 0.9061 - roc_auc: 0.9025 - val_accuracy: 0.8108 - val_loss: 0.3943 - val_pr_auc: 0.9031 - val_roc_auc: 0.8994
# Epoch 28/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8146 - loss: 0.3869 - pr_auc: 0.9062 - roc_auc: 0.9026 - val_accuracy: 0.7973 - val_loss: 0.4079 - val_pr_auc: 0.8952 - val_roc_auc: 0.8908
# Epoch 29/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8137 - loss: 0.3871 - pr_auc: 0.9061 - roc_auc: 0.9024 - val_accuracy: 0.8078 - val_loss: 0.3958 - val_pr_auc: 0.9019 - val_roc_auc: 0.8980
# Epoch 30/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8143 - loss: 0.3860 - pr_auc: 0.9067 - roc_auc: 0.9030 - val_accuracy: 0.8061 - val_loss: 0.3976 - val_pr_auc: 0.9008 - val_roc_auc: 0.8967
# Epoch 31/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8144 - loss: 0.3860 - pr_auc: 0.9067 - roc_auc: 0.9030 - val_accuracy: 0.8006 - val_loss: 0.4013 - val_pr_auc: 0.8989 - val_roc_auc: 0.8946
# Epoch 32/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8146 - loss: 0.3850 - pr_auc: 0.9072 - roc_auc: 0.9035 - val_accuracy: 0.8026 - val_loss: 0.4018 - val_pr_auc: 0.8986 - val_roc_auc: 0.8945
# Epoch 33/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8149 - loss: 0.3848 - pr_auc: 0.9074 - roc_auc: 0.9037 - val_accuracy: 0.7977 - val_loss: 0.4059 - val_pr_auc: 0.8968 - val_roc_auc: 0.8924
# Epoch 34/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8150 - loss: 0.3847 - pr_auc: 0.9074 - roc_auc: 0.9037 - val_accuracy: 0.7999 - val_loss: 0.4032 - val_pr_auc: 0.8981 - val_roc_auc: 0.8938
# Epoch 35/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8161 - loss: 0.3828 - pr_auc: 0.9084 - roc_auc: 0.9048 - val_accuracy: 0.7990 - val_loss: 0.4040 - val_pr_auc: 0.8976 - val_roc_auc: 0.8933
# Epoch 36/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8164 - loss: 0.3826 - pr_auc: 0.9085 - roc_auc: 0.9049 - val_accuracy: 0.8021 - val_loss: 0.3991 - val_pr_auc: 0.8999 - val_roc_auc: 0.8957
# Epoch 37/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8165 - loss: 0.3826 - pr_auc: 0.9085 - roc_auc: 0.9049 - val_accuracy: 0.8023 - val_loss: 0.3994 - val_pr_auc: 0.8999 - val_roc_auc: 0.8956
# Epoch 38/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8169 - loss: 0.3815 - pr_auc: 0.9091 - roc_auc: 0.9055 - val_accuracy: 0.8019 - val_loss: 0.4015 - val_pr_auc: 0.8986 - val_roc_auc: 0.8945
# Epoch 39/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8171 - loss: 0.3813 - pr_auc: 0.9092 - roc_auc: 0.9056 - val_accuracy: 0.8059 - val_loss: 0.3987 - val_pr_auc: 0.9001 - val_roc_auc: 0.8962
# Epoch 40/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8172 - loss: 0.3807 - pr_auc: 0.9095 - roc_auc: 0.9060 - val_accuracy: 0.7979 - val_loss: 0.4074 - val_pr_auc: 0.8959 - val_roc_auc: 0.8916
# [I 2025-08-14 01:11:43,670] Trial 3 finished with value: 0.8959291398282285 and parameters: {'learning_rate': 0.0016545860621267003, 'Drop_out_rate': 0.3278521407287982, 'n_layers_image': 2, 'n_neurons_image_hidden_ly0': 92, 'n_neurons_image_hidden_ly1': 76, 'n_layers_bdo': 3, 'n_neurons_bdo_hidden_ly0': 47, 'n_neurons_bdo_hidden_ly1': 23, 'n_neurons_bdo_hidden_ly2': 20, 'n_layers_ado': 3, 'n_neurons_ado_hidden_ly0': 15, 'n_neurons_ado_hidden_ly1': 8, 'n_neurons_ado_hidden_ly2': 7}. Best is trial 2 with value: 0.9049863561836399.
# Epoch 1/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7060 - loss: 0.5317 - pr_auc: 0.7875 - roc_auc: 0.7828 - val_accuracy: 0.7977 - val_loss: 0.4177 - val_pr_auc: 0.8896 - val_roc_auc: 0.8855
# Epoch 2/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7964 - loss: 0.4225 - pr_auc: 0.8854 - roc_auc: 0.8818 - val_accuracy: 0.8040 - val_loss: 0.4075 - val_pr_auc: 0.8951 - val_roc_auc: 0.8910
# Epoch 3/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8010 - loss: 0.4146 - pr_auc: 0.8903 - roc_auc: 0.8868 - val_accuracy: 0.8069 - val_loss: 0.4010 - val_pr_auc: 0.8987 - val_roc_auc: 0.8948
# Epoch 4/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8037 - loss: 0.4090 - pr_auc: 0.8937 - roc_auc: 0.8902 - val_accuracy: 0.8107 - val_loss: 0.3953 - val_pr_auc: 0.9018 - val_roc_auc: 0.8981
# Epoch 5/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8063 - loss: 0.4037 - pr_auc: 0.8969 - roc_auc: 0.8933 - val_accuracy: 0.8116 - val_loss: 0.3922 - val_pr_auc: 0.9039 - val_roc_auc: 0.9001
# Epoch 6/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8080 - loss: 0.4007 - pr_auc: 0.8986 - roc_auc: 0.8951 - val_accuracy: 0.8101 - val_loss: 0.3948 - val_pr_auc: 0.9029 - val_roc_auc: 0.8991
# Epoch 7/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8079 - loss: 0.3996 - pr_auc: 0.8993 - roc_auc: 0.8957 - val_accuracy: 0.8096 - val_loss: 0.3951 - val_pr_auc: 0.9023 - val_roc_auc: 0.8984
# Epoch 8/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8088 - loss: 0.3980 - pr_auc: 0.9002 - roc_auc: 0.8967 - val_accuracy: 0.8110 - val_loss: 0.3915 - val_pr_auc: 0.9037 - val_roc_auc: 0.9000
# Epoch 9/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8097 - loss: 0.3966 - pr_auc: 0.9011 - roc_auc: 0.8976 - val_accuracy: 0.8113 - val_loss: 0.3913 - val_pr_auc: 0.9039 - val_roc_auc: 0.9000
# Epoch 10/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8100 - loss: 0.3960 - pr_auc: 0.9015 - roc_auc: 0.8979 - val_accuracy: 0.8138 - val_loss: 0.3889 - val_pr_auc: 0.9055 - val_roc_auc: 0.9018
# Epoch 11/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8115 - loss: 0.3938 - pr_auc: 0.9025 - roc_auc: 0.8991 - val_accuracy: 0.8117 - val_loss: 0.3912 - val_pr_auc: 0.9042 - val_roc_auc: 0.9006
# Epoch 12/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8108 - loss: 0.3939 - pr_auc: 0.9024 - roc_auc: 0.8989 - val_accuracy: 0.8140 - val_loss: 0.3895 - val_pr_auc: 0.9053 - val_roc_auc: 0.9016
# Epoch 13/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8115 - loss: 0.3928 - pr_auc: 0.9030 - roc_auc: 0.8994 - val_accuracy: 0.8120 - val_loss: 0.3911 - val_pr_auc: 0.9050 - val_roc_auc: 0.9013
# Epoch 14/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8127 - loss: 0.3903 - pr_auc: 0.9044 - roc_auc: 0.9008 - val_accuracy: 0.8132 - val_loss: 0.3926 - val_pr_auc: 0.9047 - val_roc_auc: 0.9011
# Epoch 15/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8127 - loss: 0.3900 - pr_auc: 0.9045 - roc_auc: 0.9009 - val_accuracy: 0.8126 - val_loss: 0.4009 - val_pr_auc: 0.9026 - val_roc_auc: 0.8994
# Epoch 16/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8136 - loss: 0.3885 - pr_auc: 0.9054 - roc_auc: 0.9018 - val_accuracy: 0.8109 - val_loss: 0.4011 - val_pr_auc: 0.9016 - val_roc_auc: 0.8981
# Epoch 17/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8142 - loss: 0.3883 - pr_auc: 0.9055 - roc_auc: 0.9020 - val_accuracy: 0.8123 - val_loss: 0.3988 - val_pr_auc: 0.9031 - val_roc_auc: 0.8997
# Epoch 18/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8143 - loss: 0.3875 - pr_auc: 0.9059 - roc_auc: 0.9023 - val_accuracy: 0.8126 - val_loss: 0.3987 - val_pr_auc: 0.9045 - val_roc_auc: 0.9009
# Epoch 19/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8153 - loss: 0.3860 - pr_auc: 0.9068 - roc_auc: 0.9032 - val_accuracy: 0.8105 - val_loss: 0.4045 - val_pr_auc: 0.9008 - val_roc_auc: 0.8976
# Epoch 20/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8148 - loss: 0.3869 - pr_auc: 0.9063 - roc_auc: 0.9027 - val_accuracy: 0.8136 - val_loss: 0.3989 - val_pr_auc: 0.9048 - val_roc_auc: 0.9013
# Epoch 21/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8148 - loss: 0.3861 - pr_auc: 0.9067 - roc_auc: 0.9031 - val_accuracy: 0.8102 - val_loss: 0.4065 - val_pr_auc: 0.9018 - val_roc_auc: 0.8980
# Epoch 22/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8155 - loss: 0.3847 - pr_auc: 0.9074 - roc_auc: 0.9037 - val_accuracy: 0.8122 - val_loss: 0.4005 - val_pr_auc: 0.9044 - val_roc_auc: 0.9007
# Epoch 23/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8157 - loss: 0.3841 - pr_auc: 0.9078 - roc_auc: 0.9041 - val_accuracy: 0.8080 - val_loss: 0.4129 - val_pr_auc: 0.9010 - val_roc_auc: 0.8974
# Epoch 24/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8162 - loss: 0.3835 - pr_auc: 0.9082 - roc_auc: 0.9047 - val_accuracy: 0.8122 - val_loss: 0.4107 - val_pr_auc: 0.9035 - val_roc_auc: 0.9001
# Epoch 25/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8154 - loss: 0.3849 - pr_auc: 0.9075 - roc_auc: 0.9039 - val_accuracy: 0.8105 - val_loss: 0.4039 - val_pr_auc: 0.9037 - val_roc_auc: 0.9002
# Epoch 26/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8160 - loss: 0.3838 - pr_auc: 0.9079 - roc_auc: 0.9043 - val_accuracy: 0.8103 - val_loss: 0.4059 - val_pr_auc: 0.9026 - val_roc_auc: 0.8991
# Epoch 27/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8158 - loss: 0.3836 - pr_auc: 0.9081 - roc_auc: 0.9045 - val_accuracy: 0.8058 - val_loss: 0.4053 - val_pr_auc: 0.9010 - val_roc_auc: 0.8970
# Epoch 28/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8161 - loss: 0.3827 - pr_auc: 0.9085 - roc_auc: 0.9049 - val_accuracy: 0.8088 - val_loss: 0.4071 - val_pr_auc: 0.9028 - val_roc_auc: 0.8989
# Epoch 29/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8161 - loss: 0.3838 - pr_auc: 0.9079 - roc_auc: 0.9043 - val_accuracy: 0.8088 - val_loss: 0.4071 - val_pr_auc: 0.9014 - val_roc_auc: 0.8977
# Epoch 30/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8165 - loss: 0.3826 - pr_auc: 0.9086 - roc_auc: 0.9049 - val_accuracy: 0.7989 - val_loss: 0.4181 - val_pr_auc: 0.8935 - val_roc_auc: 0.8894
# [I 2025-08-14 01:13:42,594] Trial 4 finished with value: 0.8936024155651234 and parameters: {'learning_rate': 0.0046435770919939145, 'Drop_out_rate': 0.32260826917797136, 'n_layers_image': 3, 'n_neurons_image_hidden_ly0': 95, 'n_neurons_image_hidden_ly1': 71, 'n_neurons_image_hidden_ly2': 66, 'n_layers_bdo': 2, 'n_neurons_bdo_hidden_ly0': 27, 'n_neurons_bdo_hidden_ly1': 23, 'n_layers_ado': 1, 'n_neurons_ado_hidden_ly0': 16}. Best is trial 2 with value: 0.9049863561836399.
# Epoch 1/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7209 - loss: 0.5137 - pr_auc: 0.8078 - roc_auc: 0.8017 - val_accuracy: 0.7986 - val_loss: 0.4212 - val_pr_auc: 0.8878 - val_roc_auc: 0.8839
# Epoch 2/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7953 - loss: 0.4242 - pr_auc: 0.8843 - roc_auc: 0.8805 - val_accuracy: 0.7970 - val_loss: 0.4211 - val_pr_auc: 0.8887 - val_roc_auc: 0.8844
# Epoch 3/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7990 - loss: 0.4172 - pr_auc: 0.8887 - roc_auc: 0.8849 - val_accuracy: 0.8014 - val_loss: 0.4137 - val_pr_auc: 0.8909 - val_roc_auc: 0.8868
# Epoch 4/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8012 - loss: 0.4132 - pr_auc: 0.8911 - roc_auc: 0.8873 - val_accuracy: 0.8072 - val_loss: 0.4018 - val_pr_auc: 0.8981 - val_roc_auc: 0.8943
# Epoch 5/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8035 - loss: 0.4092 - pr_auc: 0.8935 - roc_auc: 0.8899 - val_accuracy: 0.8076 - val_loss: 0.4014 - val_pr_auc: 0.8988 - val_roc_auc: 0.8950
# Epoch 6/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8046 - loss: 0.4065 - pr_auc: 0.8951 - roc_auc: 0.8914 - val_accuracy: 0.8067 - val_loss: 0.4016 - val_pr_auc: 0.8982 - val_roc_auc: 0.8943
# Epoch 7/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8048 - loss: 0.4057 - pr_auc: 0.8956 - roc_auc: 0.8919 - val_accuracy: 0.8087 - val_loss: 0.3991 - val_pr_auc: 0.8995 - val_roc_auc: 0.8957
# Epoch 8/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8059 - loss: 0.4034 - pr_auc: 0.8970 - roc_auc: 0.8933 - val_accuracy: 0.8108 - val_loss: 0.3942 - val_pr_auc: 0.9024 - val_roc_auc: 0.8987
# Epoch 9/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8067 - loss: 0.4017 - pr_auc: 0.8979 - roc_auc: 0.8943 - val_accuracy: 0.8100 - val_loss: 0.3945 - val_pr_auc: 0.9025 - val_roc_auc: 0.8986
# Epoch 10/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8074 - loss: 0.4007 - pr_auc: 0.8986 - roc_auc: 0.8950 - val_accuracy: 0.8114 - val_loss: 0.3936 - val_pr_auc: 0.9028 - val_roc_auc: 0.8992
# Epoch 11/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8079 - loss: 0.3992 - pr_auc: 0.8994 - roc_auc: 0.8957 - val_accuracy: 0.8104 - val_loss: 0.3927 - val_pr_auc: 0.9032 - val_roc_auc: 0.8992
# Epoch 12/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8085 - loss: 0.3979 - pr_auc: 0.9001 - roc_auc: 0.8965 - val_accuracy: 0.8122 - val_loss: 0.3913 - val_pr_auc: 0.9038 - val_roc_auc: 0.9000
# Epoch 13/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8088 - loss: 0.3977 - pr_auc: 0.9002 - roc_auc: 0.8965 - val_accuracy: 0.8108 - val_loss: 0.3909 - val_pr_auc: 0.9041 - val_roc_auc: 0.9003
# Epoch 14/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8095 - loss: 0.3955 - pr_auc: 0.9015 - roc_auc: 0.8978 - val_accuracy: 0.8126 - val_loss: 0.3912 - val_pr_auc: 0.9039 - val_roc_auc: 0.9001
# Epoch 15/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8097 - loss: 0.3957 - pr_auc: 0.9013 - roc_auc: 0.8977 - val_accuracy: 0.8134 - val_loss: 0.3907 - val_pr_auc: 0.9048 - val_roc_auc: 0.9010
# Epoch 16/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8100 - loss: 0.3941 - pr_auc: 0.9022 - roc_auc: 0.8986 - val_accuracy: 0.8123 - val_loss: 0.3909 - val_pr_auc: 0.9043 - val_roc_auc: 0.9005
# Epoch 17/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8103 - loss: 0.3941 - pr_auc: 0.9022 - roc_auc: 0.8985 - val_accuracy: 0.8136 - val_loss: 0.3899 - val_pr_auc: 0.9049 - val_roc_auc: 0.9013
# Epoch 18/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8117 - loss: 0.3921 - pr_auc: 0.9034 - roc_auc: 0.8997 - val_accuracy: 0.8132 - val_loss: 0.3901 - val_pr_auc: 0.9046 - val_roc_auc: 0.9008
# Epoch 19/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8116 - loss: 0.3915 - pr_auc: 0.9037 - roc_auc: 0.9000 - val_accuracy: 0.8123 - val_loss: 0.3901 - val_pr_auc: 0.9045 - val_roc_auc: 0.9008
# Epoch 20/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8126 - loss: 0.3905 - pr_auc: 0.9042 - roc_auc: 0.9006 - val_accuracy: 0.8131 - val_loss: 0.3891 - val_pr_auc: 0.9050 - val_roc_auc: 0.9013
# Epoch 21/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8126 - loss: 0.3898 - pr_auc: 0.9046 - roc_auc: 0.9010 - val_accuracy: 0.8130 - val_loss: 0.3906 - val_pr_auc: 0.9043 - val_roc_auc: 0.9006
# Epoch 22/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8117 - loss: 0.3898 - pr_auc: 0.9046 - roc_auc: 0.9009 - val_accuracy: 0.8120 - val_loss: 0.3921 - val_pr_auc: 0.9035 - val_roc_auc: 0.8998
# Epoch 23/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8128 - loss: 0.3892 - pr_auc: 0.9049 - roc_auc: 0.9013 - val_accuracy: 0.8124 - val_loss: 0.3901 - val_pr_auc: 0.9048 - val_roc_auc: 0.9011
# Epoch 24/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8132 - loss: 0.3887 - pr_auc: 0.9052 - roc_auc: 0.9016 - val_accuracy: 0.8133 - val_loss: 0.3905 - val_pr_auc: 0.9047 - val_roc_auc: 0.9011
# Epoch 25/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8129 - loss: 0.3889 - pr_auc: 0.9051 - roc_auc: 0.9014 - val_accuracy: 0.8121 - val_loss: 0.3919 - val_pr_auc: 0.9035 - val_roc_auc: 0.8999
# Epoch 26/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8129 - loss: 0.3882 - pr_auc: 0.9055 - roc_auc: 0.9019 - val_accuracy: 0.8129 - val_loss: 0.3886 - val_pr_auc: 0.9054 - val_roc_auc: 0.9018
# Epoch 27/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8140 - loss: 0.3868 - pr_auc: 0.9063 - roc_auc: 0.9026 - val_accuracy: 0.8091 - val_loss: 0.3965 - val_pr_auc: 0.9020 - val_roc_auc: 0.8982
# Epoch 28/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8136 - loss: 0.3867 - pr_auc: 0.9063 - roc_auc: 0.9026 - val_accuracy: 0.8121 - val_loss: 0.3901 - val_pr_auc: 0.9047 - val_roc_auc: 0.9010
# Epoch 29/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8149 - loss: 0.3853 - pr_auc: 0.9070 - roc_auc: 0.9034 - val_accuracy: 0.8128 - val_loss: 0.3906 - val_pr_auc: 0.9043 - val_roc_auc: 0.9007
# Epoch 30/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8149 - loss: 0.3855 - pr_auc: 0.9069 - roc_auc: 0.9033 - val_accuracy: 0.8139 - val_loss: 0.3872 - val_pr_auc: 0.9061 - val_roc_auc: 0.9024
# Epoch 31/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8151 - loss: 0.3848 - pr_auc: 0.9073 - roc_auc: 0.9036 - val_accuracy: 0.8123 - val_loss: 0.3900 - val_pr_auc: 0.9046 - val_roc_auc: 0.9010
# Epoch 32/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8150 - loss: 0.3851 - pr_auc: 0.9071 - roc_auc: 0.9035 - val_accuracy: 0.8123 - val_loss: 0.3928 - val_pr_auc: 0.9039 - val_roc_auc: 0.9002
# Epoch 33/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8151 - loss: 0.3847 - pr_auc: 0.9074 - roc_auc: 0.9037 - val_accuracy: 0.8124 - val_loss: 0.3901 - val_pr_auc: 0.9045 - val_roc_auc: 0.9008
# Epoch 34/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8151 - loss: 0.3842 - pr_auc: 0.9076 - roc_auc: 0.9039 - val_accuracy: 0.8116 - val_loss: 0.3903 - val_pr_auc: 0.9044 - val_roc_auc: 0.9007
# Epoch 35/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8157 - loss: 0.3833 - pr_auc: 0.9081 - roc_auc: 0.9044 - val_accuracy: 0.8114 - val_loss: 0.3907 - val_pr_auc: 0.9043 - val_roc_auc: 0.9006
# Epoch 36/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8160 - loss: 0.3836 - pr_auc: 0.9080 - roc_auc: 0.9043 - val_accuracy: 0.8125 - val_loss: 0.3925 - val_pr_auc: 0.9032 - val_roc_auc: 0.8996
# Epoch 37/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8163 - loss: 0.3823 - pr_auc: 0.9086 - roc_auc: 0.9050 - val_accuracy: 0.8117 - val_loss: 0.3900 - val_pr_auc: 0.9047 - val_roc_auc: 0.9010
# Epoch 38/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8161 - loss: 0.3823 - pr_auc: 0.9086 - roc_auc: 0.9050 - val_accuracy: 0.8107 - val_loss: 0.3939 - val_pr_auc: 0.9028 - val_roc_auc: 0.8992
# Epoch 39/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8166 - loss: 0.3817 - pr_auc: 0.9090 - roc_auc: 0.9053 - val_accuracy: 0.8130 - val_loss: 0.3907 - val_pr_auc: 0.9043 - val_roc_auc: 0.9008
# Epoch 40/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8169 - loss: 0.3808 - pr_auc: 0.9094 - roc_auc: 0.9058 - val_accuracy: 0.8120 - val_loss: 0.3911 - val_pr_auc: 0.9040 - val_roc_auc: 0.9004
# Epoch 41/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8179 - loss: 0.3796 - pr_auc: 0.9101 - roc_auc: 0.9065 - val_accuracy: 0.8121 - val_loss: 0.3908 - val_pr_auc: 0.9043 - val_roc_auc: 0.9007
# Epoch 42/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8182 - loss: 0.3792 - pr_auc: 0.9102 - roc_auc: 0.9066 - val_accuracy: 0.8124 - val_loss: 0.3906 - val_pr_auc: 0.9044 - val_roc_auc: 0.9009
# Epoch 43/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8178 - loss: 0.3792 - pr_auc: 0.9102 - roc_auc: 0.9066 - val_accuracy: 0.8116 - val_loss: 0.3925 - val_pr_auc: 0.9034 - val_roc_auc: 0.8998
# Epoch 44/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8177 - loss: 0.3798 - pr_auc: 0.9099 - roc_auc: 0.9063 - val_accuracy: 0.8121 - val_loss: 0.3920 - val_pr_auc: 0.9037 - val_roc_auc: 0.9002
# Epoch 45/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8186 - loss: 0.3778 - pr_auc: 0.9110 - roc_auc: 0.9074 - val_accuracy: 0.8119 - val_loss: 0.3913 - val_pr_auc: 0.9040 - val_roc_auc: 0.9005
# Epoch 46/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8175 - loss: 0.3788 - pr_auc: 0.9105 - roc_auc: 0.9068 - val_accuracy: 0.8106 - val_loss: 0.3934 - val_pr_auc: 0.9027 - val_roc_auc: 0.8990
# Epoch 47/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8190 - loss: 0.3771 - pr_auc: 0.9113 - roc_auc: 0.9077 - val_accuracy: 0.8109 - val_loss: 0.3942 - val_pr_auc: 0.9025 - val_roc_auc: 0.8990
# Epoch 48/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8192 - loss: 0.3771 - pr_auc: 0.9113 - roc_auc: 0.9077 - val_accuracy: 0.8133 - val_loss: 0.3924 - val_pr_auc: 0.9038 - val_roc_auc: 0.9002
# Epoch 49/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8189 - loss: 0.3770 - pr_auc: 0.9114 - roc_auc: 0.9078 - val_accuracy: 0.8106 - val_loss: 0.3944 - val_pr_auc: 0.9027 - val_roc_auc: 0.8993
# Epoch 50/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8192 - loss: 0.3763 - pr_auc: 0.9118 - roc_auc: 0.9082 - val_accuracy: 0.8109 - val_loss: 0.3929 - val_pr_auc: 0.9032 - val_roc_auc: 0.8997
# ...
# Epoch 20/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8075 - loss: 0.4014 - pr_auc: 0.8981 - roc_auc: 0.8945 - val_accuracy: 0.8129 - val_loss: 0.3929 - val_pr_auc: 0.9031 - val_roc_auc: 0.8994
# Epoch 21/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8072 - loss: 0.4003 - pr_auc: 0.8987 - roc_auc: 0.8951 - val_accuracy: 0.8111 - val_loss: 0.3940 - val_pr_auc: 0.9025 - val_roc_auc: 0.8987
# Epoch 22/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8082 - loss: 0.3994 - pr_auc: 0.8993 - roc_auc: 0.8957 - val_accuracy: 0.8115 - val_loss: 0.3933 - val_pr_auc: 0.9029 - val_roc_auc: 0.8991
# Epoch 23/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8093 - loss: 0.3973 - pr_auc: 0.9005 - roc_auc: 0.8969 - val_accuracy: 0.8124 - val_loss: 0.3912 - val_pr_auc: 0.9039 - val_roc_auc: 0.9003
# Epoch 24/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8088 - loss: 0.3974 - pr_auc: 0.9005 - roc_auc: 0.8969 - val_accuracy: 0.8119 - val_loss: 0.3925 - val_pr_auc: 0.9032 - val_roc_auc: 0.8996
# Epoch 25/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8095 - loss: 0.3964 - pr_auc: 0.9010 - roc_auc: 0.8974 - val_accuracy: 0.8126 - val_loss: 0.3915 - val_pr_auc: 0.9039 - val_roc_auc: 0.9002
# Epoch 26/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8098 - loss: 0.3953 - pr_auc: 0.9016 - roc_auc: 0.8980 - val_accuracy: 0.8119 - val_loss: 0.3907 - val_pr_auc: 0.9045 - val_roc_auc: 0.9007
# Epoch 27/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8106 - loss: 0.3948 - pr_auc: 0.9019 - roc_auc: 0.8983 - val_accuracy: 0.8129 - val_loss: 0.3903 - val_pr_auc: 0.9044 - val_roc_auc: 0.9008
# Epoch 28/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8104 - loss: 0.3941 - pr_auc: 0.9023 - roc_auc: 0.8987 - val_accuracy: 0.8119 - val_loss: 0.3914 - val_pr_auc: 0.9037 - val_roc_auc: 0.9000
# Epoch 29/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8108 - loss: 0.3943 - pr_auc: 0.9022 - roc_auc: 0.8985 - val_accuracy: 0.8133 - val_loss: 0.3888 - val_pr_auc: 0.9052 - val_roc_auc: 0.9015
# Epoch 30/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8109 - loss: 0.3936 - pr_auc: 0.9026 - roc_auc: 0.8989 - val_accuracy: 0.8136 - val_loss: 0.3891 - val_pr_auc: 0.9050 - val_roc_auc: 0.9013
# Epoch 31/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8117 - loss: 0.3923 - pr_auc: 0.9033 - roc_auc: 0.8997 - val_accuracy: 0.8125 - val_loss: 0.3896 - val_pr_auc: 0.9049 - val_roc_auc: 0.9011
# Epoch 32/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8120 - loss: 0.3921 - pr_auc: 0.9033 - roc_auc: 0.8997 - val_accuracy: 0.8143 - val_loss: 0.3880 - val_pr_auc: 0.9057 - val_roc_auc: 0.9020
# Epoch 33/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8119 - loss: 0.3916 - pr_auc: 0.9037 - roc_auc: 0.9001 - val_accuracy: 0.8130 - val_loss: 0.3893 - val_pr_auc: 0.9051 - val_roc_auc: 0.9013
# Epoch 34/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8126 - loss: 0.3913 - pr_auc: 0.9038 - roc_auc: 0.9002 - val_accuracy: 0.8126 - val_loss: 0.3885 - val_pr_auc: 0.9054 - val_roc_auc: 0.9017
# Epoch 35/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8120 - loss: 0.3920 - pr_auc: 0.9035 - roc_auc: 0.8998 - val_accuracy: 0.8136 - val_loss: 0.3875 - val_pr_auc: 0.9059 - val_roc_auc: 0.9021
# Epoch 36/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8125 - loss: 0.3901 - pr_auc: 0.9045 - roc_auc: 0.9009 - val_accuracy: 0.8138 - val_loss: 0.3876 - val_pr_auc: 0.9059 - val_roc_auc: 0.9022
# Epoch 37/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8127 - loss: 0.3903 - pr_auc: 0.9043 - roc_auc: 0.9007 - val_accuracy: 0.8147 - val_loss: 0.3873 - val_pr_auc: 0.9060 - val_roc_auc: 0.9023
# Epoch 38/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8129 - loss: 0.3898 - pr_auc: 0.9046 - roc_auc: 0.9010 - val_accuracy: 0.8128 - val_loss: 0.3877 - val_pr_auc: 0.9058 - val_roc_auc: 0.9020
# Epoch 39/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8128 - loss: 0.3899 - pr_auc: 0.9046 - roc_auc: 0.9010 - val_accuracy: 0.8123 - val_loss: 0.3905 - val_pr_auc: 0.9045 - val_roc_auc: 0.9008
# Epoch 40/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8128 - loss: 0.3896 - pr_auc: 0.9047 - roc_auc: 0.9011 - val_accuracy: 0.8139 - val_loss: 0.3881 - val_pr_auc: 0.9059 - val_roc_auc: 0.9021
# Epoch 41/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8129 - loss: 0.3892 - pr_auc: 0.9050 - roc_auc: 0.9014 - val_accuracy: 0.8146 - val_loss: 0.3859 - val_pr_auc: 0.9067 - val_roc_auc: 0.9031
# Epoch 42/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8135 - loss: 0.3885 - pr_auc: 0.9053 - roc_auc: 0.9017 - val_accuracy: 0.8145 - val_loss: 0.3867 - val_pr_auc: 0.9063 - val_roc_auc: 0.9026
# Epoch 43/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8140 - loss: 0.3881 - pr_auc: 0.9055 - roc_auc: 0.9019 - val_accuracy: 0.8136 - val_loss: 0.3866 - val_pr_auc: 0.9064 - val_roc_auc: 0.9026
# Epoch 44/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8129 - loss: 0.3881 - pr_auc: 0.9055 - roc_auc: 0.9018 - val_accuracy: 0.8137 - val_loss: 0.3877 - val_pr_auc: 0.9058 - val_roc_auc: 0.9021
# Epoch 45/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8134 - loss: 0.3885 - pr_auc: 0.9053 - roc_auc: 0.9017 - val_accuracy: 0.8131 - val_loss: 0.3877 - val_pr_auc: 0.9059 - val_roc_auc: 0.9022
# Epoch 46/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8133 - loss: 0.3880 - pr_auc: 0.9056 - roc_auc: 0.9020 - val_accuracy: 0.8147 - val_loss: 0.3858 - val_pr_auc: 0.9067 - val_roc_auc: 0.9031
# Epoch 47/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8142 - loss: 0.3870 - pr_auc: 0.9061 - roc_auc: 0.9025 - val_accuracy: 0.8142 - val_loss: 0.3858 - val_pr_auc: 0.9067 - val_roc_auc: 0.9030
# Epoch 48/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8136 - loss: 0.3878 - pr_auc: 0.9057 - roc_auc: 0.9021 - val_accuracy: 0.8149 - val_loss: 0.3862 - val_pr_auc: 0.9066 - val_roc_auc: 0.9029
# Epoch 49/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8137 - loss: 0.3874 - pr_auc: 0.9059 - roc_auc: 0.9023 - val_accuracy: 0.8147 - val_loss: 0.3861 - val_pr_auc: 0.9066 - val_roc_auc: 0.9029
# Epoch 50/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8146 - loss: 0.3864 - pr_auc: 0.9064 - roc_auc: 0.9028 - val_accuracy: 0.8147 - val_loss: 0.3864 - val_pr_auc: 0.9064 - val_roc_auc: 0.9027
# Epoch 51/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8145 - loss: 0.3864 - pr_auc: 0.9064 - roc_auc: 0.9028 - val_accuracy: 0.8143 - val_loss: 0.3867 - val_pr_auc: 0.9063 - val_roc_auc: 0.9026
# Epoch 52/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8152 - loss: 0.3854 - pr_auc: 0.9070 - roc_auc: 0.9034 - val_accuracy: 0.8139 - val_loss: 0.3867 - val_pr_auc: 0.9063 - val_roc_auc: 0.9026
# Epoch 53/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8154 - loss: 0.3853 - pr_auc: 0.9071 - roc_auc: 0.9035 - val_accuracy: 0.8137 - val_loss: 0.3870 - val_pr_auc: 0.9061 - val_roc_auc: 0.9025
# Epoch 54/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8146 - loss: 0.3857 - pr_auc: 0.9068 - roc_auc: 0.9031 - val_accuracy: 0.8151 - val_loss: 0.3861 - val_pr_auc: 0.9065 - val_roc_auc: 0.9029
# Epoch 55/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8147 - loss: 0.3859 - pr_auc: 0.9067 - roc_auc: 0.9031 - val_accuracy: 0.8155 - val_loss: 0.3862 - val_pr_auc: 0.9064 - val_roc_auc: 0.9029
# Epoch 56/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8144 - loss: 0.3867 - pr_auc: 0.9063 - roc_auc: 0.9026 - val_accuracy: 0.8139 - val_loss: 0.3872 - val_pr_auc: 0.9061 - val_roc_auc: 0.9024
# Epoch 57/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8152 - loss: 0.3850 - pr_auc: 0.9072 - roc_auc: 0.9036 - val_accuracy: 0.8137 - val_loss: 0.3885 - val_pr_auc: 0.9053 - val_roc_auc: 0.9016
# Epoch 58/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8156 - loss: 0.3842 - pr_auc: 0.9076 - roc_auc: 0.9040 - val_accuracy: 0.8144 - val_loss: 0.3869 - val_pr_auc: 0.9063 - val_roc_auc: 0.9026
# Epoch 59/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8152 - loss: 0.3847 - pr_auc: 0.9073 - roc_auc: 0.9037 - val_accuracy: 0.8142 - val_loss: 0.3863 - val_pr_auc: 0.9066 - val_roc_auc: 0.9030
# Epoch 60/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8156 - loss: 0.3844 - pr_auc: 0.9075 - roc_auc: 0.9038 - val_accuracy: 0.8155 - val_loss: 0.3853 - val_pr_auc: 0.9070 - val_roc_auc: 0.9034
# Epoch 61/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8160 - loss: 0.3837 - pr_auc: 0.9079 - roc_auc: 0.9043 - val_accuracy: 0.8152 - val_loss: 0.3864 - val_pr_auc: 0.9064 - val_roc_auc: 0.9027
# [I 2025-08-14 08:09:52,010] Trial 98 finished with value: 0.9064942706832491 and parameters: {'learning_rate': 0.0010677243008576259, 'Drop_out_rate': 0.14784191250315185, 'n_layers_image': 1, 'n_neurons_image_hidden_ly0': 92, 'n_layers_bdo': 2, 'n_neurons_bdo_hidden_ly0': 28, 'n_neurons_bdo_hidden_ly1': 24, 'n_layers_ado': 1, 'n_neurons_ado_hidden_ly0': 16}. Best is trial 42 with value: 0.9066951503157082.
# Epoch 1/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6762 - loss: 0.5708 - pr_auc: 0.7485 - roc_auc: 0.7455 - val_accuracy: 0.7766 - val_loss: 0.4448 - val_pr_auc: 0.8732 - val_roc_auc: 0.8682
# Epoch 2/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7901 - loss: 0.4338 - pr_auc: 0.8783 - roc_auc: 0.8746 - val_accuracy: 0.7998 - val_loss: 0.4163 - val_pr_auc: 0.8901 - val_roc_auc: 0.8864
# Epoch 3/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7953 - loss: 0.4243 - pr_auc: 0.8843 - roc_auc: 0.8807 - val_accuracy: 0.8034 - val_loss: 0.4108 - val_pr_auc: 0.8928 - val_roc_auc: 0.8889
# Epoch 4/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7974 - loss: 0.4208 - pr_auc: 0.8865 - roc_auc: 0.8828 - val_accuracy: 0.8046 - val_loss: 0.4054 - val_pr_auc: 0.8960 - val_roc_auc: 0.8921
# Epoch 5/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8000 - loss: 0.4159 - pr_auc: 0.8896 - roc_auc: 0.8860 - val_accuracy: 0.8074 - val_loss: 0.4033 - val_pr_auc: 0.8980 - val_roc_auc: 0.8942
# Epoch 6/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8023 - loss: 0.4115 - pr_auc: 0.8922 - roc_auc: 0.8886 - val_accuracy: 0.8084 - val_loss: 0.3993 - val_pr_auc: 0.8997 - val_roc_auc: 0.8959
# Epoch 7/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8037 - loss: 0.4076 - pr_auc: 0.8946 - roc_auc: 0.8910 - val_accuracy: 0.8092 - val_loss: 0.3970 - val_pr_auc: 0.9008 - val_roc_auc: 0.8970
# Epoch 8/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8056 - loss: 0.4050 - pr_auc: 0.8962 - roc_auc: 0.8926 - val_accuracy: 0.8124 - val_loss: 0.3946 - val_pr_auc: 0.9022 - val_roc_auc: 0.8985
# Epoch 9/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8075 - loss: 0.4014 - pr_auc: 0.8983 - roc_auc: 0.8947 - val_accuracy: 0.8091 - val_loss: 0.3979 - val_pr_auc: 0.9003 - val_roc_auc: 0.8966
# Epoch 10/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8076 - loss: 0.3999 - pr_auc: 0.8991 - roc_auc: 0.8954 - val_accuracy: 0.8108 - val_loss: 0.3956 - val_pr_auc: 0.9018 - val_roc_auc: 0.8981
# Epoch 11/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8083 - loss: 0.3984 - pr_auc: 0.8999 - roc_auc: 0.8963 - val_accuracy: 0.8072 - val_loss: 0.4004 - val_pr_auc: 0.8989 - val_roc_auc: 0.8952
# Epoch 12/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8080 - loss: 0.3982 - pr_auc: 0.9001 - roc_auc: 0.8964 - val_accuracy: 0.8106 - val_loss: 0.3941 - val_pr_auc: 0.9027 - val_roc_auc: 0.8989
# Epoch 13/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8091 - loss: 0.3967 - pr_auc: 0.9009 - roc_auc: 0.8972 - val_accuracy: 0.8059 - val_loss: 0.4011 - val_pr_auc: 0.8986 - val_roc_auc: 0.8949
# Epoch 14/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8093 - loss: 0.3958 - pr_auc: 0.9014 - roc_auc: 0.8977 - val_accuracy: 0.8102 - val_loss: 0.3942 - val_pr_auc: 0.9025 - val_roc_auc: 0.8987
# Epoch 15/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8101 - loss: 0.3951 - pr_auc: 0.9018 - roc_auc: 0.8981 - val_accuracy: 0.8091 - val_loss: 0.3970 - val_pr_auc: 0.9009 - val_roc_auc: 0.8971
# Epoch 16/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8103 - loss: 0.3938 - pr_auc: 0.9026 - roc_auc: 0.8989 - val_accuracy: 0.8084 - val_loss: 0.3969 - val_pr_auc: 0.9009 - val_roc_auc: 0.8972
# Epoch 17/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8104 - loss: 0.3934 - pr_auc: 0.9027 - roc_auc: 0.8990 - val_accuracy: 0.8067 - val_loss: 0.4003 - val_pr_auc: 0.8991 - val_roc_auc: 0.8951
# Epoch 18/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8109 - loss: 0.3928 - pr_auc: 0.9030 - roc_auc: 0.8994 - val_accuracy: 0.8098 - val_loss: 0.3963 - val_pr_auc: 0.9016 - val_roc_auc: 0.8979
# Epoch 19/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8117 - loss: 0.3911 - pr_auc: 0.9039 - roc_auc: 0.9003 - val_accuracy: 0.8079 - val_loss: 0.4004 - val_pr_auc: 0.8992 - val_roc_auc: 0.8955
# Epoch 20/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8116 - loss: 0.3913 - pr_auc: 0.9039 - roc_auc: 0.9002 - val_accuracy: 0.8088 - val_loss: 0.3959 - val_pr_auc: 0.9014 - val_roc_auc: 0.8977
# Epoch 21/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8118 - loss: 0.3917 - pr_auc: 0.9037 - roc_auc: 0.9000 - val_accuracy: 0.8093 - val_loss: 0.3964 - val_pr_auc: 0.9012 - val_roc_auc: 0.8973
# Epoch 22/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8121 - loss: 0.3904 - pr_auc: 0.9043 - roc_auc: 0.9006 - val_accuracy: 0.8080 - val_loss: 0.3974 - val_pr_auc: 0.9008 - val_roc_auc: 0.8969
# Epoch 23/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8126 - loss: 0.3892 - pr_auc: 0.9050 - roc_auc: 0.9013 - val_accuracy: 0.8093 - val_loss: 0.3974 - val_pr_auc: 0.9013 - val_roc_auc: 0.8977
# Epoch 24/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8135 - loss: 0.3882 - pr_auc: 0.9055 - roc_auc: 0.9018 - val_accuracy: 0.8066 - val_loss: 0.4012 - val_pr_auc: 0.8988 - val_roc_auc: 0.8951
# Epoch 25/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8132 - loss: 0.3886 - pr_auc: 0.9053 - roc_auc: 0.9016 - val_accuracy: 0.8027 - val_loss: 0.4039 - val_pr_auc: 0.8977 - val_roc_auc: 0.8935
# Epoch 26/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8136 - loss: 0.3885 - pr_auc: 0.9053 - roc_auc: 0.9017 - val_accuracy: 0.8055 - val_loss: 0.4016 - val_pr_auc: 0.8986 - val_roc_auc: 0.8948
# Epoch 27/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8139 - loss: 0.3875 - pr_auc: 0.9059 - roc_auc: 0.9022 - val_accuracy: 0.8099 - val_loss: 0.3954 - val_pr_auc: 0.9024 - val_roc_auc: 0.8985
# Epoch 28/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8136 - loss: 0.3872 - pr_auc: 0.9061 - roc_auc: 0.9024 - val_accuracy: 0.8106 - val_loss: 0.3945 - val_pr_auc: 0.9033 - val_roc_auc: 0.8994
# [I 2025-08-14 08:12:15,513] Trial 99 finished with value: 0.9032945723237302 and parameters: {'learning_rate': 0.00271887367156479, 'Drop_out_rate': 0.21741918469825777, 'n_layers_image': 1, 'n_neurons_image_hidden_ly0': 92, 'n_layers_bdo': 2, 'n_neurons_bdo_hidden_ly0': 29, 'n_neurons_bdo_hidden_ly1': 24, 'n_layers_ado': 2, 'n_neurons_ado_hidden_ly0': 16, 'n_neurons_ado_hidden_ly1': 8}. Best is trial 42 with value: 0.9066951503157082.
# Best Hyperparms.: {'learning_rate': 0.00041099257236365734, 'Drop_out_rate': 0.15821664782074943, 'n_layers_image': 1, 'n_neurons_image_hidden_ly0': 94, 'n_layers_bdo': 2, 'n_neurons_bdo_hidden_ly0': 29, 'n_neurons_bdo_hidden_ly1': 24, 'n_layers_ado': 1, 'n_neurons_ado_hidden_ly0': 14}
# Best PR-AUC Value:  0.9066951503157082

# %%
optuna.visualization.matplotlib.plot_param_importances(study)
plt.legend(loc = 'lower right')
#plt.savefig('figs/Optimized Models/10x10/Hyperparameter Importance.png', format = 'png', bbox_inches = 'tight')
plt.show()
# Out:
# C:\Users\joanc\AppData\Local\Temp\ipykernel_30432\1149268645.py:1: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study)

# %% [markdown]
# ### Re-train the best Model Architecture with the weights initializer

# %%
best_model = create_OP_Model(best_trial, weights_hint = initial_pixel_weights)

history = best_model.fit(
    x = {'image_input': pixel_train_transf, 'energy_input': energy_train_transf, 'position_input': position_train_transf},
    y = {'nu_predict': labels_train},
    epochs = 200,
    batch_size = 1000,
    validation_data = ([pixel_val_transf, energy_val_transf, position_val_transf], labels_val),
    callbacks = [tf.keras.callbacks.EarlyStopping(patience=20, min_delta=1e-3, monitor="val_loss")],
    shuffle = True
)
# Out:
# Epoch 1/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6131 - loss: 0.6472 - pr_auc: 0.6507 - roc_auc: 0.6580 - val_accuracy: 0.7048 - val_loss: 0.5301 - val_pr_auc: 0.8031 - val_roc_auc: 0.7917
# Epoch 2/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7383 - loss: 0.5002 - pr_auc: 0.8309 - roc_auc: 0.8241 - val_accuracy: 0.7847 - val_loss: 0.4425 - val_pr_auc: 0.8719 - val_roc_auc: 0.8702
# Epoch 3/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7863 - loss: 0.4445 - pr_auc: 0.8702 - roc_auc: 0.8683 - val_accuracy: 0.7899 - val_loss: 0.4290 - val_pr_auc: 0.8829 - val_roc_auc: 0.8791
# Epoch 4/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7901 - loss: 0.4348 - pr_auc: 0.8775 - roc_auc: 0.8745 - val_accuracy: 0.7915 - val_loss: 0.4254 - val_pr_auc: 0.8854 - val_roc_auc: 0.8808
# Epoch 5/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7916 - loss: 0.4315 - pr_auc: 0.8800 - roc_auc: 0.8765 - val_accuracy: 0.7935 - val_loss: 0.4227 - val_pr_auc: 0.8867 - val_roc_auc: 0.8821
# Epoch 6/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7921 - loss: 0.4303 - pr_auc: 0.8808 - roc_auc: 0.8770 - val_accuracy: 0.7966 - val_loss: 0.4192 - val_pr_auc: 0.8884 - val_roc_auc: 0.8841
# Epoch 7/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7926 - loss: 0.4283 - pr_auc: 0.8820 - roc_auc: 0.8781 - val_accuracy: 0.7984 - val_loss: 0.4188 - val_pr_auc: 0.8885 - val_roc_auc: 0.8846
# Epoch 8/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7944 - loss: 0.4255 - pr_auc: 0.8836 - roc_auc: 0.8798 - val_accuracy: 0.7972 - val_loss: 0.4191 - val_pr_auc: 0.8879 - val_roc_auc: 0.8840
# Epoch 9/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7944 - loss: 0.4253 - pr_auc: 0.8837 - roc_auc: 0.8798 - val_accuracy: 0.7991 - val_loss: 0.4166 - val_pr_auc: 0.8897 - val_roc_auc: 0.8857
# Epoch 10/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7951 - loss: 0.4241 - pr_auc: 0.8844 - roc_auc: 0.8805 - val_accuracy: 0.8020 - val_loss: 0.4134 - val_pr_auc: 0.8915 - val_roc_auc: 0.8876
# Epoch 11/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7953 - loss: 0.4235 - pr_auc: 0.8847 - roc_auc: 0.8808 - val_accuracy: 0.7916 - val_loss: 0.4241 - val_pr_auc: 0.8852 - val_roc_auc: 0.8807
# Epoch 12/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7965 - loss: 0.4216 - pr_auc: 0.8859 - roc_auc: 0.8821 - val_accuracy: 0.8029 - val_loss: 0.4114 - val_pr_auc: 0.8927 - val_roc_auc: 0.8888
# Epoch 13/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7974 - loss: 0.4201 - pr_auc: 0.8868 - roc_auc: 0.8830 - val_accuracy: 0.8028 - val_loss: 0.4097 - val_pr_auc: 0.8936 - val_roc_auc: 0.8896
# Epoch 14/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7971 - loss: 0.4204 - pr_auc: 0.8867 - roc_auc: 0.8829 - val_accuracy: 0.8017 - val_loss: 0.4103 - val_pr_auc: 0.8930 - val_roc_auc: 0.8890
# Epoch 15/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7986 - loss: 0.4182 - pr_auc: 0.8881 - roc_auc: 0.8843 - val_accuracy: 0.8041 - val_loss: 0.4069 - val_pr_auc: 0.8952 - val_roc_auc: 0.8912
# Epoch 16/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7996 - loss: 0.4162 - pr_auc: 0.8893 - roc_auc: 0.8855 - val_accuracy: 0.8055 - val_loss: 0.4049 - val_pr_auc: 0.8961 - val_roc_auc: 0.8922
# Epoch 17/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7996 - loss: 0.4157 - pr_auc: 0.8896 - roc_auc: 0.8859 - val_accuracy: 0.8060 - val_loss: 0.4053 - val_pr_auc: 0.8959 - val_roc_auc: 0.8920
# Epoch 18/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8004 - loss: 0.4148 - pr_auc: 0.8901 - roc_auc: 0.8864 - val_accuracy: 0.8043 - val_loss: 0.4084 - val_pr_auc: 0.8947 - val_roc_auc: 0.8909
# Epoch 19/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8009 - loss: 0.4141 - pr_auc: 0.8906 - roc_auc: 0.8868 - val_accuracy: 0.8048 - val_loss: 0.4078 - val_pr_auc: 0.8946 - val_roc_auc: 0.8908
# Epoch 20/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8008 - loss: 0.4136 - pr_auc: 0.8909 - roc_auc: 0.8872 - val_accuracy: 0.8057 - val_loss: 0.4039 - val_pr_auc: 0.8969 - val_roc_auc: 0.8931
# Epoch 21/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8019 - loss: 0.4116 - pr_auc: 0.8921 - roc_auc: 0.8885 - val_accuracy: 0.8071 - val_loss: 0.4027 - val_pr_auc: 0.8973 - val_roc_auc: 0.8935
# Epoch 22/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8018 - loss: 0.4117 - pr_auc: 0.8920 - roc_auc: 0.8883 - val_accuracy: 0.8052 - val_loss: 0.4039 - val_pr_auc: 0.8968 - val_roc_auc: 0.8928
# Epoch 23/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8015 - loss: 0.4118 - pr_auc: 0.8919 - roc_auc: 0.8882 - val_accuracy: 0.8013 - val_loss: 0.4113 - val_pr_auc: 0.8926 - val_roc_auc: 0.8888
# Epoch 24/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8021 - loss: 0.4112 - pr_auc: 0.8923 - roc_auc: 0.8886 - val_accuracy: 0.8048 - val_loss: 0.4048 - val_pr_auc: 0.8962 - val_roc_auc: 0.8923
# Epoch 25/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8017 - loss: 0.4117 - pr_auc: 0.8921 - roc_auc: 0.8883 - val_accuracy: 0.8052 - val_loss: 0.4022 - val_pr_auc: 0.8978 - val_roc_auc: 0.8939
# Epoch 26/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8024 - loss: 0.4102 - pr_auc: 0.8929 - roc_auc: 0.8892 - val_accuracy: 0.8054 - val_loss: 0.4039 - val_pr_auc: 0.8970 - val_roc_auc: 0.8931
# Epoch 27/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8024 - loss: 0.4102 - pr_auc: 0.8929 - roc_auc: 0.8892 - val_accuracy: 0.8068 - val_loss: 0.4013 - val_pr_auc: 0.8983 - val_roc_auc: 0.8945
# Epoch 28/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8024 - loss: 0.4109 - pr_auc: 0.8925 - roc_auc: 0.8888 - val_accuracy: 0.8048 - val_loss: 0.4045 - val_pr_auc: 0.8970 - val_roc_auc: 0.8930
# Epoch 29/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8023 - loss: 0.4105 - pr_auc: 0.8928 - roc_auc: 0.8890 - val_accuracy: 0.8070 - val_loss: 0.4010 - val_pr_auc: 0.8985 - val_roc_auc: 0.8946
# Epoch 30/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8024 - loss: 0.4099 - pr_auc: 0.8931 - roc_auc: 0.8893 - val_accuracy: 0.8063 - val_loss: 0.4021 - val_pr_auc: 0.8977 - val_roc_auc: 0.8937
# Epoch 31/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8035 - loss: 0.4093 - pr_auc: 0.8934 - roc_auc: 0.8897 - val_accuracy: 0.8036 - val_loss: 0.4093 - val_pr_auc: 0.8936 - val_roc_auc: 0.8896
# Epoch 32/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8038 - loss: 0.4086 - pr_auc: 0.8939 - roc_auc: 0.8902 - val_accuracy: 0.8025 - val_loss: 0.4083 - val_pr_auc: 0.8945 - val_roc_auc: 0.8907
# Epoch 33/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8031 - loss: 0.4096 - pr_auc: 0.8933 - roc_auc: 0.8896 - val_accuracy: 0.8063 - val_loss: 0.4044 - val_pr_auc: 0.8965 - val_roc_auc: 0.8926
# Epoch 34/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8033 - loss: 0.4091 - pr_auc: 0.8936 - roc_auc: 0.8898 - val_accuracy: 0.8084 - val_loss: 0.4010 - val_pr_auc: 0.8982 - val_roc_auc: 0.8944
# Epoch 35/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8026 - loss: 0.4100 - pr_auc: 0.8931 - roc_auc: 0.8893 - val_accuracy: 0.8064 - val_loss: 0.4020 - val_pr_auc: 0.8979 - val_roc_auc: 0.8941
# Epoch 36/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8034 - loss: 0.4083 - pr_auc: 0.8941 - roc_auc: 0.8904 - val_accuracy: 0.8052 - val_loss: 0.4059 - val_pr_auc: 0.8956 - val_roc_auc: 0.8918
# Epoch 37/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8034 - loss: 0.4088 - pr_auc: 0.8938 - roc_auc: 0.8901 - val_accuracy: 0.8077 - val_loss: 0.3996 - val_pr_auc: 0.8992 - val_roc_auc: 0.8953
# Epoch 38/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8031 - loss: 0.4088 - pr_auc: 0.8937 - roc_auc: 0.8900 - val_accuracy: 0.8080 - val_loss: 0.3994 - val_pr_auc: 0.8992 - val_roc_auc: 0.8953
# Epoch 39/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8036 - loss: 0.4083 - pr_auc: 0.8940 - roc_auc: 0.8903 - val_accuracy: 0.8085 - val_loss: 0.3986 - val_pr_auc: 0.8997 - val_roc_auc: 0.8959
# Epoch 40/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8035 - loss: 0.4078 - pr_auc: 0.8944 - roc_auc: 0.8907 - val_accuracy: 0.8067 - val_loss: 0.4010 - val_pr_auc: 0.8984 - val_roc_auc: 0.8945
# Epoch 41/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8040 - loss: 0.4076 - pr_auc: 0.8945 - roc_auc: 0.8908 - val_accuracy: 0.8084 - val_loss: 0.3988 - val_pr_auc: 0.8996 - val_roc_auc: 0.8959
# Epoch 42/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8034 - loss: 0.4081 - pr_auc: 0.8941 - roc_auc: 0.8904 - val_accuracy: 0.8072 - val_loss: 0.4023 - val_pr_auc: 0.8978 - val_roc_auc: 0.8938
# Epoch 43/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8041 - loss: 0.4073 - pr_auc: 0.8947 - roc_auc: 0.8910 - val_accuracy: 0.8088 - val_loss: 0.3983 - val_pr_auc: 0.8999 - val_roc_auc: 0.8961
# Epoch 44/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8044 - loss: 0.4069 - pr_auc: 0.8949 - roc_auc: 0.8912 - val_accuracy: 0.8078 - val_loss: 0.3984 - val_pr_auc: 0.8999 - val_roc_auc: 0.8961
# Epoch 45/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8047 - loss: 0.4058 - pr_auc: 0.8955 - roc_auc: 0.8918 - val_accuracy: 0.8077 - val_loss: 0.4002 - val_pr_auc: 0.8991 - val_roc_auc: 0.8952
# Epoch 46/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8042 - loss: 0.4061 - pr_auc: 0.8954 - roc_auc: 0.8917 - val_accuracy: 0.8085 - val_loss: 0.3992 - val_pr_auc: 0.8998 - val_roc_auc: 0.8959
# Epoch 47/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8046 - loss: 0.4052 - pr_auc: 0.8959 - roc_auc: 0.8921 - val_accuracy: 0.8099 - val_loss: 0.3968 - val_pr_auc: 0.9007 - val_roc_auc: 0.8970
# Epoch 48/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8048 - loss: 0.4058 - pr_auc: 0.8956 - roc_auc: 0.8919 - val_accuracy: 0.8088 - val_loss: 0.3969 - val_pr_auc: 0.9007 - val_roc_auc: 0.8968
# Epoch 49/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8043 - loss: 0.4056 - pr_auc: 0.8957 - roc_auc: 0.8920 - val_accuracy: 0.8100 - val_loss: 0.3965 - val_pr_auc: 0.9009 - val_roc_auc: 0.8971
# Epoch 50/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8053 - loss: 0.4047 - pr_auc: 0.8962 - roc_auc: 0.8925 - val_accuracy: 0.8114 - val_loss: 0.3953 - val_pr_auc: 0.9016 - val_roc_auc: 0.8978
# Epoch 51/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8055 - loss: 0.4039 - pr_auc: 0.8967 - roc_auc: 0.8930 - val_accuracy: 0.8084 - val_loss: 0.3988 - val_pr_auc: 0.8998 - val_roc_auc: 0.8960
# Epoch 52/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8049 - loss: 0.4053 - pr_auc: 0.8959 - roc_auc: 0.8922 - val_accuracy: 0.8105 - val_loss: 0.3956 - val_pr_auc: 0.9015 - val_roc_auc: 0.8977
# Epoch 53/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8051 - loss: 0.4044 - pr_auc: 0.8964 - roc_auc: 0.8926 - val_accuracy: 0.8106 - val_loss: 0.3976 - val_pr_auc: 0.9011 - val_roc_auc: 0.8974
# Epoch 54/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8060 - loss: 0.4028 - pr_auc: 0.8973 - roc_auc: 0.8936 - val_accuracy: 0.8083 - val_loss: 0.3983 - val_pr_auc: 0.9000 - val_roc_auc: 0.8961
# Epoch 55/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8061 - loss: 0.4030 - pr_auc: 0.8972 - roc_auc: 0.8936 - val_accuracy: 0.8123 - val_loss: 0.3945 - val_pr_auc: 0.9026 - val_roc_auc: 0.8988
# Epoch 56/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8064 - loss: 0.4025 - pr_auc: 0.8975 - roc_auc: 0.8939 - val_accuracy: 0.8103 - val_loss: 0.3948 - val_pr_auc: 0.9019 - val_roc_auc: 0.8981
# Epoch 57/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8066 - loss: 0.4023 - pr_auc: 0.8976 - roc_auc: 0.8940 - val_accuracy: 0.8119 - val_loss: 0.3934 - val_pr_auc: 0.9027 - val_roc_auc: 0.8991
# Epoch 58/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8057 - loss: 0.4026 - pr_auc: 0.8975 - roc_auc: 0.8937 - val_accuracy: 0.8076 - val_loss: 0.4021 - val_pr_auc: 0.8980 - val_roc_auc: 0.8943
# Epoch 59/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8068 - loss: 0.4018 - pr_auc: 0.8979 - roc_auc: 0.8943 - val_accuracy: 0.8107 - val_loss: 0.3955 - val_pr_auc: 0.9018 - val_roc_auc: 0.8980
# Epoch 60/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8070 - loss: 0.4011 - pr_auc: 0.8983 - roc_auc: 0.8946 - val_accuracy: 0.8091 - val_loss: 0.3979 - val_pr_auc: 0.9001 - val_roc_auc: 0.8964
# Epoch 61/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8075 - loss: 0.4006 - pr_auc: 0.8986 - roc_auc: 0.8949 - val_accuracy: 0.8101 - val_loss: 0.3949 - val_pr_auc: 0.9018 - val_roc_auc: 0.8981
# Epoch 62/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8079 - loss: 0.3997 - pr_auc: 0.8991 - roc_auc: 0.8954 - val_accuracy: 0.8123 - val_loss: 0.3929 - val_pr_auc: 0.9030 - val_roc_auc: 0.8993
# Epoch 63/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8071 - loss: 0.4004 - pr_auc: 0.8987 - roc_auc: 0.8950 - val_accuracy: 0.8114 - val_loss: 0.3933 - val_pr_auc: 0.9027 - val_roc_auc: 0.8991
# Epoch 64/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8069 - loss: 0.4006 - pr_auc: 0.8985 - roc_auc: 0.8948 - val_accuracy: 0.8100 - val_loss: 0.3947 - val_pr_auc: 0.9022 - val_roc_auc: 0.8984
# Epoch 65/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8073 - loss: 0.4002 - pr_auc: 0.8989 - roc_auc: 0.8952 - val_accuracy: 0.8094 - val_loss: 0.3973 - val_pr_auc: 0.9005 - val_roc_auc: 0.8969
# Epoch 66/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8077 - loss: 0.3995 - pr_auc: 0.8993 - roc_auc: 0.8956 - val_accuracy: 0.8116 - val_loss: 0.3924 - val_pr_auc: 0.9032 - val_roc_auc: 0.8994
# Epoch 67/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8082 - loss: 0.3985 - pr_auc: 0.8998 - roc_auc: 0.8961 - val_accuracy: 0.8116 - val_loss: 0.3926 - val_pr_auc: 0.9032 - val_roc_auc: 0.8995
# Epoch 68/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8080 - loss: 0.3995 - pr_auc: 0.8993 - roc_auc: 0.8956 - val_accuracy: 0.8129 - val_loss: 0.3909 - val_pr_auc: 0.9040 - val_roc_auc: 0.9004
# Epoch 69/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8080 - loss: 0.3990 - pr_auc: 0.8995 - roc_auc: 0.8958 - val_accuracy: 0.8146 - val_loss: 0.3904 - val_pr_auc: 0.9043 - val_roc_auc: 0.9006
# Epoch 70/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8089 - loss: 0.3974 - pr_auc: 0.9004 - roc_auc: 0.8968 - val_accuracy: 0.8105 - val_loss: 0.3943 - val_pr_auc: 0.9024 - val_roc_auc: 0.8986
# Epoch 71/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8089 - loss: 0.3975 - pr_auc: 0.9003 - roc_auc: 0.8967 - val_accuracy: 0.8127 - val_loss: 0.3921 - val_pr_auc: 0.9038 - val_roc_auc: 0.9002
# Epoch 72/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8087 - loss: 0.3976 - pr_auc: 0.9003 - roc_auc: 0.8967 - val_accuracy: 0.8121 - val_loss: 0.3934 - val_pr_auc: 0.9027 - val_roc_auc: 0.8990
# Epoch 73/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8083 - loss: 0.3977 - pr_auc: 0.9003 - roc_auc: 0.8966 - val_accuracy: 0.8131 - val_loss: 0.3923 - val_pr_auc: 0.9032 - val_roc_auc: 0.8995
# Epoch 74/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8088 - loss: 0.3976 - pr_auc: 0.9003 - roc_auc: 0.8966 - val_accuracy: 0.8126 - val_loss: 0.3911 - val_pr_auc: 0.9040 - val_roc_auc: 0.9003
# Epoch 75/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8095 - loss: 0.3959 - pr_auc: 0.9013 - roc_auc: 0.8976 - val_accuracy: 0.8118 - val_loss: 0.3932 - val_pr_auc: 0.9027 - val_roc_auc: 0.8992
# Epoch 76/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8089 - loss: 0.3969 - pr_auc: 0.9007 - roc_auc: 0.8970 - val_accuracy: 0.8139 - val_loss: 0.3895 - val_pr_auc: 0.9048 - val_roc_auc: 0.9011
# Epoch 77/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8095 - loss: 0.3957 - pr_auc: 0.9014 - roc_auc: 0.8977 - val_accuracy: 0.8126 - val_loss: 0.3903 - val_pr_auc: 0.9043 - val_roc_auc: 0.9007
# Epoch 78/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8096 - loss: 0.3962 - pr_auc: 0.9011 - roc_auc: 0.8975 - val_accuracy: 0.8133 - val_loss: 0.3907 - val_pr_auc: 0.9044 - val_roc_auc: 0.9008
# Epoch 79/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8096 - loss: 0.3958 - pr_auc: 0.9013 - roc_auc: 0.8976 - val_accuracy: 0.8150 - val_loss: 0.3894 - val_pr_auc: 0.9051 - val_roc_auc: 0.9015
# Epoch 80/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8084 - loss: 0.3966 - pr_auc: 0.9009 - roc_auc: 0.8971 - val_accuracy: 0.8150 - val_loss: 0.3882 - val_pr_auc: 0.9055 - val_roc_auc: 0.9020
# Epoch 81/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8097 - loss: 0.3961 - pr_auc: 0.9012 - roc_auc: 0.8975 - val_accuracy: 0.8138 - val_loss: 0.3905 - val_pr_auc: 0.9043 - val_roc_auc: 0.9006
# Epoch 82/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8098 - loss: 0.3955 - pr_auc: 0.9015 - roc_auc: 0.8979 - val_accuracy: 0.8128 - val_loss: 0.3898 - val_pr_auc: 0.9046 - val_roc_auc: 0.9010
# Epoch 83/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8100 - loss: 0.3952 - pr_auc: 0.9016 - roc_auc: 0.8980 - val_accuracy: 0.8141 - val_loss: 0.3892 - val_pr_auc: 0.9049 - val_roc_auc: 0.9013
# Epoch 84/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8101 - loss: 0.3951 - pr_auc: 0.9017 - roc_auc: 0.8981 - val_accuracy: 0.8130 - val_loss: 0.3890 - val_pr_auc: 0.9049 - val_roc_auc: 0.9013
# Epoch 85/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8097 - loss: 0.3956 - pr_auc: 0.9015 - roc_auc: 0.8978 - val_accuracy: 0.8147 - val_loss: 0.3883 - val_pr_auc: 0.9054 - val_roc_auc: 0.9019
# Epoch 86/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8102 - loss: 0.3951 - pr_auc: 0.9017 - roc_auc: 0.8980 - val_accuracy: 0.8138 - val_loss: 0.3900 - val_pr_auc: 0.9045 - val_roc_auc: 0.9009
# Epoch 87/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8108 - loss: 0.3941 - pr_auc: 0.9023 - roc_auc: 0.8986 - val_accuracy: 0.8135 - val_loss: 0.3901 - val_pr_auc: 0.9048 - val_roc_auc: 0.9013
# Epoch 88/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8103 - loss: 0.3937 - pr_auc: 0.9025 - roc_auc: 0.8988 - val_accuracy: 0.8138 - val_loss: 0.3890 - val_pr_auc: 0.9050 - val_roc_auc: 0.9014
# Epoch 89/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8112 - loss: 0.3937 - pr_auc: 0.9025 - roc_auc: 0.8989 - val_accuracy: 0.8136 - val_loss: 0.3890 - val_pr_auc: 0.9050 - val_roc_auc: 0.9014
# Epoch 90/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8115 - loss: 0.3931 - pr_auc: 0.9028 - roc_auc: 0.8992 - val_accuracy: 0.8139 - val_loss: 0.3877 - val_pr_auc: 0.9057 - val_roc_auc: 0.9021
# Epoch 91/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8111 - loss: 0.3924 - pr_auc: 0.9032 - roc_auc: 0.8995 - val_accuracy: 0.8142 - val_loss: 0.3875 - val_pr_auc: 0.9059 - val_roc_auc: 0.9022
# Epoch 92/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8112 - loss: 0.3932 - pr_auc: 0.9028 - roc_auc: 0.8991 - val_accuracy: 0.8132 - val_loss: 0.3895 - val_pr_auc: 0.9049 - val_roc_auc: 0.9013
# Epoch 93/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8105 - loss: 0.3931 - pr_auc: 0.9028 - roc_auc: 0.8991 - val_accuracy: 0.8143 - val_loss: 0.3873 - val_pr_auc: 0.9060 - val_roc_auc: 0.9023
# Epoch 94/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8111 - loss: 0.3935 - pr_auc: 0.9026 - roc_auc: 0.8990 - val_accuracy: 0.8144 - val_loss: 0.3878 - val_pr_auc: 0.9057 - val_roc_auc: 0.9020
# Epoch 95/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8109 - loss: 0.3931 - pr_auc: 0.9028 - roc_auc: 0.8991 - val_accuracy: 0.8143 - val_loss: 0.3881 - val_pr_auc: 0.9055 - val_roc_auc: 0.9019
# Epoch 96/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8116 - loss: 0.3923 - pr_auc: 0.9033 - roc_auc: 0.8996 - val_accuracy: 0.8137 - val_loss: 0.3873 - val_pr_auc: 0.9059 - val_roc_auc: 0.9023
# Epoch 97/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8109 - loss: 0.3927 - pr_auc: 0.9031 - roc_auc: 0.8994 - val_accuracy: 0.8137 - val_loss: 0.3887 - val_pr_auc: 0.9052 - val_roc_auc: 0.9016
# Epoch 98/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8117 - loss: 0.3924 - pr_auc: 0.9032 - roc_auc: 0.8996 - val_accuracy: 0.8123 - val_loss: 0.3916 - val_pr_auc: 0.9038 - val_roc_auc: 0.9002
# Epoch 99/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8114 - loss: 0.3924 - pr_auc: 0.9032 - roc_auc: 0.8995 - val_accuracy: 0.8144 - val_loss: 0.3880 - val_pr_auc: 0.9056 - val_roc_auc: 0.9020
# Epoch 100/200
# 1031/1031 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8129 - loss: 0.3909 - pr_auc: 0.9040 - roc_auc: 0.9005 - val_accuracy: 0.8149 - val_loss: 0.3875 - val_pr_auc: 0.9058 - val_roc_auc: 0.9022

# %% [markdown]
# ## Save The Best Model and History

# %%
save_model = True # General Save for every model!
save_dir = 'C:/Users/joanc/jupyter notebooks/solar neutrino analysis/Machine Learning/TensorFlow Frame/Sequential Models/models save/10x10/optimized models/pipeline_std_minmax/'
model_name = f'Seq_MLM1_E_{energy_inf_cut}_{energy_cut_train}_MeV_R_{posr_cut}_mm_Delta_{time_res_inf_cut}_{time_res_sup_cut}_ns'
history_name = 'history_' + model_name

if save_model:
    #Save training History
    with open(save_dir + history_name + ".pkl", "wb") as f:
        pickle.dump(history, f)

    #Save the model
    best_model.save(save_dir + model_name + '.keras')

# %% [markdown]
# ## Load the Model

# %%
load = True

if load:
    #Load the dictionary history
    with open(save_dir + history_name + ".pkl", "rb") as f:
        history = pickle.load(f)

    #Load the Model
    best_model = tf.keras.models.load_model(save_dir + model_name + '.keras', custom_objects={"gelu": tf.keras.activations.gelu})
    best_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image_input (InputLayer)      │ (None, 100)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ imag_ly_0 (Dense)             │ (None, 94)                │           9,494 │ image_input[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ energy_input (InputLayer)     │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ position_input (InputLayer)   │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 96)                │               0 │ imag_ly_0[0][0],           │
# │                               │                           │                 │ energy_input[0][0],        │
# │                               │                           │                 │ position_input[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bdo_ly_0 (Dense)              │ (None, 29)                │           2,813 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bdo_ly_1 (Dense)              │ (None, 24)                │             720 │ bdo_ly_0[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 24)                │               0 │ bdo_ly_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ ado_ly_0 (Dense)              │ (None, 14)                │             350 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ nu_predict (Dense)            │ (None, 2)                 │              30 │ ado_ly_0[0][0]             │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 40,223 (157.12 KB)
#  Trainable params: 13,407 (52.37 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 26,816 (104.75 KB)

# %%
history

# %% [markdown]
# # Plots

# %%
save_fig = True #Save figures

# %% [markdown]
# ## Learning Curves

# %%
import matplotlib as mpl
# -------Save settings -------
save_dir = 'figs/Optimized Models/10x10/pipeline_std_minmax/'
fname = 'training_curves_'
pattern_train_save_name = f'E_{energy_inf_cut}_{energy_cut_train}_MeV_R_{posr_cut}_mm_Delta_({time_res_inf_cut}_{time_res_sup_cut})_ns'

# ------- Superior Title -------
main_title = 'Training Progress '
train_cut_title = rf'Dim ($\mathcal{{L}}(\Delta, \alpha) = (10,10)$), E$_\text{{train}}$: [{energy_inf_cut}, {energy_cut_train}] (MeV), R $\leq$ {posr_cut} (mm), $\Delta$: [{time_res_inf_cut}, {time_res_sup_cut}] (ns)'
full_title = main_title + '\n' + train_cut_title

plt.style.use('seaborn-v0_8-whitegrid')  # O prueba 'ggplot', 'seaborn-dark', etc.
font_style_title = {'family':'serif', 'weight': 'normal','color':'black','size':13}
font_style_axis= {'family':'serif', 'weight': 'normal','color':'black','size':12}

# Figura y subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# --- Plot 1: Loss & Accuracy ---
axes[0].plot(history.history['loss'], 'o:', color='#0528f2', label='Train Loss', linewidth=1.5, markersize=4)
axes[0].plot(history.history['accuracy'], 'x:', color='#27ad05', label='Train Accuracy', linewidth=1.5, markersize=4)
axes[0].plot(history.history['val_loss'], 's:', color='#f50505', label='Val. Loss', linewidth=1.5, markersize=4)
axes[0].plot(history.history['val_accuracy'], '*:', color='#fa9005', label='Val. Accuracy', linewidth=1.5, markersize=4)

axes[0].set_title('Training and Validation Loss / Accuracy', fontdict = font_style_title)
axes[0].set_xlabel('Epoch', fontdict = font_style_axis)
axes[0].set_ylabel('Value', fontdict = font_style_axis)
axes[0].legend(loc='center right', frameon=True, edgecolor='black', fancybox=False)
axes[0].grid(True, linestyle='--', alpha=0.5)

# axes[0].set_yscale('log')  # solo si realmente lo necesitas

# --- Plot 2: AUC ---
axes[1].plot(history.history['roc_auc'], 'o:', color='#f21d05', label='Train ROC AUC', linewidth=1.5, markersize=4)
axes[1].plot(history.history['val_roc_auc'], 'x:', color='#0d05f2', label='Val. ROC AUC', linewidth=1.5, markersize=4)
axes[1].plot(history.history['pr_auc'], 's:', color='#fa9005', label='Train PR AUC', linewidth=1.5, markersize=4)
axes[1].plot(history.history['val_pr_auc'], '*:', color='#27ad05', label='Val. PR AUC', linewidth=1.5, markersize=4)

axes[1].set_title('ROC AUC and PR AUC', fontdict = font_style_title)
axes[1].set_xlabel('Epoch', fontdict = font_style_axis)
axes[1].set_ylabel('AUC', fontdict = font_style_axis)
axes[1].set_ylim(0.7, 1)
axes[1].legend(loc='lower right', frameon=True, edgecolor='black', fancybox=False)
axes[1].grid(True, linestyle='--', alpha=0.5)

# axes[1].set_yscale('log')  # igual que arriba, solo si necesario

# Super título
fig.suptitle(full_title, backgroundcolor='#095f91', family = 'serif', color='white', fontsize=13, weight='normal', y=1.01)

fig.tight_layout()

# Save Plot
if save_figs:
    fig.savefig(save_dir + fname + pattern_train_save_name + '.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Observation and Analysis of Predictions

# %% [markdown]
# ## DNN Prediction

# %%
X_sig_pred = best_model.predict([pixel_test1_transf_sig, energy_test1_transf_sig, position_test1_transf_sig])
X_bkg_pred = best_model.predict([pixel_test1_transf_bkg, energy_test1_transf_bkg, position_test1_transf_bkg])
# Out:
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step

# %%
X_sig_pred
# Out:
# array([[9.9999839e-01, 1.6585589e-06],
#        [9.9979097e-01, 2.0654078e-04],
#        [9.7452593e-01, 2.5980543e-02],
#        ...,
#        [7.7938992e-01, 2.1906987e-01],
#        [9.9288464e-01, 7.0426255e-03],
#        [9.9979705e-01, 1.9845839e-04]], dtype=float32)

# %%
X_bkg_pred
# Out:
# array([[0.2963572 , 0.70592856],
#        [0.77614594, 0.23147728],
#        [0.6274794 , 0.37240776],
#        ...,
#        [0.6678591 , 0.3346975 ],
#        [0.71638274, 0.28899893],
#        [0.60459626, 0.3994366 ]], dtype=float32)

# %%
print('working with ' + str(len(X_sig_pred)) + ' of signal and ' + str(len(X_bkg_pred)) + ' of background as testing data')
# Out:
# working with 22347 of signal and 22346 of background as testing data

# %% [markdown]
# ## Representation of Predictions

# %% [markdown]
# ### Distribution of Probabilities

# %%
# ------- Save settings : -------
save_dir = 'figs/Optimized Models/10x10/pipeline_std_minmax/'
fname = 'Classifier_Model_Output_'
pattern_train_save_name = f'E_{energy_inf_cut}_{energy_cut_train}_MeV_R_{posr_cut}_mm_Delta_({time_res_inf_cut}_{time_res_sup_cut})_ns'

# ------- Superior Title -------
main_title = 'Classifier Model Output Distributions '
train_cut_title = rf'Dim ($\mathcal{{L}}(\Delta, \alpha) = (10,10)$), E$_\text{{train}}$: [{energy_inf_cut}, {energy_cut_train}] (MeV), R $\leq$ {posr_cut} (mm), $\Delta$: [{time_res_inf_cut}, {time_res_sup_cut}] (ns)'
full_title = main_title + '\n' + train_cut_title

sn.set_theme(style="ticks")  # o "ticks", "darkgrid", etc.
font_style_title = {'family':'serif', 'weight': 'normal','color':'black','size':16}
font_style_axis= {'family':'serif', 'weight': 'normal','color':'black','size':15}

bins = 65
fig, axes = plt.subplots(1, 2, figsize=(22, 8), sharey=True)

# Solar ν predictions
sn.histplot(X_sig_pred[:, 0], bins=bins, label='SAS', color='#bf1c0b',
             edgecolor='black', linewidth=0.3, alpha=0.8, ax=axes[0])
sn.histplot(X_sig_pred[:, 1], bins=bins, label='SAB', color='#0b14bf',
             edgecolor='black', linewidth=0.3, alpha=0.6, ax=axes[0])

# Background predictions
sn.histplot(X_bkg_pred[:, 1], bins=bins, label='BAB', color='#bf1c0b',
             edgecolor='black', linewidth=0.3, alpha=0.8, ax=axes[1])
sn.histplot(X_bkg_pred[:, 0], bins=bins, label='BAS', color='#0b14bf',
             edgecolor='black', linewidth=0.3, alpha=0.6, ax=axes[1])

# Titles and labels
axes[0].set_title('MC Solar $^8$B-$\\nu_e$ events Classification', fontdict = font_style_title)
axes[0].set_xlabel('Model Probability Predictions', fontdict = font_style_axis)
axes[0].set_ylabel('Counts (log scale)', fontdict = font_style_axis)
axes[0].legend(loc = 'best', frameon=True, edgecolor='black', fancybox=False, fontsize=14)
axes[0].set_yscale('log')

axes[1].set_title('MC $^{208}$Tl events Classification', fontdict = font_style_title)
axes[1].set_xlabel('Model Probability Predictions', fontdict = font_style_axis)
axes[1].set_ylabel('Counts (log scale)', fontdict = font_style_axis)
axes[1].legend(loc = 'upper center', frameon=True, edgecolor='black', fancybox=False, fontsize=14)
axes[1].set_yscale('log')

# General formatting
plt.suptitle(full_title, backgroundcolor='#095f91', family = 'serif', color='white', fontsize=17, weight='normal', y=1.02)

plt.tight_layout()
if save_figs:
    fig.savefig(save_dir + fname + pattern_train_save_name + '.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### ROC and PR Curves

# %%
X_pred = np.concatenate((X_sig_pred, X_bkg_pred))              #Predicted
X_exp = np.concatenate((labels_test1_sig, labels_test1_bkg))     #Expected

# ====================== ROC Calculation ======================
fpr_sig, tpr_sig, _ = roc_curve(X_exp[:,0], X_pred[:,0])
auc_sig = auc(fpr_sig, tpr_sig)

fpr_bkg, tpr_bkg, _ = roc_curve(X_exp[:,1], X_pred[:,1])
auc_bkg = auc(fpr_bkg, tpr_bkg)

fpr_all, tpr_all, _ = roc_curve(
    np.concatenate((X_exp[:,0], X_exp[:,1])),
    np.concatenate((X_pred[:,0], X_pred[:,1]))
)
auc_all = auc(fpr_all, tpr_all)

# ====================== PR Calculation ======================
prec_sig, rec_sig, _ = precision_recall_curve(X_exp[:,0], X_pred[:,0])
pr_auc_sig = auc(rec_sig, prec_sig)

prec_bkg, rec_bkg, _ = precision_recall_curve(X_exp[:,1], X_pred[:,1])
pr_auc_bkg = auc(rec_bkg, prec_bkg)

prec_all, rec_all, _ = precision_recall_curve(
    np.concatenate((X_exp[:,0], X_exp[:,1])),
    np.concatenate((X_pred[:,0], X_pred[:,1]))
)
pr_auc_all = auc(rec_all, prec_all)

# %%
# ------- Save settings : -------
save_dir = 'figs/Optimized Models/10x10/pipeline_std_minmax/'
fname = 'ROC_PR_'
pattern_train_save_name = f'E_{energy_inf_cut}_{energy_cut_train}_MeV_R_{posr_cut}_mm_Delta_({time_res_inf_cut}_{time_res_sup_cut})_ns'

# ------- Superior Title -------
main_title = 'Classifier Model Performance '
train_cut_title = rf'Dim ($\mathcal{{L}}(\Delta, \alpha) = (10,10)$), E$_\text{{train}}$: [{energy_inf_cut}, {energy_cut_train}] (MeV), R $\leq$ {posr_cut} (mm), $\Delta$: [{time_res_inf_cut}, {time_res_sup_cut}] (ns)'
full_title = main_title + '\n' + train_cut_title

sn.set_theme(style="whitegrid")
font_style_title = {'family':'serif', 'weight': 'normal','color':'black','size':14}
font_style_axis  = {'family':'serif', 'weight': 'normal','color':'black','size':13}

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# ---------- Subplot 1: ROC para sig, bkg y overall ----------
axes[0].plot([0, 1], [0, 1], 'k--', label='Random Guessing', linewidth=1)
axes[0].plot(fpr_sig, tpr_sig, color='#e74c3c', linewidth=2,
             label=f'Signal (AUC = {auc_sig:.4f})')
axes[0].plot(fpr_bkg, tpr_bkg, color='#3498db', linewidth=2,
             label=f'Background (AUC = {auc_bkg:.4f})')
axes[0].plot(fpr_all, tpr_all, color='#18a308', linewidth=2,
             label=f'Overall (AUC = {auc_all:.4f})')

axes[0].set_title('ROC Curves', fontdict=font_style_title)
axes[0].set_xlabel('False Positive Rate', fontdict=font_style_axis)
axes[0].set_ylabel('True Positive Rate', fontdict=font_style_axis)
axes[0].legend(loc='lower right', frameon=True, edgecolor='black', fancybox=False, fontsize=10)
axes[0].grid(True, linestyle='--', alpha=0.5)

# ---------- Subplot 2: Precision-Recall para sig, bkg y overall ----------
#axes[1].plot([0, 1], [1, 0], 'k--', label='Random Guessing', linewidth=1)
axes[1].plot(rec_sig, prec_sig, color='#e74c3c', linewidth=2,
             label=f'Signal (PR AUC = {pr_auc_sig:.4f})')
axes[1].plot(rec_bkg, prec_bkg, color='#3498db', linewidth=2,
             label=f'Background (PR AUC = {pr_auc_bkg:.4f})')
axes[1].plot(rec_all, prec_all, color='#18a308', linewidth=2,
             label=f'Overall (PR AUC = {pr_auc_all:.4f})')

axes[1].set_title('Precision-Recall Curves', fontdict=font_style_title)
axes[1].set_xlabel('Recall', fontdict=font_style_axis)
axes[1].set_ylabel('Precision', fontdict=font_style_axis)
axes[1].legend(loc='lower left', frameon=True, edgecolor='black', fancybox=False, fontsize=10)
axes[1].grid(True, linestyle='--', alpha=0.5)

# --------- Título general ---------
fig.suptitle(full_title, backgroundcolor='#095f91', family = 'serif', color='white', fontsize=15, weight='normal', y=1.02)

plt.tight_layout()
if save_figs:
    fig.savefig(save_dir + fname + pattern_train_save_name + '.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ###  Reconstrucción de espector de solar $ν_e$ y de Tálio
#
# Seran seleccionados unicamente energias de eventos de neutrinos solar con un predicción X_pred[:,0] > threshold para ver que tan bueno se reconstruye el espectro de neutrinos solares. Los mismo para eventos de Tálio. Asi, podra ser observado en que energias el modelo tiene mas dificultades en acertar predicciones

# %% [markdown]
# #### Recuperar Valores de Energia y Radio (Inverse Standard Scaler) y Normalización en Volumen

# %%
energy_sig_rc = scaler_energy_test.inverse_transform([energy_test1_transf_sig])[0]
energy_bkg_rc = scaler_energy_test.inverse_transform([energy_test1_transf_bkg])[0]

# Volume Normalization + Std Scaler: la formula es (R_ev^3)/(5000^3) y queremos recuperar R_ev
#Recover from Transformation Rule
position_sig_rc = scaler_position_test.inverse_transform([position_test1_transf_sig])[0]
position_bkg_rc = scaler_position_test.inverse_transform([position_test1_transf_bkg])[0]

#Recover the radius values from the Volume
radi_sig_rc = np.cbrt(position_sig_rc*vol)
radi_bkg_rc = np.cbrt(position_bkg_rc*vol)

# %% [markdown]
# ### Normalized Efficiency by N_Counts(true)
#
# Construir un plot de eficicencia normalizada por el numero total de eventos en un bin del plot "Separated Spectrums for Threshold (trh)".
# Procedimientos de construcción:
#
# 1) extraer valores de energia contenidos en cada bin de "Separated Spectrums for Threshold (trh)"
# 2) Contabilizar el nº de eventos que superan el treshold dentro del bin de energia, y dividir por el número de eventos contenido en el bin, esta será la eficiencia normalizado por N_events_true
# 3) Hacer plot de la eficiciencia normalizada en funcion del valor medio de las energias contenida en el bin (cuanto mas bins, mas puntos de eficiencia habra)

# %% [markdown]
# #### Graficos de Energia Reconstruida y de Eficiencia Normalizada para varios Threshold de Predicción del Modelo

# %% [markdown]
# ##### Extraer Información para los Gráficos

# %%
#Idea: A cada loop de thr, agregar a las listas arrays de energia reconstruida y de eficiciencia normalizada, asi cada indice de lista corresponde a un thr

bins_nu = 15             #-> Define how many intervals in energy. Equals to the number of point of norm_eff. PREDEFINED BINS = 20
bins_tl = 8              #-> BINS = 8

thr = [0.90, 0.80, 0.70, 0.60]  #-> Define the thresholds

prob_sas = X_sig_pred[:,0]      #probiblity of the event of neutrino being detected as neutrino
#prob_bab = X_bkg_pred[:,1]      #probiblity of the event of thallium being detected as thallium
prob_bas = X_bkg_pred[:,0]      #probiblity of the event of thallium being detected as neutrino

en_sig_test_count, en_sig_test_edge = np.histogram(energy_sig_rc, bins = bins_nu)   #Extract interval of binned data
en_bkg_test_count, en_bkg_test_edge = np.histogram(energy_bkg_rc, bins = bins_tl)   #Extract interval of binned data


N_edges_sig = len(en_sig_test_edge)
N_edges_bkg = len(en_bkg_test_edge)

#Information to extract--------------------------------------
nu_energy_in_sas = []
#nu_energy_out_sas = []

tl_energy_in_bas = []
#tl_energy_out_bab = []

#mean normalized eficiency values for signal as signal and bkg as sig
norm_eff_sig_in_sas = []
norm_eff_bkg_in_bas = []

norm_eff_bkg = []

#mean energy within each bin for signal and bkg data
mean_energy_sig = []  
mean_energy_bkg = []   

for thr_i in thr: 

    #Information to save in each loop of threshold --------------
    nu_energy_in_sas_thr = []
    #nu_energy_out_sas_thr = []
    
    tl_energy_in_bas_thr = []
    #tl_energy_out_bas_thr = []

    #normalized eficiency values for signal and bkg for each thr
    #Used to contruct the norm eff plot
    norm_eff_sig_in_sas_thr = np.array([])
    norm_eff_bkg_in_bas_thr = np.array([])

    #mean energy within each bin for signal and bkg data for each thr (aunque acaba siendo el mismo valor medio para cado thr y para los histogramas que preservan el número de bins).
    #Used to contruct the norm eff plot
    mean_energy_sig_thr = np.array([]) 
    mean_energy_bkg_thr = np.array([]) 

    #mean radial values within each bin for signal and bkg data for each thr
    #Used to contruct the norm eff plot
    mean_rad_sig_thr = np.array([]) 
    mean_rad_bkg_thr = np.array([]) 
    
    #----------------------------------------------

    #Extract info for Plot of energy > thr and energy < thr

    #Extract
    for i in np.where(prob_sas >= thr_i)[0]:
        nu_energy_in_sas_thr.append(energy_sig_rc[i])
        
    #for j in np.where(prob_sas < thr_i)[0]:
        #nu_energy_out_sas_thr.append(energy_sig_rc[j])
    
    for m in np.where(prob_bas >= thr_i)[0]:
        tl_energy_in_bas_thr.append(energy_bkg_rc[m])
    
    #for k in np.where(prob_bab < thr_i)[0]:
        #tl_energy_out_spectrum_thr.append(energy_bkg_rc[k])
        
    nu_energy_in_sas.append(np.array(nu_energy_in_sas_thr))
    #nu_energy_out_sas.append(np.array(nu_energy_out_sas_thr))
    tl_energy_in_bas.append(np.array(tl_energy_in_bas_thr))
    #tl_energy_out_bab.append(np.array(tl_energy_out_spectrum_thr))

    #Extract norm_eff and mean nu enery within each bin:
    #1) Extract for solar nu event predictions
    for i in range(N_edges_sig-1):
        #extract edges value of energy at each bin
        energy_edge_i = en_sig_test_edge[i]
        energy_edge_f = en_sig_test_edge[i+1]
    
        #find energy in energy_test_sig between edges values and the model prediction for SAS 
        energy_interval = np.extract((energy_sig_rc >= energy_edge_i) & (energy_sig_rc <= energy_edge_f), energy_sig_rc)
        prob_sas_interval = np.extract((energy_sig_rc >= energy_edge_i) & (energy_sig_rc <= energy_edge_f), prob_sas)
    
        #extract mean energy of binned interval
        mean_energy_interval = np.mean(energy_interval)
        
        mean_energy_sig_thr = np.append(mean_energy_sig_thr, mean_energy_interval)
        
        #Total Number of events we know are true
        N_true = len(prob_sas_interval)
    
        #find where prob. is higher than threshold and count
        condition_thr = prob_sas_interval >= thr_i
        energy_up_thr = np.extract(condition_thr, energy_interval)
        N_up_thr = len(energy_up_thr)
    
        #compute and extract normalized efficiency
        norm_eff_interval = N_up_thr / N_true
        norm_eff_sig_in_sas_thr = np.append(norm_eff_sig_in_sas_thr, norm_eff_interval)

    norm_eff_sig_in_sas.append(norm_eff_sig_in_sas_thr)
    mean_energy_sig.append(mean_energy_sig_thr)
        
    #2) Extract for Tl event predictions
    for i in range(N_edges_bkg-1):
        #extract edges value of energy at each bin
        energy_edge_i = en_bkg_test_edge[i]
        energy_edge_f = en_bkg_test_edge[i+1]
    
        #find energy in energy_test_bkg between edges values and the model prediction for BAS
        energy_interval = np.extract((energy_bkg_rc >= energy_edge_i) & (energy_bkg_rc <= energy_edge_f), energy_bkg_rc)
        prob_bas_interval = np.extract((energy_bkg_rc >= energy_edge_i) & (energy_bkg_rc <= energy_edge_f), prob_bas)
    
        #extract mean energy of binned interval
        mean_energy_interval = np.mean(energy_interval)
        
        mean_energy_bkg_thr = np.append(mean_energy_bkg_thr, mean_energy_interval)
        
        #Total Number of events we know are true
        N_true = len(prob_bas_interval)
    
        #find where prob. is higher than threshold and count
        condition_thr = prob_bas_interval >= thr_i
        energy_up_thr = np.extract(condition_thr, energy_interval)
        N_up_thr = len(energy_up_thr)
    
        #compute and extract normalized efficiency
        norm_eff_interval = N_up_thr / N_true
        norm_eff_bkg_in_bas_thr = np.append(norm_eff_bkg_in_bas_thr, norm_eff_interval)
    
    norm_eff_bkg_in_bas.append(norm_eff_bkg_in_bas_thr)
    mean_energy_bkg.append(mean_energy_bkg_thr)

#Transform lists to array where each arrow correspond to the values of (energy, norm_eff) for a certain thr
mean_energy_sig = np.array(mean_energy_sig)
norm_eff_sig_in_sas = np.array(norm_eff_sig_in_sas)

mean_energy_bkg = np.array(mean_energy_bkg)
norm_eff_bkg_in_bas = np.array(norm_eff_bkg_in_bas)

# %%
norm_eff_sig_in_sas
# Out:
# array([[9.14589104e-01, 1.08770211e-01, 1.08283703e-03, 0.00000000e+00,
#         5.74052813e-04, 4.20168067e-03, 5.80441640e-02, 6.49532710e-01,
#         9.90864371e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [9.69067405e-01, 2.86624204e-01, 6.49702220e-03, 5.56792873e-03,
#         5.74052813e-03, 1.92076831e-02, 2.27129338e-01, 8.55807744e-01,
#         9.98594519e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [9.87072946e-01, 5.00244978e-01, 3.57336221e-02, 1.22494432e-02,
#         1.49253731e-02, 6.36254502e-02, 4.03785489e-01, 9.33911883e-01,
#         9.99297259e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [9.93074792e-01, 6.83488486e-01, 1.06118029e-01, 3.95322940e-02,
#         4.82204363e-02, 1.68067227e-01, 5.86750789e-01, 9.67957276e-01,
#         9.99297259e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00]])

# %% [markdown]
# #### Construir los Gráficos

# %% [markdown]
# - Energia

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
sn.reset_orig

bas_on = False
alpha = 0

#main plot: Test Solar Energy
fig, axes = plt.subplots(1,2, figsize =(18, 6)) 
ax1_1 = axes[1].twinx()  #Right axis for the norm_eff plot due to differences between eff scales

sn.histplot(energy_sig_rc, ax = axes[0], bins = bins_nu, color = 'g' , label = r'$^8$B-$ν_e$ Spectrum', alpha = alpha, element = 'step')

#if bkg_on:
#Bkg test energy plot
#    sn.histplot(energy_bkg_rc, ax = axes[0], bins = bins_tl, color = 'black' , label = r'208-Tl Spectrum', alpha = alpha, element = 'step')

for i_dx, thr_i in enumerate(thr):  
    #Sig Spectral distribution
    sn.histplot(nu_energy_in_sas[i_dx], ax = axes[0], bins = bins_nu, color = red_variants[i_dx] , label = r'SAS (thr $\geq$'+str(thr_i)+')', 
                alpha = alpha, element = 'step')

    #Sig Efficiency normalized by N_true counts
    sn.histplot(x = mean_energy_sig[i_dx], ax = axes[1], bins=len(mean_energy_sig[i_dx]), color = red_variants[i_dx], 
                weights=norm_eff_sig_in_sas[i_dx], element = 'step', alpha = 0.0, label = r'$\epsilon_{SAS}$ (thr $\geq$ '+str(thr_i)+')')

    if bas_on:
        #bkg spectra
        sn.histplot(tl_energy_in_bas[i_dx], ax = axes[0], bins = bins_tl, color = blue_variants[i_dx] , label = r'BAS (thr $\geq$'+str(thr_i)+')', 
                    alpha = alpha, element = 'step')

        #bkg efficiency
        sn.histplot(x = mean_energy_bkg[i_dx], ax = ax1_1, bins=len(mean_energy_bkg[i_dx]), color = blue_variants[i_dx], 
                    weights=norm_eff_bkg_in_bas[i_dx], element = 'step', alpha = 0.0, label = r'$\epsilon_{BAS}$ (thr $\geq$ '+str(thr_i)+')')
        

axes[0].set_title(r'Spectral Distribution for each Threshold (thr) of Model Predictions', fontsize = 12)
axes[1].set_title(r'$\epsilon = \frac{N(>thr)}{N_{true}}$', fontsize = 12)
axes[0].legend(loc = 'lower right')
axes[1].legend(loc = 'lower right')
ax1_1.legend(loc = 'upper right')

axes[0].set_xlabel('Energy (MeV)')
axes[1].set_xlabel('Energy (MeV)')
axes[1].set_ylabel(r'$\epsilon_{SAS}$', fontsize = 14)
ax1_1.set_ylabel(r'$\epsilon_{BAS}$', fontsize = 14)

axes[1].tick_params(axis='y', labelcolor='r')
ax1_1.tick_params(axis='y', labelcolor='b')


#Agregar marcadores al eje x
#x_en_ticks = np.arange(2.5, 12, 1)   #(x_min, x_max, step)
#axes[0].x_en_ticks(x_ticks)
#axes[1].x_en_ticks(x_ticks)


#axes[0].set_xlim(2.5,12.8)
#axes[1].set_xlim(2.5,12)
#axes[1].set_ylim(np.min(norm_eff_sig_in_sas) - 0.05, 1.05)
#ax1_1.set_ylim(0.0, np.max(norm_eff_bkg_in_bas) + 0.01)

#axes[0].set_yscale('log')
axes[1].set_yscale('log')
plt.suptitle(f'Energy: [2.5,{energy_cut_train}] MeV - R < 5500 (mm)')

#if bas_on:
    #plt.savefig('figs/Optimized Models/10x10/Spectral_thr_and_Norm_eff_sig_bkg.png', format = 'png', bbox_inches = 'tight')
#else:
    #plt.savefig('figs/Optimized Models/10x10/Spectral_thr_and_Norm_eff.png', format = 'png', bbox_inches = 'tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Mean eficiency calculation in [2.5,10] for each thr in SAS

mean_eff = []  # List with the values of the mean efficicency for each threshold in energy within a range [2.5,10] MeV
eff_error = [] # list with the error value associated to hte mean_eff by the maximum desviation.
results = []   # List with explicit result of the thr and mean value of efficiency

for i_dx, thr_i in enumerate(thr):

    eff_sas_thr = norm_eff_sig_in_sas[i_dx]
    energy_sas_thr = mean_energy_sig[i_dx]
    
    #Extract the values of efficiency which verifies the energy cut
    condition = (energy_sas_thr <= 10)
    eff_sas_filter = np.extract(condition, eff_sas_thr)

    #Obtain mean value as the mean percentage of events in thr which are truly solar nu
    mean_eff_sas_thr = np.mean(eff_sas_filter, dtype = np.float16)
    mean_eff.append(mean_eff_sas_thr)

    #Compute the eff error by the maximum deviation of the samples from the mean value
    deviations = abs(eff_sas_thr -  mean_eff_sas_thr)
    max_deviation = np.max(deviations)
    eff_error.append(max_deviation)

    result_thr = 'For thr='+str(thr_i) + r', the eff for SAS is = ' + str(mean_eff_sas_thr) + ' with an error of ' + str(max_deviation)
    results.append(result_thr)

# %%
mean_eff
# Out:
# [0.599, 0.6406, 0.678, 0.7183]

# %%
eff_error
# Out:
# [0.5985577134683099,
#  0.6358453929899097,
#  0.6612284979919012,
#  0.6715277835402284]

# %%
results
# Out:
# ['For thr=0.9, the eff for SAS is = 0.599 with an error of 0.5985577134683099',
#  'For thr=0.8, the eff for SAS is = 0.6406 with an error of 0.6358453929899097',
#  'For thr=0.7, the eff for SAS is = 0.678 with an error of 0.6612284979919012',
#  'For thr=0.6, the eff for SAS is = 0.7183 with an error of 0.6715277835402284']

# %% [markdown]
# - Radius

# %%
#Idea: A cada loop de thr, agregar a las listas arrays de energia reconstruida y de eficiciencia normalizada, asi cada indice de lista corresponde a un thr

bins_rad = 20            #-> BINS = 20
thr = [0.95, 0.8, 0.70]  #-> Define the thresholds

prob_sas = X_sig_pred[:,0]
prob_bas = X_bkg_pred[:,0]

rad_sig_test_count, rad_sig_test_edge = np.histogram(radi_sig_rc, bins = bins_rad)
rad_bkg_test_count, rad_bkg_test_edge = np.histogram(radi_bkg_rc, bins = bins_rad)

N_edges= len(rad_sig_test_edge)

#mean normalized eficiency values for signal and bkg
norm_eff_sig_in_sas = []
norm_eff_bkg_in_bas = []  

#mean radial values within each bin for signal and bkg data
mean_rad_sig = []
mean_rad_bkg = []

for thr_i in thr: 

    #mean normalized eficiency values for signal and bkg for each thr
    norm_eff_sig_in_sas_thr = np.array([])
    norm_eff_bkg_in_bas_thr = np.array([])
    
    #mean radial values within each bin for signal and bkg data for each thr
    mean_rad_sig_thr = np.array([]) 
    mean_rad_bkg_thr = np.array([]) 
    
    #----------------------------------------------

    #Extract norm_eff and mean radius within each bin:
    #1) Extract for solar nu event predictions
    for i in range(N_edges-1):
        #extract edges value of energy at each bin
        radi_edge_i = rad_sig_test_edge[i]
        radi_edge_f = rad_sig_test_edge[i+1]
    
        #find energy in energy_test_sig and energy_test_bkg between edges values is and the model prediction
        radi_interval = np.extract((radi_sig_rc >= radi_edge_i) & (radi_sig_rc <= radi_edge_f), radi_sig_rc)
        prob_sas_interval = np.extract((radi_sig_rc >= radi_edge_i) & (radi_sig_rc <= radi_edge_f), prob_sas)
    
        #extract and save the mean radi of binned interval
        mean_rad_interval = np.mean(radi_interval)
        mean_rad_sig_thr = np.append(mean_rad_sig_thr, mean_rad_interval)
        
        #Total Number of events we know are true
        N_true = len(prob_sas_interval)
    
        #find where prob. is higher than threshold and count
        condition_thr = prob_sas_interval >= thr_i
        radi_up_thr = np.extract(condition_thr, radi_interval)
        N_up_thr = len(radi_up_thr)
    
        #compute and extract normalized efficiency
        norm_eff_interval = N_up_thr / N_true
        norm_eff_sig_in_sas_thr = np.append(norm_eff_sig_in_sas_thr, norm_eff_interval)

    norm_eff_sig_in_sas.append(norm_eff_sig_in_sas_thr)
    mean_rad_sig.append(mean_rad_sig_thr)
        
    #2) Extract for Tl event predictions
    for i in range(N_edges-1):
        #extract edges value of radius at each bin
        radi_edge_i = rad_bkg_test_edge[i]
        radi_edge_f = rad_bkg_test_edge[i+1]
    
        #find energy in energy_test_sig and energy_test_bkg between edges values is and the model prediction
        radi_interval = np.extract((radi_bkg_rc >= radi_edge_i) & (radi_bkg_rc <= radi_edge_f), radi_bkg_rc)
        prob_bas_interval = np.extract((radi_bkg_rc >= radi_edge_i) & (radi_bkg_rc <= radi_edge_f), prob_bas)
    
        #extract and save the mean radi of binned interval
        mean_rad_interval = np.mean(radi_interval)
        mean_rad_bkg_thr = np.append(mean_rad_bkg_thr, mean_rad_interval)
        
        #Total Number of events we know are true
        N_true = len(prob_bas_interval)
    
        #find where prob. is higher than threshold and count
        condition_thr = prob_bas_interval >= thr_i
        radi_up_thr = np.extract(condition_thr, radi_interval)
        N_up_thr = len(radi_up_thr)
    
        #compute and extract value of normalized efficiency for each bin
        norm_eff_interval = N_up_thr / N_true
        norm_eff_bkg_in_bas_thr = np.append(norm_eff_bkg_in_bas_thr, norm_eff_interval)
    
    norm_eff_bkg_in_bas.append(norm_eff_bkg_in_bas_thr)
    mean_rad_bkg.append(mean_rad_bkg_thr)
    

#Transform lists to array where each arrow correspond to the values of (energy, norm_eff) for a certain thr
mean_rad_sig = np.array(mean_rad_sig)
norm_eff_sig_in_sas = np.array(norm_eff_sig_in_sas)

mean_rad_bkg = np.array(mean_rad_bkg)
norm_eff_bkg_in_bas = np.array(norm_eff_bkg_in_bas)

# %%
bas_on = False

#main plot: Test Solar radius vs. Normalized efficiency
fig, axes_1 = plt.subplots(figsize =(8, 6))
axes_2 = axes_1.twinx()

for i_dx, thr_i in enumerate(thr):  
    #Sig Efficiency normalized by N_true counts
    sn.histplot(x = mean_rad_sig[i_dx], ax = axes_1,bins = len(mean_rad_sig[i_dx]), color = red_variants[i_dx], 
                weights = norm_eff_sig_in_sas[i_dx], element = 'step', alpha = 0.0, label = r'$\epsilon_{SAS}$(thr $\geq$ '+str(thr_i)+')')

    if bas_on:
        #bkg efficiency
        sn.histplot(x = mean_rad_bkg[i_dx], ax = axes_2, bins=len(mean_rad_bkg[i_dx]), color = blue_variants[i_dx], kde=False,
                    weights = norm_eff_bkg_in_bas[i_dx], element = 'step', alpha = 0.0, label = r'$\epsilon_{BAS}$(thr $\geq$ '+str(thr_i)+')')
        

plt.suptitle('Energy: [2.5,12] MeV - R < 5500 (mm)', fontsize = 10)
axes_1.set_title(r'$\epsilon = \frac{N(>thr)}{N_{true}}$', fontsize = 12)
axes_1.legend(loc = 'lower center')
axes_2.legend(loc = 'center right')

axes_1.tick_params(axis='y', labelcolor='r')
axes_2.tick_params(axis='y', labelcolor='b')


axes_1.set_xlabel('Radius (mm)')
axes_1.set_ylabel(r'$\epsilon_{SAS}$', fontsize = 14)
axes_2.set_ylabel(r'$\epsilon_{BAS}$', fontsize = 14)

#axes_1.set_xlim(0, 5500.0)
#axes_2.set_ylim(0, np.max(norm_eff_bkg_in_bas) + 0.15)
#axes_1.set_yscale('log')

#if bas_on:
#    plt.savefig('figs/Optimized Models/10x10/Radial_sig_bkg_thr_and_Norm_eff.png', format = 'png', bbox_inches = 'tight')
#else:
#    plt.savefig('figs/Optimized Models/10x10/Radial_thr_and_Norm_eff.png', format = 'png', bbox_inches = 'tight')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
