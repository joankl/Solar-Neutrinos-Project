# %% [markdown]
# # Notebook dedicated to construct the train dataset of solar Nue and 208Tl events

# %% [markdown]
# Convention to define the size of train and test data set: The last two files in the list of directories of .root files are for test

# %% [markdown]
# import uproot
# import numpy as np
# import pandas as pd
# import random
#
# import glob
# import re
# import os
#
# import seaborn as sn
# import matplotlib
# import matplotlib.pyplot as plt
# from matplotlib import cm

# %% [markdown]
# # Useful Functions

# %%
def magnitude(vector): 
    #Function to Compute the radial position of events
    x = vector[:,0]
    y = vector[:,1]
    z = vector[:,2]

    r = np.sqrt(x**2 + y**2 + z**2)
    r = r.astype(np.float32)
    return r

# %% [raw]
# import numpy as np
# import random
#
# def get_rotation_matrix(theta_x, theta_y, theta_z):
#     """
#     Generates the 3D Matriz Rotations Rx, Ry, Rz given an angle of rotation in deegre
#     """
#     Rx = np.array([
#         [1, 0, 0],
#         [0, np.cos(theta_x), -np.sin(theta_x)],
#         [0, np.sin(theta_x),  np.cos(theta_x)]
#     ])
#
#     Ry = np.array([
#         [ np.cos(theta_y), 0, np.sin(theta_y)],
#         [0, 1, 0],
#         [-np.sin(theta_y), 0, np.cos(theta_y)]
#     ])
#
#     Rz = np.array([
#         [np.cos(theta_z), -np.sin(theta_z), 0],
#         [np.sin(theta_z),  np.cos(theta_z), 0],
#         [0, 0, 1]
#     ])
#
#     return Rx, Ry, Rz
#
# def random_angle(deg_min=20, deg_max=160):
#
#     """
#     Returns and random angle between ±[deg_min, deg_max] degrees and then transformed to radian
#     """
#     angle_deg = np.random.uniform(deg_min, deg_max)
#     sign = np.random.choice([-1, 1])
#     return np.radians(sign * angle_deg)
#
# def apply_random_rotation_per_vector(vectors, seed=None, verbose=False):
#
#     """
#     Apply a aleatory composition of rotations (Rx, Ry and Rz) for every vector in the subset
#
#     Parameters:
#     - vectors: array with shape (N, 3)
#     - seed: int o None, to reproduce the random rotations
#
#     Returns:
#     - Rotated array with shape (N, 3)
#     """
#
#     if seed is not None:
#         np.random.seed(seed)
#         random.seed(seed)
#
#     vectors = np.asarray(vectors)
#
#     if vectors.ndim != 2 or vectors.shape[1] != 3:
#         raise ValueError(f"Esperaba array de forma (N, 3), obtuve: {vectors.shape}")
#
#     rotated_vectors = []
#
#     for idx, v in enumerate(vectors):
#         theta_x = random_angle()
#         theta_y = random_angle()
#         theta_z = random_angle()
#
#         Rx, Ry, Rz = get_rotation_matrix(theta_x, theta_y, theta_z)
#         order = random.sample(['Rx', 'Ry', 'Rz'], k=3)
#         rotation_dict = {'Rx': Rx, 'Ry': Ry, 'Rz': Rz}
#
#         R = rotation_dict[order[0]] @ rotation_dict[order[1]] @ rotation_dict[order[2]]
#         v_rot = R @ v
#         rotated_vectors.append(v_rot)
#
#         if verbose:
#             print(f"Vector {idx}: orden = {order}, ángulos (°): X={np.degrees(theta_x):.1f}, "
#                   f"Y={np.degrees(theta_y):.1f}, Z={np.degrees(theta_z):.1f}")
#
#     return np.array(rotated_vectors)

# %%
def random_unit_vector(seed=None):
    # Create a random generator with optional seed
    rng = np.random.default_rng(seed)
    # Generate 3 components from a normal distribution
    vec = rng.normal(size=3)
    # Normalize to unit length
    vec /= np.linalg.norm(vec)
    return vec

# %%
random_unit_vector()
# Out:
# array([ 0.75467275, -0.65374223, -0.05558906])

# %% [markdown]
# # Read Files: Get the file list with the full directories of .root files

# %%
main_dir = 'E:/Data/solars/mc/'
solarNue_fdir = 'solar_Nue/High Stat/solar_Nue*.root'
tl_208_fdir = '208tl/High Stat/tl208*.root'

solar_Nue_flist = glob.glob(main_dir + solarNue_fdir )[:-2] #Selected the elements in list of dir to be used for training
tl_208_flist = glob.glob(main_dir + tl_208_fdir)[:-2] #Selected the elements in list of dir to be used for training

# %%
solar_Nue_flist
# Out:
# ['E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_0.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_1.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_10.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_11.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_12.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_13.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_14.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_15.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_16.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_17.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_18.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_19.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_2.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_20.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_21.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_22.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_23.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_24.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_25.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_26.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_27.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_28.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_29.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_3.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_30.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_31.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_32.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_34.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_35.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_38.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_4.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_41.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_42.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_43.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_44.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_48.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_5.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_6.root',
#  'E:/Data/solars/mc/solar_Nue/High Stat\\solar_Nue_mc_analysis_7.root']

# %%
tl_208_flist
# Out:
# ['E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_0.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_1.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_10.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_11.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_12.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_13.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_14.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_15.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_16.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_17.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_18.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_19.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_2.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_20.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_21.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_3.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_4.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_5.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_6.root',
#  'E:/Data/solars/mc/208tl/High Stat\\tl208_mc_analysis_7.root']

# %% [markdown]
# # Analysis of .root files: Extract Observables of Interest

# %%
# ============ Data Cuts Settings ============
energy_inf_cut = 2.5
energy_sup_cut = 12

posr_cut = 5500

time_res_inf_cut = -1
time_res_sup_cut = 5

nhits_cut = 20 #Nhits cut to be applied after the time residual cuts

# Output files directory
out_file_dir = f'E:/Data/solars/mc/ML Data/Train/np_arrays/E_{energy_inf_cut}_{energy_sup_cut}_MeV_R_{posr_cut}_mm_Delta_{time_res_inf_cut}_{time_res_sup_cut}_ns/'
os.makedirs(out_file_dir, exist_ok=True)

# %% [markdown]
# ## Solars Analysis

# %%
data_type_fname = 'solarNue'

# --------------------------- Files Processing ---------------------------

for fi_dx, input_file_dir in enumerate(solar_Nue_flist):
    print(f'In file {input_file_dir}')
    
    #Load the Data:
    load_data = uproot.open(input_file_dir)
    
    #select the tree of event data and PMT info
    TTree_data_name = load_data.keys()[0]
    TTree_pmt_info_name = load_data.keys()[-1]
    
    event_data = load_data[TTree_data_name]
    pmt_data = load_data[TTree_pmt_info_name]
    
    #event info to be used:
    var_event_list = ['evtid', 'energy', 'position', 'mc_momentum',
                      'hit_pmtid', 'hit_residual' ]  #list the name of the varibles to be extracted and used for the solarnu analysis.
    
    #pmt info to be used
    var_pmt_list = ['pmt_id', 'pmt_pos_xyz', 'pmt_type']
    
    #Observables to save
    var_name_save_list = ['evtid', 'energy', 'posr', 'hit_residual']
    multi_cos_alpha = [] #create the empty list of the cos_alpha for the multiple PMTs record
    n_init_evs = []  # Initial Nº of Solar Nue MC events
    n_final_evs = [] # Initial Nº of Solar Nue MC events
    
    # Extract the variables with the name of the var_event_list in numpy.array from the .root file
    observables = {}
    
    # Load variables form the Event Info TTree Branch
    for var_name_i in var_event_list:  
        observables[var_name_i] = np.array(event_data[var_name_i])

    # ============= Count the initial Nº of events =============
    evtid = observables['evtid']
    evIDi_unique = []  #Empty list to be filled with the unique (non-redundant) values of the initial evIDs. len(evIDi_unique) = Nº of events

    N_data = len(evtid)
    indices_to_delete = [] #Indiced to remove from the observable arrays due to nhits cut

    data_break_i = [0]  #array whose elements are the index from where an event start and end.
    #Loop to extract the indices where evtid breaks
    for i_dx in range(N_data - 1):
        if evtid[i_dx] != evtid[i_dx+1]:
            data_break_i.append(i_dx + 1)
            
    data_break_i.append(N_data - 1)

    N_terms = len(data_break_i)
    
    for i_dx in range(N_terms - 2):
        init_i = data_break_i[i_dx]
        final_i = data_break_i[i_dx + 1]
        evIDi_unique.append(evtid[init_i: final_i][0])

    N_evs = len(evIDi_unique)
    print(f'Nº of initial events: {N_evs}')
    n_init_evs.append(N_evs)
    # ===========================================================
    
    # posr Computation
    observables['posr'] = magnitude(observables['position'])
    
    # Load the PMT info TTree Branch
    try:
        #Try to extract the info from the PMT Branch
        for var_name_i in var_pmt_list:
            observables[var_name_i] = np.array(pmt_data[var_name_i])
            
    except uproot.KeyInFileError as e:
        #if the Branch doesnt exist, then use the PMT info from other file that we know contais the PMT info Branch
        load_data = uproot.open('E:/Data/solars/mc/solar_Nue/High Stat/solar_Nue_mc_analysis_0.root')
        pmt_data = load_data['pmt;1']
        for var_name_i in var_pmt_list:
            observables[var_name_i] = np.array(pmt_data[var_name_i])
    
    # Filtering of valid PMT id through PMT type
    pmt_type_condition = (observables['pmt_type'] == 1)
    pmt_id_valid = observables['pmt_id'][pmt_type_condition]
    
    # general cut conditions
    hit_pmt_id_condition = np.in1d(observables['hit_pmtid'], pmt_id_valid)
    energy_condition = (observables['energy'] >= energy_inf_cut) & (observables['energy'] <= energy_sup_cut)
    time_res_condition = (observables['hit_residual'] >= time_res_inf_cut) & (observables['hit_residual'] <= time_res_sup_cut)
    posr_condition = (observables['posr'] <= posr_cut)
    
    general_condition = hit_pmt_id_condition & energy_condition & time_res_condition & posr_condition
    
    # Apply the general cut conditions to observables
    for var_name_i in var_event_list:
        observables[var_name_i] = observables[var_name_i][general_condition]
    observables['posr'] = observables['posr'][general_condition]

    #print(f'selected energies form {input_file_dir}: {observables['energy']} with shape {observables['energy'].shape}')

    # ======== Remove redundante values through evID. Nhits Cut and counts of final events ======
    print('performing nhits cuts after general selections')
    evtid = observables['evtid']
    evIDf_unique = []  #Empty list to be filled with the unique (non-redundant) values of the final evIDs. len(evIDf_unique) = Nº of final events
    N_data = len(evtid)
    indices_to_delete = [] #Indiced to remove from the observable arrays due to nhits cut

    data_break_i = [0]  #array whose elements are the index from where an event start and end.
    #Loop to extract the indices where evtid breaks
    for i_dx in range(N_data - 1):
        if evtid[i_dx] != evtid[i_dx+1]:
            data_break_i.append(i_dx + 1)
            
    data_break_i.append(N_data - 1)

    N_terms = len(data_break_i)

    for i_dx in range(N_terms - 2):
        init_i = data_break_i[i_dx]
        final_i = data_break_i[i_dx + 1]

        #Nhits cut: Remove the indices of observables that verify the nhits_cut
        #nhits_ev = final_i - init_i
        #if nhits_ev < nhits_cut:
        #    indices_to_delete.extend(range(init_i, final_i + 1))
        #    continue
            
        #else:
        #    evIDf_unique.append(evtid[init_i: final_i][0]) #Count the Number of final events
        evIDf_unique.append(evtid[init_i: final_i][0]) #Count the Number of final events
            
    N_evs = len(evIDf_unique)
    print(f'Nº of final events: {N_evs}')
    n_final_evs.append(N_evs)
     
    #indices_to_delete = np.array(indices_to_delete) due to nhits cut
    #for var_name_i in var_event_list + ['posr']:
        #observables[var_name_i] = np.delete(observables[var_name_i], indices_to_delete)

    # ====================================================================

    #Add to dictionary of observables the keys init evs and final evs
    observables['n_init_evs'] = n_init_evs
    observables['n_final_evs'] = n_final_evs
    
    # Save desired variables
    full_observable_save_list = var_name_save_list + ['n_init_evs', 'n_final_evs']
    
    print(f'saving observables {full_observable_save_list}')
    
    for var_name_i in  full_observable_save_list:
        np.save(out_file_dir + data_type_fname + '_' + var_name_i + f'_{fi_dx}.npy', observables[var_name_i])
        
    #save the solar direction of each file to be used for the 208Tl events
    #print('saving Sun direction')
    #np.save(out_file_dir + 'sun_dir' + f'_{fi_dx}.npy', observables['mc_momentum'])

    #cos_alpha computation
    #The cos_alpha computation must be done by parts using a split in the data.
    
    N_samples = len(observables['hit_residual'])

    print('Computing cos_alpha')
    
    for sample_idx in range(N_samples):
        
        sun_dir = observables['mc_momentum'][sample_idx]
        pmt_hit_id = observables['hit_pmtid'][sample_idx]
        pmt_hit_xyz = observables['pmt_pos_xyz'][pmt_hit_id]

        norm1 = np.linalg.norm(sun_dir)
        norm2 = np.linalg.norm(pmt_hit_xyz)
        
        sun_dir = sun_dir / norm1
        sun_dir = sun_dir.astype(np.float32)
        
        pmt_hit_xyz = pmt_hit_xyz / norm2
        pmt_hit_xyz = pmt_hit_xyz.astype(np.float32)
    
        dot_prod = np.dot(sun_dir, pmt_hit_xyz)
        cos_alpha = dot_prod
    
        multi_cos_alpha.append(cos_alpha)

    multi_cos_alpha = np.array(multi_cos_alpha)
    print('saving cos_alpha')
    # save the cos(alpha)
    np.save(out_file_dir + data_type_fname + '_cos_alpha' + f'_{fi_dx}.npy', multi_cos_alpha)

print('Analysis Done!')
# Out:
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_0.root
# Nº of initial events: 77653
# performing nhits cuts after general selections
# Nº of final events: 27219
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_1.root
# Nº of initial events: 77830
# performing nhits cuts after general selections
# Nº of final events: 27227
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_10.root
# Nº of initial events: 76822
# performing nhits cuts after general selections
# Nº of final events: 27050
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_11.root
# Nº of initial events: 77275
# performing nhits cuts after general selections
# Nº of final events: 27175
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_12.root
# Nº of initial events: 77468
# performing nhits cuts after general selections
# Nº of final events: 27345
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_13.root
# Nº of initial events: 77129
# performing nhits cuts after general selections
# Nº of final events: 27321
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_14.root
# Nº of initial events: 77222
# performing nhits cuts after general selections
# Nº of final events: 27099
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_15.root
# Nº of initial events: 40589
# performing nhits cuts after general selections
# Nº of final events: 14277
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_16.root
# Nº of initial events: 77272
# performing nhits cuts after general selections
# Nº of final events: 27211
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_17.root
# Nº of initial events: 76898
# performing nhits cuts after general selections
# Nº of final events: 27125
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_18.root
# Nº of initial events: 5739
# performing nhits cuts after general selections
# Nº of final events: 2043
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_19.root
# Nº of initial events: 74698
# performing nhits cuts after general selections
# Nº of final events: 26445
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_2.root
# Nº of initial events: 78086
# performing nhits cuts after general selections
# Nº of final events: 27357
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_20.root
# Nº of initial events: 77028
# performing nhits cuts after general selections
# Nº of final events: 27105
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_21.root
# Nº of initial events: 77252
# performing nhits cuts after general selections
# Nº of final events: 27043
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_22.root
# Nº of initial events: 77328
# performing nhits cuts after general selections
# Nº of final events: 27305
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_23.root
# Nº of initial events: 76416
# performing nhits cuts after general selections
# Nº of final events: 26934
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_24.root
# Nº of initial events: 76688
# performing nhits cuts after general selections
# Nº of final events: 27297
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_25.root
# Nº of initial events: 75779
# performing nhits cuts after general selections
# Nº of final events: 26801
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_26.root
# Nº of initial events: 50372
# performing nhits cuts after general selections
# Nº of final events: 17774
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_27.root
# Nº of initial events: 77268
# performing nhits cuts after general selections
# Nº of final events: 27592
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_28.root
# Nº of initial events: 75137
# performing nhits cuts after general selections
# Nº of final events: 26603
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_29.root
# Nº of initial events: 76292
# performing nhits cuts after general selections
# Nº of final events: 26746
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_3.root
# Nº of initial events: 76223
# performing nhits cuts after general selections
# Nº of final events: 26717
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_30.root
# Nº of initial events: 77440
# performing nhits cuts after general selections
# Nº of final events: 27490
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_31.root
# Nº of initial events: 74177
# performing nhits cuts after general selections
# Nº of final events: 26227
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_32.root
# Nº of initial events: 76962
# performing nhits cuts after general selections
# Nº of final events: 27276
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_34.root
# Nº of initial events: 76246
# performing nhits cuts after general selections
# Nº of final events: 27060
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_35.root
# Nº of initial events: 77010
# performing nhits cuts after general selections
# Nº of final events: 27265
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_38.root
# Nº of initial events: 75536
# performing nhits cuts after general selections
# Nº of final events: 26891
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_4.root
# Nº of initial events: 17152
# performing nhits cuts after general selections
# Nº of final events: 6043
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_41.root
# Nº of initial events: 75713
# performing nhits cuts after general selections
# Nº of final events: 27075
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_42.root
# Nº of initial events: 76109
# performing nhits cuts after general selections
# Nº of final events: 27160
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_43.root
# Nº of initial events: 74605
# performing nhits cuts after general selections
# Nº of final events: 26848
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_44.root
# Nº of initial events: 75306
# performing nhits cuts after general selections
# Nº of final events: 26917
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_48.root
# Nº of initial events: 75542
# performing nhits cuts after general selections
# Nº of final events: 27053
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_5.root
# Nº of initial events: 77573
# performing nhits cuts after general selections
# Nº of final events: 27227
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_6.root
# Nº of initial events: 77612
# performing nhits cuts after general selections
# Nº of final events: 27312
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/solar_Nue/High Stat\solar_Nue_mc_analysis_7.root
# Nº of initial events: 77084
# performing nhits cuts after general selections
# Nº of final events: 27066
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# Analysis Done!

# %% [markdown]
# ## 208Tl Analysis

# %%
data_type_fname = '208Tl'

# -------------------------------------------------------

for fi_dx, input_file_dir in enumerate(tl_208_flist):
    print(f'In file {input_file_dir}')
    
    #Load the Data:
    load_data = uproot.open(input_file_dir)  #ROOT File
    #sun_dir = np.load(out_file_dir + f'sun_dir_{fi_dx}.npy') #Solar direction from MC Solar Nue Data to replace 208Tl event
    #solar_evID = np.load(out_file_dir + f'solarNue_evtid_{fi_dx}.npy') #Solar evID to cut on 208Tl data due to direction replacement
    
    #select the tree of event data and PMT info
    TTree_data_name = load_data.keys()[0]
    TTree_pmt_info_name = load_data.keys()[-1]
    
    event_data = load_data[TTree_data_name]
    pmt_data = load_data[TTree_pmt_info_name]
    
    #event info to be used:
    var_event_list = ['evtid', 'energy', 'position', 'mc_momentum',
                      'hit_pmtid', 'hit_residual' ]  #list the name of the varibles to be extracted and used for the solarnu analysis.
    
    #pmt info to be used
    var_pmt_list = ['pmt_id', 'pmt_pos_xyz', 'pmt_type']
    
    #Observables to save
    var_name_save_list = ['evtid', 'energy', 'posr', 'hit_residual']
    multi_cos_alpha = [] #create the empty list of the cos_alpha for the multiple PMTs record
    n_init_evs = []  # Initial Nº of 208Tl  MC events
    n_final_evs = [] # Initial Nº of 208Tl MC events
    
    # Extract the variables with the name of the var_event_list in numpy.array from the .root file
    observables = {}
    
    # Load variables form the Event Info TTree Branch
    for var_name_i in var_event_list:
        observables[var_name_i] = np.array(event_data[var_name_i])

    # ============= Count the initial Nº of events =============
    evtid = observables['evtid']
    evIDi_unique = []  #Empty list to be filled with the unique (non-redundant) values of the initial evIDs. len(evIDi_unique) = Nº of events

    N_data = len(evtid)
    indices_to_delete = [] #Indiced to remove from the observable arrays due to nhits cut

    data_break_i = [0]  #array whose elements are the index from where an event start and end.
    #Loop to extract the indices where evtid breaks
    for i_dx in range(N_data - 1):
        if evtid[i_dx] != evtid[i_dx+1]:
            data_break_i.append(i_dx + 1)
            
    data_break_i.append(N_data - 1)

    N_terms = len(data_break_i)
    
    for i_dx in range(N_terms - 2):
        init_i = data_break_i[i_dx]
        final_i = data_break_i[i_dx + 1]
        evIDi_unique.append(evtid[init_i: final_i][0])

    N_evs = len(evIDi_unique)
    print(f'Nº of initial events: {N_evs}')
    n_init_evs.append(N_evs)
    # ===========================================================
    
    # posr Calculation
    observables['posr'] = magnitude(observables['position'])
    
    # Load the PMT info TTree Branch
    try:
        #Try to extract the info from the PMT Branch
        for var_name_i in var_pmt_list:
            observables[var_name_i] = np.array(pmt_data[var_name_i])
            
    except uproot.KeyInFileError as e:
        #if the Branch doesnt exist, then use the PMT info from other file that we know contais the PMT info Branch
        load_data = uproot.open('E:/Data/solars/mc/solar_Nue/High Stat/solar_Nue_mc_analysis_0.root')
        pmt_data = load_data['pmt;1']
        for var_name_i in var_pmt_list:
            observables[var_name_i] = np.array(pmt_data[var_name_i])
    
    # Filtering of valid PMT id through PMT type
    pmt_type_condition = (observables['pmt_type'] == 1)
    pmt_id_valid = observables['pmt_id'][pmt_type_condition]
    
    # general cut conditions
    hit_pmt_id_condition = np.in1d(observables['hit_pmtid'], pmt_id_valid)
    energy_condition = (observables['energy'] >= energy_inf_cut) & (observables['energy'] <= energy_sup_cut)
    time_res_condition = (observables['hit_residual'] >= time_res_inf_cut) & (observables['hit_residual'] <= time_res_sup_cut)
    posr_condition = (observables['posr'] <= posr_cut)
    
    general_condition = hit_pmt_id_condition & energy_condition & time_res_condition & posr_condition
    
    # Apply the general cut conditions to observables
    for var_name_i in var_event_list:
        observables[var_name_i] = observables[var_name_i][general_condition]
    observables['posr'] = observables['posr'][general_condition]

    print('Redefining 208Tl direction')
    #208Tl direction Redefinition with random rotations of vectors: ----------------------------------------------------------------
    seed = 54321
    # Verify where the data recorded during and event breaks
    tl_break_i = [0]
    tl208_evID = observables['evtid']

    tl_N_data = len(tl208_evID)
    for tl_i in range(tl_N_data - 1):
        if tl208_evID[tl_i] != tl208_evID[tl_i+1]:
            tl_break_i.append(tl_i+1) #append the index where data breaks

    #Redefine every repeated value direction with the new rotated direction
    #print(f'True 208Tl momentum {observables['mc_momentum']}')
    N_breaks = len(tl_break_i)
    for i_dx in range(N_breaks - 1):
        random_vec = random_unit_vector(seed = 42)
        i_tl = tl_break_i[i_dx]
        f_tl = tl_break_i[i_dx + 1]
        observables['mc_momentum'][i_tl:f_tl] = random_vec
        #observables['mc_momentum'][i_tl:f_tl] = apply_random_rotation_per_vector([observables['mc_momentum'][i_tl:f_tl][0]], seed = seed, verbose = False)
    observables['mc_momentum'][tl_break_i[-1]:] = random_vec
    #observables['mc_momentum'][tl_break_i[-1]:] = apply_random_rotation_per_vector([observables['mc_momentum'][-1]], seed = seed, verbose = False)
    
    
    #208Tl direction Redefinition with the direction of solar Nue Mc: ----------------------------------------------------------------
    
    #Match the Nº of events on Tl208 with the solar Nue to correctly replace the 208Tl direction with the sun direction
    #1) Verify where the data recorded during and event breaks;
    #2) Evaluate for each event record the number of entries;
    #3) Evaluate if N_Nue < or > than N_208Tl, and cut depending on this;

    #print('evaluating where the indices Break')
    #1)
    #solar_break_i = [0] #List with the indices where the ev data breaks
    #tl_break_i = [0]
    #tl208_evID = observables['evtid']

    #solar_N_data = len(solar_evID)
    #for solar_i in range(solar_N_data - 1):
    #    if solar_evID[solar_i] != solar_evID[solar_i+1]:
    #        solar_break_i.append(solar_i+1) #append the index where data breaks
        
    #tl_N_data = len(tl208_evID)
    #for tl_i in range(tl_N_data - 1):
    #    if tl208_evID[tl_i] != tl208_evID[tl_i+1]:
    #        tl_break_i.append(tl_i+1) #append the index where data breaks

    #2) and 3)
    #N_solar_evs = len(solar_break_i)
    #N_tl_evs = len(tl_break_i)

    #print(f'N_solar_evs = {N_solar_evs}')
    #print(f'N_208Tl_evs = {N_tl_evs}')

    #if N_solar_evs > N_tl_evs:
    #    solar_break_i = solar_break_i[0:tl_N_data]        
    
    #if  N_tl_evs > N_solar_evs:
    #    tl_break_i = tl_break_i[0:N_solar_evs]

    #print(f'True 208Tl momentum {observables['mc_momentum']}')

    #N_breaks = len(tl_break_i)
    #for i_dx in range(N_breaks - 1):
    #    i_solar = solar_break_i[i_dx]
    #    f_solar = solar_break_i[i_dx + 1]
    #    i_tl = tl_break_i[i_dx]
    #    f_tl = tl_break_i[i_dx + 1]
    #    observables['mc_momentum'][i_tl:f_tl] = sun_dir[i_solar:f_solar][0]
    #observables['mc_momentum'][tl_break_i[-1]:-1] = sun_dir[-1]
    
    #print(f'new 208Tl momentum {observables['mc_momentum']}')
    print('208Tl direction redefined!')

    #print(f'selected energies form {input_file_dir}: {observables['energy']} with shape {observables['energy'].shape}')

    # ======== Remove redundante values through evID. Nhits Cut and counts of final events ======
    print('performing nhits cuts after general selection')
    evtid = observables['evtid']
    evIDf_unique = []  #Empty list to be filled with the unique (non-redundant) values of the final evIDs. len(evIDf_unique) = Nº of final events
    N_data = len(evtid)
    indices_to_delete = [] #Indiced to remove from the observable arrays due to nhits cut

    data_break_i = [0]  #array whose elements are the index from where an event start and end.
    #Loop to extract the indices where evtid breaks
    for i_dx in range(N_data - 1):
        if evtid[i_dx] != evtid[i_dx+1]:
            data_break_i.append(i_dx + 1)
            
    data_break_i.append(N_data - 1)

    N_terms = len(data_break_i)

    for i_dx in range(N_terms - 2):
        init_i = data_break_i[i_dx]
        final_i = data_break_i[i_dx + 1]

        #Nhits cut: Remove the indices of observables that verify the nhits_cut
        #nhits_ev = final_i - init_i
        #if nhits_ev < nhits_cut:
        #    indices_to_delete.extend(range(init_i, final_i + 1))
        #    continue
            
        #else:
        #    evIDf_unique.append(evtid[init_i: final_i][0]) #Count the Number of final events
        
        evIDf_unique.append(evtid[init_i: final_i][0]) #Count the Number of final events
           
    N_evs = len(evIDf_unique)
    print(f'Nº of final events: {N_evs}')
    n_final_evs.append(N_evs)
     
    #indices_to_delete = np.array(indices_to_delete) due to nhits cut
    #for var_name_i in var_event_list + ['posr']:
    #    observables[var_name_i] = np.delete(observables[var_name_i], indices_to_delete)

    # ====================================================================

    #Add to dictionary of observables the keys init evs and final evs
    observables['n_init_evs'] = n_init_evs
    observables['n_final_evs'] = n_final_evs
    
    # Save desired variables
    full_observable_save_list = var_name_save_list + ['n_init_evs', 'n_final_evs']
    
    print(f'saving observables {full_observable_save_list}')
    
    for var_name_i in  full_observable_save_list:
        np.save(out_file_dir + data_type_fname + '_' + var_name_i + f'_{fi_dx}.npy', observables[var_name_i])

    #cos_alpha computation
    #The cos_alpha computation must be done by parts using a split in the data.
    
    N_samples = len(observables['hit_residual'])

    print('Computing cos_alpha')
    
    for sample_idx in range(N_samples):
        
        fake_dir = observables['mc_momentum'][sample_idx]
        pmt_hit_id = observables['hit_pmtid'][sample_idx]
        pmt_hit_xyz = observables['pmt_pos_xyz'][pmt_hit_id]

        norm1 = np.linalg.norm(fake_dir)
        norm2 = np.linalg.norm(pmt_hit_xyz)
        
        fake_dir = fake_dir / norm1
        
        pmt_hit_xyz = pmt_hit_xyz / norm2
        pmt_hit_xyz = pmt_hit_xyz
    
        dot_prod = np.dot(fake_dir, pmt_hit_xyz)
        cos_alpha = dot_prod
    
        multi_cos_alpha.append(cos_alpha)

    multi_cos_alpha = np.array(multi_cos_alpha)
    print('saving cos_alpha')
    # save the cos(alpha)
    np.save(out_file_dir + data_type_fname + '_cos_alpha' + f'_{fi_dx}.npy', multi_cos_alpha)

print('Analysis Done!')
# Out:
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_0.root
# Nº of initial events: 47658
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25765
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_1.root
# Nº of initial events: 47848
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 26062
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_10.root
# Nº of initial events: 47498
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25921
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_11.root
# Nº of initial events: 46181
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25190
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_12.root
# Nº of initial events: 47464
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25811
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_13.root
# Nº of initial events: 47020
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25954
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_14.root
# Nº of initial events: 46658
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25683
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_15.root
# Nº of initial events: 46678
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25748
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_16.root
# Nº of initial events: 47052
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 26086
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_17.root
# Nº of initial events: 45883
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25482
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_18.root
# Nº of initial events: 45772
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25651
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_19.root
# Nº of initial events: 46148
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25663
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_2.root
# Nº of initial events: 48121
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 26124
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_20.root
# Nº of initial events: 46504
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25721
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_21.root
# Nº of initial events: 45862
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25636
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_3.root
# Nº of initial events: 47501
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25765
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_4.root
# Nº of initial events: 47798
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25924
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_5.root
# Nº of initial events: 46991
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25659
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_6.root
# Nº of initial events: 46990
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25622
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# In file E:/Data/solars/mc/208tl/High Stat\tl208_mc_analysis_7.root
# Nº of initial events: 46687
# Redefining 208Tl direction
# 208Tl direction redefined!
# performing nhits cuts after general selection
# Nº of final events: 25567
# saving observables ['evtid', 'energy', 'posr', 'hit_residual', 'n_init_evs', 'n_final_evs']
# Computing cos_alpha
# saving cos_alpha
# Analysis Done!

# %% [markdown]
# # Load Numpy files

# %%
main_dir = f'E:/Data/solars/mc/ML Data/Train/np_arrays/E_{energy_inf_cut}_{energy_sup_cut}_MeV_R_{posr_cut}_mm_Delta_{time_res_inf_cut}_{time_res_sup_cut}_ns/'
solar_fpattern = 'SolarNue_'
tl208_fpattern = '208Tl_'

observable_name = ['evtid', 'energy', 'posr', 'cos_alpha', 'hit_residual']

solar_dict = {var_i: np.array([]) for var_i in observable_name}
tl208_dict = {var_i: np.array([]) for var_i in observable_name}

#Load each varibles within a loop of variables and fill the dictionaries
#Loop over var names
for var_i in observable_name:
    #create flist for the multiple var_i observables (exm: evID_0, evID_1, ...)
    solar_var_i_flist = glob.glob(main_dir + solar_fpattern + var_i + '*.npy')
    tl208_var_i_flist = glob.glob(main_dir + tl208_fpattern + var_i + '*.npy')

    #Loop over flist:
    for solar_file_i in solar_var_i_flist:
        load_solar_var_i = np.load(solar_file_i)
        solar_dict[var_i] = np.append(solar_dict[var_i], load_solar_var_i)

    for tl208_file_i in tl208_var_i_flist:
        load_208tl_var_i = np.load(tl208_file_i)
        tl208_dict[var_i] = np.append(tl208_dict[var_i], load_208tl_var_i)

# %% [markdown]
# ## Remove Redundant Values

# %%
#Extract the redundant evID
solar_evID = solar_dict['evtid']
tl208_evID = tl208_dict['evtid']

redundant_observables_name = ['evtid', 'posr', 'energy'] #List of observables with redundant values to cut

# Empty lists which will contain the non-repeated values of the observables for singles events
solar_dict_ev = {var_i: [] for var_i in redundant_observables_name}
tl208_dict_ev = {var_i: [] for var_i in redundant_observables_name}

#evID index break list
solar_data_break_i = [0]  #array whose elements are the index from where an event start and end.
tl208_data_break_i = [0]

solar_N_data = len(solar_evID)
tl208_N_data = len(tl208_evID)

print('Looking for break index in solars evID')
for i_dx in range(solar_N_data - 1):
    if solar_evID[i_dx] != solar_evID[i_dx+1]:
        solar_data_break_i.append(i_dx+1)

print('Looking for break index in 208Tl evID')
for i_dx in range(tl208_N_data - 1):
    if tl208_evID[i_dx] != tl208_evID[i_dx+1]:
        tl208_data_break_i.append(i_dx+1)

#add the last index to complete the data_break_i list
solar_data_break_i.append(solar_N_data - 1)
tl208_data_break_i.append(tl208_N_data - 1)

N_solar_terms = len(solar_data_break_i)
N_tl208_terms = len(tl208_data_break_i)

#Start to save the non-redundant values and separate the time residuals and angles for each event
#Solar Loop
print(f'saving the non-redundant values for solars')
for i_dx in range(N_solar_terms - 1):
    init_i = solar_data_break_i[i_dx]
    final_i = solar_data_break_i[i_dx+1]
    
    for var_i in redundant_observables_name:
        non_redundant_var_i_value = solar_dict[var_i][init_i : final_i][0]
        solar_dict_ev[var_i].append(non_redundant_var_i_value)

#Transform to array
print('Transforming solars to np.array')
for var_i in redundant_observables_name:
    solar_dict_ev[var_i] = np.array(solar_dict_ev[var_i])

#Now append time residual and cos_alpha to solars
solar_dict_ev['cos_alpha'] = solar_dict['cos_alpha']
solar_dict_ev['hit_residual'] = solar_dict['hit_residual']

#208Tl Loop
print('Transforming 208Tl to np.array')
print(f'saving the non-redundant values for 208Tl')
for i_dx in range(N_tl208_terms - 1):
    init_i = tl208_data_break_i[i_dx]
    final_i = tl208_data_break_i[i_dx+1]

    for var_i in redundant_observables_name:
        non_redundant_var_i_value = tl208_dict[var_i][init_i : final_i][0]
        tl208_dict_ev[var_i].append(non_redundant_var_i_value)

#Transform to array
for var_i in redundant_observables_name:
    tl208_dict_ev[var_i] = np.array(tl208_dict_ev[var_i])

#Now append time residual and cos_alpha to 208Tl
tl208_dict_ev['cos_alpha'] = tl208_dict['cos_alpha']
tl208_dict_ev['hit_residual'] = tl208_dict['hit_residual']
# Out:
# Looking for break index in solars evID
# Looking for break index in 208Tl evID
# saving the non-redundant values for solars
# Transforming solars to np.array
# Transforming 208Tl to np.array
# saving the non-redundant values for 208Tl

# %% [markdown]
# ## NHits Cut: Select only events that verify nhits >= nhits_cut within the $\Delta$ window

# %%
nhits_cut = 20

# ========= nhits cut on Solar Data =========
solar_energy = solar_dict_ev['energy']
solar_posr = solar_dict_ev['posr']
solar_hit_residual = solar_dict_ev['hit_residual']
solar_cos_alpha = solar_dict_ev['cos_alpha']

solar_cos_alpha_ev = []  #cos(alpha) list to be filled with arrays, each one correspondign to an event record
solar_time_residual_ev = [] #time residual list to be filled with arrays, each one correspondign to an event record
solar_nhits = [] #List to be filled with the Nº of hits of each event within the  time residual window

#Loop to extract the Nº of hits per event using the evID break
for i_dx in range(N_solar_terms - 1):
    init_i = solar_data_break_i[i_dx]
    final_i = solar_data_break_i[i_dx+1]
    
    solar_cos_alpha_ev_i = solar_cos_alpha[init_i:final_i]
    solar_hit_residual_ev_i = solar_hit_residual[init_i:final_i]
    nhits_ev_i = len(solar_cos_alpha_ev_i)

    solar_cos_alpha_ev.append(solar_cos_alpha_ev_i)
    solar_time_residual_ev.append(solar_hit_residual_ev_i)
    solar_nhits.append(nhits_ev_i)
solar_nhits = np.array(solar_nhits)

#Selection of Events
nhits_condition = (solar_nhits >= nhits_cut)

solar_energy = solar_energy[nhits_condition]
solar_posr = solar_posr[nhits_condition]
solar_cos_alpha_ev = [arr for arr, cond in zip(solar_cos_alpha_ev, nhits_condition) if cond]
solar_time_residual_ev = [arr for arr, cond in zip(solar_time_residual_ev, nhits_condition) if cond]

# ========= nhits cut on 208Tl =========
tl208_energy = tl208_dict_ev['energy']
tl208_posr = tl208_dict_ev['posr']
tl208_hit_residual = tl208_dict_ev['hit_residual']
tl208_cos_alpha = tl208_dict_ev['cos_alpha']

tl208_cos_alpha_ev = []  #cos(alpha) list to be filled with arrays, each one correspondign to an event record
tl208_time_residual_ev = [] #time residual list to be filled with arrays, each one correspondign to an event record
tl208_nhits = [] #List to be filled with the Nº of hits of each event within the  time residual window

#Loop to extract the Nº of hits per event using the evID break
for i_dx in range(N_tl208_terms - 1):
    init_i = tl208_data_break_i[i_dx]
    final_i = tl208_data_break_i[i_dx+1]
    
    tl208_cos_alpha_ev_i = tl208_cos_alpha[init_i:final_i]
    tl208_hit_residual_ev_i = tl208_hit_residual[init_i:final_i]
    nhits_ev_i = len(tl208_cos_alpha_ev_i)

    tl208_cos_alpha_ev.append(tl208_cos_alpha_ev_i)
    tl208_time_residual_ev.append(tl208_hit_residual_ev_i)
    tl208_nhits.append(nhits_ev_i)
tl208_nhits = np.array(tl208_nhits)

#Selection of Events
nhits_condition = (tl208_nhits >= nhits_cut)

tl208_energy = tl208_energy[nhits_condition]
tl208_posr = tl208_posr[nhits_condition]
tl208_cos_alpha_ev = [arr for arr, cond in zip(tl208_cos_alpha_ev, nhits_condition) if cond]
tl208_time_residual_ev = [arr for arr, cond in zip(tl208_time_residual_ev, nhits_condition) if cond]

# %% [markdown]
# ### Verify Plots

# %%
sn.histplot(solar_energy, bins = 40)
sn.histplot(tl208_energy, bins = 40)
# Out:
# <Axes: ylabel='Count'>

# %%
sn.histplot(solar_posr, bins = 40)
sn.histplot(tl208_posr, bins = 40)
# Out:
# <Axes: ylabel='Count'>

# %%
sn.histplot(solar_cos_alpha, bins = 40)
plt.yscale('log')

# %%
sn.histplot(tl208_cos_alpha, bins = 40)
plt.yscale('log')

# %%
sn.histplot(solar_hit_residual, bins = 40)
# Out:
# <Axes: ylabel='Count'>

# %%
sn.histplot(tl208_hit_residual, bins = 40)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # Dataset Construction

# %% [markdown]
# ## Solar Nue Dataset

# %% [markdown]
# ### Features Construction: Pixels and Labels

# %%
image_dim = (10,10)
range_time = (time_res_inf_cut, time_res_sup_cut)
range_cos = (-1, 1)

H_flaten_nu = []  #flatten images of solar nu evs with shape (n_samples, bins x bins)
labels_nu = []  #save label of solar nu evs as [1,0]

N_evs = len(solar_cos_alpha_ev)

for i_dx in range(N_evs):

    solar_time_res_ev_i = solar_time_residual_ev[i_dx]
    solar_cos_ev_i = solar_cos_alpha_ev[i_dx]

    #raw histogram
    bins = image_dim[0]
    H_nu_ev, _, _ = np.histogram2d(x = solar_cos_ev_i, y = solar_time_res_ev_i, bins = [bins, bins], range = [range_cos, range_time])
    #normalization by NHits within slice of cos_alpha
    sum_hit_nu_ev = np.sum(H_nu_ev,axis=0)
    H_nu_ev_norm = H_nu_ev/sum_hit_nu_ev
    H_nu_ev_norm = np.nan_to_num(H_nu_ev_norm, nan = 0.0)

    H_flatten_ev = H_nu_ev_norm.ravel()
    H_flaten_nu.append(np.array(H_flatten_ev))
    labels_nu.append([1,0])
    
H_flaten_nu = np.array(H_flaten_nu)
labels_nu = np.array(labels_nu)
# Out:
# C:\Users\joanc\AppData\Local\Temp\ipykernel_11544\1040089279.py:20: RuntimeWarning: invalid value encountered in divide
#   H_nu_ev_norm = H_nu_ev/sum_hit_nu_ev

# %%
H_flaten_nu.shape
# Out:
# (987759, 100)

# %%
labels_nu.shape
# Out:
# (987759, 2)

# %% [markdown]
# ### Verify the Images

# %%
#High Stat
ev_i = 5
H_single_ev = H_flaten_nu[ev_i].reshape(bins, bins)
plt.imshow(H_single_ev)

# %%
#High Stat
H_high_stat = np.sum(H_flaten_nu, axis = 0)
H_high_stat = H_high_stat.reshape(bins, bins)
plt.imshow(H_high_stat)

# %% [markdown]
# ### Pandas Dataframe

# %%
df_solar_data = {}

N_pixel = bins*bins
for j in range(N_pixel):
    pixel_i = H_flaten_nu[:, j]
    df_solar_data['pixel_'+str(j)] = pixel_i

df_solar_data['energy (MeV)'] = solar_energy
df_solar_data['radius (mm)'] = solar_posr
df_solar_data['IsNu'] = labels_nu[:,0]
df_solar_data['IsTl'] = labels_nu[:,1]

df_solar_data = pd.DataFrame(df_solar_data)

# %%
df_solar_data
# Out:
#         pixel_0  pixel_1   pixel_2   pixel_3   pixel_4   pixel_5   pixel_6  \
# 0           0.0      0.0  0.000000  0.000000  0.000000  0.000000  0.055556
# 1           0.0      0.0  0.000000  0.250000  0.125000  0.100000  0.318182
# 2           0.0      0.0  0.000000  0.000000  0.066667  0.100000  0.080000
# 3           0.0      0.0  0.000000  0.333333  0.166667  0.166667  0.000000
# 4           0.0      0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# ...         ...      ...       ...       ...       ...       ...       ...
# 987754      0.0      0.0  0.000000  0.000000  0.000000  0.250000  0.187500
# 987755      0.0      0.0  0.000000  0.000000  0.000000  0.000000  0.090909
# 987756      1.0      0.0  0.166667  0.285714  0.133333  0.086957  0.153846
# 987757      0.0      0.0  0.000000  0.000000  0.000000  0.000000  0.300000
# 987758      0.0      0.0  0.000000  0.000000  0.000000  0.062500  0.062500
#
#          pixel_7   pixel_8   pixel_9  ...  pixel_94  pixel_95  pixel_96  \
# 0       0.000000  0.000000  0.100000  ...  0.333333  0.111111  0.111111
# 1       0.105263  0.062500  0.136364  ...  0.000000  0.000000  0.000000
# 2       0.074074  0.157895  0.090909  ...  0.000000  0.000000  0.000000
# 3       0.187500  0.187500  0.281250  ...  0.000000  0.083333  0.000000
# 4       0.000000  0.029412  0.000000  ...  0.133333  0.100000  0.090909
# ...          ...       ...       ...  ...       ...       ...       ...
# 987754  0.266667  0.222222  0.111111  ...  0.000000  0.000000  0.000000
# 987755  0.071429  0.095238  0.083333  ...  0.166667  0.000000  0.181818
# 987756  0.075000  0.210526  0.166667  ...  0.066667  0.000000  0.000000
# 987757  0.000000  0.111111  0.000000  ...  0.000000  0.333333  0.000000
# 987758  0.000000  0.037037  0.028571  ...  0.100000  0.062500  0.062500
#
#         pixel_97  pixel_98  pixel_99  energy (MeV)  radius (mm)  IsNu  IsTl
# 0       0.000000  0.096774  0.033333      6.531870  2766.903564     1     0
# 1       0.000000  0.000000  0.045455      3.790905  4070.427490     1     0
# 2       0.037037  0.105263  0.090909      6.842120  3602.227295     1     0
# 3       0.000000  0.000000  0.000000      6.679560  3016.685791     1     0
# 4       0.178571  0.205882  0.234043      4.889297  5068.320312     1     0
# ...          ...       ...       ...           ...          ...   ...   ...
# 987754  0.000000  0.027778  0.074074      7.668172  3124.261230     1     0
# 987755  0.142857  0.095238  0.000000      2.695328  4455.503418     1     0
# 987756  0.000000  0.026316  0.020833      6.919887  4616.769531     1     0
# 987757  0.250000  0.333333  0.176471      2.951337  2480.473389     1     0
# 987758  0.043478  0.111111  0.028571      7.554810  3217.766357     1     0
#
# [987759 rows x 104 columns]

# %% [markdown]
# ## 208Tl Dataset

# %% [markdown]
# ### Features Construction: Pixels and Labels

# %%
image_dim = (10,10)
range_time = (time_res_inf_cut, time_res_sup_cut)
range_cos = (-1, 1)

H_flaten_tl = []  #flatten images of 208Tl nu evs with shape (n_samples, bins x bins)
labels_tl = []  #save label of solar nu evs as [0,1]

N_evs = len(tl208_cos_alpha_ev)

for i_dx in range(N_evs):

    tl208_time_res_ev_i = tl208_time_residual_ev[i_dx]
    tl208_cos_ev_i =  tl208_cos_alpha_ev[i_dx]

    #raw histogram
    bins = image_dim[0]
    H_tl_ev, _, _ = np.histogram2d(x = tl208_cos_ev_i, y =  tl208_time_res_ev_i, bins = [bins, bins], range = [range_cos, range_time])
    #normalization by NHits within slice of cos_alpha
    sum_hit_tl_ev = np.sum(H_tl_ev,axis=0)
    H_tl_ev_norm = H_tl_ev/sum_hit_tl_ev
    H_tl_ev_norm = np.nan_to_num(H_tl_ev_norm, nan = 0.0)

    H_flatten_ev = H_tl_ev_norm.ravel()
    H_flaten_tl.append(np.array(H_flatten_ev))
    labels_tl.append([0, 1])
    
H_flaten_tl = np.array(H_flaten_tl)
labels_tl = np.array(labels_tl)
# Out:
# C:\Users\joanc\AppData\Local\Temp\ipykernel_11544\4015640549.py:20: RuntimeWarning: invalid value encountered in divide
#   H_tl_ev_norm = H_tl_ev/sum_hit_tl_ev

# %%
H_flaten_tl.shape
# Out:
# (515054, 100)

# %%
labels_tl.shape
# Out:
# (515054, 2)

# %% [markdown]
# ### Verify the Images

# %%
#High Stat
ev_i = 5
H_single_ev = H_flaten_tl[ev_i].reshape(bins, bins)
plt.imshow(H_single_ev)

# %%
#High Stat
H_high_stat = np.sum(H_flaten_tl, axis = 0)
H_high_stat = H_high_stat.reshape(bins, bins)
plt.imshow(H_high_stat)

# %% [markdown]
# ### Pandas Dataframe

# %%
df_tl208_data = {}

N_pixel = bins*bins
for j in range(N_pixel):
    pixel_i = H_flaten_tl[:, j]
    df_tl208_data['pixel_'+str(j)] = pixel_i

df_tl208_data['energy (MeV)'] = tl208_energy
df_tl208_data['radius (mm)'] = tl208_posr
df_tl208_data['IsNu'] = labels_tl[:,0]
df_tl208_data['IsTl'] = labels_tl[:,1]

df_tl208_data = pd.DataFrame(df_tl208_data)

# %%
df_tl208_data
# Out:
#         pixel_0   pixel_1   pixel_2   pixel_3   pixel_4   pixel_5   pixel_6  \
# 0           0.0  0.000000  0.500000  0.000000  0.000000  0.142857  0.000000
# 1           0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.142857
# 2           0.0  0.000000  0.000000  0.000000  0.000000  0.133333  0.000000
# 3           0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4           0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 515049      0.0  0.000000  0.000000  0.125000  0.125000  0.000000  0.076923
# 515050      0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 515051      0.0  0.250000  0.333333  0.200000  0.454545  0.545455  0.500000
# 515052      0.0  0.000000  0.000000  0.125000  0.200000  0.083333  0.066667
# 515053      1.0  0.333333  0.333333  0.363636  0.300000  0.500000  0.250000
#
#          pixel_7   pixel_8   pixel_9  ...  pixel_94  pixel_95  pixel_96  \
# 0       0.000000  0.095238  0.136364  ...  0.000000  0.000000  0.000000
# 1       0.000000  0.055556  0.058824  ...  0.000000  0.133333  0.142857
# 2       0.000000  0.000000  0.000000  ...  0.000000  0.066667  0.000000
# 3       0.000000  0.100000  0.000000  ...  0.000000  0.285714  0.111111
# 4       0.000000  0.000000  0.000000  ...  0.642857  0.294118  0.400000
# ...          ...       ...       ...  ...       ...       ...       ...
# 515049  0.066667  0.081081  0.192308  ...  0.000000  0.000000  0.000000
# 515050  0.000000  0.000000  0.000000  ...  0.200000  0.142857  0.142857
# 515051  0.375000  0.291667  0.157895  ...  0.000000  0.000000  0.000000
# 515052  0.066667  0.047619  0.000000  ...  0.000000  0.000000  0.000000
# 515053  0.333333  0.285714  0.210526  ...  0.000000  0.000000  0.000000
#
#         pixel_97  pixel_98  pixel_99  energy (MeV)  radius (mm)  IsNu  IsTl
# 0       0.062500  0.095238  0.045455      3.636871  3702.250244     0     1
# 1       0.045455  0.111111  0.058824      3.548111  4104.201660     0     1
# 2       0.105263  0.040000  0.045455      3.242101  4966.423828     0     1
# 3       0.384615  0.400000  0.125000      4.196140  2854.459961     0     1
# 4       0.454545  0.538462  0.500000      3.645633  5343.075684     0     1
# ...          ...       ...       ...           ...          ...   ...   ...
# 515049  0.000000  0.000000  0.000000      4.068833  5019.541016     0     1
# 515050  0.142857  0.200000  0.250000      3.527987  3981.181396     0     1
# 515051  0.000000  0.000000  0.000000      3.831699  4614.803711     0     1
# 515052  0.000000  0.000000  0.125000      3.451234  5135.644531     0     1
# 515053  0.000000  0.000000  0.000000      3.369952  5210.795410     0     1
#
# [515054 rows x 104 columns]

# %% [markdown]
# ## Unify Solar_Nue and 208Tl Datasets

# %%
save = True
save_dir = 'E:/Data/solars/mc/ML Data/Train/pd_dataframe/'
fname = f'df_Dim_{image_dim[0]}_E_{energy_inf_cut}_{energy_sup_cut}_MeV_R_{posr_cut}_mm_Delta_{time_res_inf_cut}_{time_res_sup_cut}_ns.csv'

df = pd.concat([df_solar_data, df_tl208_data], ignore_index=True)

if save:
    df.to_csv(save_dir + fname, index=False)
df

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv(f'E:/Data/solars/mc/ML Data/Train/pd_dataframe/df_{image_dim[0]}_{posr_cut}_({energy_inf_cut}_{energy_sup_cut})_({time_res_inf_cut}_{time_res_sup_cut}).csv')

# %% [markdown]
# ## Feature Correlation Study

# %%
plt.figure(figsize = (30,20))
sn.heatmap(df[df['IsNu'] == 1].corr(), cmap='winter', linewidths= 0.1)#, vmin = -1, vmax = 1)
plt.title('Correlation Matrix Between Solar Nue Features - Energy: [2.5,12] MeV - R < 5500 (mm)', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix Between Solar Nue Features - Energy: [2.5,12] MeV - R < 5500 (mm)')

# %%
plt.figure(figsize = (30,20))
sn.heatmap(df[df['IsTl'] == 1].corr(), cmap='winter', linewidths= 0.1)#, vmin = -1, vmax = 1)
plt.title('Correlation Matrix Between 208-Tl Features - Energy: [2.5, 12] MeV - R < 5500 (mm)', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix Between 208-Tl Features - Energy: [2.5,12] MeV - R < 5500 (mm)')

# %% [markdown]
# # Concatenate new 208Tl Dataset to the pre-existing solar data set

# %%
df = pd.read_csv('E:/Data/solars/mc/ML Data/Train/pd_dataframe/df_10_5500_(2.5_14)_(-5_7).csv')

# %%
df
# Out:
#               pixel_0       pixel_1       pixel_2       pixel_3       pixel_4  \
# 0        1.000000e-01  1.000000e-01  1.000000e-10  1.000000e-10  3.333333e-11
# 1        1.000000e-01  1.000000e-01  1.000000e-10  1.000000e-10  1.666667e-11
# 2        1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-10  8.333333e-12
# 3        1.000000e-10  1.000000e-10  1.000000e-01  1.000000e-01  2.000000e-01
# 4        1.000000e-01  1.000000e-10  1.000000e-01  5.000000e-11  6.666667e-12
# ...               ...           ...           ...           ...           ...
# 1349016  1.000000e-01  1.000000e-01  1.000000e+00  1.000000e-10  2.000000e-11
# 1349017  1.000000e-10  1.000000e-01  1.000000e-10  2.500000e-11  2.500000e-01
# 1349018  1.000000e-01  1.000000e-01  1.000000e-10  1.000000e+00  5.000000e-01
# 1349019  1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-10  5.000000e-11
# 1349020  1.000000e-01  1.000000e-01  1.000000e+00  1.000000e-10  1.000000e-10
#
#               pixel_5       pixel_6   pixel_7       pixel_8       pixel_9  \
# 0        1.000000e-11  2.857143e-02  0.019608  8.641975e-02  5.000000e-02
# 1        1.666667e-01  2.285714e-01  0.095238  6.521739e-02  1.296296e-01
# 2        5.000000e-02  1.111111e-01  0.114286  9.677419e-02  6.930693e-02
# 3        2.500000e-01  7.407407e-02  0.204082  1.445783e-01  1.797753e-01
# 4        2.941176e-12  2.325581e-12  0.014706  1.282051e-12  1.639344e-12
# ...               ...           ...       ...           ...           ...
# 1349016  2.000000e-11  1.538462e-01  0.047619  2.222222e-01  1.200000e-01
# 1349017  5.000000e-02  2.941176e-02  0.052632  6.818182e-02  4.545455e-02
# 1349018  2.000000e-01  1.612903e-01  0.310345  1.363636e-01  2.444444e-01
# 1349019  1.666667e-11  5.000000e-12  0.032258  4.166667e-12  2.857143e-02
# 1349020  3.636364e-01  1.538462e-01  0.210526  1.250000e-01  1.428571e-01
#
#          ...      pixel_94      pixel_95      pixel_96      pixel_97  \
# 0        ...  3.333333e-11  3.000000e-01  5.714286e-02  5.882353e-02
# 1        ...  1.666667e-11  8.333333e-12  2.857143e-12  2.380952e-12
# 2        ...  8.333333e-12  5.000000e-12  2.777778e-12  7.142857e-02
# 3        ...  2.000000e-11  8.333333e-12  3.703704e-02  2.040816e-12
# 4        ...  2.666667e-01  8.823529e-02  9.302326e-02  2.205882e-01
# ...      ...           ...           ...           ...           ...
# 1349016  ...  2.000000e-11  2.000000e-01  7.692308e-02  9.523810e-02
# 1349017  ...  2.500000e-11  5.000000e-12  8.823529e-02  2.631579e-02
# 1349018  ...  1.250000e-11  1.000000e-11  3.225806e-12  3.448276e-12
# 1349019  ...  1.000000e+00  3.333333e-01  4.000000e-01  1.935484e-01
# 1349020  ...  1.000000e-10  9.090909e-12  7.692308e-12  5.263158e-12
#
#          pixel_98      pixel_99  energy (MeV)  radius (mm)  IsNu  IsTl
# 0        0.074074  1.375000e-01      6.531870  2766.903564     1     0
# 1        0.043478  3.703704e-02      3.790905  4070.427490     1     0
# 2        0.064516  9.900990e-02      6.842120  3602.227295     1     0
# 3        0.024096  5.617978e-02      6.679560  3016.685791     1     0
# 4        0.217949  1.311475e-01      4.889297  5068.320312     1     0
# ...           ...           ...           ...          ...   ...   ...
# 1349016  0.037037  4.000000e-02      3.639944  2389.689941     0     1
# 1349017  0.045455  2.272727e-02      4.161620  4196.363281     0     1
# 1349018  0.045455  2.222222e-12      3.320010  4496.370117     0     1
# 1349019  0.208333  2.857143e-01      3.193365  3205.321045     0     1
# 1349020  0.031250  2.857143e-02      3.155162  3545.121338     0     1
#
# [1349021 rows x 104 columns]

# %%
df_solar = df[df['IsNu'] == 1]
df_solar
# Out:
#              pixel_0       pixel_1       pixel_2       pixel_3       pixel_4  \
# 0       1.000000e-01  1.000000e-01  1.000000e-10  1.000000e-10  3.333333e-11
# 1       1.000000e-01  1.000000e-01  1.000000e-10  1.000000e-10  1.666667e-11
# 2       1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-10  8.333333e-12
# 3       1.000000e-10  1.000000e-10  1.000000e-01  1.000000e-01  2.000000e-01
# 4       1.000000e-01  1.000000e-10  1.000000e-01  5.000000e-11  6.666667e-12
# ...              ...           ...           ...           ...           ...
# 987755  1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-01  3.333333e-11
# 987756  1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-10  1.428571e-11
# 987757  1.000000e-01  1.000000e-01  1.000000e-01  5.000000e-01  2.222222e-01
# 987758  1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-01  3.333333e-11
# 987759  1.000000e-01  1.000000e-01  1.000000e-10  1.000000e-01  1.428571e-11
#
#              pixel_5       pixel_6   pixel_7       pixel_8       pixel_9  ...  \
# 0       1.000000e-11  2.857143e-02  0.019608  8.641975e-02  5.000000e-02  ...
# 1       1.666667e-01  2.285714e-01  0.095238  6.521739e-02  1.296296e-01  ...
# 2       5.000000e-02  1.111111e-01  0.114286  9.677419e-02  6.930693e-02  ...
# 3       2.500000e-01  7.407407e-02  0.204082  1.445783e-01  1.797753e-01  ...
# 4       2.941176e-12  2.325581e-12  0.014706  1.282051e-12  1.639344e-12  ...
# ...              ...           ...       ...           ...           ...  ...
# 987755  8.695652e-02  1.951220e-01  0.263158  1.764706e-01  1.743119e-01  ...
# 987756  9.090909e-12  4.166667e-02  0.090909  5.263158e-02  2.325581e-12  ...
# 987757  1.250000e-01  1.016949e-01  0.166667  1.034483e-01  1.807229e-01  ...
# 987758  1.250000e-11  2.000000e-01  0.052632  2.631579e-12  2.500000e-12  ...
# 987759  7.692308e-12  6.250000e-02  0.017241  3.846154e-02  8.000000e-02  ...
#
#             pixel_94      pixel_95      pixel_96      pixel_97      pixel_98  \
# 0       3.333333e-11  3.000000e-01  5.714286e-02  5.882353e-02  7.407407e-02
# 1       1.666667e-11  8.333333e-12  2.857143e-12  2.380952e-12  4.347826e-02
# 2       8.333333e-12  5.000000e-12  2.777778e-12  7.142857e-02  6.451613e-02
# 3       2.000000e-11  8.333333e-12  3.703704e-02  2.040816e-12  2.409639e-02
# 4       2.666667e-01  8.823529e-02  9.302326e-02  2.205882e-01  2.179487e-01
# ...              ...           ...           ...           ...           ...
# 987755  3.333333e-11  4.347826e-02  2.439024e-12  1.754386e-02  7.058824e-02
# 987756  1.428571e-11  9.090909e-02  8.333333e-02  1.212121e-01  5.263158e-02
# 987757  1.111111e-11  4.166667e-02  1.694915e-12  2.564103e-02  1.149425e-12
# 987758  3.333333e-11  1.250000e-01  1.333333e-01  2.105263e-01  1.578947e-01
# 987759  1.428571e-11  7.692308e-02  6.250000e-02  6.896552e-02  1.025641e-01
#
#         pixel_99  energy (MeV)  radius (mm)  IsNu  IsTl
# 0       0.137500      6.531870  2766.903564     1     0
# 1       0.037037      3.790905  4070.427490     1     0
# 2       0.099010      6.842120  3602.227295     1     0
# 3       0.056180      6.679560  3016.685791     1     0
# 4       0.131148      4.889297  5068.320312     1     0
# ...          ...           ...          ...   ...   ...
# 987755  0.027523      7.668172  3124.261230     1     0
# 987756  0.069767      2.695328  4455.503418     1     0
# 987757  0.036145      6.919887  4616.769531     1     0
# 987758  0.150000      2.951337  2480.473389     1     0
# 987759  0.090000      7.554810  3217.766357     1     0
#
# [987760 rows x 104 columns]

# %%
df = pd.concat([df_solar, df_tl208_data], ignore_index=True)
df.to_csv('E:/Data/solars/mc/ML Data/Train/pd_dataframe/df_10_5500_(2.5_14)_(-5_7).csv', index=False)
df
# Out:
#               pixel_0       pixel_1       pixel_2       pixel_3       pixel_4  \
# 0        1.000000e-01  1.000000e-01  1.000000e-10  1.000000e-10  3.333333e-11
# 1        1.000000e-01  1.000000e-01  1.000000e-10  1.000000e-10  1.666667e-11
# 2        1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-10  8.333333e-12
# 3        1.000000e-10  1.000000e-10  1.000000e-01  1.000000e-01  2.000000e-01
# 4        1.000000e-01  1.000000e-10  1.000000e-01  5.000000e-11  6.666667e-12
# ...               ...           ...           ...           ...           ...
# 1502809  1.000000e-01  1.000000e-01  5.000000e-11  1.666667e-11  1.000000e-11
# 1502810  1.000000e-01  1.000000e-01  1.000000e-01  2.500000e-01  2.500000e-11
# 1502811  1.000000e-01  1.000000e-01  1.000000e-10  1.000000e-10  1.250000e-11
# 1502812  1.000000e-01  1.000000e-01  1.000000e-10  1.666667e-11  1.250000e-11
# 1502813  1.000000e-01  1.000000e-01  1.000000e-01  1.428571e-11  1.666667e-11
#
#               pixel_5       pixel_6       pixel_7       pixel_8       pixel_9  \
# 0        1.000000e-11  2.857143e-02  1.960784e-02  8.641975e-02  5.000000e-02
# 1        1.666667e-01  2.285714e-01  9.523810e-02  6.521739e-02  1.296296e-01
# 2        5.000000e-02  1.111111e-01  1.142857e-01  9.677419e-02  6.930693e-02
# 3        2.500000e-01  7.407407e-02  2.040816e-01  1.445783e-01  1.797753e-01
# 4        2.941176e-12  2.325581e-12  1.470588e-02  1.282051e-12  1.639344e-12
# ...               ...           ...           ...           ...           ...
# 1502809  4.000000e-12  3.448276e-02  1.785714e-02  2.816901e-02  4.918033e-02
# 1502810  8.333333e-02  6.666667e-12  3.846154e-12  5.555556e-02  8.771930e-02
# 1502811  5.882353e-12  7.142857e-02  2.222222e-02  1.333333e-01  1.153846e-01
# 1502812  6.666667e-12  3.571429e-02  2.777778e-02  2.631579e-12  2.040816e-12
# 1502813  4.761905e-12  4.000000e-12  2.380952e-12  1.960784e-02  2.127660e-02
#
#          ...      pixel_94      pixel_95      pixel_96      pixel_97  \
# 0        ...  3.333333e-11  3.000000e-01  5.714286e-02  5.882353e-02
# 1        ...  1.666667e-11  8.333333e-12  2.857143e-12  2.380952e-12
# 2        ...  8.333333e-12  5.000000e-12  2.777778e-12  7.142857e-02
# 3        ...  2.000000e-11  8.333333e-12  3.703704e-02  2.040816e-12
# 4        ...  2.666667e-01  8.823529e-02  9.302326e-02  2.205882e-01
# ...      ...           ...           ...           ...           ...
# 1502809  ...  1.000000e-11  4.000000e-12  6.896552e-02  7.142857e-02
# 1502810  ...  2.500000e-11  8.333333e-12  1.333333e-01  3.846154e-12
# 1502811  ...  1.250000e-11  5.882353e-12  7.142857e-02  6.666667e-02
# 1502812  ...  1.250000e-11  1.333333e-01  1.785714e-01  1.944444e-01
# 1502813  ...  1.666667e-11  4.761905e-12  4.000000e-02  9.523810e-02
#
#              pixel_98  pixel_99  energy (MeV)  radius (mm)  IsNu  IsTl
# 0        7.407407e-02  0.137500      6.531870  2766.903564     1     0
# 1        4.347826e-02  0.037037      3.790905  4070.427490     1     0
# 2        6.451613e-02  0.099010      6.842120  3602.227295     1     0
# 3        2.409639e-02  0.056180      6.679560  3016.685791     1     0
# 4        2.179487e-01  0.131148      4.889297  5068.320312     1     0
# ...               ...       ...           ...          ...   ...   ...
# 1502809  7.042254e-02  0.131148      4.068833  5019.541016     0     1
# 1502810  2.777778e-12  0.052632      3.527987  3981.181396     0     1
# 1502811  2.222222e-02  0.057692      3.831699  4614.803711     0     1
# 1502812  1.315789e-01  0.102041      3.451234  5135.644531     0     1
# 1502813  5.882353e-02  0.063830      3.369952  5210.795410     0     1
#
# [1502814 rows x 104 columns]
