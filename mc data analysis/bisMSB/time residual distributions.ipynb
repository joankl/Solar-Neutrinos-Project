# %% [markdown]
# # Notebook Dedicated to Construct the Time Residual Distriburions of the Dataset

# %%
import numpy as np
import glob
import os

import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, ScalarFormatter
import seaborn as sn

# %% [markdown]
# # Load Data

# %%
# Directories
#main_dir = '/home/joankl/data/solars/real_data/bisMSB/first_candidates/ratds/analysis*/ratds_data/*.root'
main_dir = 'E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files/hit_residual*.npy'
flist = glob.glob(main_dir)

time_res = np.array([])

#Time residual cuts
time_res_inf_cut = -1.0
time_res_sup_cut = 50

for file_i in flist:

    print(f'reading File {file_i}')

    time_res_i = np.load(file_i)

    time_res_cut = (time_res_i >= time_res_inf_cut) & (time_res_i <= time_res_sup_cut)
    time_res_i = time_res_i[time_res_cut]

    time_res = np.append(time_res, time_res_i)

print('Done')
# Out:
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_0.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_1.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_10.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_13.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_16.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_19.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_2.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_20.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_21.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_22.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_23.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_24.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_25.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_27.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_3.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_35.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_36.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_39.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_4.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_40.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_42.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_5.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_6.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_7.npy
# reading File E:/Data/solars/mc/bisMSB/b8Nue/ratds_np/np_files\hit_residual_9.npy
# Done

# %% [markdown]
# # Time Residual Plot

# %%
fig, ax = plt.subplots(figsize=(8,6))

bins = 250

sn.histplot(time_res, bins = bins, element = 'step', alpha = 0, linewidth = 1.06)

plt.xlabel('Time Residual (ns)')
plt.title(rf'MC 8B-$\nu_e $Data - Solar Candidates - E $\geq$ 5 MeV & R $\leq$ 5.5 m', y = 1.02)

plt.yscale('log')
plt.xlim(time_res_inf_cut, time_res_sup_cut)

ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.xaxis.set_major_locator(MultipleLocator(2))

ax.tick_params(which='minor', top=True, bottom=True, left=True, right=True)
ax.tick_params(which='major', top=True, bottom=True, left=True, right=True)

plt.show()
